# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (0.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '039-train-02'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=481.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
    
        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(768, 512), # 1024(元は768)は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(768, 1)                        
        )
        
    # %profile
    def forward(self, input_ids, attention_mask):
        #print('model: get_roberta_out: Start', gpuinfo())                 
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        #print('model: get_roberta_out: Done', gpuinfo())                 

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        last_layer_hidden_states = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base). # 
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        weights = self.attention(last_layer_hidden_states) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する
# Out:
# default
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/basic.py:300: UserWarning: %profile is now deprecated. Please use get_ipython().profile instead.
#   warn("%profile is now deprecated. Please use get_ipython().profile instead.")

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
    del input_ids
    del attention_mask
    del target
  
    return mse_sum / len(data_loader.dataset) # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)   
            #print(f'train_{epoch}_{batch_num}: get_input: Done', gpuinfo())                 

            optimizer.zero_grad() # 勾配を初期化
            
            model.train() # 学習モード開始

            #print(f'train_{epoch}_{batch_num}: get_pred: Start', gpuinfo())                 
            pred = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            #print(f'train_{epoch}_{batch_num}: get_pred: Done', gpuinfo())  

            #print(f'train_{epoch}_{batch_num}: get_loss: Start', gpuinfo())                 
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target) # 予測結果からMSEを得る(これが損失関数となる?)
            #print(f'train_{epoch}_{batch_num}: get_loss: Done', gpuinfo())                 

            mse.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                val_rmse = math.sqrt(eval_mse(model, val_loader)) # valid-setによるrmse計算                           

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}") # epoch, batch, score

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            del target
            del pred
            del mse
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01
        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4
            
        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    #print('getmodel: Start', gpuinfo())                 
    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    #print('getmodel: Done', gpuinfo())                 

    #print('get_optim_sched: Start', gpuinfo())                 
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    #print('get_optim_sched: Done', gpuinfo())                 

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501200538.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 3.52 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9537
# New best_val_rmse: 0.9537
#
# 16 steps took 3.18 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.8151
# New best_val_rmse: 0.8151
#
# 16 steps took 3.18 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7784
# New best_val_rmse: 0.7784
#
# 16 steps took 3.19 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7967
# Still best_val_rmse: 0.7784 (from epoch 0)
#
# 16 steps took 3.2 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7128
# New best_val_rmse: 0.7128
#
# 16 steps took 3.18 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5955
# New best_val_rmse: 0.5955
#
# 16 steps took 3.2 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5996
# Still best_val_rmse: 0.5955 (from epoch 0)
#
# 16 steps took 3.19 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.7353
# Still best_val_rmse: 0.5955 (from epoch 0)
#
# 16 steps took 3.17 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5447
# New best_val_rmse: 0.5447
#
# 16 steps took 3.21 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.5985
# Still best_val_rmse: 0.5447 (from epoch 0)
#
# 16 steps took 3.22 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.5507
# Still best_val_rmse: 0.5447 (from epoch 0)
#
# 16 steps took 3.21 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.5338
# New best_val_rmse: 0.5338
#
# 16 steps took 3.21 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.5262
# New best_val_rmse: 0.5262
#
# 16 steps took 3.22 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.559
# Still best_val_rmse: 0.5262 (from epoch 0)
#
# 16 steps took 3.22 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.6551
# Still best_val_rmse: 0.5262 (from epoch 0)
#
# 16 steps took 3.21 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.613
# Still best_val_rmse: 0.5262 (from epoch 0)
#
# 16 steps took 3.22 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5397
# Still best_val_rmse: 0.5262 (from epoch 0)
#
# 16 steps took 3.35 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.6009
# Still best_val_rmse: 0.5262 (from epoch 0)
#
# 16 steps took 3.23 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5129
# New best_val_rmse: 0.5129
#
# 16 steps took 3.24 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5921
# Still best_val_rmse: 0.5129 (from epoch 1)
#
# 16 steps took 3.23 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5782
# Still best_val_rmse: 0.5129 (from epoch 1)
#
# 16 steps took 3.22 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5036
# New best_val_rmse: 0.5036
#
# 16 steps took 3.24 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5031
# New best_val_rmse: 0.5031
#
# 16 steps took 3.22 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5639
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.21 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5343
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.2 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.5189
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.23 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.5821
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.21 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.5224
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.22 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5459
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.23 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.5508
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.24 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5773
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.24 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5269
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 16 steps took 3.26 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5017
# New best_val_rmse: 0.5017
#
# 16 steps took 3.22 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.5276
# Still best_val_rmse: 0.5017 (from epoch 1)
#
# 16 steps took 3.22 seconds
# Epoch: 1 batch_num: 277 val_rmse: 0.5277
# Still best_val_rmse: 0.5017 (from epoch 1)
#
# 16 steps took 3.36 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5004
# New best_val_rmse: 0.5004
#
# 16 steps took 3.24 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.5242
# Still best_val_rmse: 0.5004 (from epoch 2)
#
# 16 steps took 3.22 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4979
# New best_val_rmse: 0.4979
#
# 8 steps took 1.62 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.5119
# Still best_val_rmse: 0.4979 (from epoch 2)
#
# 16 steps took 3.23 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4943
# New best_val_rmse: 0.4943
#
# 8 steps took 1.62 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4961
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 8 steps took 1.61 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4948
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 8 steps took 1.62 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.525
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.21 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.5217
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.23 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.5022
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.5069
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.26 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.5062
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 170 val_rmse: 0.5293
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 186 val_rmse: 0.5154
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.5271
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.22 seconds
# Epoch: 2 batch_num: 218 val_rmse: 0.4998
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 8 steps took 1.62 seconds
# Epoch: 2 batch_num: 226 val_rmse: 0.5259
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.5243
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.24 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.5014
# Still best_val_rmse: 0.4943 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4926
# New best_val_rmse: 0.4926
#
# 8 steps took 1.61 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.5046
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 16 steps took 3.38 seconds
# Epoch: 3 batch_num: 15 val_rmse: 0.4985
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 8 steps took 1.61 seconds
# Epoch: 3 batch_num: 23 val_rmse: 0.5111
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 3 batch_num: 39 val_rmse: 0.5058
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 3 batch_num: 55 val_rmse: 0.5277
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 16 steps took 3.25 seconds
# Epoch: 3 batch_num: 71 val_rmse: 0.4982
# Still best_val_rmse: 0.4926 (from epoch 2)
#
# 8 steps took 1.62 seconds
# Epoch: 3 batch_num: 79 val_rmse: 0.4918
# New best_val_rmse: 0.4918
#
# 8 steps took 1.62 seconds
# Epoch: 3 batch_num: 87 val_rmse: 0.4897
# New best_val_rmse: 0.4897
#
# 4 steps took 0.81 seconds
# Epoch: 3 batch_num: 91 val_rmse: 0.5079
# Still best_val_rmse: 0.4897 (from epoch 3)
#
# 16 steps took 3.24 seconds
# Epoch: 3 batch_num: 107 val_rmse: 0.4862
# New best_val_rmse: 0.4862
#
# 4 steps took 0.806 seconds
# Epoch: 3 batch_num: 111 val_rmse: 0.4887
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 4 steps took 0
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.6 seconds
# Epoch: 4 batch_num: 212 val_rmse: 0.491
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.62 seconds
# Epoch: 4 batch_num: 220 val_rmse: 0.4912
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.62 seconds
# Epoch: 4 batch_num: 228 val_rmse: 0.4912
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.62 seconds
# Epoch: 4 batch_num: 236 val_rmse: 0.4913
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.62 seconds
# Epoch: 4 batch_num: 244 val_rmse: 0.4914
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.63 seconds
# Epoch: 4 batch_num: 252 val_rmse: 0.4914
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.63 seconds
# Epoch: 4 batch_num: 260 val_rmse: 0.4914
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.61 seconds
# Epoch: 4 batch_num: 268 val_rmse: 0.4914
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# 8 steps took 1.61 seconds
# Epoch: 4 batch_num: 276 val_rmse: 0.4914
# Still best_val_rmse: 0.4862 (from epoch 3)
#
# Performance estimates:
# [0.4862048129622688]
# Mean: 0.4862048129622688
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 3.19 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.008
# New best_val_rmse: 1.008
#
# 16 steps took 2.96 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7596
# New best_val_rmse: 0.7596
#
# 16 steps took 2.96 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7747
# Still best_val_rmse: 0.7596 (from epoch 0)
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7581
# New best_val_rmse: 0.7581
#
# 16 steps took 2.98 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6138
# New best_val_rmse: 0.6138
#
# 16 steps took 2.95 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.5823
# New best_val_rmse: 0.5823
#
# 16 steps took 2.96 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.5562
# New best_val_rmse: 0.5562
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6128
# Still best_val_rmse: 0.5562 (from epoch 0)
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.5961
# Still best_val_rmse: 0.5562 (from epoch 0)
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.5429
# New best_val_rmse: 0.5429
#
# 16 steps took 2.96 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.5431
# Still best_val_rmse: 0.5429 (from epoch 0)
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.5195
# New best_val_rmse: 0.5195
#
# 16 steps took 2.98 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.5275
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 2.95 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.5351
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 2.99 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.5332
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 2.97 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5498
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 2.98 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5403
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 3.13 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.5221
# Still best_val_rmse: 0.5195 (from epoch 0)
#
# 16 steps took 2.95 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5186
# New best_val_rmse: 0.5186
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.6064
# Still best_val_rmse: 0.5186 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5158
# New best_val_rmse: 0.5158
#
# 16 steps took 2.98 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5021
# New best_val_rmse: 0.5021
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.4856
# New best_val_rmse: 0.4856
#
# 4 steps took 0.743 seconds
# Epoch: 1 batch_num: 89 val_rmse: 0.4997
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.47 seconds
# Epoch: 1 batch_num: 97 val_rmse: 0.5354
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 113 val_rmse: 0.506
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 129 val_rmse: 0.5478
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 145 val_rmse: 0.5063
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 161 val_rmse: 0.4934
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.49 seconds
# Epoch: 1 batch_num: 169 val_rmse: 0.6022
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 185 val_rmse: 0.5042
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 201 val_rmse: 0.4955
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.48 seconds
# Epoch: 1 batch_num: 209 val_rmse: 0.5158
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.96 seconds
# Epoch: 1 batch_num: 225 val_rmse: 0.4958
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.49 seconds
# Epoch: 1 batch_num: 233 val_rmse: 0.4953
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.49 seconds
# Epoch: 1 batch_num: 241 val_rmse: 0.5114
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 1 batch_num: 257 val_rmse: 0.5322
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.99 seconds
# Epoch: 1 batch_num: 273 val_rmse: 0.4991
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 8 steps took 1.48 seconds
# Epoch: 1 batch_num: 281 val_rmse: 0.5253
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 3.13 seconds
# Epoch: 2 batch_num: 14 val_rmse: 0.5872
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.96 seconds
# Epoch: 2 batch_num: 30 val_rmse: 0.5088
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.98 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.5231
# Still best_val_rmse: 0.4856 (from epoch 1)
#
# 16 steps took 2.97 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4846
# New best_val_rmse: 0.4846
#
# 4 steps took 0.741 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4848
# Still best_val_rmse: 0.4846 (from epoch 2)
#
# 4 steps took 0.742 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.5005
# Still best_val_rmse: 0.4846 (from epoch 2)
#
# 16 steps took 2.98 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4754
# New best_val_rmse: 0.4754
#
# 2 steps took 0.364 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4769
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 2 steps took 0.373 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4763
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 2 steps took 0.366 seconds
# Epoch: 2 batch_num: 92 val_rmse: 0.4768
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 2 steps took 0.366 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.484
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.736 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.4853
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.742 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4884
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.746 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4825
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.736 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.5088
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 3.0 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4856
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.739 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4811
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.744 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4902
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 8 steps took 1.49 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4776
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 2 steps took 0.374 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.5228
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 2.98 seconds
# Epoch: 2 batch_num: 160 val_rmse: 0.535
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 2.96 seconds
# Epoch: 2 batch_num: 176 val_rmse: 0.5217
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 2.97 seconds
# Epoch: 2 batch_num: 192 val_rmse: 0.5048
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 2.98 seconds
# Epoch: 2 batch_num: 208 val_rmse: 0.4967
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 8 steps took 1.48 seconds
# Epoch: 2 batch_num: 216 val_rmse: 0.4918
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 8 steps took 1.48 seconds
# Epoch: 2 batch_num: 224 val_rmse: 0.5355
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 16 steps took 2.97 seconds
# Epoch: 2 batch_num: 240 val_rmse: 0.4766
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 2 steps took 0.369 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.486
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.736 seconds
# Epoch: 2 batch_num: 246 val_rmse: 0.4803
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 4 steps took 0.738 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.4728
# New best_val_rmse: 0.4728
#
# 2 steps took 0.365 seconds
# Epoch: 2 batch_num: 252 val_rmse: 0.4773
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.365 seconds
# Epoch: 2 batch_num: 254 val_rmse: 0.4784
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.364 seconds
# Epoch: 2 batch_num: 256 val_rmse: 0.4761
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.364 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.4751
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.367 seconds
# Epoch: 2 batch_num: 260 val_rmse: 0.4806
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 4 steps took 0.735 seconds
# Epoch: 2 batch_num: 264 val_rmse: 0.4788
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.365 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.4744
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.369 seconds
# Epoch: 2 batch_num: 268 val_rmse: 0.4741
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.374 seconds
# Epoch: 2 batch_num: 270 val_rmse: 0.4745
# Still best_val_rmse: 0.4728 (from epoch 2)
#
# 2 steps took 0.37 seconds
# Epoch: 2 batch_num: 272 val_rmse: 0.4727
# New best_val_rmse: 0.4727
#
# 2 steps took 0.37 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4729
# Still best_val_rmse: 0.4727 (from epoch 2)
#
# 2 steps took 0.362 seconds
# Epoch: 2 batch_num: 276 val_rmse: 0.4787
# Still best_val_rmse: 0.4727 (from epoch 2)
#
# 2 steps took 0.366 seconds
# Epoch: 2 batch_num: 278 val_rmse: 0.481
# Still best_val_rmse: 0.4727 (from epoch 2)
#
# 4 steps took 0.748 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.4694
# New best_val_rmse: 0.4694
#
# 1 steps took 0.374 seconds
# Epoch: 3 batch_num: 0 val_rmse: 0.47
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.366 seconds
# Epoch: 3 batch_num: 2 val_rmse: 0.4719
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.366 seconds
# Epoch: 3 batch_num: 4 val_rmse: 0.4766
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.374 seconds
# Epoch: 3 batch_num: 6 val_rmse: 0.4794
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.369 seconds
# Epoch: 3 batch_num: 8 val_rmse: 0.4782
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.367 seconds
# Epoch: 3 batch_num: 10 val_rmse: 0.4746
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.37 seconds
# Epoch: 3 batch_num: 12 val_rmse: 0.4718
# Still best_val_rmse: 0.4694 (from epoch 2)
#
# 2 steps took 0.369 seconds
# Epoch: 3 batch_num: 14 val_rmse: 0.4689
# New best_val_rmse: 0.4689
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 15 val_rmse: 0.4683
# New best_val_rmse: 0.4683
#
# 1 steps took 0.179 seconds
# Epoch: 3 batch_num: 16 val_rmse: 0.4686
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.181 seconds
# Epoch: 3 batch_num: 17 val_rmse: 0.4689
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 18 val_rmse: 0.469
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 19 val_rmse: 0.4689
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 20 val_rmse: 0.4688
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.184 seconds
# Epoch: 3 batch_num: 21 val_rmse: 0.4685
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.182 seconds
# Epoch: 3 batch_num: 22 val_rmse: 0.4686
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.189 seconds
# Epoch: 3 batch_num: 23 val_rmse: 0.4698
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.181 seconds
# Epoch: 3 batch_num: 24 val_rmse: 0.4695
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.181 seconds
# Epoch: 3 batch_num: 25 val_rmse: 0.47
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.179 seconds
# Epoch: 3 batch_num: 26 val_rmse: 0.4714
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 2 steps took 0.366 seconds
# Epoch: 3 batch_num: 28 val_rmse: 0.4687
# Still best_val_rmse: 0.4683 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 29 val_rmse: 0.4681
# New best_val_rmse: 0.4681
#
# 1 steps took 0.179 seconds
# Epoch: 3 batch_num: 30 val_rmse: 0.4691
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 1 steps took 0.179 seconds
# Epoch: 3 batch_num: 31 val_rmse: 0.4706
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0.364 seconds
# Epoch: 3 batch_num: 33 val_rmse: 0.4741
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0.364 seconds
# Epoch: 3 batch_num: 35 val_rmse: 0.4761
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0.364 seconds
# Epoch: 3 batch_num: 37 val_rmse: 0.4773
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0.37 seconds
# Epoch: 3 batch_num: 39 val_rmse: 0.4788
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0.371 seconds
# Epoch: 3 batch_num: 41 val_rmse: 0.4807
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 4 steps took 0.738 seconds
# Epoch: 3 batch_num: 45 val_rmse: 0.4717
# Still best_val_rmse: 0.4681 (from epoch 3)
#
# 2 steps took 0
#
# 1 steps took 0.182 seconds
# Epoch: 3 batch_num: 273 val_rmse: 0.4665
# New best_val_rmse: 0.4665
#
# 1 steps took 0.182 seconds
# Epoch: 3 batch_num: 274 val_rmse: 0.4664
# New best_val_rmse: 0.4664
#
# 1 steps took 0.181 seconds
# Epoch: 3 batch_num: 275 val_rmse: 0.4664
# New best_val_rmse: 0.4664
#
# 1 steps took 0.199 seconds
# Epoch: 3 batch_num: 276 val_rmse: 0.4662
# New best_val_rmse: 0.4662
#
# 1 steps took 0.178 seconds
# Epoch: 3 batch_num: 277 val_rmse: 0.4662
# New best_val_rmse: 0.4662
#
# 1 steps took 0.18 seconds
# Epoch: 3 batch_num: 278 val_rmse: 0.4661
# New best_val_rmse: 0.4661
#
# 1 steps took 0.178 seconds
# Epoch: 3 batch_num: 279 val_rmse: 0.4661
# New best_val_rmse: 0.4661
#
# 1 steps took 0.179 seconds
# Epoch: 3 batch_num: 280 val_rmse: 0.4662
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.183 seconds
# Epoch: 3 batch_num: 281 val_rmse: 0.4665
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.178 seconds
# Epoch: 3 batch_num: 282 val_rmse: 0.467
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.34 seconds
# Epoch: 4 batch_num: 0 val_rmse: 0.4678
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.188 seconds
# Epoch: 4 batch_num: 1 val_rmse: 0.4686
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.179 seconds
# Epoch: 4 batch_num: 2 val_rmse: 0.4692
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 4 batch_num: 3 val_rmse: 0.4695
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.177 seconds
# Epoch: 4 batch_num: 4 val_rmse: 0.4698
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.186 seconds
# Epoch: 4 batch_num: 5 val_rmse: 0.4702
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 2 steps took 0.366 seconds
# Epoch: 4 batch_num: 7 val_rmse: 0.471
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 2 steps took 0.365 seconds
# Epoch: 4 batch_num: 9 val_rmse: 0.4714
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 2 steps took 0.373 seconds
# Epoch: 4 batch_num: 11 val_rmse: 0.47
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.184 seconds
# Epoch: 4 batch_num: 12 val_rmse: 0.4691
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.184 seconds
# Epoch: 4 batch_num: 13 val_rmse: 0.4684
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 4 batch_num: 14 val_rmse: 0.4677
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.182 seconds
# Epoch: 4 batch_num: 15 val_rmse: 0.4671
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.179 seconds
# Epoch: 4 batch_num: 16 val_rmse: 0.4667
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 4 batch_num: 17 val_rmse: 0.4663
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.18 seconds
# Epoch: 4 batch_num: 18 val_rmse: 0.4661
# Still best_val_rmse: 0.4661 (from epoch 3)
#
# 1 steps took 0.182 seconds
# Epoch: 4 batch_num: 19 val_rmse: 0.4659
# New best_val_rmse: 0.4659
#
# 1 steps took 0.177 seconds
# Epoch: 4 batch_num: 20 val_rmse: 0.4657
# New best_val_rmse: 0.4657
#
# 1 steps took 0.181 seconds
# Epoch: 4 batch_num: 21 val_rmse: 0.4657
# New best_val_rmse: 0.4657
#
# 1 steps took 0.181 seconds
# Epoch: 4 batch_num: 22 val_rmse: 0.4656
# New best_val_rmse: 0.4656
#
# 1 steps took 0.181 seconds
# Epoch: 4 batch_num: 23 val_rmse: 0.4656
# New best_val_rmse: 0.4656
#
# 1 steps took 0.18 seconds
# Epoch: 4 batch_num: 24 val_rmse: 0.4655
# New best_val_rmse: 0.4655
#
# 1 steps took 0.179 seconds
# Epoch: 4 batch_num: 25 val_rmse: 0.4655
# New best_val_rmse: 0.4655
#
# 1 steps took 0.181 seconds
# Epoch: 4 batch_num: 26 val_rmse: 0.4655
# Still best_val_rmse: 0.4655 (from epoch 4)
#
# 1 steps took 0.182 seconds
# Epoch: 4 batch_num: 27 val_rmse: 0.4657
# Still best_val_rmse: 0.4655 (from epoch 4)
#
# ...
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0
val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.357 seconds
# Epoch: 4 batch_num: 254 val_rmse: 0.4734
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.367 seconds
# Epoch: 4 batch_num: 256 val_rmse: 0.4734
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.357 seconds
# Epoch: 4 batch_num: 258 val_rmse: 0.4734
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.359 seconds
# Epoch: 4 batch_num: 260 val_rmse: 0.4734
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.354 seconds
# Epoch: 4 batch_num: 262 val_rmse: 0.4734
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.36 seconds
# Epoch: 4 batch_num: 264 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.36 seconds
# Epoch: 4 batch_num: 266 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.356 seconds
# Epoch: 4 batch_num: 268 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.352 seconds
# Epoch: 4 batch_num: 270 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.357 seconds
# Epoch: 4 batch_num: 272 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.354 seconds
# Epoch: 4 batch_num: 274 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.352 seconds
# Epoch: 4 batch_num: 276 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.351 seconds
# Epoch: 4 batch_num: 278 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.357 seconds
# Epoch: 4 batch_num: 280 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 0.366 seconds
# Epoch: 4 batch_num: 282 val_rmse: 0.4735
# Still best_val_rmse: 0.469 (from epoch 3)
#
# Performance estimates:
# [0.4862048129622688, 0.4655137592191203, 0.46728311918699816, 0.47951150116929175, 0.4689675083710589]
# Mean: 0.47349614018174757

# %%
print(list_val_rmse)
# Out:
# [0.4862048129622688, 0.4655137592191203, 0.46728311918699816, 0.47951150116929175, 0.4689675083710589]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Starting upload for file model_3.pth
# 100%|██████████| 477M/477M [00:20<00:00, 24.7MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_2.pth
# 100%|██████████| 477M/477M [00:20<00:00, 24.1MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_5.pth
# 100%|██████████| 477M/477M [00:18<00:00, 27.7MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_1.pth
# 100%|██████████| 477M/477M [00:20<00:00, 24.1MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_1.pth (477MB)
# Starting upload for file model_4.pth
# 100%|██████████| 477M/477M [00:20<00:00, 24.6MB/s]
# Upload successful: model_4.pth (477MB)

# %%
for index in range(len(list_val_rmse)): # Fold数ごとに推論する
    model_path = f"model_{index + 1}.pth" # 対応するモデルを読む
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    # 対応するモデルから、重みを読み込む

# %%
test_dataset = LitDataset(test_df, inference_only=True) # TestのDataset作成

# %%
# 推論実行
all_predictions = np.zeros((len(list_val_rmse), len(test_df))) # 推論結果について、「fold　× 推論df」のzero行列で枠を作る

test_dataset = LitDataset(test_df, inference_only=True) # TestのDataset(何で、もう一回作るのだろう？)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2) # TestのDataLoader

for index in range(len(list_val_rmse)): # Fold数ごとに推論する
    model_path = f"model_{index + 1}.pth" # 対応するモデルを読む
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    # 対応するモデルから、重みを読み込む
    model.to(DEVICE) # モデルをDEVICEへぶち込む
    
    all_predictions[index] = predict(model, test_loader) # 推論結果行列の対象列に、推論結果を入力(以後、繰り返し)
    
    del model
    gc.collect()

# %%
predictions = all_predictions.mean(axis=0) # 全FOLDの推論の平均を最終結果とする。
submission_df.target = predictions # 予測結果をsub用dfと結合
print(submission_df) # 結果表示
submission_df.to_csv("submission.csv", index=False) # sub用csv出力
