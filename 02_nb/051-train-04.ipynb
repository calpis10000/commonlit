# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-04'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 300 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )
        
        self.layer_norm = nn.LayerNorm(config.hidden_size) # layer_normレイヤー
        
        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        norm_embeddings = self.layer_norm(context_vector)
        return self.regressor(norm_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得

    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
    norm_parameters = list(model.layer_norm.named_parameters())

    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]

    parameters = []
    parameters += attention_group
    parameters += regressor_group
    parameters += norm_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 73.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6175 train_rmse_stderror: 0.04452 train_kl_div: 0.8357
# val_rmse_target: 0.7703 val_rmse_stderror: 1.852
# New best_val_rmse: 0.7703
#
# 64 steps took 72.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6241 train_rmse_stderror: 0.02841 train_kl_div: 0.8568
# val_rmse_target: 0.6986 val_rmse_stderror: 1.85
# New best_val_rmse: 0.6986
#
# 64 steps took 72.3 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.573 train_rmse_stderror: 0.0313 train_kl_div: 0.6449
# val_rmse_target: 0.6286 val_rmse_stderror: 1.841
# New best_val_rmse: 0.6286
#
# 64 steps took 72.4 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4488 train_rmse_stderror: 0.03339 train_kl_div: 0.366
# val_rmse_target: 0.6001 val_rmse_stderror: 1.84
# New best_val_rmse: 0.6001
#
# 64 steps took 72.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5897 train_rmse_stderror: 0.05471 train_kl_div: 0.7176
# val_rmse_target: 0.5667 val_rmse_stderror: 1.834
# New best_val_rmse: 0.5667
#
# 64 steps took 72.6 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2227 train_rmse_stderror: 0.02379 train_kl_div: 0.1182
# val_rmse_target: 0.5461 val_rmse_stderror: 1.835
# New best_val_rmse: 0.5461
#
# 32 steps took 36.3 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.3619 train_rmse_stderror: 0.02809 train_kl_div: 0.2987
# val_rmse_target: 0.5388 val_rmse_stderror: 1.847
# New best_val_rmse: 0.5388
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4718 train_rmse_stderror: 0.03641 train_kl_div: 0.4893
# val_rmse_target: 0.661 val_rmse_stderror: 1.835
# Still best_val_rmse: 0.5388 (from epoch 1)
#
# 64 steps took 72.0 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.356 train_rmse_stderror: 0.02251 train_kl_div: 0.286
# val_rmse_target: 0.5331 val_rmse_stderror: 1.867
# New best_val_rmse: 0.5331
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.6158 train_rmse_stderror: 0.04519 train_kl_div: 0.8259
# val_rmse_target: 0.5451 val_rmse_stderror: 1.862
# Still best_val_rmse: 0.5331 (from epoch 1)
#
# 32 steps took 36.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3833 train_rmse_stderror: 0.01948 train_kl_div: 0.269
# val_rmse_target: 0.5036 val_rmse_stderror: 1.835
# New best_val_rmse: 0.5036
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2791 train_rmse_stderror: 0.03493 train_kl_div: 0.1608
# val_rmse_target: 0.4937 val_rmse_stderror: 1.867
# New best_val_rmse: 0.4937
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2507 train_rmse_stderror: 0.01811 train_kl_div: 0.1421
# val_rmse_target: 0.4964 val_rmse_stderror: 1.848
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.4052 train_rmse_stderror: 0.03233 train_kl_div: 0.3571
# val_rmse_target: 0.5355 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.4501 train_rmse_stderror: 0.05146 train_kl_div: 0.3055
# val_rmse_target: 0.514 val_rmse_stderror: 1.851
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.292 train_rmse_stderror: 0.02644 train_kl_div: 0.1587
# val_rmse_target: 0.5431 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2122 train_rmse_stderror: 0.02037 train_kl_div: 0.09783
# val_rmse_target: 0.5212 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2076 train_rmse_stderror: 0.02148 train_kl_div: 0.08912
# val_rmse_target: 0.5737 val_rmse_stderror: 1.838
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 64 steps took 72.6 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2676 train_rmse_stderror: 0.02589 train_kl_div: 0.1432
# val_rmse_target: 0.5147 val_rmse_stderror: 1.851
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1741 train_rmse_stderror: 0.02912 train_kl_div: 0.06523
# val_rmse_target: 0.5011 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.07864 train_rmse_stderror: 0.01852 train_kl_div: 0.0132
# val_rmse_target: 0.5095 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2029 train_rmse_stderror: 0.03818 train_kl_div: 0.07253
# val_rmse_target: 0.5001 val_rmse_stderror: 1.859
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.2813 train_rmse_stderror: 0.02835 train_kl_div: 0.1166
# val_rmse_target: 0.4977 val_rmse_stderror: 1.848
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.08614 train_rmse_stderror: 0.02009 train_kl_div: 0.01916
# val_rmse_target: 0.5018 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.07397 train_rmse_stderror: 0.01296 train_kl_div: 0.01319
# val_rmse_target: 0.4956 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4937 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1736 train_rmse_stderror: 0.02482 train_kl_div: 0.06593
# val_rmse_target: 0.487 val_rmse_stderror: 1.852
# New best_val_rmse: 0.487
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1914 train_rmse_stderror: 0.02206 train_kl_div: 0.08281
# val_rmse_target: 0.4994 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1166 train_rmse_stderror: 0.03734 train_kl_div: 0.02977
# val_rmse_target: 0.4979 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08494 train_rmse_stderror: 0.0314 train_kl_div: 0.01931
# val_rmse_target: 0.5044 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.07488 train_rmse_stderror: 0.01694 train_kl_div: 0.01341
# val_rmse_target: 0.4978 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1284 train_rmse_stderror: 0.03319 train_kl_div: 0.03138
# val_rmse_target: 0.498 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07486 train_rmse_stderror: 0.01853 train_kl_div: 0.01335
# val_rmse_target: 0.4975 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.2097 train_rmse_stderror: 0.02642 train_kl_div: 0.08053
# val_rmse_target: 0.5004 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.0618 train_rmse_stderror: 0.02106 train_kl_div: 0.01015
# val_rmse_target: 0.4995 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.08045 train_rmse_stderror: 0.01846 train_kl_div: 0.01515
# val_rmse_target: 0.4995 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.09654 train_rmse_stderror: 0.03075 train_kl_div: 0.02434
# val_rmse_target: 0.4995 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.487 (from epoch 3)
#
# Performance estimates:
# [0.486983364294258]
# Mean: 0.486983364294258
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 73.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8647 train_rmse_stderror: 0.05285 train_kl_div: 1.376
# val_rmse_target: 0.767 val_rmse_stderror: 1.096
# New best_val_rmse: 0.767
#
# 64 steps took 72.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8309 train_rmse_stderror: 0.06493 train_kl_div: 0.9505
# val_rmse_target: 0.6336 val_rmse_stderror: 1.1
# New best_val_rmse: 0.6336
#
# 64 steps took 72.5 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.409 train_rmse_stderror: 0.04567 train_kl_div: 0.3573
# val_rmse_target: 0.5779 val_rmse_stderror: 1.099
# New best_val_rmse: 0.5779
#
# 64 steps took 72.2 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4107 train_rmse_stderror: 0.06579 train_kl_div: 0.3457
# val_rmse_target: 0.5916 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5779 (from epoch 0)
#
# 64 steps took 72.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5956 train_rmse_stderror: 0.04091 train_kl_div: 0.6584
# val_rmse_target: 0.5385 val_rmse_stderror: 1.103
# New best_val_rmse: 0.5385
#
# 32 steps took 36.3 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.5188 train_rmse_stderror: 0.04373 train_kl_div: 0.6163
# val_rmse_target: 0.5636 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.5385 (from epoch 1)
#
# 64 steps took 72.3 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.6343 train_rmse_stderror: 0.03006 train_kl_div: 0.7484
# val_rmse_target: 0.5477 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.5385 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4044 train_rmse_stderror: 0.02369 train_kl_div: 0.3415
# val_rmse_target: 0.5376 val_rmse_stderror: 1.115
# New best_val_rmse: 0.5376
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.4663 train_rmse_stderror: 0.0416 train_kl_div: 0.391
# val_rmse_target: 0.5412 val_rmse_stderror: 1.096
# Still best_val_rmse: 0.5376 (from epoch 1)
#
# 32 steps took 36.3 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4219 train_rmse_stderror: 0.0323 train_kl_div: 0.3539
# val_rmse_target: 0.5313 val_rmse_stderror: 1.111
# New best_val_rmse: 0.5313
#
# 32 steps took 36.3 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.5136 train_rmse_stderror: 0.04751 train_kl_div: 0.481
# val_rmse_target: 0.5149 val_rmse_stderror: 1.112
# New best_val_rmse: 0.5149
#
# 32 steps took 36.6 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3614 train_rmse_stderror: 0.02343 train_kl_div: 0.2936
# val_rmse_target: 0.5096 val_rmse_stderror: 1.107
# New best_val_rmse: 0.5096
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4246 train_rmse_stderror: 0.04616 train_kl_div: 0.3346
# val_rmse_target: 0.5169 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5096 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3882 train_rmse_stderror: 0.02157 train_kl_div: 0.3366
# val_rmse_target: 0.526 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5096 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1881 train_rmse_stderror: 0.03356 train_kl_div: 0.08452
# val_rmse_target: 0.5294 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5096 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.3622 train_rmse_stderror: 0.02385 train_kl_div: 0.28
# val_rmse_target: 0.5269 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.5096 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2682 train_rmse_stderror: 0.02743 train_kl_div: 0.1523
# val_rmse_target: 0.5091 val_rmse_stderror: 1.111
# New best_val_rmse: 0.5091
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3771 train_rmse_stderror: 0.02323 train_kl_div: 0.2937
# val_rmse_target: 0.5057 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5057
#
# 32 steps took 36.4 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2453 train_rmse_stderror: 0.02902 train_kl_div: 0.1255
# val_rmse_target: 0.4967 val_rmse_stderror: 1.112
# New best_val_rmse: 0.4967
#
# 32 steps took 36.3 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2637 train_rmse_stderror: 0.04688 train_kl_div: 0.1368
# val_rmse_target: 0.5018 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.4967 (from epoch 2)
#
# 32 steps took 36.7 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1537 train_rmse_stderror: 0.0196 train_kl_div: 0.05388
# val_rmse_target: 0.5212 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4967 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2952 train_rmse_stderror: 0.02998 train_kl_div: 0.1513
# val_rmse_target: 0.5204 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4967 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1396 train_rmse_stderror: 0.02392 train_kl_div: 0.0406
# val_rmse_target: 0.4955 val_rmse_stderror: 1.104
# New best_val_rmse: 0.4955
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1238 train_rmse_stderror: 0.03934 train_kl_div: 0.03045
# val_rmse_target: 0.4904 val_rmse_stderror: 1.116
# New best_val_rmse: 0.4904
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1912 train_rmse_stderror: 0.02468 train_kl_div: 0.07969
# val_rmse_target: 0.5053 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.183 train_rmse_stderror: 0.01767 train_kl_div: 0.06463
# val_rmse_target: 0.4957 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.2911 train_rmse_stderror: 0.02888 train_kl_div: 0.1698
# val_rmse_target: 0.4947 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.2172 train_rmse_stderror: 0.02681 train_kl_div: 0.1034
# val_rmse_target: 0.4904 val_rmse_stderror: 1.112
# New best_val_rmse: 0.4904
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.3055 train_rmse_stderror: 0.02995 train_kl_div: 0.2138
# val_rmse_target: 0.4918 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1669 train_rmse_stderror: 0.01571 train_kl_div: 0.05518
# val_rmse_target: 0.4948 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.07547 train_rmse_stderror: 0.02116 train_kl_div: 0.0141
# val_rmse_target: 0.4907 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.137 train_rmse_stderror: 0.01999 train_kl_div: 0.03953
# val_rmse_target: 0.495 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1276 train_rmse_stderror: 0.01387 train_kl_div: 0.03556
# val_rmse_target: 0.4951 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1794 train_rmse_stderror: 0.02695 train_kl_div: 0.06945
# val_rmse_target: 0.491 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1396 train_rmse_stderror: 0.02146 train_kl_div: 0.04288
# val_rmse_target: 0.4925 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.07978 train_rmse_stderror: 0.03131 train_kl_div: 0.0161
# val_rmse_target: 0.4933 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.2235 train_rmse_stderror: 0.03485 train_kl_div: 0.0844
# val_rmse_target: 0.4924 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.07214 train_rmse_stderror: 0.02851 train_kl_div: 0.01475
# val_rmse_target: 0.4922 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4904 (from epoch 3)
#
# Performance estimates:
# [0.486983364294258, 0.4904161287051945]
# Mean: 0.48869974649972625
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 73.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5962 train_rmse_stderror: 0.0311 train_kl_div: 0.7143
# val_rmse_target: 0.6766 val_rmse_stderror: 1.754
# New best_val_rmse: 0.6766
#
# 64 steps took 72.3 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6139 train_rmse_stderror: 0.05435 train_kl_div: 0.7723
# val_rmse_target: 0.6245 val_rmse_stderror: 1.737
# New best_val_rmse: 0.6245
#
# 64 steps took 72.0 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5552 train_rmse_stderror: 0.04717 train_kl_div: 0.6799
# val_rmse_target: 0.6298 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.6245 (from epoch 0)
#
# 64 steps took 72.4 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5773 train_rmse_stderror: 0.04691 train_kl_div: 0.5938
# val_rmse_target: 0.6006 val_rmse_stderror: 1.74
# New best_val_rmse: 0.6006
#
# 64 steps took 72.6 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.431 train_rmse_stderror: 0.02031 train_kl_div: 0.4234
# val_rmse_target: 0.5524 val_rmse_stderror: 1.738
# New best_val_rmse: 0.5524
#
# 64 steps took 72.4 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.47 train_rmse_stderror: 0.04334 train_kl_div: 0.3832
# val_rmse_target: 0.5031 val_rmse_stderror: 1.751
# New best_val_rmse: 0.5031
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.3197 train_rmse_stderror: 0.03014 train_kl_div: 0.2166
# val_rmse_target: 0.5083 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.5031 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4867 train_rmse_stderror: 0.02228 train_kl_div: 0.4695
# val_rmse_target: 0.503 val_rmse_stderror: 1.752
# New best_val_rmse: 0.503
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.3371 train_rmse_stderror: 0.01861 train_kl_div: 0.2419
# val_rmse_target: 0.5106 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.503 (from epoch 1)
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3021 train_rmse_stderror: 0.04091 train_kl_div: 0.1778
# val_rmse_target: 0.4894 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4894
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4162 train_rmse_stderror: 0.0186 train_kl_div: 0.3544
# val_rmse_target: 0.5007 val_rmse_stderror: 1.729
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.5 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2956 train_rmse_stderror: 0.03997 train_kl_div: 0.167
# val_rmse_target: 0.5079 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.3 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3067 train_rmse_stderror: 0.02817 train_kl_div: 0.2104
# val_rmse_target: 0.5008 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.19 train_rmse_stderror: 0.01679 train_kl_div: 0.06895
# val_rmse_target: 0.5079 val_rmse_stderror: 1.732
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.4 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3769 train_rmse_stderror: 0.02507 train_kl_div: 0.3107
# val_rmse_target: 0.5455 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.3 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1932 train_rmse_stderror: 0.02406 train_kl_div: 0.08472
# val_rmse_target: 0.4951 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3886 train_rmse_stderror: 0.0507 train_kl_div: 0.228
# val_rmse_target: 0.4875 val_rmse_stderror: 1.743
# New best_val_rmse: 0.4875
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1585 train_rmse_stderror: 0.03397 train_kl_div: 0.06097
# val_rmse_target: 0.4905 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2543 train_rmse_stderror: 0.04488 train_kl_div: 0.1422
# val_rmse_target: 0.4862 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4862
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2815 train_rmse_stderror: 0.02857 train_kl_div: 0.1639
# val_rmse_target: 0.4909 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4862 (from epoch 2)
#
# 32 steps took 36.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1089 train_rmse_stderror: 0.01509 train_kl_div: 0.02383
# val_rmse_target: 0.4824 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4824
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1718 train_rmse_stderror: 0.02037 train_kl_div: 0.06103
# val_rmse_target: 0.4835 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1428 train_rmse_stderror: 0.02307 train_kl_div: 0.04239
# val_rmse_target: 0.4895 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.148 train_rmse_stderror: 0.02858 train_kl_div: 0.05262
# val_rmse_target: 0.4825 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.08602 train_rmse_stderror: 0.02972 train_kl_div: 0.01718
# val_rmse_target: 0.4821 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4821
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1242 train_rmse_stderror: 0.0174 train_kl_div: 0.03884
# val_rmse_target: 0.4823 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4821 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.151 train_rmse_stderror: 0.02206 train_kl_div: 0.04533
# val_rmse_target: 0.4786 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4786
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.07075 train_rmse_stderror: 0.02232 train_kl_div: 0.01151
# val_rmse_target: 0.4831 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.2232 train_rmse_stderror: 0.02953 train_kl_div: 0.102
# val_rmse_target: 0.4811 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.5 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1681 train_rmse_stderror: 0.03993 train_kl_div: 0.05219
# val_rmse_target: 0.4804 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1074 train_rmse_stderror: 0.01311 train_kl_div: 0.02489
# val_rmse_target: 0.4795 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1237 train_rmse_stderror: 0.03725 train_kl_div: 0.02666
# val_rmse_target: 0.4801 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1045 train_rmse_stderror: 0.02285 train_kl_div: 0.02623
# val_rmse_target: 0.4811 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.05319 train_rmse_stderror: 0.0194 train_kl_div: 0.00666
# val_rmse_target: 0.481 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.05176 train_rmse_stderror: 0.02165 train_kl_div: 0.007493
# val_rmse_target: 0.4814 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09706 train_rmse_stderror: 0.02831 train_kl_div: 0.02397
# val_rmse_target: 0.4816 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1027 train_rmse_stderror: 0.02503 train_kl_div: 0.0234
# val_rmse_target: 0.4812 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.05034 train_rmse_stderror: 0.02217 train_kl_div: 0.007622
# val_rmse_target: 0.4812 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4786 (from epoch 3)
#
# Performance estimates:
# [0.486983364294258, 0.4904161287051945, 0.47862931525827096]
# Mean: 0.48534293608590784
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.9485 train_rmse_stderror: 0.06108 train_kl_div: 1.683
# val_rmse_target: 0.7673 val_rmse_stderror: 1.771
# New best_val_rmse: 0.7673
#
# 64 steps took 72.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6195 train_rmse_stderror: 0.0319 train_kl_div: 0.7701
# val_rmse_target: 0.6074 val_rmse_stderror: 1.783
# New best_val_rmse: 0.6074
#
# 64 steps took 72.2 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.3901 train_rmse_stderror: 0.02933 train_kl_div: 0.3139
# val_rmse_target: 0.6345 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.6074 (from epoch 0)
#
# 64 steps took 72.3 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.8771 train_rmse_stderror: 0.01885 train_kl_div: 1.654
# val_rmse_target: 0.5475 val_rmse_stderror: 1.8
# New best_val_rmse: 0.5475
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.6136 train_rmse_stderror: 0.04919 train_kl_div: 0.5838
# val_rmse_target: 0.6184 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.5475 (from epoch 0)
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.5626 train_rmse_stderror: 0.02678 train_kl_div: 0.7093
# val_rmse_target: 0.5139 val_rmse_stderror: 1.785
# New best_val_rmse: 0.5139
#
# 32 steps took 36.2 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.5831 train_rmse_stderror: 0.0227 train_kl_div: 0.7205
# val_rmse_target: 0.5545 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.5139 (from epoch 1)
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.6584 train_rmse_stderror: 0.06878 train_kl_div: 0.6918
# val_rmse_target: 0.4852 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4852
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.436 train_rmse_stderror: 0.04611 train_kl_div: 0.3652
# val_rmse_target: 0.5134 val_rmse_stderror: 1.782
# Still best_val_rmse: 0.4852 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4251 train_rmse_stderror: 0.04394 train_kl_div: 0.3847
# val_rmse_target: 0.4915 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4852 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.3823 train_rmse_stderror: 0.0243 train_kl_div: 0.2863
# val_rmse_target: 0.5164 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.4852 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.195 train_rmse_stderror: 0.02614 train_kl_div: 0.08298
# val_rmse_target: 0.554 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4852 (from epoch 1)
#
# 64 steps took 72.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3448 train_rmse_stderror: 0.03381 train_kl_div: 0.2458
# val_rmse_target: 0.4746 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4746
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3863 train_rmse_stderror: 0.03154 train_kl_div: 0.2957
# val_rmse_target: 0.4625 val_rmse_stderror: 1.779
# New best_val_rmse: 0.4625
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.3324 train_rmse_stderror: 0.02094 train_kl_div: 0.2418
# val_rmse_target: 0.4681 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4625 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2896 train_rmse_stderror: 0.0213 train_kl_div: 0.1807
# val_rmse_target: 0.4602 val_rmse_stderror: 1.785
# New best_val_rmse: 0.4602
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2698 train_rmse_stderror: 0.04138 train_kl_div: 0.1464
# val_rmse_target: 0.5006 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4602 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2753 train_rmse_stderror: 0.03013 train_kl_div: 0.1626
# val_rmse_target: 0.4541 val_rmse_stderror: 1.792
# New best_val_rmse: 0.4541
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2834 train_rmse_stderror: 0.02979 train_kl_div: 0.1528
# val_rmse_target: 0.4751 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4541 (from epoch 2)
#
# 32 steps took 36.3 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.142 train_rmse_stderror: 0.02233 train_kl_div: 0.04622
# val_rmse_target: 0.4496 val_rmse_stderror: 1.783
# New best_val_rmse: 0.4496
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1539 train_rmse_stderror: 0.017 train_kl_div: 0.04302
# val_rmse_target: 0.466 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1677 train_rmse_stderror: 0.01899 train_kl_div: 0.0656
# val_rmse_target: 0.4657 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.154 train_rmse_stderror: 0.0224 train_kl_div: 0.05203
# val_rmse_target: 0.4574 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.07658 train_rmse_stderror: 0.01833 train_kl_div: 0.01359
# val_rmse_target: 0.4542 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1732 train_rmse_stderror: 0.02391 train_kl_div: 0.06379
# val_rmse_target: 0.4656 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1569 train_rmse_stderror: 0.02248 train_kl_div: 0.04756
# val_rmse_target: 0.4502 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.2392 train_rmse_stderror: 0.03648 train_kl_div: 0.08877
# val_rmse_target: 0.4522 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.09981 train_rmse_stderror: 0.01871 train_kl_div: 0.02355
# val_rmse_target: 0.4521 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.09656 train_rmse_stderror: 0.01271 train_kl_div: 0.01937
# val_rmse_target: 0.4527 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1369 train_rmse_stderror: 0.02784 train_kl_div: 0.04838
# val_rmse_target: 0.4538 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.09562 train_rmse_stderror: 0.03076 train_kl_div: 0.02074
# val_rmse_target: 0.4531 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.0911 train_rmse_stderror: 0.01863 train_kl_div: 0.0186
# val_rmse_target: 0.4543 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1625 train_rmse_stderror: 0.02101 train_kl_div: 0.04718
# val_rmse_target: 0.4543 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.09793 train_rmse_stderror: 0.02598 train_kl_div: 0.02208
# val_rmse_target: 0.4526 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09352 train_rmse_stderror: 0.02603 train_kl_div: 0.01916
# val_rmse_target: 0.4529 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1466 train_rmse_stderror: 0.01786 train_kl_div: 0.04006
# val_rmse_target: 0.4536 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1605 train_rmse_stderror: 0.03026 train_kl_div: 0.04824
# val_rmse_target: 0.4535 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4496 (from epoch 3)
#
# Performance estimates:
# [0.486983364294258, 0.4904161287051945, 0.47862931525827096, 0.4495811738091218]
# Mean: 0.4764024955167113
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.3267 train_rmse_stderror: 0.0533 train_kl_div: 0.2499
# val_rmse_target: 0.6259 val_rmse_stderror: 1.769
# New best_val_rmse: 0.6259
#
# 64 steps took 71.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4215 train_rmse_stderror: 0.05187 train_kl_div: 0.3733
# val_rmse_target: 0.6266 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.6259 (from epoch 0)
#
# 64 steps took 72.3 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4623 train_rmse_stderror: 0.0245 train_kl_div: 0.4328
# val_rmse_target: 0.5811 val_rmse_stderror: 1.752
# New best_val_rmse: 0.5811
#
# 64 steps took 72.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4376 train_rmse_stderror: 0.02944 train_kl_div: 0.3881
# val_rmse_target: 0.6098 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.5811 (from epoch 0)
#
# 64 steps took 72.2 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.507 train_rmse_stderror: 0.0374 train_kl_div: 0.5358
# val_rmse_target: 0.5305 val_rmse_stderror: 1.791
# New best_val_rmse: 0.5305
#
# 32 steps took 36.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.58 train_rmse_stderror: 0.03241 train_kl_div: 0.758
# val_rmse_target: 0.5198 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5198
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2878 train_rmse_stderror: 0.01853 train_kl_div: 0.1752
# val_rmse_target: 0.5222 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.5198 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.5046 train_rmse_stderror: 0.04785 train_kl_div: 0.4403
# val_rmse_target: 0.4957 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4957
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4843 train_rmse_stderror: 0.0402 train_kl_div: 0.4731
# val_rmse_target: 0.4902 val_rmse_stderror: 1.781
# New best_val_rmse: 0.4902
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.4949 train_rmse_stderror: 0.0347 train_kl_div: 0.4068
# val_rmse_target: 0.5 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4902 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4265 train_rmse_stderror: 0.03839 train_kl_div: 0.3653
# val_rmse_target: 0.5011 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4902 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4788 train_rmse_stderror: 0.02936 train_kl_div: 0.4612
# val_rmse_target: 0.4893 val_rmse_stderror: 1.764
# New best_val_rmse: 0.4893
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2717 train_rmse_stderror: 0.02345 train_kl_div: 0.1698
# val_rmse_target: 0.4902 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4893 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3425 train_rmse_stderror: 0.02301 train_kl_div: 0.2771
# val_rmse_target: 0.5109 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4893 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2 train_rmse_stderror: 0.01567 train_kl_div: 0.08825
# val_rmse_target: 0.4938 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4893 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2226 train_rmse_stderror: 0.04869 train_kl_div: 0.09166
# val_rmse_target: 0.4955 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4893 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.4245 train_rmse_stderror: 0.02484 train_kl_div: 0.3657
# val_rmse_target: 0.5054 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4893 (from epoch 1)
#
# 32 steps took 36.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2946 train_rmse_stderror: 0.02582 train_kl_div: 0.187
# val_rmse_target: 0.489 val_rmse_stderror: 1.773
# New best_val_rmse: 0.489
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2037 train_rmse_stderror: 0.04273 train_kl_div: 0.07741
# val_rmse_target: 0.4848 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4848
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2005 train_rmse_stderror: 0.01399 train_kl_div: 0.08844
# val_rmse_target: 0.4988 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2286 train_rmse_stderror: 0.01778 train_kl_div: 0.1182
# val_rmse_target: 0.4854 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.154 train_rmse_stderror: 0.02858 train_kl_div: 0.05055
# val_rmse_target: 0.4868 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.195 train_rmse_stderror: 0.02599 train_kl_div: 0.08081
# val_rmse_target: 0.4872 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 36.2 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.09784 train_rmse_stderror: 0.01949 train_kl_div: 0.02224
# val_rmse_target: 0.4814 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4814
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1489 train_rmse_stderror: 0.01621 train_kl_div: 0.04935
# val_rmse_target: 0.4817 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.2199 train_rmse_stderror: 0.01412 train_kl_div: 0.09602
# val_rmse_target: 0.4848 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1827 train_rmse_stderror: 0.02721 train_kl_div: 0.05539
# val_rmse_target: 0.4857 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1268 train_rmse_stderror: 0.01814 train_kl_div: 0.03557
# val_rmse_target: 0.4899 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1655 train_rmse_stderror: 0.03027 train_kl_div: 0.05704
# val_rmse_target: 0.4818 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1188 train_rmse_stderror: 0.0242 train_kl_div: 0.03501
# val_rmse_target: 0.4818 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4814 (from epoch 3)
#
# 32 steps took 36.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1954 train_rmse_stderror: 0.03415 train_kl_div: 0.06107
# val_rmse_target: 0.4776 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4776
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1571 train_rmse_stderror: 0.02764 train_kl_div: 0.04481
# val_rmse_target: 0.4835 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.09951 train_rmse_stderror: 0.02266 train_kl_div: 0.02477
# val_rmse_target: 0.4834 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1068 train_rmse_stderror: 0.01769 train_kl_div: 0.02596
# val_rmse_target: 0.4815 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 36.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.09292 train_rmse_stderror: 0.03485 train_kl_div: 0.01977
# val_rmse_target: 0.4816 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1159 train_rmse_stderror: 0.01772 train_kl_div: 0.02607
# val_rmse_target: 0.4817 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.08776 train_rmse_stderror: 0.006913 train_kl_div: 0.01691
# val_rmse_target: 0.4818 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.08011 train_rmse_stderror: 0.03951 train_kl_div: 0.01594
# val_rmse_target: 0.4819 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.09754 train_rmse_stderror: 0.01971 train_kl_div: 0.02422
# val_rmse_target: 0.4818 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4776 (from epoch 4)
#
# Performance estimates:
# [0.486983364294258, 0.4904161287051945, 0.47862931525827096, 0.4495811738091218, 0.4775719138503998]
# Mean: 0.47663637918344903
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.486983364294258, 0.4904161287051945, 0.47862931525827096, 0.4495811738091218, 0.4775719138503998]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   1%|          | 11.0M/1.33G [00:00<00:12, 112MB/s]
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:16<00:00, 86.0MB/s]
#   1%|          | 11.0M/1.33G [00:00<00:12, 112MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:12<00:00, 110MB/s]
#   1%|          | 6.82M/1.33G [00:00<00:19, 71.5MB/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:12<00:00, 114MB/s]
#   1%|          | 10.9M/1.33G [00:00<00:12, 114MB/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:15<00:00, 94.9MB/s]
#   1%|          | 10.6M/1.33G [00:00<00:12, 111MB/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:12<00:00, 110MB/s]
# Upload successful: model_1.pth (1GB)
