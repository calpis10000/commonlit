# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
  #!cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5' '/content/clrp-roberta-large'
  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
"""
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/
"""
# Out:
# '\n%cd\n!mkdir .kaggle\n!mkdir /content/model\n!cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/\n'

# %%
"""
# !mkdir /content/pre-trained-roberta
# !kaggle datasets download -p /content/pre-trained-roberta clrprobertalarge --unzip
# !cp -r /content/pre-trained-roberta/ /content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5
"""
# Out:
# '\n!mkdir /content/pre-trained-roberta\n!kaggle datasets download -p /content/pre-trained-roberta clrprobertalarge --unzip\n!cp -r /content/pre-trained-roberta/ /content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5\n'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '048-train-01'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (0.50, 32), (0.49, 16), (0.48, 8), (0.47, 4), (0.46, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %% [markdown]
# # Dataset

# %%
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# 検証用_単語を長さに変換して格納する。効きそうなら、本体にマージする。
class LitDatasetWordLen(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = text_normalization(df.excerpt)
        self.text_len = self.text.map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)
        
        if self.inference_only:
            return input_len            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
# ワード長のモデル。上手くいきそうなら、本体にマージする。
class LitModelWordLen(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv1d(1, 8, kernel_size=3, stride=1)
        self.bn1 = nn.BatchNorm1d(8)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=2)

        self.conv2 = nn.Conv1d(8, 16,kernel_size=3, stride=1)
        self.bn2 = nn.BatchNorm1d(16)
        self.conv3 = nn.Conv1d(16,64,kernel_size=3, stride=1)
        self.gap = nn.AdaptiveAvgPool1d(1)

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(64, 2)
        )

    def forward(self, input_ids):
        x = 
        x = self.conv1(input_ids)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.conv3(x)
        x = self.gap(x)
        x = x.view(x.size(0),-1)
        return self.regressor(x)

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
                        
            output = model(input_ids) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
            
    named_group = [params for (name, params) in named_parameters] # attention用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": named_group}) # パラメータをリストに辞書として格納していく

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDatasetWordLen(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDatasetWordLen(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModelWordLen().to(DEVICE) # modelをDEVICEへぶち込む
    #optimizer = create_optimizer(model) # optimizerをモデルから作成
    optimizer = AdamW(model.parameters(), lr=0.01)
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# ワード長のモデル。上手くいきそうなら、本体にマージする。
class LitModelWordLen(nn.Module):
    def __init__(self):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 2)

        )

    def forward(self, input_ids):
        return self.layers(input_ids)

# %%
# ワード長のモデル。上手くいきそうなら、本体にマージする。
class LitModelWordLenConv1d(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1_layers = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=3, stride=1),
            nn.BatchNorm1d(16),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=3, stride=2),

            nn.Conv1d(16, 64,kernel_size=3, stride=1),
            nn.BatchNorm1d(64),
            nn.Conv1d(64, 256,kernel_size=3, stride=1),
            nn.AdaptiveAvgPool1d(1)
        )
        self.fc = nn.Linear(256,2)

    def forward(self, input_ids):
        input_chnl = input_ids.unsqueeze(1)
        conv1_layers = self.conv1_layers(input_chnl)
        conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)
        return self.fc(conv1_layers_v)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDatasetWordLen(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDatasetWordLen(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModelWordLenConv1d().to(DEVICE) # modelをDEVICEへぶち込む
    #optimizer = create_optimizer(model) # optimizerをモデルから作成
    optimizer = AdamW(model.parameters(), lr=0.01)
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

#kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 947}
#
# 64 steps took 0.382 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8741 train_rmse_stderror: 1.211 train_kl_div: 5.723
# val_rmse_target: 1.808 val_rmse_stderror: 2.461
# New best_val_rmse: 1.808
#
# 64 steps took 0.313 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.9699 train_rmse_stderror: 0.0993 train_kl_div: 2.059
# val_rmse_target: 0.979 val_rmse_stderror: 1.724
# New best_val_rmse: 0.979
#
# 64 steps took 0.418 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.9024 train_rmse_stderror: 0.1404 train_kl_div: 1.709
# val_rmse_target: 0.9489 val_rmse_stderror: 1.708
# New best_val_rmse: 0.9489
#
# 64 steps took 0.325 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.8002 train_rmse_stderror: 0.05183 train_kl_div: 1.282
# val_rmse_target: 0.8494 val_rmse_stderror: 1.72
# New best_val_rmse: 0.8494
#
# 64 steps took 0.321 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.7758 train_rmse_stderror: 0.04739 train_kl_div: 1.088
# val_rmse_target: 0.8868 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.8494 (from epoch 1)
#
# 64 steps took 0.436 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.7216 train_rmse_stderror: 0.04121 train_kl_div: 0.9917
# val_rmse_target: 0.848 val_rmse_stderror: 1.689
# New best_val_rmse: 0.848
#
# 64 steps took 0.348 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.9299 train_rmse_stderror: 0.02274 train_kl_div: 1.817
# val_rmse_target: 0.8495 val_rmse_stderror: 1.69
# Still best_val_rmse: 0.848 (from epoch 2)
#
# 64 steps took 0.344 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 1.134 train_rmse_stderror: 0.07678 train_kl_div: 2.07
# val_rmse_target: 0.8858 val_rmse_stderror: 1.693
# Still best_val_rmse: 0.848 (from epoch 2)
#
# 64 steps took 0.454 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.811 train_rmse_stderror: 0.04046 train_kl_div: 1.104
# val_rmse_target: 0.8569 val_rmse_stderror: 1.703
# Still best_val_rmse: 0.848 (from epoch 2)
#
# 64 steps took 0.341 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 1.047 train_rmse_stderror: 0.04575 train_kl_div: 2.09
# val_rmse_target: 0.8713 val_rmse_stderror: 1.687
# Still best_val_rmse: 0.848 (from epoch 2)
#
# 64 steps took 0.327 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.8065 train_rmse_stderror: 0.03706 train_kl_div: 1.263
# val_rmse_target: 0.8485 val_rmse_stderror: 1.702
# Still best_val_rmse: 0.848 (from epoch 2)
#
# 64 steps took 0.443 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.7984 train_rmse_stderror: 0.03493 train_kl_div: 1.201
# val_rmse_target: 0.8465 val_rmse_stderror: 1.699
# New best_val_rmse: 0.8465
#
# 64 steps took 0.357 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 1.043 train_rmse_stderror: 0.02223 train_kl_div: 2.168
# val_rmse_target: 0.8482 val_rmse_stderror: 1.704
# Still best_val_rmse: 0.8465 (from epoch 4)
#
# 64 steps took 0.34 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.9881 train_rmse_stderror: 0.05027 train_kl_div: 1.827
# val_rmse_target: 0.8514 val_rmse_stderror: 1.699
# Still best_val_rmse: 0.8465 (from epoch 4)
#
# Performance estimates:
# [0.8465396504896017]
# Mean: 0.8465396504896017
# {'total_MiB': 16280, 'used_MiB': 947}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 947}
#
# 64 steps took 0.425 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6447 train_rmse_stderror: 0.4472 train_kl_div: 1.841
# val_rmse_target: 0.9983 val_rmse_stderror: 1.673
# New best_val_rmse: 0.9983
#
# 64 steps took 0.352 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8384 train_rmse_stderror: 0.4696 train_kl_div: 2.366
# val_rmse_target: 1.418 val_rmse_stderror: 1.808
# Still best_val_rmse: 0.9983 (from epoch 0)
#
# 64 steps took 0.439 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 1.046 train_rmse_stderror: 1.02 train_kl_div: 4.979
# val_rmse_target: 0.9272 val_rmse_stderror: 1.639
# New best_val_rmse: 0.9272
#
# 64 steps took 0.355 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.9728 train_rmse_stderror: 1.064 train_kl_div: 5.086
# val_rmse_target: 0.9309 val_rmse_stderror: 1.232
# Still best_val_rmse: 0.9272 (from epoch 1)
#
# 64 steps took 0.337 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.7963 train_rmse_stderror: 1.61 train_kl_div: 8.068
# val_rmse_target: 0.9476 val_rmse_stderror: 3.276
# Still best_val_rmse: 0.9272 (from epoch 1)
#
# 64 steps took 0.45 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.7708 train_rmse_stderror: 0.2603 train_kl_div: 1.596
# val_rmse_target: 0.9917 val_rmse_stderror: 1.616
# Still best_val_rmse: 0.9272 (from epoch 1)
#
# 64 steps took 0.344 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 1.168 train_rmse_stderror: 0.3086 train_kl_div: 2.815
# val_rmse_target: 1.007 val_rmse_stderror: 1.233
# Still best_val_rmse: 0.9272 (from epoch 1)
#
# 64 steps took 0.347 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 1.123 train_rmse_stderror: 0.4291 train_kl_div: 3.328
# val_rmse_target: 0.9152 val_rmse_stderror: 1.702
# New best_val_rmse: 0.9152
#
# 64 steps took 0.448 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.7837 train_rmse_stderror: 1.155 train_kl_div: 5.115
# val_rmse_target: 0.9469 val_rmse_stderror: 2.421
# Still best_val_rmse: 0.9152 (from epoch 2)
#
# 64 steps took 0.339 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 1.097 train_rmse_stderror: 0.1614 train_kl_div: 2.687
# val_rmse_target: 1.022 val_rmse_stderror: 1.22
# Still best_val_rmse: 0.9152 (from epoch 2)
#
# 64 steps took 0.34 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 1.022 train_rmse_stderror: 0.0795 train_kl_div: 1.877
# val_rmse_target: 0.8864 val_rmse_stderror: 1.203
# New best_val_rmse: 0.8864
#
# 64 steps took 0.452 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.6668 train_rmse_stderror: 0.05593 train_kl_div: 0.8847
# val_rmse_target: 0.8892 val_rmse_stderror: 1.185
# Still best_val_rmse: 0.8864 (from epoch 3)
#
# 64 steps took 0.357 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.6853 train_rmse_stderror: 0.06248 train_kl_div: 1.089
# val_rmse_target: 0.8812 val_rmse_stderror: 1.184
# New best_val_rmse: 0.8812
#
# 64 steps took 0.344 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.7511 train_rmse_stderror: 0.06079 train_kl_div: 1.152
# val_rmse_target: 0.8821 val_rmse_stderror: 1.18
# Still best_val_rmse: 0.8812 (from epoch 4)
#
# Performance estimates:
# [0.8465396504896017, 0.8812090526941311]
# Mean: 0.8638743515918663
# {'total_MiB': 16280, 'used_MiB': 947}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 947}
#
# 64 steps took 0.427 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.098 train_rmse_stderror: 0.4776 train_kl_div: 3.01
# val_rmse_target: 1.116 val_rmse_stderror: 1.169
# New best_val_rmse: 1.116
#
# 64 steps took 0.343 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.109 train_rmse_stderror: 0.08804 train_kl_div: 2.258
# val_rmse_target: 1.163 val_rmse_stderror: 1.072
# Still best_val_rmse: 1.116 (from epoch 0)
#
# 64 steps took 0.45 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.8443 train_rmse_stderror: 0.04283 train_kl_div: 1.356
# val_rmse_target: 0.9031 val_rmse_stderror: 1.11
# New best_val_rmse: 0.9031
#
# 64 steps took 0.333 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.9467 train_rmse_stderror: 0.08668 train_kl_div: 1.584
# val_rmse_target: 0.8988 val_rmse_stderror: 1.08
# New best_val_rmse: 0.8988
#
# 64 steps took 0.342 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.6471 train_rmse_stderror: 0.05738 train_kl_div: 0.8244
# val_rmse_target: 0.9188 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.8988 (from epoch 1)
#
# 64 steps took 0.433 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.8852 train_rmse_stderror: 0.06945 train_kl_div: 1.546
# val_rmse_target: 0.9308 val_rmse_stderror: 1.095
# Still best_val_rmse: 0.8988 (from epoch 1)
#
# 64 steps took 0.334 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.9065 train_rmse_stderror: 0.02341 train_kl_div: 1.843
# val_rmse_target: 0.8956 val_rmse_stderror: 1.11
# New best_val_rmse: 0.8956
#
# 64 steps took 0.357 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.8325 train_rmse_stderror: 0.1469 train_kl_div: 1.598
# val_rmse_target: 0.919 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.8956 (from epoch 2)
#
# 64 steps took 0.463 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.8135 train_rmse_stderror: 0.03195 train_kl_div: 1.329
# val_rmse_target: 0.9133 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.8956 (from epoch 2)
#
# 64 steps took 0.327 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.6676 train_rmse_stderror: 0.02772 train_kl_div: 0.9161
# val_rmse_target: 0.919 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.8956 (from epoch 2)
#
# 64 steps took 0.331 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.7763 train_rmse_stderror: 0.04233 train_kl_div: 1.202
# val_rmse_target: 0.9069 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.8956 (from epoch 2)
#
# 64 steps took 0.414 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 1.09 train_rmse_stderror: 0.0433 train_kl_div: 2.136
# val_rmse_target: 0.894 val_rmse_stderror: 1.092
# New best_val_rmse: 0.894
#
# 64 steps took 0.312 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.8132 train_rmse_stderror: 0.03521 train_kl_div: 1.329
# val_rmse_target: 0.8914 val_rmse_stderror: 1.102
# New best_val_rmse: 0.8914
#
# 64 steps took 0.318 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.5432 train_rmse_stderror: 0.03975 train_kl_div: 0.5288
# val_rmse_target: 0.8915 val_rmse_stderror: 1.094
# Still best_val_rmse: 0.8914 (from epoch 4)
#
# Performance estimates:
# [0.8465396504896017, 0.8812090526941311, 0.891424810656021]
# Mean: 0.8730578379465846
# {'total_MiB': 16280, 'used_MiB': 947}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 947}
#
# 64 steps took 0.438 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.7908 train_rmse_stderror: 0.4162 train_kl_div: 2.176
# val_rmse_target: 1.366 val_rmse_stderror: 1.396
# New best_val_rmse: 1.366
#
# 64 steps took 0.342 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8802 train_rmse_stderror: 1.55 train_kl_div: 8.168
# val_rmse_target: 0.9448 val_rmse_stderror: 1.823
# New best_val_rmse: 0.9448
#
# 64 steps took 0.402 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 1.336 train_rmse_stderror: 0.299 train_kl_div: 3.73
# val_rmse_target: 1.001 val_rmse_stderror: 1.235
# Still best_val_rmse: 0.9448 (from epoch 0)
#
# 64 steps took 0.318 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.7903 train_rmse_stderror: 0.9606 train_kl_div: 4.413
# val_rmse_target: 1.011 val_rmse_stderror: 1.633
# Still best_val_rmse: 0.9448 (from epoch 0)
#
# 64 steps took 0.32 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.8304 train_rmse_stderror: 0.275 train_kl_div: 1.948
# val_rmse_target: 1.035 val_rmse_stderror: 1.387
# Still best_val_rmse: 0.9448 (from epoch 0)
#
# 64 steps took 0.427 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.6469 train_rmse_stderror: 0.3947 train_kl_div: 1.421
# val_rmse_target: 1.02 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.9448 (from epoch 0)
#
# 64 steps took 0.325 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.9551 train_rmse_stderror: 0.6927 train_kl_div: 3.454
# val_rmse_target: 0.9921 val_rmse_stderror: 1.416
# Still best_val_rmse: 0.9448 (from epoch 0)
#
# 64 steps took 0.309 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 1.013 train_rmse_stderror: 0.06531 train_kl_div: 1.929
# val_rmse_target: 0.9437 val_rmse_stderror: 1.161
# New best_val_rmse: 0.9437
#
# 64 steps took 0.427 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.8167 train_rmse_stderror: 0.02781 train_kl_div: 1.476
# val_rmse_target: 0.9391 val_rmse_stderror: 1.152
# New best_val_rmse: 0.9391
#
# 64 steps took 0.33 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.927 train_rmse_stderror: 0.053 train_kl_div: 1.432
# val_rmse_target: 0.9343 val_rmse_stderror: 1.154
# New best_val_rmse: 0.9343
#
# 64 steps took 0.329 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.6806 train_rmse_stderror: 0.04751 train_kl_div: 0.9509
# val_rmse_target: 0.9275 val_rmse_stderror: 1.149
# New best_val_rmse: 0.9275
#
# 64 steps took 0.434 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.8986 train_rmse_stderror: 0.02903 train_kl_div: 1.691
# val_rmse_target: 0.9318 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.9275 (from epoch 3)
#
# 64 steps took 0.321 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 1.248 train_rmse_stderror: 0.03411 train_kl_div: 2.981
# val_rmse_target: 0.9259 val_rmse_stderror: 1.153
# New best_val_rmse: 0.9259
#
# 64 steps took 0.316 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.9291 train_rmse_stderror: 0.02224 train_kl_div: 1.687
# val_rmse_target: 0.9263 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.9259 (from epoch 4)
#
# Performance estimates:
# [0.8465396504896017, 0.8812090526941311, 0.891424810656021, 0.9258919872732149]
# Mean: 0.8862663752782421
# {'total_MiB': 16280, 'used_MiB': 947}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 947}
#
# 64 steps took 0.399 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.49 train_rmse_stderror: 0.2869 train_kl_div: 4.585
# val_rmse_target: 1.192 val_rmse_stderror: 3.274
# New best_val_rmse: 1.192
#
# 64 steps took 0.316 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8546 train_rmse_stderror: 0.5015 train_kl_div: 2.528
# val_rmse_target: 1.038 val_rmse_stderror: 1.352
# New best_val_rmse: 1.038
#
# 64 steps took 0.421 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 1.0 train_rmse_stderror: 0.06239 train_kl_div: 1.877
# val_rmse_target: 0.9296 val_rmse_stderror: 1.196
# New best_val_rmse: 0.9296
#
# 64 steps took 0.326 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5668 train_rmse_stderror: 0.08177 train_kl_div: 0.675
# val_rmse_target: 1.053 val_rmse_stderror: 1.219
# Still best_val_rmse: 0.9296 (from epoch 1)
#
# 64 steps took 0.323 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.9464 train_rmse_stderror: 0.04674 train_kl_div: 1.701
# val_rmse_target: 0.9138 val_rmse_stderror: 1.176
# New best_val_rmse: 0.9138
#
# 64 steps took 0.42 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.9641 train_rmse_stderror: 0.06428 train_kl_div: 1.688
# val_rmse_target: 0.8929 val_rmse_stderror: 1.155
# New best_val_rmse: 0.8929
#
# 64 steps took 0.305 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.5947 train_rmse_stderror: 0.06176 train_kl_div: 0.6953
# val_rmse_target: 0.9796 val_rmse_stderror: 1.215
# Still best_val_rmse: 0.8929 (from epoch 2)
#
# 64 steps took 0.306 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.6815 train_rmse_stderror: 0.05577 train_kl_div: 1.0
# val_rmse_target: 0.8968 val_rmse_stderror: 1.192
# Still best_val_rmse: 0.8929 (from epoch 2)
#
# 64 steps took 0.441 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.8141 train_rmse_stderror: 0.03194 train_kl_div: 1.267
# val_rmse_target: 0.915 val_rmse_stderror: 1.189
# Still best_val_rmse: 0.8929 (from epoch 2)
#
# 64 steps took 0.315 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 1.124 train_rmse_stderror: 0.0283 train_kl_div: 2.502
# val_rmse_target: 0.898 val_rmse_stderror: 1.177
# Still best_val_rmse: 0.8929 (from epoch 2)
#
# 64 steps took 0.33 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.854 train_rmse_stderror: 0.0297 train_kl_div: 1.423
# val_rmse_target: 0.8915 val_rmse_stderror: 1.189
# New best_val_rmse: 0.8915
#
# 64 steps took 0.417 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.7441 train_rmse_stderror: 0.03058 train_kl_div: 1.194
# val_rmse_target: 0.9031 val_rmse_stderror: 1.179
# Still best_val_rmse: 0.8915 (from epoch 3)
#
# 64 steps took 0.321 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.8251 train_rmse_stderror: 0.02738 train_kl_div: 1.368
# val_rmse_target: 0.8988 val_rmse_stderror: 1.182
# Still best_val_rmse: 0.8915 (from epoch 3)
#
# 64 steps took 0.321 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 1.027 train_rmse_stderror: 0.0405 train_kl_div: 1.919
# val_rmse_target: 0.8944 val_rmse_stderror: 1.182
# Still best_val_rmse: 0.8915 (from epoch 3)
#
# Performance estimates:
# [0.8465396504896017, 0.8812090526941311, 0.891424810656021, 0.9258919872732149, 0.8914800198940015]
# Mean: 0.887309104201394
# {'total_MiB': 16280, 'used_MiB': 947}

# %%
print(list_val_rmse)
# Out:
# [0.48686168177282346, 0.49318919309887377, 0.4632869161410703, 0.48028027209396107, 0.47730628278272486]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [01:28<00:00, 16.0MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [01:26<00:00, 16.4MB/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [01:25<00:00, 16.7MB/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [01:23<00:00, 17.0MB/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [01:24<00:00, 16.8MB/s]
# Upload successful: model_3.pth (1GB)
