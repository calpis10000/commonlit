# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5' '/content/clrp-roberta-large'
  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '049-train-01'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 10 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (0.50, 32), (0.49, 16), (-1., 16)] # val計算&モデル保存間隔
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            #standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る

            # by Yirun Zhang: https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            #p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            #q = torch.distributions.Normal(target, standard_error)
            #kl_vector = torch.distributions.kl_divergence(p, q)
            #loss = kl_vector.mean()

            # by cccntu: https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            crit = torch.nn.GaussianNLLLoss()
            logits = output[:,0] # num_labels = 2
            standard_error = output[:,1]
            loss = crit(input=logits, target=target, var=standard_error ** 2) # var needs to be positive

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.05

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
# 検証用
SEED = 1000
st_kfold_bins_df = create_folds(train_df, num_splits=5, SEED=SEED, return_df=True)
st_kfold_bins_df['bins_tg'] = st_kfold_bins_df['bins_tg'].map(lambda x: float(x))
st_kfold_bins_df['bins_std'] = st_kfold_bins_df['bins_std'].map(lambda x: float(x))
st_kfold_bins_df.groupby('kfold').agg({'bins_tg': ['min', 'max', 'mean'],
                                    'bins_std': ['min', 'max', 'mean']})
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#       bins_tg                 bins_std
#           min   max      mean      min   max      mean
# kfold
# 0         0.0  11.0  5.571429      0.0  11.0  2.948854
# 1         0.0  11.0  5.532628      0.0  11.0  2.908289
# 2         0.0  11.0  5.537919      0.0  11.0  2.915344
# 3         0.0  11.0  5.558304      0.0  11.0  2.931095
# 4         0.0  11.0  5.549470      0.0  11.0  2.941696

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

#kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 48.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.003 train_rmse_stderror: 0.0 train_kl_div: 0.5925
# val_rmse_target: 1.093 val_rmse_stderror: 2.559
# New best_val_rmse: 1.093
#
# 64 steps took 49.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5882 train_rmse_stderror: 0.0 train_kl_div: 0.04343
# val_rmse_target: 0.6492 val_rmse_stderror: 2.092
# New best_val_rmse: 0.6492
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.6657 train_rmse_stderror: 0.0 train_kl_div: 0.1265
# val_rmse_target: 0.5738 val_rmse_stderror: 2.111
# New best_val_rmse: 0.5738
#
# 64 steps took 48.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4275 train_rmse_stderror: 0.0 train_kl_div: -0.1797
# val_rmse_target: 0.5475 val_rmse_stderror: 1.966
# New best_val_rmse: 0.5475
#
# 32 steps took 24.3 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.562 train_rmse_stderror: 0.0 train_kl_div: 0.01306
# val_rmse_target: 0.5893 val_rmse_stderror: 2.035
# Still best_val_rmse: 0.5475 (from epoch 1)
#
# 64 steps took 48.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5718 train_rmse_stderror: 0.0 train_kl_div: 0.0578
# val_rmse_target: 0.7082 val_rmse_stderror: 2.092
# Still best_val_rmse: 0.5475 (from epoch 1)
#
# 64 steps took 48.9 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.466 train_rmse_stderror: 0.0 train_kl_div: -0.2514
# val_rmse_target: 0.5302 val_rmse_stderror: 1.807
# New best_val_rmse: 0.5302
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.523 train_rmse_stderror: 0.0 train_kl_div: -0.1749
# val_rmse_target: 0.4988 val_rmse_stderror: 1.808
# New best_val_rmse: 0.4988
#
# 16 steps took 12.1 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.5613 train_rmse_stderror: 0.0 train_kl_div: 0.0275
# val_rmse_target: 0.5006 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4988 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.4222 train_rmse_stderror: 0.0 train_kl_div: -0.3052
# val_rmse_target: 0.6595 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4988 (from epoch 2)
#
# 64 steps took 48.8 seconds
# Epoch: 2 batch_num: 184
# train_rmse_target: 0.2968 train_rmse_stderror: 0.0 train_kl_div: -0.5865
# val_rmse_target: 0.504 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4988 (from epoch 2)
#
# 32 steps took 24.6 seconds
# Epoch: 3 batch_num: 28
# train_rmse_target: 0.4184 train_rmse_stderror: 0.0 train_kl_div: -0.4535
# val_rmse_target: 0.4945 val_rmse_stderror: 1.795
# New best_val_rmse: 0.4945
#
# 16 steps took 12.1 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2652 train_rmse_stderror: 0.0 train_kl_div: -0.7791
# val_rmse_target: 0.6625 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4945 (from epoch 3)
#
# 64 steps took 48.8 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.3919 train_rmse_stderror: 0.0 train_kl_div: -0.4458
# val_rmse_target: 0.5011 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4945 (from epoch 3)
#
# 32 steps took 24.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.2931 train_rmse_stderror: 0.0 train_kl_div: -0.4372
# val_rmse_target: 0.5329 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.4945 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.3563 train_rmse_stderror: 0.0 train_kl_div: -0.5188
# val_rmse_target: 0.4916 val_rmse_stderror: 1.708
# New best_val_rmse: 0.4916
#
# 16 steps took 12.3 seconds
# Epoch: 4 batch_num: 0
# train_rmse_target: 0.396 train_rmse_stderror: 0.0 train_kl_div: -0.4043
# val_rmse_target: 0.5107 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4916 (from epoch 3)
#
# 32 steps took 24.3 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.4568 train_rmse_stderror: 0.0 train_kl_div: 0.08496
# val_rmse_target: 0.5111 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4916 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.2781 train_rmse_stderror: 0.0 train_kl_div: -0.7505
# val_rmse_target: 0.4897 val_rmse_stderror: 1.693
# New best_val_rmse: 0.4897
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.2709 train_rmse_stderror: 0.0 train_kl_div: -0.8352
# val_rmse_target: 0.5252 val_rmse_stderror: 1.601
# Still best_val_rmse: 0.4897 (from epoch 4)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.2486 train_rmse_stderror: 0.0 train_kl_div: -0.7416
# val_rmse_target: 0.5121 val_rmse_stderror: 1.721
# Still best_val_rmse: 0.4897 (from epoch 4)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.3853 train_rmse_stderror: 0.0 train_kl_div: -0.3071
# val_rmse_target: 0.52 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4897 (from epoch 4)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.3798 train_rmse_stderror: 0.0 train_kl_div: -0.373
# val_rmse_target: 0.5687 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4897 (from epoch 4)
#
# 64 steps took 49.0 seconds
# Epoch: 5 batch_num: 52
# train_rmse_target: 0.2825 train_rmse_stderror: 0.0 train_kl_div: -0.845
# val_rmse_target: 0.5417 val_rmse_stderror: 1.616
# Still best_val_rmse: 0.4897 (from epoch 4)
#
# 32 steps took 24.5 seconds
# Epoch: 5 batch_num: 84
# train_rmse_target: 0.2854 train_rmse_stderror: 0.0 train_kl_div: -0.8104
# val_rmse_target: 0.4756 val_rmse_stderror: 1.565
# New best_val_rmse: 0.4756
#
# 16 steps took 12.1 seconds
# Epoch: 5 batch_num: 100
# train_rmse_target: 0.2945 train_rmse_stderror: 0.0 train_kl_div: -0.7423
# val_rmse_target: 0.4866 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 16 steps took 12.2 seconds
# Epoch: 5 batch_num: 116
# train_rmse_target: 0.2748 train_rmse_stderror: 0.0 train_kl_div: -0.7781
# val_rmse_target: 0.6382 val_rmse_stderror: 1.607
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 64 steps took 48.8 seconds
# Epoch: 5 batch_num: 180
# train_rmse_target: 0.275 train_rmse_stderror: 0.0 train_kl_div: -0.6753
# val_rmse_target: 0.5238 val_rmse_stderror: 1.599
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 32 steps took 24.6 seconds
# Epoch: 6 batch_num: 24
# train_rmse_target: 0.1796 train_rmse_stderror: 0.0 train_kl_div: -1.173
# val_rmse_target: 0.496 val_rmse_stderror: 1.544
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 16 steps took 12.2 seconds
# Epoch: 6 batch_num: 40
# train_rmse_target: 0.1624 train_rmse_stderror: 0.0 train_kl_div: -1.1
# val_rmse_target: 0.4869 val_rmse_stderror: 1.635
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 16 steps took 12.2 seconds
# Epoch: 6 batch_num: 56
# train_rmse_target: 0.2756 train_rmse_stderror: 0.0 train_kl_div: -0.5775
# val_rmse_target: 0.5157 val_rmse_stderror: 1.557
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 32 steps took 24.4 seconds
# Epoch: 6 batch_num: 88
# train_rmse_target: 0.243 train_rmse_stderror: 0.0 train_kl_div: -0.8696
# val_rmse_target: 0.4843 val_rmse_stderror: 1.577
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 16 steps took 12.2 seconds
# Epoch: 6 batch_num: 104
# train_rmse_target: 0.1749 train_rmse_stderror: 0.0 train_kl_div: -1.26
# val_rmse_target: 0.4842 val_rmse_stderror: 1.557
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 16 steps took 12.2 seconds
# Epoch: 6 batch_num: 120
# train_rmse_target: 0.3225 train_rmse_stderror: 0.0 train_kl_div: -0.6068
# val_rmse_target: 0.5107 val_rmse_stderror: 1.59
# Still best_val_rmse: 0.4756 (from epoch 5)
#
# 32 steps took 24.4 seconds
# Epoch: 6 batch_num: 152
# train_rmse_target: 0.1519 train_rmse_stderror: 0.0 train_kl_div: -1.34
# val_rmse_target: 0.4708 val_rmse_stderror: 1.588
# New best_val_rmse: 0.4708
#
# 16 steps took 12.2 seconds
# Epoch: 6 batch_num: 168
# train_rmse_target: 0.2299 train_rmse_stderror: 0.0 train_kl_div: -0.9714
# val_rmse_target: 0.5242 val_rmse_stderror: 1.6
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 32 steps took 24.6 seconds
# Epoch: 7 batch_num: 12
# train_rmse_target: 0.1999 train_rmse_stderror: 0.0 train_kl_div: -1.046
# val_rmse_target: 0.4946 val_rmse_stderror: 1.533
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 28
# train_rmse_target: 0.1664 train_rmse_stderror: 0.0 train_kl_div: -1.463
# val_rmse_target: 0.4777 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 44
# train_rmse_target: 0.185 train_rmse_stderror: 0.0 train_kl_div: -1.027
# val_rmse_target: 0.4801 val_rmse_stderror: 1.535
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 60
# train_rmse_target: 0.1945 train_rmse_stderror: 0.0 train_kl_div: -1.168
# val_rmse_target: 0.4773 val_rmse_stderror: 1.528
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 76
# train_rmse_target: 0.142 train_rmse_stderror: 0.0 train_kl_div: -1.433
# val_rmse_target: 0.4943 val_rmse_stderror: 1.532
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 92
# train_rmse_target: 0.2459 train_rmse_stderror: 0.0 train_kl_div: -0.4978
# val_rmse_target: 0.4845 val_rmse_stderror: 1.531
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 108
# train_rmse_target: 0.1471 train_rmse_stderror: 0.0 train_kl_div: -1.386
# val_rmse_target: 0.4835 val_rmse_stderror: 1.554
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.3 seconds
# Epoch: 7 batch_num: 124
# train_rmse_target: 0.224 train_rmse_stderror: 0.0 train_kl_div: -1.111
# val_rmse_target: 0.4748 val_rmse_stderror: 1.518
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 140
# train_rmse_target: 0.1087 train_rmse_stderror: 0.0 train_kl_div: -1.535
# val_rmse_target: 0.4941 val_rmse_stderror: 1.552
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 7 batch_num: 156
# train_rmse_target: 0.08719 train_rmse_stderror: 0.0 train_kl_div: -1.805
# val_rmse_target: 0.4723 val_rmse_stderror: 1.507
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.3 seconds
# Epoch: 7 batch_num: 172
# train_rmse_target: 0.1349 train_rmse_stderror: 0.0 train_kl_div: -1.391
# val_rmse_target: 0.4759 val_rmse_stderror: 1.557
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.4 seconds
# Epoch: 8 batch_num: 0
# train_rmse_target: 0.1258 train_rmse_stderror: 0.0 train_kl_div: -1.679
# val_rmse_target: 0.4733 val_rmse_stderror: 1.544
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 16
# train_rmse_target: 0.1703 train_rmse_stderror: 0.0 train_kl_div: -0.9818
# val_rmse_target: 0.4971 val_rmse_stderror: 1.503
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 32
# train_rmse_target: 0.09983 train_rmse_stderror: 0.0 train_kl_div: -1.706
# val_rmse_target: 0.4736 val_rmse_stderror: 1.515
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 48
# train_rmse_target: 0.07583 train_rmse_stderror: 0.0 train_kl_div: -1.805
# val_rmse_target: 0.4948 val_rmse_stderror: 1.528
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 64
# train_rmse_target: 0.1575 train_rmse_stderror: 0.0 train_kl_div: -1.237
# val_rmse_target: 0.481 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 80
# train_rmse_target: 0.08937 train_rmse_stderror: 0.0 train_kl_div: -1.782
# val_rmse_target: 0.4723 val_rmse_stderror: 1.502
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 96
# train_rmse_target: 0.1243 train_rmse_stderror: 0.0 train_kl_div: -1.48
# val_rmse_target: 0.4739 val_rmse_stderror: 1.545
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 112
# train_rmse_target: 0.09989 train_rmse_stderror: 0.0 train_kl_div: -1.773
# val_rmse_target: 0.4781 val_rmse_stderror: 1.505
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 128
# train_rmse_target: 0.09889 train_rmse_stderror: 0.0 train_kl_div: -1.849
# val_rmse_target: 0.4732 val_rmse_stderror: 1.487
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 144
# train_rmse_target: 0.1014 train_rmse_stderror: 0.0 train_kl_div: -1.793
# val_rmse_target: 0.4779 val_rmse_stderror: 1.495
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 160
# train_rmse_target: 0.0918 train_rmse_stderror: 0.0 train_kl_div: -1.869
# val_rmse_target: 0.4713 val_rmse_stderror: 1.496
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 8 batch_num: 176
# train_rmse_target: 0.1555 train_rmse_stderror: 0.0 train_kl_div: -1.293
# val_rmse_target: 0.4761 val_rmse_stderror: 1.494
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.4 seconds
# Epoch: 9 batch_num: 4
# train_rmse_target: 0.06467 train_rmse_stderror: 0.0 train_kl_div: -2.159
# val_rmse_target: 0.482 val_rmse_stderror: 1.496
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 20
# train_rmse_target: 0.07859 train_rmse_stderror: 0.0 train_kl_div: -1.887
# val_rmse_target: 0.483 val_rmse_stderror: 1.471
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 36
# train_rmse_target: 0.0769 train_rmse_stderror: 0.0 train_kl_div: -2.038
# val_rmse_target: 0.4781 val_rmse_stderror: 1.479
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 52
# train_rmse_target: 0.04741 train_rmse_stderror: 0.0 train_kl_div: -2.285
# val_rmse_target: 0.478 val_rmse_stderror: 1.478
# Still best_val_rmse: 0.4708 (from epoch 6)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 68
# train_rmse_target: 0.09148 train_rmse_stderror: 0.0 train_kl_div: -1.87
# val_rmse_target: 0.4705 val_rmse_stderror: 1.47
# New best_val_rmse: 0.4705
#
# 16 steps took 12.1 seconds
# Epoch: 9 batch_num: 84
# train_rmse_target: 0.07769 train_rmse_stderror: 0.0 train_kl_div: -2.158
# val_rmse_target: 0.4721 val_rmse_stderror: 1.464
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 100
# train_rmse_target: 0.05417 train_rmse_stderror: 0.0 train_kl_div: -2.374
# val_rmse_target: 0.4737 val_rmse_stderror: 1.467
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 116
# train_rmse_target: 0.06073 train_rmse_stderror: 0.0 train_kl_div: -2.275
# val_rmse_target: 0.4727 val_rmse_stderror: 1.468
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 132
# train_rmse_target: 0.06399 train_rmse_stderror: 0.0 train_kl_div: -2.13
# val_rmse_target: 0.4731 val_rmse_stderror: 1.467
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 148
# train_rmse_target: 0.0378 train_rmse_stderror: 0.0 train_kl_div: -2.465
# val_rmse_target: 0.473 val_rmse_stderror: 1.468
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.1 seconds
# Epoch: 9 batch_num: 164
# train_rmse_target: 0.07588 train_rmse_stderror: 0.0 train_kl_div: -2.006
# val_rmse_target: 0.4733 val_rmse_stderror: 1.469
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# 16 steps took 12.2 seconds
# Epoch: 9 batch_num: 180
# train_rmse_target: 0.05466 train_rmse_stderror: 0.0 train_kl_div: -2.404
# val_rmse_target: 0.4731 val_rmse_stderror: 1.469
# Still best_val_rmse: 0.4705 (from epoch 9)
#
# Performance estimates:
# [0.4705248779696915]
# Mean: 0.4705248779696915
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.2 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6957 train_rmse_stderror: 1.591 train_kl_div: 0.1908
# val_rmse_target: 0.8453 val_rmse_stderror: 0.8234
# New best_val_rmse: 0.8453
#
# 64 steps took 48.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.9185 train_rmse_stderror: 2.045 train_kl_div: 0.4257
# val_rmse_target: 1.033 val_rmse_stderror: 1.016
# Still best_val_rmse: 0.8453 (from epoch 0)
#
# 64 steps took 49.8 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 1.116 train_rmse_stderror: 2.263 train_kl_div: 0.6099
# val_rmse_target: 1.066 val_rmse_stderror: 1.027
# Still best_val_rmse: 0.8453 (from epoch 0)
#
# 64 steps took 48.8 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.9698 train_rmse_stderror: 2.137 train_kl_div: 0.4782
# val_rmse_target: 1.021 val_rmse_stderror: 1.021
# Still best_val_rmse: 0.8453 (from epoch 0)
#
# 64 steps took 48.8 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 1.217 train_rmse_stderror: 1.995 train_kl_div: 0.7421
# val_rmse_target: 1.019 val_rmse_stderror: 1.018
# Still best_val_rmse: 0.8453 (from epoch 0)
#
# 64 steps took 49.1 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.8457 train_rmse_stderror: 1.98 train_kl_div: 0.3548
# val_rmse_target: 1.019 val_rmse_stderror: 1.016
# Still best_val_rmse: 0.8453 (from epoch 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-bf8661c26b41> in <module>()
#      11     model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
#      12     set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
# ---> 13     list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))
#      14
#      15     print("\nPerformance estimates:")
#
# <ipython-input-22-0ab8e515d049> in train_and_save_model(train_indices, val_indices, model_path)
#      14         num_training_steps=NUM_EPOCHS * len(train_loader),
#      15         num_warmup_steps=50)
# ---> 16     rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)
#      17
#      18     del train_dataset
#
# <ipython-input-18-7bf003f6a879> in train(model, model_path, train_loader, val_loader, optimizer, scheduler, num_epochs)
#      43             loss = crit(input=logits, target=target, var=standard_error ** 2) # var needs to be positive
#      44
# ---> 45             loss.backward() # 誤差逆伝播法により勾配を得る
#      46             optimizer.step() # 重みを更新する
#      47
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     150
#     151
#
# KeyboardInterrupt:

# %%
print(list_val_rmse)

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
