# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_roberta_large_300/clrp_roberta_large_300/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' 
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' 
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '053-train-02'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 300 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df_src = pd.read_csv(DATA_DIR/"train.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
print(train_df_src.shape)
train_df_src.head()
# Out:
# (2834, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # word_length_mlm
        mlm_layers = self.mlm_layers(input_len)


        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_layers], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_parameters = list(model.mlm_layers.named_parameters())
    mlm_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.599 train_rmse_stderror: 0.1093 train_kl_div: 0.7832
# val_rmse_target: 0.7343 val_rmse_stderror: 1.203
# New best_val_rmse: 0.7343
#
# 64 steps took 71.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7077 train_rmse_stderror: 0.07 train_kl_div: 1.2
# val_rmse_target: 0.7337 val_rmse_stderror: 1.188
# New best_val_rmse: 0.7337
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 1.149 train_rmse_stderror: 0.06579 train_kl_div: 2.627
# val_rmse_target: 0.651 val_rmse_stderror: 1.227
# New best_val_rmse: 0.651
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6475 train_rmse_stderror: 0.06768 train_kl_div: 0.8192
# val_rmse_target: 0.5709 val_rmse_stderror: 1.214
# New best_val_rmse: 0.5709
#
# 64 steps took 72.0 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3652 train_rmse_stderror: 0.1262 train_kl_div: 0.2829
# val_rmse_target: 0.5542 val_rmse_stderror: 1.218
# New best_val_rmse: 0.5542
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.3734 train_rmse_stderror: 0.05351 train_kl_div: 0.3095
# val_rmse_target: 0.5827 val_rmse_stderror: 1.179
# Still best_val_rmse: 0.5542 (from epoch 1)
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5106 train_rmse_stderror: 0.09142 train_kl_div: 0.517
# val_rmse_target: 0.5179 val_rmse_stderror: 1.203
# New best_val_rmse: 0.5179
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.2807 train_rmse_stderror: 0.06625 train_kl_div: 0.1916
# val_rmse_target: 0.525 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.5179 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4351 train_rmse_stderror: 0.06482 train_kl_div: 0.3774
# val_rmse_target: 0.5043 val_rmse_stderror: 1.205
# New best_val_rmse: 0.5043
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.7031 train_rmse_stderror: 0.06935 train_kl_div: 1.053
# val_rmse_target: 0.5224 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.5043 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1746 train_rmse_stderror: 0.06588 train_kl_div: 0.08818
# val_rmse_target: 0.5113 val_rmse_stderror: 1.19
# Still best_val_rmse: 0.5043 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.1903 train_rmse_stderror: 0.03732 train_kl_div: 0.0859
# val_rmse_target: 0.5114 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.5043 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1828 train_rmse_stderror: 0.05708 train_kl_div: 0.07448
# val_rmse_target: 0.4882 val_rmse_stderror: 1.186
# New best_val_rmse: 0.4882
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1806 train_rmse_stderror: 0.04159 train_kl_div: 0.08011
# val_rmse_target: 0.4973 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1711 train_rmse_stderror: 0.08184 train_kl_div: 0.09186
# val_rmse_target: 0.5063 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3215 train_rmse_stderror: 0.05874 train_kl_div: 0.2449
# val_rmse_target: 0.4983 val_rmse_stderror: 1.188
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.253 train_rmse_stderror: 0.09981 train_kl_div: 0.1841
# val_rmse_target: 0.4938 val_rmse_stderror: 1.182
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.3104 train_rmse_stderror: 0.06185 train_kl_div: 0.1854
# val_rmse_target: 0.4909 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2168 train_rmse_stderror: 0.0483 train_kl_div: 0.1077
# val_rmse_target: 0.5228 val_rmse_stderror: 1.214
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.09553 train_rmse_stderror: 0.06603 train_kl_div: 0.03744
# val_rmse_target: 0.5207 val_rmse_stderror: 1.208
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1387 train_rmse_stderror: 0.03565 train_kl_div: 0.04707
# val_rmse_target: 0.4982 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1425 train_rmse_stderror: 0.03986 train_kl_div: 0.04661
# val_rmse_target: 0.4894 val_rmse_stderror: 1.189
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1884 train_rmse_stderror: 0.0557 train_kl_div: 0.09316
# val_rmse_target: 0.4921 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1507 train_rmse_stderror: 0.05709 train_kl_div: 0.06707
# val_rmse_target: 0.4987 val_rmse_stderror: 1.204
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1356 train_rmse_stderror: 0.04075 train_kl_div: 0.0453
# val_rmse_target: 0.5095 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1325 train_rmse_stderror: 0.05138 train_kl_div: 0.04702
# val_rmse_target: 0.495 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1248 train_rmse_stderror: 0.04941 train_kl_div: 0.04106
# val_rmse_target: 0.4989 val_rmse_stderror: 1.204
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1826 train_rmse_stderror: 0.04574 train_kl_div: 0.07885
# val_rmse_target: 0.4967 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1285 train_rmse_stderror: 0.03903 train_kl_div: 0.04195
# val_rmse_target: 0.493 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.05649 train_rmse_stderror: 0.0618 train_kl_div: 0.02229
# val_rmse_target: 0.4962 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06932 train_rmse_stderror: 0.05491 train_kl_div: 0.02406
# val_rmse_target: 0.4955 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1254 train_rmse_stderror: 0.06412 train_kl_div: 0.04974
# val_rmse_target: 0.4969 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.08938 train_rmse_stderror: 0.04722 train_kl_div: 0.02507
# val_rmse_target: 0.4965 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.08511 train_rmse_stderror: 0.05008 train_kl_div: 0.02427
# val_rmse_target: 0.498 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.07544 train_rmse_stderror: 0.04807 train_kl_div: 0.02035
# val_rmse_target: 0.4968 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1115 train_rmse_stderror: 0.05107 train_kl_div: 0.03967
# val_rmse_target: 0.4959 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08031 train_rmse_stderror: 0.05038 train_kl_div: 0.02603
# val_rmse_target: 0.4959 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4882 (from epoch 2)
#
# Performance estimates:
# [0.4882065680441906]
# Mean: 0.4882065680441906
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.9074 train_rmse_stderror: 0.155 train_kl_div: 1.863
# val_rmse_target: 0.6394 val_rmse_stderror: 1.76
# New best_val_rmse: 0.6394
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4389 train_rmse_stderror: 0.1007 train_kl_div: 0.4556
# val_rmse_target: 0.5688 val_rmse_stderror: 1.8
# New best_val_rmse: 0.5688
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5573 train_rmse_stderror: 0.06577 train_kl_div: 0.6994
# val_rmse_target: 0.7149 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.5688 (from epoch 0)
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.8707 train_rmse_stderror: 0.05963 train_kl_div: 1.617
# val_rmse_target: 0.728 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.5688 (from epoch 0)
#
# 64 steps took 71.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.4461 train_rmse_stderror: 0.06779 train_kl_div: 0.4188
# val_rmse_target: 0.5743 val_rmse_stderror: 1.716
# Still best_val_rmse: 0.5688 (from epoch 0)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4516 train_rmse_stderror: 0.1315 train_kl_div: 0.4601
# val_rmse_target: 0.5504 val_rmse_stderror: 1.72
# New best_val_rmse: 0.5504
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4455 train_rmse_stderror: 0.09079 train_kl_div: 0.3951
# val_rmse_target: 0.554 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.5504 (from epoch 1)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.5515 train_rmse_stderror: 0.07482 train_kl_div: 0.5951
# val_rmse_target: 0.5204 val_rmse_stderror: 1.739
# New best_val_rmse: 0.5204
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.6295 train_rmse_stderror: 0.03882 train_kl_div: 0.8746
# val_rmse_target: 0.5226 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.5204 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2827 train_rmse_stderror: 0.04072 train_kl_div: 0.1849
# val_rmse_target: 0.5477 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.5204 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2726 train_rmse_stderror: 0.06453 train_kl_div: 0.1616
# val_rmse_target: 0.5288 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5204 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3881 train_rmse_stderror: 0.08469 train_kl_div: 0.3322
# val_rmse_target: 0.5081 val_rmse_stderror: 1.78
# New best_val_rmse: 0.5081
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3013 train_rmse_stderror: 0.05263 train_kl_div: 0.1857
# val_rmse_target: 0.5056 val_rmse_stderror: 1.782
# New best_val_rmse: 0.5056
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2011 train_rmse_stderror: 0.06315 train_kl_div: 0.1095
# val_rmse_target: 0.5043 val_rmse_stderror: 1.759
# New best_val_rmse: 0.5043
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2977 train_rmse_stderror: 0.04346 train_kl_div: 0.1567
# val_rmse_target: 0.5011 val_rmse_stderror: 1.733
# New best_val_rmse: 0.5011
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2674 train_rmse_stderror: 0.06093 train_kl_div: 0.1852
# val_rmse_target: 0.5033 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.5011 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.5511 train_rmse_stderror: 0.09693 train_kl_div: 0.5848
# val_rmse_target: 0.5063 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.5011 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2296 train_rmse_stderror: 0.03991 train_kl_div: 0.114
# val_rmse_target: 0.5044 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.5011 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.0919 train_rmse_stderror: 0.04473 train_kl_div: 0.02756
# val_rmse_target: 0.5013 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.5011 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1511 train_rmse_stderror: 0.04013 train_kl_div: 0.05134
# val_rmse_target: 0.5095 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.5011 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1188 train_rmse_stderror: 0.05945 train_kl_div: 0.04319
# val_rmse_target: 0.4984 val_rmse_stderror: 1.733
# New best_val_rmse: 0.4984
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1404 train_rmse_stderror: 0.06074 train_kl_div: 0.05265
# val_rmse_target: 0.4998 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4984 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.06663 train_rmse_stderror: 0.05324 train_kl_div: 0.02145
# val_rmse_target: 0.4985 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4984 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1206 train_rmse_stderror: 0.05289 train_kl_div: 0.04307
# val_rmse_target: 0.4982 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4982
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1392 train_rmse_stderror: 0.07218 train_kl_div: 0.04514
# val_rmse_target: 0.5001 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4982 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1629 train_rmse_stderror: 0.03808 train_kl_div: 0.0683
# val_rmse_target: 0.4983 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4982 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.162 train_rmse_stderror: 0.03188 train_kl_div: 0.0563
# val_rmse_target: 0.4973 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4973
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.05641 train_rmse_stderror: 0.03742 train_kl_div: 0.01276
# val_rmse_target: 0.4978 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.07444 train_rmse_stderror: 0.03526 train_kl_div: 0.01711
# val_rmse_target: 0.4996 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.08209 train_rmse_stderror: 0.03597 train_kl_div: 0.01912
# val_rmse_target: 0.501 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1005 train_rmse_stderror: 0.05355 train_kl_div: 0.03252
# val_rmse_target: 0.5002 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1208 train_rmse_stderror: 0.03314 train_kl_div: 0.03311
# val_rmse_target: 0.5004 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.0816 train_rmse_stderror: 0.05584 train_kl_div: 0.02554
# val_rmse_target: 0.4995 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09599 train_rmse_stderror: 0.04914 train_kl_div: 0.02801
# val_rmse_target: 0.4994 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1642 train_rmse_stderror: 0.03308 train_kl_div: 0.05475
# val_rmse_target: 0.499 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1428 train_rmse_stderror: 0.05063 train_kl_div: 0.05783
# val_rmse_target: 0.4991 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4973 (from epoch 3)
#
# Performance estimates:
# [0.4882065680441906, 0.4973048110982398]
# Mean: 0.4927556895712152
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6643 train_rmse_stderror: 0.08753 train_kl_div: 0.961
# val_rmse_target: 0.9376 val_rmse_stderror: 1.088
# New best_val_rmse: 0.9376
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7206 train_rmse_stderror: 0.05021 train_kl_div: 1.2
# val_rmse_target: 0.6454 val_rmse_stderror: 1.081
# New best_val_rmse: 0.6454
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.6586 train_rmse_stderror: 0.09745 train_kl_div: 0.8645
# val_rmse_target: 0.5773 val_rmse_stderror: 1.094
# New best_val_rmse: 0.5773
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.3999 train_rmse_stderror: 0.05507 train_kl_div: 0.3447
# val_rmse_target: 0.6566 val_rmse_stderror: 1.075
# Still best_val_rmse: 0.5773 (from epoch 0)
#
# 64 steps took 71.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5002 train_rmse_stderror: 0.05294 train_kl_div: 0.5504
# val_rmse_target: 0.6887 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.5773 (from epoch 0)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.7274 train_rmse_stderror: 0.1502 train_kl_div: 1.307
# val_rmse_target: 0.5709 val_rmse_stderror: 1.087
# New best_val_rmse: 0.5709
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5978 train_rmse_stderror: 0.0434 train_kl_div: 0.6301
# val_rmse_target: 0.5182 val_rmse_stderror: 1.095
# New best_val_rmse: 0.5182
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.1893 train_rmse_stderror: 0.05882 train_kl_div: 0.08936
# val_rmse_target: 0.5102 val_rmse_stderror: 1.12
# New best_val_rmse: 0.5102
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.5163 train_rmse_stderror: 0.04827 train_kl_div: 0.622
# val_rmse_target: 0.5203 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.5102 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4575 train_rmse_stderror: 0.08882 train_kl_div: 0.4289
# val_rmse_target: 0.5303 val_rmse_stderror: 1.09
# Still best_val_rmse: 0.5102 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1952 train_rmse_stderror: 0.05153 train_kl_div: 0.09173
# val_rmse_target: 0.5052 val_rmse_stderror: 1.098
# New best_val_rmse: 0.5052
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2007 train_rmse_stderror: 0.0665 train_kl_div: 0.09505
# val_rmse_target: 0.5063 val_rmse_stderror: 1.095
# Still best_val_rmse: 0.5052 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2361 train_rmse_stderror: 0.05158 train_kl_div: 0.1142
# val_rmse_target: 0.5162 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.5052 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2963 train_rmse_stderror: 0.01909 train_kl_div: 0.1949
# val_rmse_target: 0.5023 val_rmse_stderror: 1.098
# New best_val_rmse: 0.5023
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.207 train_rmse_stderror: 0.05717 train_kl_div: 0.09852
# val_rmse_target: 0.52 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.5023 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2418 train_rmse_stderror: 0.03006 train_kl_div: 0.1154
# val_rmse_target: 0.5036 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.5023 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2947 train_rmse_stderror: 0.03714 train_kl_div: 0.1822
# val_rmse_target: 0.5116 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5023 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2935 train_rmse_stderror: 0.0637 train_kl_div: 0.1666
# val_rmse_target: 0.4982 val_rmse_stderror: 1.103
# New best_val_rmse: 0.4982
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1831 train_rmse_stderror: 0.02205 train_kl_div: 0.07365
# val_rmse_target: 0.4995 val_rmse_stderror: 1.095
# Still best_val_rmse: 0.4982 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1772 train_rmse_stderror: 0.04064 train_kl_div: 0.07248
# val_rmse_target: 0.4983 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4982 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2995 train_rmse_stderror: 0.01778 train_kl_div: 0.1448
# val_rmse_target: 0.4915 val_rmse_stderror: 1.099
# New best_val_rmse: 0.4915
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1691 train_rmse_stderror: 0.03675 train_kl_div: 0.06921
# val_rmse_target: 0.5008 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.4915 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1573 train_rmse_stderror: 0.02562 train_kl_div: 0.05077
# val_rmse_target: 0.4889 val_rmse_stderror: 1.11
# New best_val_rmse: 0.4889
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.175 train_rmse_stderror: 0.02888 train_kl_div: 0.05868
# val_rmse_target: 0.4899 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1268 train_rmse_stderror: 0.03538 train_kl_div: 0.03738
# val_rmse_target: 0.4917 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1967 train_rmse_stderror: 0.02799 train_kl_div: 0.08067
# val_rmse_target: 0.4895 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.2087 train_rmse_stderror: 0.03554 train_kl_div: 0.09518
# val_rmse_target: 0.4916 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1387 train_rmse_stderror: 0.04323 train_kl_div: 0.04345
# val_rmse_target: 0.4937 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.07319 train_rmse_stderror: 0.04458 train_kl_div: 0.01956
# val_rmse_target: 0.4941 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08894 train_rmse_stderror: 0.04118 train_kl_div: 0.02724
# val_rmse_target: 0.4907 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.063 train_rmse_stderror: 0.04577 train_kl_div: 0.017
# val_rmse_target: 0.491 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.07574 train_rmse_stderror: 0.04582 train_kl_div: 0.02077
# val_rmse_target: 0.4964 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.09917 train_rmse_stderror: 0.02409 train_kl_div: 0.02288
# val_rmse_target: 0.494 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1081 train_rmse_stderror: 0.02431 train_kl_div: 0.02603
# val_rmse_target: 0.4935 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05141 train_rmse_stderror: 0.05409 train_kl_div: 0.01856
# val_rmse_target: 0.4938 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.08193 train_rmse_stderror: 0.02357 train_kl_div: 0.01494
# val_rmse_target: 0.4943 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1665 train_rmse_stderror: 0.03633 train_kl_div: 0.05665
# val_rmse_target: 0.4942 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# Performance estimates:
# [0.4882065680441906, 0.4973048110982398, 0.4888965347783274]
# Mean: 0.49146930464025257
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8485 train_rmse_stderror: 0.1203 train_kl_div: 1.144
# val_rmse_target: 0.7101 val_rmse_stderror: 1.851
# New best_val_rmse: 0.7101
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6503 train_rmse_stderror: 0.05983 train_kl_div: 0.884
# val_rmse_target: 0.6302 val_rmse_stderror: 1.797
# New best_val_rmse: 0.6302
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5085 train_rmse_stderror: 0.04894 train_kl_div: 0.5047
# val_rmse_target: 0.5776 val_rmse_stderror: 1.803
# New best_val_rmse: 0.5776
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5193 train_rmse_stderror: 0.1026 train_kl_div: 0.5196
# val_rmse_target: 0.7211 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.5776 (from epoch 0)
#
# 64 steps took 71.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3061 train_rmse_stderror: 0.0661 train_kl_div: 0.2193
# val_rmse_target: 0.5291 val_rmse_stderror: 1.793
# New best_val_rmse: 0.5291
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.3086 train_rmse_stderror: 0.04313 train_kl_div: 0.2006
# val_rmse_target: 0.508 val_rmse_stderror: 1.769
# New best_val_rmse: 0.508
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2602 train_rmse_stderror: 0.03037 train_kl_div: 0.1404
# val_rmse_target: 0.5173 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.508 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.3252 train_rmse_stderror: 0.08266 train_kl_div: 0.233
# val_rmse_target: 0.5513 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.508 (from epoch 1)
#
# 64 steps took 71.6 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.3779 train_rmse_stderror: 0.08966 train_kl_div: 0.353
# val_rmse_target: 0.4858 val_rmse_stderror: 1.791
# New best_val_rmse: 0.4858
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.5432 train_rmse_stderror: 0.05639 train_kl_div: 0.6509
# val_rmse_target: 0.5299 val_rmse_stderror: 1.804
# Still best_val_rmse: 0.4858 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4646 train_rmse_stderror: 0.05133 train_kl_div: 0.4644
# val_rmse_target: 0.483 val_rmse_stderror: 1.796
# New best_val_rmse: 0.483
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1739 train_rmse_stderror: 0.05878 train_kl_div: 0.07269
# val_rmse_target: 0.5226 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.483 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3438 train_rmse_stderror: 0.05699 train_kl_div: 0.2692
# val_rmse_target: 0.4823 val_rmse_stderror: 1.789
# New best_val_rmse: 0.4823
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1694 train_rmse_stderror: 0.05011 train_kl_div: 0.07581
# val_rmse_target: 0.4993 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4823 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2691 train_rmse_stderror: 0.0469 train_kl_div: 0.1415
# val_rmse_target: 0.4711 val_rmse_stderror: 1.793
# New best_val_rmse: 0.4711
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1949 train_rmse_stderror: 0.0576 train_kl_div: 0.08753
# val_rmse_target: 0.4866 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.1804 train_rmse_stderror: 0.03193 train_kl_div: 0.0776
# val_rmse_target: 0.4807 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.275 train_rmse_stderror: 0.0468 train_kl_div: 0.1761
# val_rmse_target: 0.4772 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1776 train_rmse_stderror: 0.05445 train_kl_div: 0.07754
# val_rmse_target: 0.4766 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.3119 train_rmse_stderror: 0.04036 train_kl_div: 0.2218
# val_rmse_target: 0.4778 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4711 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1018 train_rmse_stderror: 0.04305 train_kl_div: 0.02692
# val_rmse_target: 0.4658 val_rmse_stderror: 1.787
# New best_val_rmse: 0.4658
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1276 train_rmse_stderror: 0.04246 train_kl_div: 0.04009
# val_rmse_target: 0.4748 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.2044 train_rmse_stderror: 0.03568 train_kl_div: 0.09322
# val_rmse_target: 0.4799 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.06057 train_rmse_stderror: 0.05157 train_kl_div: 0.01756
# val_rmse_target: 0.4656 val_rmse_stderror: 1.794
# New best_val_rmse: 0.4656
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1333 train_rmse_stderror: 0.04288 train_kl_div: 0.04738
# val_rmse_target: 0.4708 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4656 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.2144 train_rmse_stderror: 0.02967 train_kl_div: 0.07276
# val_rmse_target: 0.4763 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4656 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1318 train_rmse_stderror: 0.04044 train_kl_div: 0.04545
# val_rmse_target: 0.471 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4656 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1662 train_rmse_stderror: 0.04479 train_kl_div: 0.06434
# val_rmse_target: 0.4687 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4656 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1084 train_rmse_stderror: 0.04248 train_kl_div: 0.03252
# val_rmse_target: 0.4622 val_rmse_stderror: 1.79
# New best_val_rmse: 0.4622
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1096 train_rmse_stderror: 0.04337 train_kl_div: 0.03471
# val_rmse_target: 0.4648 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.06444 train_rmse_stderror: 0.03726 train_kl_div: 0.0153
# val_rmse_target: 0.4686 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1101 train_rmse_stderror: 0.02099 train_kl_div: 0.02784
# val_rmse_target: 0.4686 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.08379 train_rmse_stderror: 0.03644 train_kl_div: 0.02112
# val_rmse_target: 0.4682 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1016 train_rmse_stderror: 0.01196 train_kl_div: 0.02322
# val_rmse_target: 0.4679 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.108 train_rmse_stderror: 0.0387 train_kl_div: 0.0254
# val_rmse_target: 0.4699 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09541 train_rmse_stderror: 0.04815 train_kl_div: 0.02977
# val_rmse_target: 0.4684 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1481 train_rmse_stderror: 0.04454 train_kl_div: 0.05182
# val_rmse_target: 0.4677 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1516 train_rmse_stderror: 0.02671 train_kl_div: 0.05497
# val_rmse_target: 0.4676 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4622 (from epoch 3)
#
# Performance estimates:
# [0.4882065680441906, 0.4973048110982398, 0.4888965347783274, 0.4622114912424326]
# Mean: 0.4841548512907976
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4108 train_rmse_stderror: 0.1915 train_kl_div: 0.4798
# val_rmse_target: 0.6418 val_rmse_stderror: 1.007
# New best_val_rmse: 0.6418
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6849 train_rmse_stderror: 0.08631 train_kl_div: 0.9571
# val_rmse_target: 0.5668 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5668
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4152 train_rmse_stderror: 0.07474 train_kl_div: 0.385
# val_rmse_target: 0.5571 val_rmse_stderror: 1.11
# New best_val_rmse: 0.5571
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6105 train_rmse_stderror: 0.06814 train_kl_div: 0.7343
# val_rmse_target: 0.5264 val_rmse_stderror: 1.135
# New best_val_rmse: 0.5264
#
# 32 steps took 36.0 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.5765 train_rmse_stderror: 0.04296 train_kl_div: 0.6913
# val_rmse_target: 0.5393 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.5264 (from epoch 0)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3605 train_rmse_stderror: 0.0703 train_kl_div: 0.271
# val_rmse_target: 0.5596 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.5264 (from epoch 0)
#
# 64 steps took 71.5 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4255 train_rmse_stderror: 0.1013 train_kl_div: 0.4348
# val_rmse_target: 0.5163 val_rmse_stderror: 1.101
# New best_val_rmse: 0.5163
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.381 train_rmse_stderror: 0.1217 train_kl_div: 0.2952
# val_rmse_target: 0.5324 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.5163 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3454 train_rmse_stderror: 0.06891 train_kl_div: 0.2515
# val_rmse_target: 0.5119 val_rmse_stderror: 1.076
# New best_val_rmse: 0.5119
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.4625 train_rmse_stderror: 0.07578 train_kl_div: 0.425
# val_rmse_target: 0.5288 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.5119 (from epoch 1)
#
# 32 steps took 35.7 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3803 train_rmse_stderror: 0.05327 train_kl_div: 0.3326
# val_rmse_target: 0.5629 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5119 (from epoch 1)
#
# 64 steps took 71.7 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2572 train_rmse_stderror: 0.06696 train_kl_div: 0.1544
# val_rmse_target: 0.5425 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5119 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3286 train_rmse_stderror: 0.05762 train_kl_div: 0.2134
# val_rmse_target: 0.4998 val_rmse_stderror: 1.118
# New best_val_rmse: 0.4998
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1962 train_rmse_stderror: 0.05607 train_kl_div: 0.09793
# val_rmse_target: 0.5156 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4998 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2149 train_rmse_stderror: 0.03772 train_kl_div: 0.09117
# val_rmse_target: 0.508 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.4998 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2737 train_rmse_stderror: 0.07153 train_kl_div: 0.1693
# val_rmse_target: 0.501 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.4998 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.4412 train_rmse_stderror: 0.05066 train_kl_div: 0.3896
# val_rmse_target: 0.4942 val_rmse_stderror: 1.105
# New best_val_rmse: 0.4942
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1636 train_rmse_stderror: 0.04208 train_kl_div: 0.05522
# val_rmse_target: 0.4996 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4942 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1385 train_rmse_stderror: 0.06553 train_kl_div: 0.05661
# val_rmse_target: 0.4971 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4942 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1808 train_rmse_stderror: 0.05599 train_kl_div: 0.07134
# val_rmse_target: 0.4928 val_rmse_stderror: 1.116
# New best_val_rmse: 0.4928
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1264 train_rmse_stderror: 0.06151 train_kl_div: 0.04954
# val_rmse_target: 0.4889 val_rmse_stderror: 1.101
# New best_val_rmse: 0.4889
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1322 train_rmse_stderror: 0.07947 train_kl_div: 0.06452
# val_rmse_target: 0.4936 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.2275 train_rmse_stderror: 0.05027 train_kl_div: 0.1028
# val_rmse_target: 0.5071 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1181 train_rmse_stderror: 0.03938 train_kl_div: 0.03348
# val_rmse_target: 0.4937 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1244 train_rmse_stderror: 0.0502 train_kl_div: 0.04222
# val_rmse_target: 0.4945 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1297 train_rmse_stderror: 0.07182 train_kl_div: 0.05254
# val_rmse_target: 0.4904 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4889 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1458 train_rmse_stderror: 0.05056 train_kl_div: 0.04827
# val_rmse_target: 0.4885 val_rmse_stderror: 1.113
# New best_val_rmse: 0.4885
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1658 train_rmse_stderror: 0.03597 train_kl_div: 0.06592
# val_rmse_target: 0.4901 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.09194 train_rmse_stderror: 0.05105 train_kl_div: 0.02978
# val_rmse_target: 0.4902 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1404 train_rmse_stderror: 0.03391 train_kl_div: 0.0384
# val_rmse_target: 0.4933 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1225 train_rmse_stderror: 0.0538 train_kl_div: 0.03992
# val_rmse_target: 0.4923 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.139 train_rmse_stderror: 0.05657 train_kl_div: 0.04222
# val_rmse_target: 0.4917 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.08685 train_rmse_stderror: 0.05227 train_kl_div: 0.02457
# val_rmse_target: 0.4924 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07553 train_rmse_stderror: 0.03332 train_kl_div: 0.017
# val_rmse_target: 0.4908 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.06488 train_rmse_stderror: 0.03581 train_kl_div: 0.01489
# val_rmse_target: 0.4922 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.0491 train_rmse_stderror: 0.03334 train_kl_div: 0.01045
# val_rmse_target: 0.4906 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1109 train_rmse_stderror: 0.02403 train_kl_div: 0.02796
# val_rmse_target: 0.4909 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08071 train_rmse_stderror: 0.04395 train_kl_div: 0.0234
# val_rmse_target: 0.491 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4885 (from epoch 3)
#
# Performance estimates:
# [0.4882065680441906, 0.4973048110982398, 0.4888965347783274, 0.4622114912424326, 0.48849860065593015]
# Mean: 0.48502360116382415
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.4882065680441906, 0.4973048110982398, 0.4888965347783274, 0.4622114912424326, 0.48849860065593015]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [01:20<00:00, 17.6MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [01:22<00:00, 17.2MB/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [01:21<00:00, 17.5MB/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [01:24<00:00, 16.8MB/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [01:29<00:00, 16.0MB/s]
# Upload successful: model_5.pth (1GB)
