# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_03' '/content/clrp-roberta-large'
  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = 'roberta-large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-roberta-large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '046-train-03'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (0.50, 32), (0.49, 16), (0.48, 8), (0.47, 4), (0.46, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=482.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
# 検証用
SEED = 1000
st_kfold_bins_df = create_folds(train_df, num_splits=5, SEED=SEED, return_df=True)
st_kfold_bins_df['bins_tg'] = st_kfold_bins_df['bins_tg'].map(lambda x: float(x))
st_kfold_bins_df['bins_std'] = st_kfold_bins_df['bins_std'].map(lambda x: float(x))
st_kfold_bins_df.groupby('kfold').agg({'bins_tg': ['min', 'max', 'mean'],
                                    'bins_std': ['min', 'max', 'mean']})
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#       bins_tg                 bins_std
#           min   max      mean      min   max      mean
# kfold
# 0         0.0  11.0  5.514991      0.0  11.0  2.910053
# 1         0.0  11.0  5.553792      0.0  11.0  2.878307
# 2         0.0  11.0  5.589065      0.0  11.0  2.936508
# 3         0.0  11.0  5.553004      0.0  11.0  2.966431
# 4         0.0  11.0  5.538869      0.0  11.0  2.954064

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

#kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.0 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.7355 train_rmse_stderror: 0.04194 train_kl_div: 1.052
# val_rmse_target: 0.6939 val_rmse_stderror: 1.765
# New best_val_rmse: 0.6939
#
# 64 steps took 80.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6893 train_rmse_stderror: 0.04536 train_kl_div: 0.9577
# val_rmse_target: 0.5936 val_rmse_stderror: 1.748
# New best_val_rmse: 0.5936
#
# 64 steps took 80.8 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.6405 train_rmse_stderror: 0.04754 train_kl_div: 0.8583
# val_rmse_target: 0.5093 val_rmse_stderror: 1.775
# New best_val_rmse: 0.5093
#
# 32 steps took 40.3 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.1896 train_rmse_stderror: 0.04889 train_kl_div: 0.08468
# val_rmse_target: 0.5381 val_rmse_stderror: 1.798
# Still best_val_rmse: 0.5093 (from epoch 1)
#
# 32 steps took 40.3 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5568 train_rmse_stderror: 0.04235 train_kl_div: 0.5803
# val_rmse_target: 0.555 val_rmse_stderror: 1.82
# Still best_val_rmse: 0.5093 (from epoch 1)
#
# 64 steps took 80.6 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.3719 train_rmse_stderror: 0.03007 train_kl_div: 0.2553
# val_rmse_target: 0.5024 val_rmse_stderror: 1.794
# New best_val_rmse: 0.5024
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5463 train_rmse_stderror: 0.02979 train_kl_div: 0.6341
# val_rmse_target: 0.5307 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.5024 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.4551 train_rmse_stderror: 0.03656 train_kl_div: 0.3684
# val_rmse_target: 0.5336 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.5024 (from epoch 1)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.09026 train_rmse_stderror: 0.02608 train_kl_div: 0.01957
# val_rmse_target: 0.5171 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.5024 (from epoch 1)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3282 train_rmse_stderror: 0.03692 train_kl_div: 0.1756
# val_rmse_target: 0.4965 val_rmse_stderror: 1.786
# New best_val_rmse: 0.4965
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.2012 train_rmse_stderror: 0.02106 train_kl_div: 0.08916
# val_rmse_target: 0.5258 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4965 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.1756 train_rmse_stderror: 0.03925 train_kl_div: 0.07791
# val_rmse_target: 0.4906 val_rmse_stderror: 1.81
# New best_val_rmse: 0.4906
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2357 train_rmse_stderror: 0.02715 train_kl_div: 0.1082
# val_rmse_target: 0.5684 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 64 steps took 80.8 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1674 train_rmse_stderror: 0.02279 train_kl_div: 0.05248
# val_rmse_target: 0.5047 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.137 train_rmse_stderror: 0.0219 train_kl_div: 0.04329
# val_rmse_target: 0.5002 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1489 train_rmse_stderror: 0.02979 train_kl_div: 0.04953
# val_rmse_target: 0.5201 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1995 train_rmse_stderror: 0.02923 train_kl_div: 0.09181
# val_rmse_target: 0.5165 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1416 train_rmse_stderror: 0.03154 train_kl_div: 0.0463
# val_rmse_target: 0.4983 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 156
# train_rmse_target: 0.1465 train_rmse_stderror: 0.0244 train_kl_div: 0.04824
# val_rmse_target: 0.5015 val_rmse_stderror: 1.782
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 0
# train_rmse_target: 0.09717 train_rmse_stderror: 0.02248 train_kl_div: 0.02101
# val_rmse_target: 0.4977 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1154 train_rmse_stderror: 0.02845 train_kl_div: 0.02815
# val_rmse_target: 0.5033 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1574 train_rmse_stderror: 0.03943 train_kl_div: 0.05011
# val_rmse_target: 0.503 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.09433 train_rmse_stderror: 0.02494 train_kl_div: 0.01969
# val_rmse_target: 0.5035 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.06984 train_rmse_stderror: 0.02425 train_kl_div: 0.01364
# val_rmse_target: 0.5001 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.09592 train_rmse_stderror: 0.01476 train_kl_div: 0.01875
# val_rmse_target: 0.5025 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1034 train_rmse_stderror: 0.01583 train_kl_div: 0.02422
# val_rmse_target: 0.5017 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4906 (from epoch 2)
#
# Performance estimates:
# [0.49057017464743213]
# Mean: 0.49057017464743213
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4496 train_rmse_stderror: 0.1468 train_kl_div: 0.5215
# val_rmse_target: 0.612 val_rmse_stderror: 1.047
# New best_val_rmse: 0.612
#
# 64 steps took 80.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8196 train_rmse_stderror: 0.1139 train_kl_div: 1.389
# val_rmse_target: 0.5659 val_rmse_stderror: 1.044
# New best_val_rmse: 0.5659
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4777 train_rmse_stderror: 0.03474 train_kl_div: 0.3661
# val_rmse_target: 0.6069 val_rmse_stderror: 1.044
# Still best_val_rmse: 0.5659 (from epoch 0)
#
# 64 steps took 80.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.3423 train_rmse_stderror: 0.03937 train_kl_div: 0.2582
# val_rmse_target: 0.516 val_rmse_stderror: 1.067
# New best_val_rmse: 0.516
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4859 train_rmse_stderror: 0.02387 train_kl_div: 0.4481
# val_rmse_target: 0.5881 val_rmse_stderror: 1.076
# Still best_val_rmse: 0.516 (from epoch 1)
#
# 64 steps took 80.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4199 train_rmse_stderror: 0.04165 train_kl_div: 0.3634
# val_rmse_target: 0.556 val_rmse_stderror: 1.073
# Still best_val_rmse: 0.516 (from epoch 1)
#
# 64 steps took 80.8 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.1781 train_rmse_stderror: 0.02125 train_kl_div: 0.0674
# val_rmse_target: 0.4946 val_rmse_stderror: 1.072
# New best_val_rmse: 0.4946
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 56
# train_rmse_target: 0.2944 train_rmse_stderror: 0.02502 train_kl_div: 0.1785
# val_rmse_target: 0.4964 val_rmse_stderror: 1.067
# Still best_val_rmse: 0.4946 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3057 train_rmse_stderror: 0.02459 train_kl_div: 0.1739
# val_rmse_target: 0.4945 val_rmse_stderror: 1.068
# New best_val_rmse: 0.4945
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.3792 train_rmse_stderror: 0.04003 train_kl_div: 0.3161
# val_rmse_target: 0.4991 val_rmse_stderror: 1.074
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3089 train_rmse_stderror: 0.0327 train_kl_div: 0.1804
# val_rmse_target: 0.496 val_rmse_stderror: 1.067
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.3211 train_rmse_stderror: 0.02934 train_kl_div: 0.2178
# val_rmse_target: 0.5084 val_rmse_stderror: 1.075
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 152
# train_rmse_target: 0.2335 train_rmse_stderror: 0.0376 train_kl_div: 0.1125
# val_rmse_target: 0.5032 val_rmse_stderror: 1.063
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 184
# train_rmse_target: 0.1332 train_rmse_stderror: 0.02058 train_kl_div: 0.03876
# val_rmse_target: 0.5053 val_rmse_stderror: 1.073
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 28
# train_rmse_target: 0.09318 train_rmse_stderror: 0.01786 train_kl_div: 0.02018
# val_rmse_target: 0.4965 val_rmse_stderror: 1.068
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.122 train_rmse_stderror: 0.02421 train_kl_div: 0.03395
# val_rmse_target: 0.4975 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 60
# train_rmse_target: 0.1447 train_rmse_stderror: 0.02728 train_kl_div: 0.04939
# val_rmse_target: 0.4955 val_rmse_stderror: 1.067
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1895 train_rmse_stderror: 0.02388 train_kl_div: 0.07446
# val_rmse_target: 0.4954 val_rmse_stderror: 1.064
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 92
# train_rmse_target: 0.08485 train_rmse_stderror: 0.02931 train_kl_div: 0.01932
# val_rmse_target: 0.4947 val_rmse_stderror: 1.065
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1714 train_rmse_stderror: 0.01867 train_kl_div: 0.06712
# val_rmse_target: 0.4961 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 124
# train_rmse_target: 0.1534 train_rmse_stderror: 0.0257 train_kl_div: 0.04859
# val_rmse_target: 0.4971 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1028 train_rmse_stderror: 0.02218 train_kl_div: 0.02442
# val_rmse_target: 0.4949 val_rmse_stderror: 1.076
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 156
# train_rmse_target: 0.1378 train_rmse_stderror: 0.01883 train_kl_div: 0.03902
# val_rmse_target: 0.4969 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.1 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1146 train_rmse_stderror: 0.0191 train_kl_div: 0.02873
# val_rmse_target: 0.4968 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.3 seconds
# Epoch: 4 batch_num: 0
# train_rmse_target: 0.07409 train_rmse_stderror: 0.02897 train_kl_div: 0.01384
# val_rmse_target: 0.4958 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.1 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1042 train_rmse_stderror: 0.0229 train_kl_div: 0.02402
# val_rmse_target: 0.4966 val_rmse_stderror: 1.074
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.1297 train_rmse_stderror: 0.01682 train_kl_div: 0.037
# val_rmse_target: 0.4955 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.07811 train_rmse_stderror: 0.02043 train_kl_div: 0.01418
# val_rmse_target: 0.4977 val_rmse_stderror: 1.076
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.04442 train_rmse_stderror: 0.02887 train_kl_div: 0.007866
# val_rmse_target: 0.4957 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08072 train_rmse_stderror: 0.01861 train_kl_div: 0.01418
# val_rmse_target: 0.4961 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 96
# train_rmse_target: 0.05645 train_rmse_stderror: 0.02067 train_kl_div: 0.008474
# val_rmse_target: 0.4965 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1192 train_rmse_stderror: 0.02146 train_kl_div: 0.02516
# val_rmse_target: 0.4951 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 128
# train_rmse_target: 0.1048 train_rmse_stderror: 0.02281 train_kl_div: 0.02576
# val_rmse_target: 0.4947 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1022 train_rmse_stderror: 0.02352 train_kl_div: 0.0226
# val_rmse_target: 0.4948 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 160
# train_rmse_target: 0.05474 train_rmse_stderror: 0.02059 train_kl_div: 0.007933
# val_rmse_target: 0.4947 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1027 train_rmse_stderror: 0.02936 train_kl_div: 0.02073
# val_rmse_target: 0.4948 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4945 (from epoch 2)
#
# Performance estimates:
# [0.49057017464743213, 0.4944596251774411]
# Mean: 0.4925148999124366
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8965 train_rmse_stderror: 0.04586 train_kl_div: 1.35
# val_rmse_target: 0.6888 val_rmse_stderror: 1.863
# New best_val_rmse: 0.6888
#
# 64 steps took 80.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5153 train_rmse_stderror: 0.0447 train_kl_div: 0.5609
# val_rmse_target: 0.8802 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.6888 (from epoch 0)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.2775 train_rmse_stderror: 0.03293 train_kl_div: 0.1727
# val_rmse_target: 0.5579 val_rmse_stderror: 1.78
# New best_val_rmse: 0.5579
#
# 64 steps took 80.8 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4585 train_rmse_stderror: 0.04059 train_kl_div: 0.4591
# val_rmse_target: 0.6118 val_rmse_stderror: 1.829
# Still best_val_rmse: 0.5579 (from epoch 1)
#
# 64 steps took 80.7 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.3685 train_rmse_stderror: 0.02667 train_kl_div: 0.2724
# val_rmse_target: 0.5334 val_rmse_stderror: 1.824
# New best_val_rmse: 0.5334
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5011 train_rmse_stderror: 0.03054 train_kl_div: 0.5222
# val_rmse_target: 0.5504 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.5334 (from epoch 1)
#
# 64 steps took 80.9 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3547 train_rmse_stderror: 0.04854 train_kl_div: 0.2893
# val_rmse_target: 0.5502 val_rmse_stderror: 1.833
# Still best_val_rmse: 0.5334 (from epoch 1)
#
# 64 steps took 80.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3651 train_rmse_stderror: 0.04627 train_kl_div: 0.2597
# val_rmse_target: 0.5137 val_rmse_stderror: 1.805
# New best_val_rmse: 0.5137
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.422 train_rmse_stderror: 0.0409 train_kl_div: 0.3933
# val_rmse_target: 0.5226 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.5137 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2771 train_rmse_stderror: 0.03912 train_kl_div: 0.1615
# val_rmse_target: 0.5357 val_rmse_stderror: 1.818
# Still best_val_rmse: 0.5137 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.3788 train_rmse_stderror: 0.03578 train_kl_div: 0.2709
# val_rmse_target: 0.5179 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.5137 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.3397 train_rmse_stderror: 0.01979 train_kl_div: 0.2591
# val_rmse_target: 0.5125 val_rmse_stderror: 1.83
# New best_val_rmse: 0.5125
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1951 train_rmse_stderror: 0.02949 train_kl_div: 0.08249
# val_rmse_target: 0.5081 val_rmse_stderror: 1.822
# New best_val_rmse: 0.5081
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2831 train_rmse_stderror: 0.02402 train_kl_div: 0.1787
# val_rmse_target: 0.5115 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.5081 (from epoch 3)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.3232 train_rmse_stderror: 0.04229 train_kl_div: 0.1839
# val_rmse_target: 0.5168 val_rmse_stderror: 1.812
# Still best_val_rmse: 0.5081 (from epoch 3)
#
# 32 steps took 40.3 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2681 train_rmse_stderror: 0.02718 train_kl_div: 0.1352
# val_rmse_target: 0.52 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.5081 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1486 train_rmse_stderror: 0.0236 train_kl_div: 0.04518
# val_rmse_target: 0.5105 val_rmse_stderror: 1.824
# Still best_val_rmse: 0.5081 (from epoch 3)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.2696 train_rmse_stderror: 0.03403 train_kl_div: 0.1231
# val_rmse_target: 0.5075 val_rmse_stderror: 1.82
# New best_val_rmse: 0.5075
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.2174 train_rmse_stderror: 0.02149 train_kl_div: 0.09774
# val_rmse_target: 0.5041 val_rmse_stderror: 1.819
# New best_val_rmse: 0.5041
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1907 train_rmse_stderror: 0.0351 train_kl_div: 0.06287
# val_rmse_target: 0.5121 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.5041 (from epoch 4)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1665 train_rmse_stderror: 0.02604 train_kl_div: 0.06128
# val_rmse_target: 0.5121 val_rmse_stderror: 1.819
# Still best_val_rmse: 0.5041 (from epoch 4)
#
# 32 steps took 40.3 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.225 train_rmse_stderror: 0.03033 train_kl_div: 0.09172
# val_rmse_target: 0.5117 val_rmse_stderror: 1.819
# Still best_val_rmse: 0.5041 (from epoch 4)
#
# Performance estimates:
# [0.49057017464743213, 0.4944596251774411, 0.5041230975372093]
# Mean: 0.49638429912069415
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6058 train_rmse_stderror: 0.08209 train_kl_div: 0.75
# val_rmse_target: 0.5942 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5942
#
# 64 steps took 80.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4205 train_rmse_stderror: 0.04935 train_kl_div: 0.3992
# val_rmse_target: 0.5803 val_rmse_stderror: 1.747
# New best_val_rmse: 0.5803
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.6436 train_rmse_stderror: 0.03578 train_kl_div: 0.7647
# val_rmse_target: 0.5472 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5472
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.3638 train_rmse_stderror: 0.03097 train_kl_div: 0.2488
# val_rmse_target: 0.5801 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.5472 (from epoch 1)
#
# 64 steps took 80.7 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.2688 train_rmse_stderror: 0.03312 train_kl_div: 0.1666
# val_rmse_target: 0.5225 val_rmse_stderror: 1.736
# New best_val_rmse: 0.5225
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4995 train_rmse_stderror: 0.03712 train_kl_div: 0.5287
# val_rmse_target: 0.4884 val_rmse_stderror: 1.764
# New best_val_rmse: 0.4884
#
# 8 steps took 10.1 seconds
# Epoch: 1 batch_num: 140
# train_rmse_target: 0.4139 train_rmse_stderror: 0.03032 train_kl_div: 0.3346
# val_rmse_target: 0.4962 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4884 (from epoch 1)
#
# 16 steps took 20.2 seconds
# Epoch: 1 batch_num: 156
# train_rmse_target: 0.3157 train_rmse_stderror: 0.01507 train_kl_div: 0.2082
# val_rmse_target: 0.5045 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4884 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 0
# train_rmse_target: 0.35 train_rmse_stderror: 0.02823 train_kl_div: 0.2497
# val_rmse_target: 0.5281 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4884 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 32
# train_rmse_target: 0.2183 train_rmse_stderror: 0.02211 train_kl_div: 0.09307
# val_rmse_target: 0.4768 val_rmse_stderror: 1.765
# New best_val_rmse: 0.4768
#
# 4 steps took 5.05 seconds
# Epoch: 2 batch_num: 36
# train_rmse_target: 0.214 train_rmse_stderror: 0.02057 train_kl_div: 0.09702
# val_rmse_target: 0.476 val_rmse_stderror: 1.757
# New best_val_rmse: 0.476
#
# 4 steps took 5.04 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2649 train_rmse_stderror: 0.02497 train_kl_div: 0.1367
# val_rmse_target: 0.4677 val_rmse_stderror: 1.73
# New best_val_rmse: 0.4677
#
# 2 steps took 2.54 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2309 train_rmse_stderror: 0.02288 train_kl_div: 0.1151
# val_rmse_target: 0.4651 val_rmse_stderror: 1.741
# New best_val_rmse: 0.4651
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 44
# train_rmse_target: 0.2572 train_rmse_stderror: 0.02769 train_kl_div: 0.1243
# val_rmse_target: 0.4653 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 46
# train_rmse_target: 0.2429 train_rmse_stderror: 0.02808 train_kl_div: 0.1064
# val_rmse_target: 0.4699 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 2 steps took 2.52 seconds
# Epoch: 2 batch_num: 48
# train_rmse_target: 0.3159 train_rmse_stderror: 0.03639 train_kl_div: 0.2009
# val_rmse_target: 0.4797 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 52
# train_rmse_target: 0.1787 train_rmse_stderror: 0.02072 train_kl_div: 0.0641
# val_rmse_target: 0.4705 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 56
# train_rmse_target: 0.303 train_rmse_stderror: 0.02463 train_kl_div: 0.1869
# val_rmse_target: 0.4733 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 4 steps took 5.04 seconds
# Epoch: 2 batch_num: 60
# train_rmse_target: 0.3343 train_rmse_stderror: 0.02044 train_kl_div: 0.2667
# val_rmse_target: 0.5019 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 32 steps took 40.3 seconds
# Epoch: 2 batch_num: 92
# train_rmse_target: 0.3266 train_rmse_stderror: 0.02416 train_kl_div: 0.2333
# val_rmse_target: 0.4807 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4651 (from epoch 2)
#
# 8 steps took 10.1 seconds
# Epoch: 2 batch_num: 100
# train_rmse_target: 0.2799 train_rmse_stderror: 0.02672 train_kl_div: 0.1658
# val_rmse_target: 0.4644 val_rmse_stderror: 1.758
# New best_val_rmse: 0.4644
#
# 2 steps took 2.54 seconds
# Epoch: 2 batch_num: 102
# train_rmse_target: 0.2046 train_rmse_stderror: 0.02576 train_kl_div: 0.09257
# val_rmse_target: 0.4644 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4644 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2088 train_rmse_stderror: 0.02259 train_kl_div: 0.09601
# val_rmse_target: 0.4672 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4644 (from epoch 2)
#
# 2 steps took 2.52 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3072 train_rmse_stderror: 0.02658 train_kl_div: 0.1935
# val_rmse_target: 0.4639 val_rmse_stderror: 1.738
# New best_val_rmse: 0.4639
#
# 2 steps took 2.53 seconds
# Epoch: 2 batch_num: 108
# train_rmse_target: 0.24 train_rmse_stderror: 0.04205 train_kl_div: 0.1006
# val_rmse_target: 0.4721 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4639 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 112
# train_rmse_target: 0.2668 train_rmse_stderror: 0.03129 train_kl_div: 0.1317
# val_rmse_target: 0.4719 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4639 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 116
# train_rmse_target: 0.2443 train_rmse_stderror: 0.03513 train_kl_div: 0.1322
# val_rmse_target: 0.4635 val_rmse_stderror: 1.76
# New best_val_rmse: 0.4635
#
# 2 steps took 2.54 seconds
# Epoch: 2 batch_num: 118
# train_rmse_target: 0.2851 train_rmse_stderror: 0.0305 train_kl_div: 0.1682
# val_rmse_target: 0.4682 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.1976 train_rmse_stderror: 0.02998 train_kl_div: 0.0736
# val_rmse_target: 0.4761 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 124
# train_rmse_target: 0.3604 train_rmse_stderror: 0.03006 train_kl_div: 0.2796
# val_rmse_target: 0.4832 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 8 steps took 10.1 seconds
# Epoch: 2 batch_num: 132
# train_rmse_target: 0.2253 train_rmse_stderror: 0.0321 train_kl_div: 0.08751
# val_rmse_target: 0.4892 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 8 steps took 10.1 seconds
# Epoch: 2 batch_num: 140
# train_rmse_target: 0.255 train_rmse_stderror: 0.02363 train_kl_div: 0.1316
# val_rmse_target: 0.4818 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 8 steps took 10.1 seconds
# Epoch: 2 batch_num: 148
# train_rmse_target: 0.3074 train_rmse_stderror: 0.01937 train_kl_div: 0.2009
# val_rmse_target: 0.4725 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 4 steps took 5.04 seconds
# Epoch: 2 batch_num: 152
# train_rmse_target: 0.205 train_rmse_stderror: 0.03079 train_kl_div: 0.0973
# val_rmse_target: 0.4638 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 154
# train_rmse_target: 0.182 train_rmse_stderror: 0.02225 train_kl_div: 0.07178
# val_rmse_target: 0.4682 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 156
# train_rmse_target: 0.274 train_rmse_stderror: 0.01529 train_kl_div: 0.1657
# val_rmse_target: 0.4683 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 158
# train_rmse_target: 0.311 train_rmse_stderror: 0.02941 train_kl_div: 0.1901
# val_rmse_target: 0.4774 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 2 batch_num: 162
# train_rmse_target: 0.3438 train_rmse_stderror: 0.02003 train_kl_div: 0.2352
# val_rmse_target: 0.494 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4635 (from epoch 2)
#
# 16 steps took 20.2 seconds
# Epoch: 2 batch_num: 178
# train_rmse_target: 0.287 train_rmse_stderror: 0.02766 train_kl_div: 0.1651
# val_rmse_target: 0.4613 val_rmse_stderror: 1.759
# New best_val_rmse: 0.4613
#
# 2 steps took 2.54 seconds
# Epoch: 2 batch_num: 180
# train_rmse_target: 0.2089 train_rmse_stderror: 0.0268 train_kl_div: 0.0935
# val_rmse_target: 0.4654 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 182
# train_rmse_target: 0.2153 train_rmse_stderror: 0.02443 train_kl_div: 0.103
# val_rmse_target: 0.4678 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.52 seconds
# Epoch: 2 batch_num: 184
# train_rmse_target: 0.1627 train_rmse_stderror: 0.03 train_kl_div: 0.05904
# val_rmse_target: 0.4629 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 2 batch_num: 186
# train_rmse_target: 0.3333 train_rmse_stderror: 0.03007 train_kl_div: 0.2305
# val_rmse_target: 0.4622 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.68 seconds
# Epoch: 3 batch_num: 0
# train_rmse_target: 0.1721 train_rmse_stderror: 0.02269 train_kl_div: 0.06247
# val_rmse_target: 0.4631 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 2
# train_rmse_target: 0.1766 train_rmse_stderror: 0.03622 train_kl_div: 0.06126
# val_rmse_target: 0.4662 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 4
# train_rmse_target: 0.2159 train_rmse_stderror: 0.03326 train_kl_div: 0.1123
# val_rmse_target: 0.4753 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 8
# train_rmse_target: 0.1083 train_rmse_stderror: 0.0267 train_kl_div: 0.02795
# val_rmse_target: 0.4772 val_rmse_stderror: 1.728
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.104 train_rmse_stderror: 0.03178 train_kl_div: 0.02692
# val_rmse_target: 0.4632 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 14
# train_rmse_target: 0.235 train_rmse_stderror: 0.02799 train_kl_div: 0.1187
# val_rmse_target: 0.463 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4613 (from epoch 2)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 16
# train_rmse_target: 0.1754 train_rmse_stderror: 0.02035 train_kl_div: 0.05403
# val_rmse_target: 0.461 val_rmse_stderror: 1.755
# New best_val_rmse: 0.461
#
# 2 steps took 2.54 seconds
# Epoch: 3 batch_num: 18
# train_rmse_target: 0.13 train_rmse_stderror: 0.02021 train_kl_div: 0.03848
# val_rmse_target: 0.4661 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.461 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 20
# train_rmse_target: 0.2079 train_rmse_stderror: 0.0211 train_kl_div: 0.09442
# val_rmse_target: 0.4647 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.461 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 22
# train_rmse_target: 0.1312 train_rmse_stderror: 0.03228 train_kl_div: 0.03647
# val_rmse_target: 0.4602 val_rmse_stderror: 1.746
# New best_val_rmse: 0.4602
#
# 2 steps took 2.53 seconds
# Epoch: 3 batch_num: 24
# train_rmse_target: 0.1454 train_rmse_stderror: 0.0187 train_kl_div: 0.0452
# val_rmse_target: 0.4589 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4589
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 25
# train_rmse_target: 0.1794 train_rmse_stderror: 0.01925 train_kl_div: 0.07539
# val_rmse_target: 0.4589 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4589
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 26
# train_rmse_target: 0.1705 train_rmse_stderror: 0.0214 train_kl_div: 0.05967
# val_rmse_target: 0.459 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 27
# train_rmse_target: 0.1514 train_rmse_stderror: 0.02629 train_kl_div: 0.04463
# val_rmse_target: 0.459 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 28
# train_rmse_target: 0.2379 train_rmse_stderror: 0.02571 train_kl_div: 0.1021
# val_rmse_target: 0.4589 val_rmse_stderror: 1.751
# New best_val_rmse: 0.4589
#
# 1 steps took 1.27 seconds
# Epoch: 3 batch_num: 29
# train_rmse_target: 0.192 train_rmse_stderror: 0.01716 train_kl_div: 0.07548
# val_rmse_target: 0.4593 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 30
# train_rmse_target: 0.1596 train_rmse_stderror: 0.01953 train_kl_div: 0.05527
# val_rmse_target: 0.4605 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 32
# train_rmse_target: 0.07885 train_rmse_stderror: 0.01836 train_kl_div: 0.01436
# val_rmse_target: 0.4621 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 34
# train_rmse_target: 0.1004 train_rmse_stderror: 0.01896 train_kl_div: 0.02356
# val_rmse_target: 0.4622 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 36
# train_rmse_target: 0.1458 train_rmse_stderror: 0.01714 train_kl_div: 0.042
# val_rmse_target: 0.463 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 38
# train_rmse_target: 0.1427 train_rmse_stderror: 0.01631 train_kl_div: 0.03928
# val_rmse_target: 0.4601 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 40
# train_rmse_target: 0.1636 train_rmse_stderror: 0.01943 train_kl_div: 0.05877
# val_rmse_target: 0.46 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 42
# train_rmse_target: 0.1948 train_rmse_stderror: 0.01752 train_kl_div: 0.08122
# val_rmse_target: 0.4614 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.216 train_rmse_stderror: 0.03854 train_kl_div: 0.09241
# val_rmse_target: 0.4649 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 46
# train_rmse_target: 0.1626 train_rmse_stderror: 0.0249 train_kl_div: 0.06087
# val_rmse_target: 0.4648 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 48
# train_rmse_target: 0.133 train_rmse_stderror: 0.02459 train_kl_div: 0.03251
# val_rmse_target: 0.4629 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 50
# train_rmse_target: 0.1731 train_rmse_stderror: 0.01519 train_kl_div: 0.0596
# val_rmse_target: 0.4635 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 52
# train_rmse_target: 0.1656 train_rmse_stderror: 0.02028 train_kl_div: 0.05239
# val_rmse_target: 0.4621 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 54
# train_rmse_target: 0.2705 train_rmse_stderror: 0.03753 train_kl_div: 0.1076
# val_rmse_target: 0.4614 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 56
# train_rmse_target: 0.184 train_rmse_stderror: 0.0301 train_kl_div: 0.06908
# val_rmse_target: 0.4609 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 58
# train_rmse_target: 0.2042 train_rmse_stderror: 0.02091 train_kl_div: 0.08858
# val_rmse_target: 0.4599 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 59
# train_rmse_target: 0.119 train_rmse_stderror: 0.01575 train_kl_div: 0.03395
# val_rmse_target: 0.4602 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 61
# train_rmse_target: 0.1076 train_rmse_stderror: 0.02495 train_kl_div: 0.02588
# val_rmse_target: 0.4614 val_rmse_stderror: 1.732
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 63
# train_rmse_target: 0.1626 train_rmse_stderror: 0.03003 train_kl_div: 0.05456
# val_rmse_target: 0.4614 val_rmse_stderror: 1.733
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 65
# train_rmse_target: 0.1817 train_rmse_stderror: 0.03696 train_kl_div: 0.06272
# val_rmse_target: 0.4591 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4589 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 66
# train_rmse_target: 0.1254 train_rmse_stderror: 0.01493 train_kl_div: 0.0344
# val_rmse_target: 0.4588 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4588
#
# 1 steps took 1.27 seconds
# Epoch: 3 batch_num: 67
# train_rmse_target: 0.09627 train_rmse_stderror: 0.01482 train_kl_div: 0.02006
# val_rmse_target: 0.4587 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4587
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 68
# train_rmse_target: 0.1616 train_rmse_stderror: 0.02137 train_kl_div: 0.05411
# val_rmse_target: 0.4589 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 69
# train_rmse_target: 0.1327 train_rmse_stderror: 0.02243 train_kl_div: 0.03968
# val_rmse_target: 0.459 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 70
# train_rmse_target: 0.1939 train_rmse_stderror: 0.01926 train_kl_div: 0.07358
# val_rmse_target: 0.4592 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 71
# train_rmse_target: 0.1472 train_rmse_stderror: 0.02755 train_kl_div: 0.04784
# val_rmse_target: 0.4595 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 72
# train_rmse_target: 0.1427 train_rmse_stderror: 0.0185 train_kl_div: 0.04729
# val_rmse_target: 0.46 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 73
# train_rmse_target: 0.1456 train_rmse_stderror: 0.03365 train_kl_div: 0.04183
# val_rmse_target: 0.46 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 74
# train_rmse_target: 0.2078 train_rmse_stderror: 0.03149 train_kl_div: 0.07968
# val_rmse_target: 0.4598 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 75
# train_rmse_target: 0.2028 train_rmse_stderror: 0.0168 train_kl_div: 0.08617
# val_rmse_target: 0.4597 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1628 train_rmse_stderror: 0.02126 train_kl_div: 0.05472
# val_rmse_target: 0.4597 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 77
# train_rmse_target: 0.1304 train_rmse_stderror: 0.02487 train_kl_div: 0.04198
# val_rmse_target: 0.46 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1076 train_rmse_stderror: 0.02801 train_kl_div: 0.02674
# val_rmse_target: 0.4611 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 81
# train_rmse_target: 0.152 train_rmse_stderror: 0.02578 train_kl_div: 0.04659
# val_rmse_target: 0.4619 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 83
# train_rmse_target: 0.1401 train_rmse_stderror: 0.02313 train_kl_div: 0.03936
# val_rmse_target: 0.4614 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 85
# train_rmse_target: 0.1436 train_rmse_stderror: 0.02388 train_kl_div: 0.04559
# val_rmse_target: 0.4623 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 87
# train_rmse_target: 0.1373 train_rmse_stderror: 0.02296 train_kl_div: 0.04211
# val_rmse_target: 0.4659 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 89
# train_rmse_target: 0.1922 train_rmse_stderror: 0.02317 train_kl_div: 0.07327
# val_rmse_target: 0.4665 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 91
# train_rmse_target: 0.1822 train_rmse_stderror: 0.02935 train_kl_div: 0.05845
# val_rmse_target: 0.4674 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 93
# train_rmse_target: 0.1015 train_rmse_stderror: 0.02315 train_kl_div: 0.02435
# val_rmse_target: 0.4659 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 95
# train_rmse_target: 0.1311 train_rmse_stderror: 0.02833 train_kl_div: 0.04021
# val_rmse_target: 0.4653 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 97
# train_rmse_target: 0.07314 train_rmse_stderror: 0.01692 train_kl_div: 0.01253
# val_rmse_target: 0.4624 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 99
# train_rmse_target: 0.1776 train_rmse_stderror: 0.02442 train_kl_div: 0.06855
# val_rmse_target: 0.4608 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 101
# train_rmse_target: 0.1089 train_rmse_stderror: 0.02643 train_kl_div: 0.02549
# val_rmse_target: 0.4607 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 103
# train_rmse_target: 0.1358 train_rmse_stderror: 0.01536 train_kl_div: 0.04117
# val_rmse_target: 0.4606 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 105
# train_rmse_target: 0.1687 train_rmse_stderror: 0.03432 train_kl_div: 0.05783
# val_rmse_target: 0.4607 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 107
# train_rmse_target: 0.1872 train_rmse_stderror: 0.03143 train_kl_div: 0.07228
# val_rmse_target: 0.4605 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 109
# train_rmse_target: 0.1581 train_rmse_stderror: 0.02846 train_kl_div: 0.05423
# val_rmse_target: 0.4595 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 110
# train_rmse_target: 0.1271 train_rmse_stderror: 0.0133 train_kl_div: 0.03656
# val_rmse_target: 0.4594 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1093 train_rmse_stderror: 0.02561 train_kl_div: 0.02619
# val_rmse_target: 0.4598 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 112
# train_rmse_target: 0.1008 train_rmse_stderror: 0.01582 train_kl_div: 0.02319
# val_rmse_target: 0.4608 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 114
# train_rmse_target: 0.167 train_rmse_stderror: 0.01372 train_kl_div: 0.05504
# val_rmse_target: 0.4641 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.52 seconds
# Epoch: 3 batch_num: 116
# train_rmse_target: 0.1105 train_rmse_stderror: 0.02435 train_kl_div: 0.02951
# val_rmse_target: 0.466 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 118
# train_rmse_target: 0.151 train_rmse_stderror: 0.03871 train_kl_div: 0.04869
# val_rmse_target: 0.4639 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 120
# train_rmse_target: 0.1357 train_rmse_stderror: 0.02434 train_kl_div: 0.04286
# val_rmse_target: 0.4604 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 122
# train_rmse_target: 0.1023 train_rmse_stderror: 0.01595 train_kl_div: 0.0235
# val_rmse_target: 0.4599 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 1 steps took 1.25 seconds
# Epoch: 3 batch_num: 123
# train_rmse_target: 0.1006 train_rmse_stderror: 0.02107 train_kl_div: 0.02193
# val_rmse_target: 0.4601 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4587 (from epoch 3)
#
# 2 steps took 2.51 seconds
# Epoch: 3 batch_num: 125
# ...
# val_rmse_target: 0.515 val_rmse_stderror: 1.837
# Still best_val_rmse: 0.4838 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 4
# train_rmse_target: 0.1003 train_rmse_stderror: 0.01615 train_kl_div: 0.02413
# val_rmse_target: 0.4817 val_rmse_stderror: 1.837
# New best_val_rmse: 0.4817
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1892 train_rmse_stderror: 0.02196 train_kl_div: 0.0744
# val_rmse_target: 0.4767 val_rmse_stderror: 1.843
# New best_val_rmse: 0.4767
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 16
# train_rmse_target: 0.1461 train_rmse_stderror: 0.03751 train_kl_div: 0.04732
# val_rmse_target: 0.4768 val_rmse_stderror: 1.84
# Still best_val_rmse: 0.4767 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 20
# train_rmse_target: 0.1981 train_rmse_stderror: 0.01996 train_kl_div: 0.08016
# val_rmse_target: 0.4933 val_rmse_stderror: 1.84
# Still best_val_rmse: 0.4767 (from epoch 3)
#
# 16 steps took 20.2 seconds
# Epoch: 3 batch_num: 36
# train_rmse_target: 0.1246 train_rmse_stderror: 0.0175 train_kl_div: 0.03545
# val_rmse_target: 0.4785 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4767 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 40
# train_rmse_target: 0.143 train_rmse_stderror: 0.02899 train_kl_div: 0.04234
# val_rmse_target: 0.4816 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4767 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 48
# train_rmse_target: 0.1386 train_rmse_stderror: 0.01532 train_kl_div: 0.04419
# val_rmse_target: 0.4764 val_rmse_stderror: 1.834
# New best_val_rmse: 0.4764
#
# 4 steps took 5.05 seconds
# Epoch: 3 batch_num: 52
# train_rmse_target: 0.09917 train_rmse_stderror: 0.01455 train_kl_div: 0.02144
# val_rmse_target: 0.4765 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 56
# train_rmse_target: 0.08969 train_rmse_stderror: 0.02087 train_kl_div: 0.01805
# val_rmse_target: 0.4789 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 60
# train_rmse_target: 0.1035 train_rmse_stderror: 0.01585 train_kl_div: 0.02074
# val_rmse_target: 0.4831 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 68
# train_rmse_target: 0.1479 train_rmse_stderror: 0.02471 train_kl_div: 0.04469
# val_rmse_target: 0.4779 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 72
# train_rmse_target: 0.1139 train_rmse_stderror: 0.04048 train_kl_div: 0.03012
# val_rmse_target: 0.4779 val_rmse_stderror: 1.832
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.116 train_rmse_stderror: 0.02026 train_kl_div: 0.02753
# val_rmse_target: 0.4792 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4764 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 80
# train_rmse_target: 0.1395 train_rmse_stderror: 0.02823 train_kl_div: 0.0454
# val_rmse_target: 0.4753 val_rmse_stderror: 1.85
# New best_val_rmse: 0.4753
#
# 4 steps took 5.05 seconds
# Epoch: 3 batch_num: 84
# train_rmse_target: 0.1259 train_rmse_stderror: 0.01998 train_kl_div: 0.03483
# val_rmse_target: 0.4773 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4753 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 88
# train_rmse_target: 0.153 train_rmse_stderror: 0.0272 train_kl_div: 0.05523
# val_rmse_target: 0.4789 val_rmse_stderror: 1.833
# Still best_val_rmse: 0.4753 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 92
# train_rmse_target: 0.1189 train_rmse_stderror: 0.02114 train_kl_div: 0.03289
# val_rmse_target: 0.4743 val_rmse_stderror: 1.841
# New best_val_rmse: 0.4743
#
# 4 steps took 5.08 seconds
# Epoch: 3 batch_num: 96
# train_rmse_target: 0.1611 train_rmse_stderror: 0.02014 train_kl_div: 0.053
# val_rmse_target: 0.4741 val_rmse_stderror: 1.853
# New best_val_rmse: 0.4741
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 100
# train_rmse_target: 0.1689 train_rmse_stderror: 0.02149 train_kl_div: 0.05359
# val_rmse_target: 0.4793 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 104
# train_rmse_target: 0.1505 train_rmse_stderror: 0.0244 train_kl_div: 0.04703
# val_rmse_target: 0.4817 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 112
# train_rmse_target: 0.1535 train_rmse_stderror: 0.02422 train_kl_div: 0.04596
# val_rmse_target: 0.4832 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 120
# train_rmse_target: 0.1102 train_rmse_stderror: 0.02466 train_kl_div: 0.02857
# val_rmse_target: 0.4819 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 128
# train_rmse_target: 0.1528 train_rmse_stderror: 0.03106 train_kl_div: 0.04918
# val_rmse_target: 0.483 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 136
# train_rmse_target: 0.1752 train_rmse_stderror: 0.03297 train_kl_div: 0.05391
# val_rmse_target: 0.4753 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1038 train_rmse_stderror: 0.02331 train_kl_div: 0.02539
# val_rmse_target: 0.475 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 144
# train_rmse_target: 0.2413 train_rmse_stderror: 0.03833 train_kl_div: 0.09911
# val_rmse_target: 0.4846 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 152
# train_rmse_target: 0.1432 train_rmse_stderror: 0.02834 train_kl_div: 0.04794
# val_rmse_target: 0.482 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 160
# train_rmse_target: 0.06283 train_rmse_stderror: 0.02408 train_kl_div: 0.01043
# val_rmse_target: 0.4745 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 3 batch_num: 164
# train_rmse_target: 0.1476 train_rmse_stderror: 0.01833 train_kl_div: 0.04742
# val_rmse_target: 0.4761 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 3 batch_num: 168
# train_rmse_target: 0.1327 train_rmse_stderror: 0.02117 train_kl_div: 0.04094
# val_rmse_target: 0.488 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 3 batch_num: 176
# train_rmse_target: 0.0762 train_rmse_stderror: 0.02309 train_kl_div: 0.01465
# val_rmse_target: 0.4957 val_rmse_stderror: 1.837
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 16 steps took 20.3 seconds
# Epoch: 4 batch_num: 4
# train_rmse_target: 0.09557 train_rmse_stderror: 0.01135 train_kl_div: 0.0206
# val_rmse_target: 0.4766 val_rmse_stderror: 1.844
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 8
# train_rmse_target: 0.06832 train_rmse_stderror: 0.02016 train_kl_div: 0.01134
# val_rmse_target: 0.4786 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 12
# train_rmse_target: 0.09836 train_rmse_stderror: 0.02057 train_kl_div: 0.02305
# val_rmse_target: 0.4817 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.08745 train_rmse_stderror: 0.02304 train_kl_div: 0.01911
# val_rmse_target: 0.4807 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 4 batch_num: 28
# train_rmse_target: 0.08008 train_rmse_stderror: 0.01562 train_kl_div: 0.01404
# val_rmse_target: 0.4758 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.08067 train_rmse_stderror: 0.02172 train_kl_div: 0.01374
# val_rmse_target: 0.4751 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.02 seconds
# Epoch: 4 batch_num: 36
# train_rmse_target: 0.06895 train_rmse_stderror: 0.03207 train_kl_div: 0.01279
# val_rmse_target: 0.4758 val_rmse_stderror: 1.84
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 40
# train_rmse_target: 0.1082 train_rmse_stderror: 0.02257 train_kl_div: 0.02403
# val_rmse_target: 0.4791 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 44
# train_rmse_target: 0.08751 train_rmse_stderror: 0.02483 train_kl_div: 0.01893
# val_rmse_target: 0.4819 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08373 train_rmse_stderror: 0.01153 train_kl_div: 0.01509
# val_rmse_target: 0.4807 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 4 batch_num: 60
# train_rmse_target: 0.1288 train_rmse_stderror: 0.02246 train_kl_div: 0.03696
# val_rmse_target: 0.4764 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.1076 train_rmse_stderror: 0.02928 train_kl_div: 0.02167
# val_rmse_target: 0.4764 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 68
# train_rmse_target: 0.116 train_rmse_stderror: 0.02132 train_kl_div: 0.0323
# val_rmse_target: 0.4763 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 72
# train_rmse_target: 0.09742 train_rmse_stderror: 0.02353 train_kl_div: 0.02306
# val_rmse_target: 0.4768 val_rmse_stderror: 1.846
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 76
# train_rmse_target: 0.07143 train_rmse_stderror: 0.02505 train_kl_div: 0.0122
# val_rmse_target: 0.4781 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.05983 train_rmse_stderror: 0.02129 train_kl_div: 0.009503
# val_rmse_target: 0.4795 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.02 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.08975 train_rmse_stderror: 0.02793 train_kl_div: 0.01961
# val_rmse_target: 0.4803 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 8 steps took 10.1 seconds
# Epoch: 4 batch_num: 92
# train_rmse_target: 0.06711 train_rmse_stderror: 0.03148 train_kl_div: 0.01367
# val_rmse_target: 0.4792 val_rmse_stderror: 1.84
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 96
# train_rmse_target: 0.1232 train_rmse_stderror: 0.03273 train_kl_div: 0.02744
# val_rmse_target: 0.4786 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 100
# train_rmse_target: 0.08115 train_rmse_stderror: 0.02253 train_kl_div: 0.0152
# val_rmse_target: 0.4784 val_rmse_stderror: 1.844
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 104
# train_rmse_target: 0.08176 train_rmse_stderror: 0.02893 train_kl_div: 0.01707
# val_rmse_target: 0.4787 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 108
# train_rmse_target: 0.09398 train_rmse_stderror: 0.0234 train_kl_div: 0.02139
# val_rmse_target: 0.4782 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1289 train_rmse_stderror: 0.02401 train_kl_div: 0.03437
# val_rmse_target: 0.4774 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1186 train_rmse_stderror: 0.01566 train_kl_div: 0.02788
# val_rmse_target: 0.4771 val_rmse_stderror: 1.844
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 120
# train_rmse_target: 0.07616 train_rmse_stderror: 0.02346 train_kl_div: 0.01297
# val_rmse_target: 0.4772 val_rmse_stderror: 1.844
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 124
# train_rmse_target: 0.126 train_rmse_stderror: 0.01954 train_kl_div: 0.03223
# val_rmse_target: 0.4775 val_rmse_stderror: 1.843
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 128
# train_rmse_target: 0.085 train_rmse_stderror: 0.02521 train_kl_div: 0.01751
# val_rmse_target: 0.4777 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 132
# train_rmse_target: 0.1023 train_rmse_stderror: 0.01508 train_kl_div: 0.02163
# val_rmse_target: 0.4779 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 136
# train_rmse_target: 0.08519 train_rmse_stderror: 0.01337 train_kl_div: 0.01806
# val_rmse_target: 0.478 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 140
# train_rmse_target: 0.1047 train_rmse_stderror: 0.01614 train_kl_div: 0.01942
# val_rmse_target: 0.4781 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.09359 train_rmse_stderror: 0.01898 train_kl_div: 0.02006
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07672 train_rmse_stderror: 0.02047 train_kl_div: 0.01445
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.02 seconds
# Epoch: 4 batch_num: 152
# train_rmse_target: 0.1059 train_rmse_stderror: 0.0293 train_kl_div: 0.02397
# val_rmse_target: 0.4781 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 156
# train_rmse_target: 0.1404 train_rmse_stderror: 0.02307 train_kl_div: 0.03581
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.02 seconds
# Epoch: 4 batch_num: 160
# train_rmse_target: 0.07764 train_rmse_stderror: 0.02133 train_kl_div: 0.0152
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 164
# train_rmse_target: 0.08137 train_rmse_stderror: 0.02071 train_kl_div: 0.01597
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 168
# train_rmse_target: 0.08631 train_rmse_stderror: 0.01803 train_kl_div: 0.01815
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 172
# train_rmse_target: 0.1185 train_rmse_stderror: 0.0175 train_kl_div: 0.02961
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.03 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.06468 train_rmse_stderror: 0.02123 train_kl_div: 0.01043
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1525 train_rmse_stderror: 0.01851 train_kl_div: 0.05268
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 4 steps took 5.04 seconds
# Epoch: 4 batch_num: 184
# train_rmse_target: 0.09565 train_rmse_stderror: 0.03289 train_kl_div: 0.01959
# val_rmse_target: 0.4782 val_rmse_stderror: 1.841
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# Performance estimates:
# [0.49057017464743213, 0.4944596251774411, 0.5041230975372093, 0.458726046638517, 0.47407526219362645]
# Mean: 0.48439084123884524
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.49057017464743213, 0.4944596251774411, 0.5041230975372093, 0.458726046638517, 0.47407526219362645]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root
# mkdir: cannot create directory ‘.kaggle’: File exists

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:51<00:00, 27.7MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:49<00:00, 28.7MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:51<00:00, 27.6MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:47<00:00, 29.9MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:48<00:00, 29.2MB/s]
# Upload successful: model_5.pth (1GB)
