# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-08'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df_src = pd.read_csv(DATA_DIR/"train.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
print(train_df_src.shape)
train_df_src.head()
# Out:
# (2834, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # word_length_mlm
        mlm_layers = self.mlm_layers(input_len)


        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_layers], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_parameters = list(model.mlm_layers.named_parameters())
    mlm_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2277}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.713 train_rmse_stderror: 0.08995 train_kl_div: 1.046
# val_rmse_target: 0.9492 val_rmse_stderror: 1.194
# New best_val_rmse: 0.9492
#
# 64 steps took 81.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7823 train_rmse_stderror: 0.1092 train_kl_div: 1.309
# val_rmse_target: 0.6887 val_rmse_stderror: 1.235
# New best_val_rmse: 0.6887
#
# 64 steps took 81.2 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.3545 train_rmse_stderror: 0.07624 train_kl_div: 0.2791
# val_rmse_target: 0.5742 val_rmse_stderror: 1.2
# New best_val_rmse: 0.5742
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4697 train_rmse_stderror: 0.0809 train_kl_div: 0.4966
# val_rmse_target: 0.5689 val_rmse_stderror: 1.184
# New best_val_rmse: 0.5689
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5867 train_rmse_stderror: 0.0639 train_kl_div: 0.7189
# val_rmse_target: 0.5544 val_rmse_stderror: 1.191
# New best_val_rmse: 0.5544
#
# 64 steps took 81.3 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.4781 train_rmse_stderror: 0.07322 train_kl_div: 0.4338
# val_rmse_target: 0.5036 val_rmse_stderror: 1.191
# New best_val_rmse: 0.5036
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.4238 train_rmse_stderror: 0.09272 train_kl_div: 0.3885
# val_rmse_target: 0.5278 val_rmse_stderror: 1.204
# Still best_val_rmse: 0.5036 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3626 train_rmse_stderror: 0.07714 train_kl_div: 0.2999
# val_rmse_target: 0.4965 val_rmse_stderror: 1.197
# New best_val_rmse: 0.4965
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3349 train_rmse_stderror: 0.06171 train_kl_div: 0.2449
# val_rmse_target: 0.5232 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4965 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3933 train_rmse_stderror: 0.07227 train_kl_div: 0.3441
# val_rmse_target: 0.5109 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4965 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3051 train_rmse_stderror: 0.07731 train_kl_div: 0.2103
# val_rmse_target: 0.5303 val_rmse_stderror: 1.192
# Still best_val_rmse: 0.4965 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.3254 train_rmse_stderror: 0.08628 train_kl_div: 0.2603
# val_rmse_target: 0.4954 val_rmse_stderror: 1.186
# New best_val_rmse: 0.4954
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2214 train_rmse_stderror: 0.06688 train_kl_div: 0.1204
# val_rmse_target: 0.5307 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4954 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.3167 train_rmse_stderror: 0.08968 train_kl_div: 0.1892
# val_rmse_target: 0.5167 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4954 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2255 train_rmse_stderror: 0.05371 train_kl_div: 0.1096
# val_rmse_target: 0.4928 val_rmse_stderror: 1.195
# New best_val_rmse: 0.4928
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.2323 train_rmse_stderror: 0.07584 train_kl_div: 0.1415
# val_rmse_target: 0.4983 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.3255 train_rmse_stderror: 0.05811 train_kl_div: 0.2331
# val_rmse_target: 0.5085 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.2148 train_rmse_stderror: 0.07053 train_kl_div: 0.1173
# val_rmse_target: 0.5064 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.2117 train_rmse_stderror: 0.07147 train_kl_div: 0.1153
# val_rmse_target: 0.5009 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.2138 train_rmse_stderror: 0.06132 train_kl_div: 0.09508
# val_rmse_target: 0.5086 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.3069 train_rmse_stderror: 0.06696 train_kl_div: 0.1977
# val_rmse_target: 0.5018 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1453 train_rmse_stderror: 0.07221 train_kl_div: 0.06554
# val_rmse_target: 0.505 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1674 train_rmse_stderror: 0.06517 train_kl_div: 0.07903
# val_rmse_target: 0.5047 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4928 (from epoch 3)
#
# Performance estimates:
# [0.492798290064862]
# Mean: 0.492798290064862
# {'total_MiB': 16280, 'used_MiB': 2295}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 2295}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6021 train_rmse_stderror: 0.09909 train_kl_div: 0.8592
# val_rmse_target: 0.6238 val_rmse_stderror: 1.735
# New best_val_rmse: 0.6238
#
# 64 steps took 81.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6353 train_rmse_stderror: 0.1017 train_kl_div: 0.9277
# val_rmse_target: 0.5797 val_rmse_stderror: 1.771
# New best_val_rmse: 0.5797
#
# 64 steps took 81.3 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.6552 train_rmse_stderror: 0.08032 train_kl_div: 0.9077
# val_rmse_target: 0.5512 val_rmse_stderror: 1.765
# New best_val_rmse: 0.5512
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.2515 train_rmse_stderror: 0.0712 train_kl_div: 0.1599
# val_rmse_target: 0.5111 val_rmse_stderror: 1.758
# New best_val_rmse: 0.5111
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4254 train_rmse_stderror: 0.07847 train_kl_div: 0.3595
# val_rmse_target: 0.5373 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.3927 train_rmse_stderror: 0.08837 train_kl_div: 0.3264
# val_rmse_target: 0.5256 val_rmse_stderror: 1.709
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.487 train_rmse_stderror: 0.1034 train_kl_div: 0.4046
# val_rmse_target: 0.5162 val_rmse_stderror: 1.717
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.32 train_rmse_stderror: 0.06644 train_kl_div: 0.2169
# val_rmse_target: 0.5112 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2981 train_rmse_stderror: 0.07176 train_kl_div: 0.2085
# val_rmse_target: 0.5156 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.295 train_rmse_stderror: 0.05844 train_kl_div: 0.2003
# val_rmse_target: 0.504 val_rmse_stderror: 1.73
# New best_val_rmse: 0.504
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3253 train_rmse_stderror: 0.05903 train_kl_div: 0.2259
# val_rmse_target: 0.4981 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4981
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.1634 train_rmse_stderror: 0.05712 train_kl_div: 0.05985
# val_rmse_target: 0.5177 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3828 train_rmse_stderror: 0.0607 train_kl_div: 0.2684
# val_rmse_target: 0.503 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1856 train_rmse_stderror: 0.08447 train_kl_div: 0.09567
# val_rmse_target: 0.4964 val_rmse_stderror: 1.759
# New best_val_rmse: 0.4964
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1682 train_rmse_stderror: 0.03874 train_kl_div: 0.05875
# val_rmse_target: 0.4958 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4958
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1412 train_rmse_stderror: 0.04534 train_kl_div: 0.04412
# val_rmse_target: 0.4943 val_rmse_stderror: 1.743
# New best_val_rmse: 0.4943
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1467 train_rmse_stderror: 0.03664 train_kl_div: 0.05229
# val_rmse_target: 0.4965 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4943 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1625 train_rmse_stderror: 0.04147 train_kl_div: 0.06359
# val_rmse_target: 0.4945 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4943 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1404 train_rmse_stderror: 0.04355 train_kl_div: 0.05046
# val_rmse_target: 0.4937 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4937
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09119 train_rmse_stderror: 0.04295 train_kl_div: 0.02453
# val_rmse_target: 0.4935 val_rmse_stderror: 1.741
# New best_val_rmse: 0.4935
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.08714 train_rmse_stderror: 0.03766 train_kl_div: 0.02095
# val_rmse_target: 0.4937 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4935 (from epoch 4)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.09135 train_rmse_stderror: 0.05946 train_kl_div: 0.03361
# val_rmse_target: 0.4923 val_rmse_stderror: 1.752
# New best_val_rmse: 0.4923
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.06984 train_rmse_stderror: 0.03474 train_kl_div: 0.01508
# val_rmse_target: 0.4927 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4923 (from epoch 4)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1174 train_rmse_stderror: 0.04326 train_kl_div: 0.03625
# val_rmse_target: 0.4927 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4923 (from epoch 4)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.05105 train_rmse_stderror: 0.03843 train_kl_div: 0.01086
# val_rmse_target: 0.493 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4923 (from epoch 4)
#
# Performance estimates:
# [0.492798290064862, 0.49234482201515917]
# Mean: 0.49257155604001057
# {'total_MiB': 16280, 'used_MiB': 2295}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 2295}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.648 train_rmse_stderror: 0.07712 train_kl_div: 0.8338
# val_rmse_target: 0.7267 val_rmse_stderror: 1.131
# New best_val_rmse: 0.7267
#
# 64 steps took 81.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7996 train_rmse_stderror: 0.08025 train_kl_div: 1.218
# val_rmse_target: 0.6522 val_rmse_stderror: 1.084
# New best_val_rmse: 0.6522
#
# 64 steps took 81.3 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.3039 train_rmse_stderror: 0.04643 train_kl_div: 0.2067
# val_rmse_target: 0.5306 val_rmse_stderror: 1.11
# New best_val_rmse: 0.5306
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.4245 train_rmse_stderror: 0.04531 train_kl_div: 0.3378
# val_rmse_target: 0.5562 val_rmse_stderror: 1.084
# Still best_val_rmse: 0.5306 (from epoch 1)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4836 train_rmse_stderror: 0.0682 train_kl_div: 0.5301
# val_rmse_target: 0.6131 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5306 (from epoch 1)
#
# 64 steps took 81.0 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4382 train_rmse_stderror: 0.09666 train_kl_div: 0.3779
# val_rmse_target: 0.5753 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.5306 (from epoch 1)
#
# 64 steps took 81.3 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3059 train_rmse_stderror: 0.06484 train_kl_div: 0.174
# val_rmse_target: 0.4989 val_rmse_stderror: 1.099
# New best_val_rmse: 0.4989
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3319 train_rmse_stderror: 0.06256 train_kl_div: 0.254
# val_rmse_target: 0.5116 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4989 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3225 train_rmse_stderror: 0.05485 train_kl_div: 0.2162
# val_rmse_target: 0.51 val_rmse_stderror: 1.095
# Still best_val_rmse: 0.4989 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3437 train_rmse_stderror: 0.06041 train_kl_div: 0.2712
# val_rmse_target: 0.5016 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4989 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2662 train_rmse_stderror: 0.04648 train_kl_div: 0.1555
# val_rmse_target: 0.4974 val_rmse_stderror: 1.104
# New best_val_rmse: 0.4974
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1607 train_rmse_stderror: 0.06004 train_kl_div: 0.07384
# val_rmse_target: 0.4911 val_rmse_stderror: 1.114
# New best_val_rmse: 0.4911
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2274 train_rmse_stderror: 0.05234 train_kl_div: 0.1253
# val_rmse_target: 0.4926 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4911 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.152 train_rmse_stderror: 0.05599 train_kl_div: 0.06397
# val_rmse_target: 0.493 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4911 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1871 train_rmse_stderror: 0.05485 train_kl_div: 0.07162
# val_rmse_target: 0.4903 val_rmse_stderror: 1.107
# New best_val_rmse: 0.4903
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1801 train_rmse_stderror: 0.0393 train_kl_div: 0.06949
# val_rmse_target: 0.4877 val_rmse_stderror: 1.104
# New best_val_rmse: 0.4877
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1805 train_rmse_stderror: 0.03746 train_kl_div: 0.07054
# val_rmse_target: 0.4895 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1264 train_rmse_stderror: 0.05504 train_kl_div: 0.03817
# val_rmse_target: 0.4955 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1277 train_rmse_stderror: 0.03857 train_kl_div: 0.03846
# val_rmse_target: 0.4927 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08532 train_rmse_stderror: 0.02872 train_kl_div: 0.01851
# val_rmse_target: 0.4909 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1256 train_rmse_stderror: 0.04013 train_kl_div: 0.03493
# val_rmse_target: 0.4913 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1176 train_rmse_stderror: 0.04708 train_kl_div: 0.03773
# val_rmse_target: 0.4907 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.09049 train_rmse_stderror: 0.04748 train_kl_div: 0.0254
# val_rmse_target: 0.4907 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4877 (from epoch 3)
#
# Performance estimates:
# [0.492798290064862, 0.49234482201515917, 0.4877030381982966]
# Mean: 0.49094871675943924
# {'total_MiB': 16280, 'used_MiB': 2295}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 2295}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5747 train_rmse_stderror: 0.1672 train_kl_div: 0.7633
# val_rmse_target: 0.6816 val_rmse_stderror: 1.848
# New best_val_rmse: 0.6816
#
# 64 steps took 81.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5526 train_rmse_stderror: 0.06288 train_kl_div: 0.624
# val_rmse_target: 0.6099 val_rmse_stderror: 1.783
# New best_val_rmse: 0.6099
#
# 64 steps took 81.3 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.2923 train_rmse_stderror: 0.08704 train_kl_div: 0.2044
# val_rmse_target: 0.5324 val_rmse_stderror: 1.79
# New best_val_rmse: 0.5324
#
# 32 steps took 40.6 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.4811 train_rmse_stderror: 0.06002 train_kl_div: 0.4718
# val_rmse_target: 0.5359 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.5324 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.529 train_rmse_stderror: 0.04143 train_kl_div: 0.5722
# val_rmse_target: 0.5908 val_rmse_stderror: 1.808
# Still best_val_rmse: 0.5324 (from epoch 1)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5402 train_rmse_stderror: 0.09058 train_kl_div: 0.5169
# val_rmse_target: 0.5451 val_rmse_stderror: 1.809
# Still best_val_rmse: 0.5324 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.3289 train_rmse_stderror: 0.05537 train_kl_div: 0.2473
# val_rmse_target: 0.5352 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.5324 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2956 train_rmse_stderror: 0.0632 train_kl_div: 0.2058
# val_rmse_target: 0.5536 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.5324 (from epoch 1)
#
# 64 steps took 81.1 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.311 train_rmse_stderror: 0.08442 train_kl_div: 0.2293
# val_rmse_target: 0.4883 val_rmse_stderror: 1.803
# New best_val_rmse: 0.4883
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.4301 train_rmse_stderror: 0.04636 train_kl_div: 0.4126
# val_rmse_target: 0.4742 val_rmse_stderror: 1.797
# New best_val_rmse: 0.4742
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.4221 train_rmse_stderror: 0.04922 train_kl_div: 0.3053
# val_rmse_target: 0.4776 val_rmse_stderror: 1.806
# Still best_val_rmse: 0.4742 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2903 train_rmse_stderror: 0.03122 train_kl_div: 0.1785
# val_rmse_target: 0.4785 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.4742 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1667 train_rmse_stderror: 0.05982 train_kl_div: 0.07468
# val_rmse_target: 0.4812 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.4742 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1389 train_rmse_stderror: 0.05423 train_kl_div: 0.05314
# val_rmse_target: 0.4829 val_rmse_stderror: 1.8
# Still best_val_rmse: 0.4742 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2367 train_rmse_stderror: 0.04941 train_kl_div: 0.1192
# val_rmse_target: 0.4709 val_rmse_stderror: 1.804
# New best_val_rmse: 0.4709
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1662 train_rmse_stderror: 0.05227 train_kl_div: 0.07403
# val_rmse_target: 0.4715 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4709 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1925 train_rmse_stderror: 0.0687 train_kl_div: 0.09935
# val_rmse_target: 0.4708 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4708
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2105 train_rmse_stderror: 0.05425 train_kl_div: 0.1113
# val_rmse_target: 0.4716 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1187 train_rmse_stderror: 0.05608 train_kl_div: 0.04095
# val_rmse_target: 0.4727 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1245 train_rmse_stderror: 0.05743 train_kl_div: 0.0432
# val_rmse_target: 0.4748 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.09149 train_rmse_stderror: 0.06953 train_kl_div: 0.03707
# val_rmse_target: 0.4713 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.14 train_rmse_stderror: 0.05713 train_kl_div: 0.04484
# val_rmse_target: 0.4719 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1401 train_rmse_stderror: 0.03433 train_kl_div: 0.04681
# val_rmse_target: 0.473 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1862 train_rmse_stderror: 0.0411 train_kl_div: 0.06348
# val_rmse_target: 0.4723 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4708 (from epoch 3)
#
# Performance estimates:
# [0.492798290064862, 0.49234482201515917, 0.4877030381982966, 0.4707838411296969]
# Mean: 0.48590749785200366
# {'total_MiB': 16280, 'used_MiB': 2295}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 2295}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4674 train_rmse_stderror: 0.09241 train_kl_div: 0.4992
# val_rmse_target: 0.6674 val_rmse_stderror: 1.133
# New best_val_rmse: 0.6674
#
# 64 steps took 81.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4242 train_rmse_stderror: 0.0733 train_kl_div: 0.3998
# val_rmse_target: 0.5723 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5723
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5181 train_rmse_stderror: 0.0829 train_kl_div: 0.5839
# val_rmse_target: 0.5391 val_rmse_stderror: 1.118
# New best_val_rmse: 0.5391
#
# 32 steps took 40.6 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.3061 train_rmse_stderror: 0.06187 train_kl_div: 0.1922
# val_rmse_target: 0.5481 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.5391 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4191 train_rmse_stderror: 0.0761 train_kl_div: 0.3416
# val_rmse_target: 0.6055 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.5391 (from epoch 1)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.529 train_rmse_stderror: 0.04722 train_kl_div: 0.5429
# val_rmse_target: 0.6135 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.5391 (from epoch 1)
#
# 64 steps took 81.3 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3279 train_rmse_stderror: 0.03546 train_kl_div: 0.2425
# val_rmse_target: 0.571 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.5391 (from epoch 1)
#
# 64 steps took 81.0 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.1952 train_rmse_stderror: 0.05542 train_kl_div: 0.09248
# val_rmse_target: 0.5273 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5273
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2503 train_rmse_stderror: 0.08146 train_kl_div: 0.1598
# val_rmse_target: 0.5 val_rmse_stderror: 1.111
# New best_val_rmse: 0.5
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2787 train_rmse_stderror: 0.05486 train_kl_div: 0.1772
# val_rmse_target: 0.5149 val_rmse_stderror: 1.096
# Still best_val_rmse: 0.5 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.1935 train_rmse_stderror: 0.06037 train_kl_div: 0.09908
# val_rmse_target: 0.5003 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.5 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1246 train_rmse_stderror: 0.04267 train_kl_div: 0.04313
# val_rmse_target: 0.4968 val_rmse_stderror: 1.107
# New best_val_rmse: 0.4968
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1351 train_rmse_stderror: 0.0542 train_kl_div: 0.04907
# val_rmse_target: 0.4987 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.4968 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.195 train_rmse_stderror: 0.05474 train_kl_div: 0.08609
# val_rmse_target: 0.5091 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4968 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1526 train_rmse_stderror: 0.05156 train_kl_div: 0.06116
# val_rmse_target: 0.4925 val_rmse_stderror: 1.106
# New best_val_rmse: 0.4925
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.2256 train_rmse_stderror: 0.06527 train_kl_div: 0.09679
# val_rmse_target: 0.4967 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1487 train_rmse_stderror: 0.0526 train_kl_div: 0.05129
# val_rmse_target: 0.4934 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.05845 train_rmse_stderror: 0.04181 train_kl_div: 0.01564
# val_rmse_target: 0.4983 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1549 train_rmse_stderror: 0.0403 train_kl_div: 0.05474
# val_rmse_target: 0.4956 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.09089 train_rmse_stderror: 0.04691 train_kl_div: 0.02438
# val_rmse_target: 0.4977 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09596 train_rmse_stderror: 0.05682 train_kl_div: 0.03428
# val_rmse_target: 0.4955 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1109 train_rmse_stderror: 0.05258 train_kl_div: 0.03545
# val_rmse_target: 0.495 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.09682 train_rmse_stderror: 0.03558 train_kl_div: 0.02507
# val_rmse_target: 0.4953 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4925 (from epoch 3)
#
# Performance estimates:
# [0.492798290064862, 0.49234482201515917, 0.4877030381982966, 0.4707838411296969, 0.4924983622947501]
# Mean: 0.487225670740553
# {'total_MiB': 16280, 'used_MiB': 2295}

# %%
print(list_val_rmse)
# Out:
# [0.492798290064862, 0.49234482201515917, 0.4877030381982966, 0.4707838411296969, 0.4924983622947501]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:13<00:00, 104MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:17<00:00, 80.5MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:13<00:00, 107MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:14<00:00, 99.3MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:15<00:00, 93.9MB/s]
# Upload successful: model_5.pth (1GB)
