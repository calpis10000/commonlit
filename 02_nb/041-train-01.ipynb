# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Collecting pytorch_memlab
#   Downloading https://files.pythonhosted.org/packages/c4/90/0e2e7a9efd85a208a43cce627d4d718738a01c1713d129a08d714becff5d/pytorch_memlab-0.2.3.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Collecting calmsize
#   Downloading https://files.pythonhosted.org/packages/da/69/382ee4e1553f15321dd76109325f6a186a79354c53e8ac97cf79a2ebddbe/calmsize-0.1.3.tar.gz
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)
# Building wheels for collected packages: pytorch-memlab, calmsize
#   Building wheel for pytorch-memlab (setup.py) ... done
#   Created wheel for pytorch-memlab: filename=pytorch_memlab-0.2.3-cp37-none-any.whl size=20200 sha256=62e73ffea7fec2af430dcff78962f304eb25ee793369438b426ddf878760d3e5
#   Stored in directory: /root/.cache/pip/wheels/0f/5a/89/2469c2174bfe7a9cdee7e2faa97be08b6f85cffca423b57e31
#   Building wheel for calmsize (setup.py) ... done
#   Created wheel for calmsize: filename=calmsize-0.1.3-cp37-none-any.whl size=2887 sha256=eb6f49b810e8418450b35b412b6c7e3ffdc603910f6bca96abb59af87b3c9ea3
#   Stored in directory: /root/.cache/pip/wheels/02/ac/1a/2a3418bc8f81abda6cd1b6d0f8f287556fc8de80dbabab75d1
# Successfully built pytorch-memlab calmsize
# Installing collected packages: calmsize, pytorch-memlab
# Successfully installed calmsize-0.1.3 pytorch-memlab-0.2.3

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-base'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '041-train-01'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 3 # Epochs
BATCH_SIZE = 16 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=481.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(768, 512), # 768は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor_target = nn.Sequential( # 出力レイヤー                    
            nn.Linear(768, 1)                        
        )

        self.regressor_stderror = nn.Sequential( # 出力レイヤー                    
            nn.Linear(768, 1)                        
        )

    def forward(self, input_ids, attention_mask):
        #print('model: get_roberta_out: Start', gpuinfo())                 
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        #print('model: get_roberta_out: Done', gpuinfo())                 

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        last_layer_hidden_states = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base). # 
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        weights = self.attention(last_layer_hidden_states) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor_target(context_vector), self.regressor_stderror(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse01_sum = 0
    mse02_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            pred01, pred02 = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse01_sum += nn.MSELoss(reduction="sum")(pred01.flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse02_sum += nn.MSELoss(reduction="sum")(pred02.flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
    del input_ids
    del attention_mask
    del target

    mse01_result = mse01_sum / len(data_loader.dataset)
    mse02_result = mse02_sum / len(data_loader.dataset)
  
    return mse01_result, mse02_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred, pred02 = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            pred01, pred02 = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            mse01 = nn.MSELoss(reduction="mean")(pred01.flatten(), target)
            mse02 = nn.MSELoss(reduction="mean")(pred02.flatten(), standard_error)
            mse = mse01 + mse02

            mse.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                val_mse01, val_mse02 = eval_mse(model, val_loader)
                val_rmse01 = math.sqrt(val_mse01) # valid-setによるrmse計算                           
                val_rmse02 = math.sqrt(val_mse02) # valid-setによるrmse計算                           

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse_target: {val_rmse01:0.4}",
                      f"val_rmse_stderror: {val_rmse02:0.4}")

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_rmse01 >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_rmse01 < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_rmse01
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = named_parameters[:197] # パラメータをroberta用、attention用、regressor用に格納。(どうやって決めてるのだろう？)
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    #print('getmodel: Start', gpuinfo())                 
    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    #print('getmodel: Done', gpuinfo())                 

    #print('get_optim_sched: Start', gpuinfo())                 
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    #print('get_optim_sched: Done', gpuinfo())                 

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.42 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9481 val_rmse_stderror: 1.634
# New best_val_rmse: 0.9481
#
# 16 steps took 8.85 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.736 val_rmse_stderror: 1.591
# New best_val_rmse: 0.736
#
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7849 val_rmse_stderror: 1.823
# Still best_val_rmse: 0.736 (from epoch 0)
#
# 16 steps took 8.85 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7174 val_rmse_stderror: 1.696
# New best_val_rmse: 0.7174
#
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.7352 val_rmse_stderror: 1.829
# Still best_val_rmse: 0.7174 (from epoch 0)
#
# 16 steps took 8.83 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5788 val_rmse_stderror: 1.723
# New best_val_rmse: 0.5788
#
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5657 val_rmse_stderror: 1.768
# New best_val_rmse: 0.5657
#
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5823 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.5657 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5247 val_rmse_stderror: 1.762
# New best_val_rmse: 0.5247
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.6436 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.5247 (from epoch 1)
#
# 16 steps took 8.86 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5526 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.5247 (from epoch 1)
#
# 16 steps took 8.85 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5045 val_rmse_stderror: 1.769
# New best_val_rmse: 0.5045
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5383 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 8.85 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5092 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5009 val_rmse_stderror: 1.781
# New best_val_rmse: 0.5009
#
# 16 steps took 8.86 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.493 val_rmse_stderror: 1.784
# New best_val_rmse: 0.493
#
# 8 steps took 4.43 seconds
# Epoch: 1 batch_num: 123 val_rmse_target: 0.5272 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.493 (from epoch 1)
#
# 16 steps took 8.82 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.5713 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.493 (from epoch 1)
#
# 16 steps took 8.96 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.4872 val_rmse_stderror: 1.775
# New best_val_rmse: 0.4872
#
# 4 steps took 2.2 seconds
# Epoch: 2 batch_num: 18 val_rmse_target: 0.4901 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4872 (from epoch 2)
#
# 8 steps took 4.42 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.5147 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4872 (from epoch 2)
#
# 16 steps took 8.86 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.4929 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4872 (from epoch 2)
#
# 8 steps took 4.42 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4869 val_rmse_stderror: 1.78
# New best_val_rmse: 0.4869
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4928 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4869 (from epoch 2)
#
# 8 steps took 4.42 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4876 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4869 (from epoch 2)
#
# 4 steps took 2.2 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4862 val_rmse_stderror: 1.77
# New best_val_rmse: 0.4862
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4849 val_rmse_stderror: 1.775
# New best_val_rmse: 0.4849
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4915 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 8 steps took 4.42 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.5057 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 16 steps took 8.85 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4852 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4863 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4878 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.2 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4876 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4878 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4881 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4883 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4884 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4882 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4882 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 4 steps took 2.21 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4881 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# Performance estimates:
# [0.48492947465747144]
# Mean: 0.48492947465747144
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.21 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9551 val_rmse_stderror: 1.827
# New best_val_rmse: 0.9551
#
# 16 steps took 8.71 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.7914 val_rmse_stderror: 1.843
# New best_val_rmse: 0.7914
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.8814 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.7914 (from epoch 0)
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6693 val_rmse_stderror: 1.746
# New best_val_rmse: 0.6693
#
# 16 steps took 8.72 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6561 val_rmse_stderror: 1.781
# New best_val_rmse: 0.6561
#
# 16 steps took 8.72 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6075 val_rmse_stderror: 1.805
# New best_val_rmse: 0.6075
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5241 val_rmse_stderror: 1.778
# New best_val_rmse: 0.5241
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5361 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.5241 (from epoch 0)
#
# 16 steps took 8.83 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5149 val_rmse_stderror: 1.769
# New best_val_rmse: 0.5149
#
# 16 steps took 8.71 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5214 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.5149 (from epoch 1)
#
# 16 steps took 8.72 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.6267 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.5149 (from epoch 1)
#
# 16 steps took 8.71 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.4957 val_rmse_stderror: 1.773
# New best_val_rmse: 0.4957
#
# 8 steps took 4.35 seconds
# Epoch: 1 batch_num: 59 val_rmse_target: 0.5382 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4957 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 75 val_rmse_target: 0.5 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4957 (from epoch 1)
#
# 16 steps took 8.72 seconds
# Epoch: 1 batch_num: 91 val_rmse_target: 0.4961 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4957 (from epoch 1)
#
# 8 steps took 4.37 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.4841 val_rmse_stderror: 1.769
# New best_val_rmse: 0.4841
#
# 4 steps took 2.18 seconds
# Epoch: 1 batch_num: 103 val_rmse_target: 0.4893 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4841 (from epoch 1)
#
# 4 steps took 2.17 seconds
# Epoch: 1 batch_num: 107 val_rmse_target: 0.4993 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4841 (from epoch 1)
#
# 8 steps took 4.35 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5048 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.4841 (from epoch 1)
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.4682 val_rmse_stderror: 1.774
# New best_val_rmse: 0.4682
#
# 1 steps took 0.538 seconds
# Epoch: 1 batch_num: 132 val_rmse_target: 0.4774 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 2 steps took 1.08 seconds
# Epoch: 1 batch_num: 134 val_rmse_target: 0.5022 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 16 steps took 8.87 seconds
# Epoch: 2 batch_num: 9 val_rmse_target: 0.4665 val_rmse_stderror: 1.79
# New best_val_rmse: 0.4665
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 10 val_rmse_target: 0.4678 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 11 val_rmse_target: 0.4684 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 12 val_rmse_target: 0.4694 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 13 val_rmse_target: 0.4709 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 15 val_rmse_target: 0.4754 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 17 val_rmse_target: 0.4781 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 19 val_rmse_target: 0.4805 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 23 val_rmse_target: 0.4975 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4665 (from epoch 2)
#
# 8 steps took 4.36 seconds
# Epoch: 2 batch_num: 31 val_rmse_target: 0.4655 val_rmse_stderror: 1.778
# New best_val_rmse: 0.4655
#
# 1 steps took 0.559 seconds
# Epoch: 2 batch_num: 32 val_rmse_target: 0.4663 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 33 val_rmse_target: 0.4656 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.465 val_rmse_stderror: 1.783
# New best_val_rmse: 0.465
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 35 val_rmse_target: 0.4652 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.465 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 36 val_rmse_target: 0.4645 val_rmse_stderror: 1.784
# New best_val_rmse: 0.4645
#
# 1 steps took 0.556 seconds
# Epoch: 2 batch_num: 37 val_rmse_target: 0.4647 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.465 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.542 seconds
# Epoch: 2 batch_num: 39 val_rmse_target: 0.466 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 40 val_rmse_target: 0.4688 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 41 val_rmse_target: 0.4736 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 43 val_rmse_target: 0.4795 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 45 val_rmse_target: 0.4813 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 4 steps took 2.18 seconds
# Epoch: 2 batch_num: 49 val_rmse_target: 0.4714 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 51 val_rmse_target: 0.4666 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 52 val_rmse_target: 0.4653 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4645 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 53 val_rmse_target: 0.4644 val_rmse_stderror: 1.767
# New best_val_rmse: 0.4644
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4638 val_rmse_stderror: 1.767
# New best_val_rmse: 0.4638
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 55 val_rmse_target: 0.4637 val_rmse_stderror: 1.768
# New best_val_rmse: 0.4637
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 56 val_rmse_target: 0.4639 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 57 val_rmse_target: 0.464 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.4643 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 59 val_rmse_target: 0.4643 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 60 val_rmse_target: 0.4638 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 1 steps took 0.542 seconds
# Epoch: 2 batch_num: 61 val_rmse_target: 0.4631 val_rmse_stderror: 1.778
# New best_val_rmse: 0.4631
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4623 val_rmse_stderror: 1.779
# New best_val_rmse: 0.4623
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 63 val_rmse_target: 0.4619 val_rmse_stderror: 1.78
# New best_val_rmse: 0.4619
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 64 val_rmse_target: 0.4623 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 65 val_rmse_target: 0.463 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4642 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 67 val_rmse_target: 0.4655 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.542 seconds
# Epoch: 2 batch_num: 68 val_rmse_target: 0.4665 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 69 val_rmse_target: 0.4673 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.468 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 71 val_rmse_target: 0.4693 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 72 val_rmse_target: 0.4712 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4747 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.4755 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4735 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4735 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.4732 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4714 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4711 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 88 val_rmse_target: 0.4703 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.47 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.4685 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 93 val_rmse_target: 0.4678 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4672 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 95 val_rmse_target: 0.4662 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 96 val_rmse_target: 0.4654 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 97 val_rmse_target: 0.4648 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4645 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 99 val_rmse_target: 0.4641 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 100 val_rmse_target: 0.4636 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 101 val_rmse_target: 0.4631 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4627 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 103 val_rmse_target: 0.462 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4619 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 104 val_rmse_target: 0.4615 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4615
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 105 val_rmse_target: 0.461 val_rmse_stderror: 1.776
# New best_val_rmse: 0.461
#
# 1 steps took 0.543 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4606 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4606
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 107 val_rmse_target: 0.4604 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4604
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 108 val_rmse_target: 0.4602 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4602
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 109 val_rmse_target: 0.4602 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4602
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4602 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4602
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 111 val_rmse_target: 0.4602 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4602 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.4601 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4601
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 113 val_rmse_target: 0.4602 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.541 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4603 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 115 val_rmse_target: 0.4604 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.543 seconds
# Epoch: 2 batch_num: 116 val_rmse_target: 0.4605 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 117 val_rmse_target: 0.4607 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4608 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 119 val_rmse_target: 0.461 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 120 val_rmse_target: 0.4612 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 121 val_rmse_target: 0.4613 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4614 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.536 seconds
# Epoch: 2 batch_num: 123 val_rmse_target: 0.4616 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 124 val_rmse_target: 0.4617 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.543 seconds
# Epoch: 2 batch_num: 125 val_rmse_target: 0.4618 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.536 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4619 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.542 seconds
# Epoch: 2 batch_num: 127 val_rmse_target: 0.462 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 128 val_rmse_target: 0.4621 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 129 val_rmse_target: 0.4621 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4621 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.54 seconds
# Epoch: 2 batch_num: 131 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.536 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 133 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.538 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 135 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 136 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 137 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.539 seconds
# Epoch: 2 batch_num: 139 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 1 steps took 0.537 seconds
# Epoch: 2 batch_num: 140 val_rmse_target: 0.4622 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# Performance estimates:
# [0.48492947465747144, 0.46014416143049347]
# Mean: 0.47253681804398245
#
# Fold 3/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.02 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.089 val_rmse_stderror: 1.893
# New best_val_rmse: 1.089
#
# 16 steps took 8.51 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.9122 val_rmse_stderror: 1.85
# New best_val_rmse: 0.9122
#
# 16 steps took 8.52 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7118 val_rmse_stderror: 1.81
# New best_val_rmse: 0.7118
#
# 16 steps took 8.53 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7081 val_rmse_stderror: 1.79
# New best_val_rmse: 0.7081
#
# 16 steps took 8.53 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.7268 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.7081 (from epoch 0)
#
# 16 steps took 8.53 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6346 val_rmse_stderror: 1.776
# New best_val_rmse: 0.6346
#
# 16 steps took 8.51 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6084 val_rmse_stderror: 1.801
# New best_val_rmse: 0.6084
#
# 16 steps took 8.51 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5819 val_rmse_stderror: 1.794
# New best_val_rmse: 0.5819
#
# 16 steps took 8.67 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5457 val_rmse_stderror: 1.807
# New best_val_rmse: 0.5457
#
# 16 steps took 8.54 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5256 val_rmse_stderror: 1.82
# New best_val_rmse: 0.5256
#
# 16 steps took 8.52 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5165 val_rmse_stderror: 1.828
# New best_val_rmse: 0.5165
#
# 16 steps took 8.54 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5111 val_rmse_stderror: 1.83
# New best_val_rmse: 0.5111
#
# 16 steps took 8.51 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5128 val_rmse_stderror: 1.818
# Still best_val_rmse: 0.5111 (from epoch 1)
#
# 16 steps took 8.51 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5104 val_rmse_stderror: 1.81
# New best_val_rmse: 0.5104
#
# 16 steps took 8.51 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5156 val_rmse_stderror: 1.805
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 16 steps took 8.53 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.4908 val_rmse_stderror: 1.807
# New best_val_rmse: 0.4908
#
# 8 steps took 4.27 seconds
# Epoch: 1 batch_num: 123 val_rmse_target: 0.4895 val_rmse_stderror: 1.822
# New best_val_rmse: 0.4895
#
# 4 steps took 2.14 seconds
# Epoch: 1 batch_num: 127 val_rmse_target: 0.4911 val_rmse_stderror: 1.825
# Still best_val_rmse: 0.4895 (from epoch 1)
#
# 8 steps took 4.26 seconds
# Epoch: 1 batch_num: 135 val_rmse_target: 0.4893 val_rmse_stderror: 1.804
# New best_val_rmse: 0.4893
#
# 4 steps took 2.13 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.489 val_rmse_stderror: 1.808
# New best_val_rmse: 0.489
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 2 val_rmse_target: 0.494 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.489 (from epoch 1)
#
# 8 steps took 4.26 seconds
# Epoch: 2 batch_num: 10 val_rmse_target: 0.4846 val_rmse_stderror: 1.821
# New best_val_rmse: 0.4846
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.475 val_rmse_stderror: 1.817
# New best_val_rmse: 0.475
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 16 val_rmse_target: 0.4732 val_rmse_stderror: 1.815
# New best_val_rmse: 0.4732
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 18 val_rmse_target: 0.4731 val_rmse_stderror: 1.813
# New best_val_rmse: 0.4731
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 20 val_rmse_target: 0.4725 val_rmse_stderror: 1.811
# New best_val_rmse: 0.4725
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.472 val_rmse_stderror: 1.81
# New best_val_rmse: 0.472
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 24 val_rmse_target: 0.4718 val_rmse_stderror: 1.809
# New best_val_rmse: 0.4718
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.4732 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 28 val_rmse_target: 0.4733 val_rmse_stderror: 1.812
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.4722 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 32 val_rmse_target: 0.4721 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.4721 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 36 val_rmse_target: 0.4736 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4776 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 40 val_rmse_target: 0.4797 val_rmse_stderror: 1.817
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.4791 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 44 val_rmse_target: 0.4739 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4728 val_rmse_stderror: 1.812
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 48 val_rmse_target: 0.4731 val_rmse_stderror: 1.811
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4738 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 52 val_rmse_target: 0.4742 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4732 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 56 val_rmse_target: 0.4762 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.479 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 60 val_rmse_target: 0.4788 val_rmse_stderror: 1.811
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.479 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 64 val_rmse_target: 0.478 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4783 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 68 val_rmse_target: 0.478 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4776 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 72 val_rmse_target: 0.4763 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.475 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.4736 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4727 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4727 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.4726 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4728 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4729 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 88 val_rmse_target: 0.4719 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.4714 val_rmse_stderror: 1.816
# New best_val_rmse: 0.4714
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.4718 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4725 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 96 val_rmse_target: 0.4733 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4741 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 100 val_rmse_target: 0.475 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.477 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 104 val_rmse_target: 0.4785 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4798 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 108 val_rmse_target: 0.4801 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 4 steps took 2.12 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.4807 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 4 steps took 2.13 seconds
# Epoch: 2 batch_num: 116 val_rmse_target: 0.4787 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4776 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 120 val_rmse_target: 0.477 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4765 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 124 val_rmse_target: 0.476 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4756 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 128 val_rmse_target: 0.4754 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4752 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4751 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.475 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 136 val_rmse_target: 0.475 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.475 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# 2 steps took 1.06 seconds
# Epoch: 2 batch_num: 140 val_rmse_target: 0.475 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4714 (from epoch 2)
#
# Performance estimates:
# [0.48492947465747144, 0.46014416143049347, 0.4714131356173499]
# Mean: 0.4721622572351049
#
# Fold 4/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 8.81 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9971 val_rmse_stderror: 1.911
# New best_val_rmse: 0.9971
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.7583 val_rmse_stderror: 1.766
# New best_val_rmse: 0.7583
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7297 val_rmse_stderror: 1.826
# New best_val_rmse: 0.7297
#
# 16 steps took 8.32 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.62 val_rmse_stderror: 1.787
# New best_val_rmse: 0.62
#
# 16 steps took 8.33 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.5498 val_rmse_stderror: 1.824
# New best_val_rmse: 0.5498
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6211 val_rmse_stderror: 1.818
# Still best_val_rmse: 0.5498 (from epoch 0)
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6516 val_rmse_stderror: 1.806
# Still best_val_rmse: 0.5498 (from epoch 0)
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.563 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.5498 (from epoch 0)
#
# 16 steps took 8.47 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.536 val_rmse_stderror: 1.789
# New best_val_rmse: 0.536
#
# 16 steps took 8.32 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5155 val_rmse_stderror: 1.797
# New best_val_rmse: 0.5155
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5303 val_rmse_stderror: 1.812
# Still best_val_rmse: 0.5155 (from epoch 1)
#
# 16 steps took 8.32 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5143 val_rmse_stderror: 1.831
# New best_val_rmse: 0.5143
#
# 16 steps took 8.31 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5157 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.5143 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5094 val_rmse_stderror: 1.804
# New best_val_rmse: 0.5094
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5176 val_rmse_stderror: 1.809
# Still best_val_rmse: 0.5094 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.4972 val_rmse_stderror: 1.789
# New best_val_rmse: 0.4972
#
# 8 steps took 4.15 seconds
# Epoch: 1 batch_num: 123 val_rmse_target: 0.5 val_rmse_stderror: 1.814
# Still best_val_rmse: 0.4972 (from epoch 1)
#
# 8 steps took 4.16 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.4842 val_rmse_stderror: 1.788
# New best_val_rmse: 0.4842
#
# 4 steps took 2.07 seconds
# Epoch: 1 batch_num: 135 val_rmse_target: 0.5061 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4842 (from epoch 1)
#
# 16 steps took 8.43 seconds
# Epoch: 2 batch_num: 10 val_rmse_target: 0.501 val_rmse_stderror: 1.804
# Still best_val_rmse: 0.4842 (from epoch 1)
#
# 16 steps took 8.29 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.4857 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4842 (from epoch 1)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.4833 val_rmse_stderror: 1.792
# New best_val_rmse: 0.4833
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.485 val_rmse_stderror: 1.798
# Still best_val_rmse: 0.4833 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4857 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.4833 (from epoch 2)
#
# 4 steps took 2.08 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.4956 val_rmse_stderror: 1.801
# Still best_val_rmse: 0.4833 (from epoch 2)
#
# 8 steps took 4.15 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4811 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4811
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4828 val_rmse_stderror: 1.801
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.4889 val_rmse_stderror: 1.8
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.5031 val_rmse_stderror: 1.801
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 16 steps took 8.3 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4908 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 8 steps took 4.16 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4933 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 8 steps took 4.16 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4863 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.08 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4849 val_rmse_stderror: 1.798
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4859 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4887 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4909 val_rmse_stderror: 1.798
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 8 steps took 4.15 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4908 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 8 steps took 4.15 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.489 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4885 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4883 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4883 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# Performance estimates:
# [0.48492947465747144, 0.46014416143049347, 0.4714131356173499, 0.4811283970651009]
# Mean: 0.47440379219260387
#
# Fold 5/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 8.83 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9309 val_rmse_stderror: 1.756
# New best_val_rmse: 0.9309
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.7992 val_rmse_stderror: 1.748
# New best_val_rmse: 0.7992
#
# 16 steps took 8.29 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7126 val_rmse_stderror: 1.726
# New best_val_rmse: 0.7126
#
# 16 steps took 8.29 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6015 val_rmse_stderror: 1.677
# New best_val_rmse: 0.6015
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.5588 val_rmse_stderror: 1.69
# New best_val_rmse: 0.5588
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6506 val_rmse_stderror: 1.715
# Still best_val_rmse: 0.5588 (from epoch 0)
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.7177 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.5588 (from epoch 0)
#
# 16 steps took 8.28 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5749 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.5588 (from epoch 0)
#
# 16 steps took 8.42 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5771 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.5588 (from epoch 0)
#
# 16 steps took 8.28 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5488 val_rmse_stderror: 1.734
# New best_val_rmse: 0.5488
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5013 val_rmse_stderror: 1.731
# New best_val_rmse: 0.5013
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.519 val_rmse_stderror: 1.706
# Still best_val_rmse: 0.5013 (from epoch 1)
#
# 16 steps took 8.27 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.504 val_rmse_stderror: 1.724
# Still best_val_rmse: 0.5013 (from epoch 1)
#
# 16 steps took 8.28 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.492 val_rmse_stderror: 1.763
# New best_val_rmse: 0.492
#
# 8 steps took 4.13 seconds
# Epoch: 1 batch_num: 91 val_rmse_target: 0.5111 val_rmse_stderror: 1.727
# Still best_val_rmse: 0.492 (from epoch 1)
#
# 16 steps took 8.29 seconds
# Epoch: 1 batch_num: 107 val_rmse_target: 0.4899 val_rmse_stderror: 1.733
# New best_val_rmse: 0.4899
#
# 4 steps took 2.07 seconds
# Epoch: 1 batch_num: 111 val_rmse_target: 0.5225 val_rmse_stderror: 1.732
# Still best_val_rmse: 0.4899 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 127 val_rmse_target: 0.5627 val_rmse_stderror: 1.731
# Still best_val_rmse: 0.4899 (from epoch 1)
#
# 16 steps took 8.42 seconds
# Epoch: 2 batch_num: 2 val_rmse_target: 0.4786 val_rmse_stderror: 1.771
# New best_val_rmse: 0.4786
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 4 val_rmse_target: 0.4792 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.4818 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 10 val_rmse_target: 0.4915 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 8 steps took 4.14 seconds
# Epoch: 2 batch_num: 18 val_rmse_target: 0.4993 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 8 steps took 4.14 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.4969 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 8 steps took 4.14 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.4865 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4867 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.4892 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.5102 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 16 steps took 8.28 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4807 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4923 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 8 steps took 4.15 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4859 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4786 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4769 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4769
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4765 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4765
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.4762 val_rmse_stderror: 1.749
# New best_val_rmse: 0.4762
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4759 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4759
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4757 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4757
#
# 2 steps took 1.04 seconds
# Epoch: 2 batch_num: 88 val_rmse_target: 0.4765 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.4781 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.4799 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 2 steps took 1.03 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.482 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4865 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4885 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4851 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.06 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4838 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4835 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4825 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4823 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4825 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4825 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4825 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# 4 steps took 2.07 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4825 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4757 (from epoch 2)
#
# Performance estimates:
# [0.48492947465747144, 0.46014416143049347, 0.4714131356173499, 0.4811283970651009, 0.475721452058328]
# Mean: 0.47466732416574875

# %%
print(list_val_rmse)
# Out:
# [0.4823114265044416, 0.46504391109194415, 0.47078830284675466, 0.4878951380783082, 0.47400883621435297]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 477M/477M [00:30<00:00, 16.4MB/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_3.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.2MB/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_5.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.3MB/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_4.pth
# 100%|██████████| 477M/477M [00:34<00:00, 14.4MB/s]
# Upload successful: model_4.pth (477MB)
# Starting upload for file model_1.pth
# 100%|██████████| 477M/477M [00:36<00:00, 13.9MB/s]
# Upload successful: model_1.pth (477MB)
