# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '054-train-04'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import pickle
import gc
gc.enable()

# %%
2**14
# Out:
# 16384

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 248 # ベクトル長
TFIDF_MAX_FEAT = 16384

EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# 参考: https://www.guruguru.science/competitions/16/discussions/556029f7-484d-40d4-ad6a-9d86337487e2/
from sklearn.feature_extraction.text import TfidfVectorizer

# ベースとなる継承元のクラス
class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    def transform(self, input_df):
        raise NotImplementedError()


class TfidfSimpleBlock(BaseBlock):
    """シンプルなTF-IDF特徴を作成する block"""
    def __init__(self, column: str, max_features=50, ngram_range=(1,1), use_idf=True):
        """
        args:
            column: str
                変換対象のカラム名
        """
        self.column = column
        self.max_features=max_features
        self.ngram_range=ngram_range
        self.use_idf=use_idf
        self.param_prefix=f"col={column}_max_features={max_features}_\
                              ngram={ngram_range[0]}_{ngram_range[1]}_use_idf={use_idf}"

    def preprocess(self, input_df):
        x = text_normalization(input_df[self.column])
        return x

    def get_master(self, _master_df):
        """tdidfを計算するための全体集合を返す."""
        return _master_df
    def fit(self, 
            input_df, 
            _master_df=None, 
            y=None
           ):
        master_df = input_df if _master_df is None else self.get_master(_master_df)
        text = self.preprocess(master_df)
        self.vectorizer_ = TfidfVectorizer(max_features=self.max_features
                                      ,ngram_range=self.ngram_range
                                      ,use_idf=self.use_idf)

        self.vectorizer_.fit(text)
        self.prefix = 'tfidf' if self.use_idf == True else 'tf'
        return self.transform(input_df)

    def transform(self, input_df):
        text = self.preprocess(input_df)
        z = self.vectorizer_.transform(text)

        out_df = pd.DataFrame(z.toarray())
        out_df.columns = self.vectorizer_.get_feature_names()
        return out_df.add_prefix(f'{self.prefix}_')

# %%
class LitDataset(Dataset):
    def __init__(self, df, tfidf, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])
        self.tfidf = tfidf # fit済みのものを入力する。（クラス内ではtransformのみ行う）
        self.tfidf_vector = tfidf.transform(df).values

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)
        input_tfidf = torch.tensor(self.tfidf_vector[index, :], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len, input_tfidf)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, input_tfidf, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_wordlen = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64)
        )

        self.mlm_tfidf = nn.Sequential(
            nn.Linear(TFIDF_MAX_FEAT, 192),
            nn.ReLU(),
            nn.Linear(192, 192),
            nn.ReLU(),
            nn.Linear(192, 64)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64 + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len, input_tfidf):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # mlm_layers
        mlm_wordlen = self.mlm_wordlen(input_len)
        mlm_tfidf = self.mlm_tfidf(input_tfidf)

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_wordlen, mlm_tfidf], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len, input_tfidf) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target
    del input_len
    del input_tfidf

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len, input_tfidf) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += output.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len, input_tfidf) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_wrd_parameters = list(model.mlm_wordlen.named_parameters())
    mlm_wrd_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_wrd_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_wrd_group

    mlm_tfidf_parameters = list(model.mlm_tfidf.named_parameters())
    mlm_tfidf_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_tfidf_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_tfidf_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path, feat_suffix):
    tfidf = TfidfSimpleBlock('excerpt', max_features=TFIDF_MAX_FEAT)
    df_tfidf = tfidf.fit(train_df.loc[train_indices]) # TODO: fit_transformみたいなメソッド作って、fitではdfが返らないようにする。

    with open(f'TFIDF_{feat_suffix}', 'wb') as f:
      pickle.dump(tfidf, f)

    train_dataset = LitDataset(train_df.loc[train_indices], tfidf) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices], tfidf)
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    feat_suffix = f"{fold + 1}.pkl" 

    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path, feat_suffix))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8809 train_rmse_stderror: 0.09551 train_kl_div: 1.623
# val_rmse_target: 0.8871 val_rmse_stderror: 1.185
# New best_val_rmse: 0.8871
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5735 train_rmse_stderror: 0.1208 train_kl_div: 0.7891
# val_rmse_target: 0.6411 val_rmse_stderror: 1.201
# New best_val_rmse: 0.6411
#
# 64 steps took 37.8 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4722 train_rmse_stderror: 0.08429 train_kl_div: 0.4952
# val_rmse_target: 0.6081 val_rmse_stderror: 1.18
# New best_val_rmse: 0.6081
#
# 64 steps took 37.8 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5966 train_rmse_stderror: 0.1029 train_kl_div: 0.7444
# val_rmse_target: 0.5782 val_rmse_stderror: 1.207
# New best_val_rmse: 0.5782
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5966 train_rmse_stderror: 0.06729 train_kl_div: 0.6752
# val_rmse_target: 0.5666 val_rmse_stderror: 1.211
# New best_val_rmse: 0.5666
#
# 64 steps took 37.9 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.3018 train_rmse_stderror: 0.05449 train_kl_div: 0.2057
# val_rmse_target: 0.5378 val_rmse_stderror: 1.195
# New best_val_rmse: 0.5378
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.4768 train_rmse_stderror: 0.04126 train_kl_div: 0.4929
# val_rmse_target: 0.7337 val_rmse_stderror: 1.215
# Still best_val_rmse: 0.5378 (from epoch 1)
#
# 64 steps took 37.9 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.4837 train_rmse_stderror: 0.06163 train_kl_div: 0.5035
# val_rmse_target: 0.5328 val_rmse_stderror: 1.196
# New best_val_rmse: 0.5328
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.6789 train_rmse_stderror: 0.06286 train_kl_div: 0.9575
# val_rmse_target: 0.6051 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.5328 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1812 train_rmse_stderror: 0.04385 train_kl_div: 0.07698
# val_rmse_target: 0.5107 val_rmse_stderror: 1.188
# New best_val_rmse: 0.5107
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3236 train_rmse_stderror: 0.05514 train_kl_div: 0.1972
# val_rmse_target: 0.5133 val_rmse_stderror: 1.206
# Still best_val_rmse: 0.5107 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3674 train_rmse_stderror: 0.05295 train_kl_div: 0.3092
# val_rmse_target: 0.4862 val_rmse_stderror: 1.192
# New best_val_rmse: 0.4862
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1441 train_rmse_stderror: 0.05509 train_kl_div: 0.05299
# val_rmse_target: 0.532 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4862 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1906 train_rmse_stderror: 0.07639 train_kl_div: 0.1037
# val_rmse_target: 0.4985 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4862 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2214 train_rmse_stderror: 0.0575 train_kl_div: 0.1091
# val_rmse_target: 0.4754 val_rmse_stderror: 1.197
# New best_val_rmse: 0.4754
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3368 train_rmse_stderror: 0.06455 train_kl_div: 0.2401
# val_rmse_target: 0.482 val_rmse_stderror: 1.202
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.343 train_rmse_stderror: 0.02652 train_kl_div: 0.2271
# val_rmse_target: 0.4911 val_rmse_stderror: 1.205
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2869 train_rmse_stderror: 0.06588 train_kl_div: 0.1915
# val_rmse_target: 0.5129 val_rmse_stderror: 1.192
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1658 train_rmse_stderror: 0.04485 train_kl_div: 0.0574
# val_rmse_target: 0.4836 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.08884 train_rmse_stderror: 0.04221 train_kl_div: 0.02401
# val_rmse_target: 0.4848 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1213 train_rmse_stderror: 0.0517 train_kl_div: 0.0405
# val_rmse_target: 0.4865 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1485 train_rmse_stderror: 0.03558 train_kl_div: 0.05007
# val_rmse_target: 0.4863 val_rmse_stderror: 1.193
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1276 train_rmse_stderror: 0.04247 train_kl_div: 0.04185
# val_rmse_target: 0.4823 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.09183 train_rmse_stderror: 0.03334 train_kl_div: 0.0229
# val_rmse_target: 0.4869 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1304 train_rmse_stderror: 0.03779 train_kl_div: 0.04191
# val_rmse_target: 0.4926 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1358 train_rmse_stderror: 0.04435 train_kl_div: 0.04525
# val_rmse_target: 0.488 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.09868 train_rmse_stderror: 0.0379 train_kl_div: 0.02372
# val_rmse_target: 0.4874 val_rmse_stderror: 1.202
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1072 train_rmse_stderror: 0.04545 train_kl_div: 0.03318
# val_rmse_target: 0.4881 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08168 train_rmse_stderror: 0.02608 train_kl_div: 0.01672
# val_rmse_target: 0.4874 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06822 train_rmse_stderror: 0.02568 train_kl_div: 0.01223
# val_rmse_target: 0.4894 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.07047 train_rmse_stderror: 0.04174 train_kl_div: 0.01887
# val_rmse_target: 0.4922 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07453 train_rmse_stderror: 0.04233 train_kl_div: 0.01836
# val_rmse_target: 0.4891 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.06833 train_rmse_stderror: 0.03507 train_kl_div: 0.0157
# val_rmse_target: 0.4899 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05512 train_rmse_stderror: 0.04047 train_kl_div: 0.0133
# val_rmse_target: 0.4885 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1094 train_rmse_stderror: 0.02781 train_kl_div: 0.02445
# val_rmse_target: 0.4884 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.06605 train_rmse_stderror: 0.03593 train_kl_div: 0.01528
# val_rmse_target: 0.4886 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4754 (from epoch 2)
#
# Performance estimates:
# [0.47536843052512934]
# Mean: 0.47536843052512934
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6551 train_rmse_stderror: 0.09839 train_kl_div: 0.8569
# val_rmse_target: 0.9325 val_rmse_stderror: 1.089
# New best_val_rmse: 0.9325
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.05 train_rmse_stderror: 0.03588 train_kl_div: 2.092
# val_rmse_target: 0.6404 val_rmse_stderror: 1.113
# New best_val_rmse: 0.6404
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5853 train_rmse_stderror: 0.07893 train_kl_div: 0.6353
# val_rmse_target: 0.5646 val_rmse_stderror: 1.112
# New best_val_rmse: 0.5646
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.3019 train_rmse_stderror: 0.05651 train_kl_div: 0.2113
# val_rmse_target: 0.5758 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.5646 (from epoch 0)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.503 train_rmse_stderror: 0.07905 train_kl_div: 0.5799
# val_rmse_target: 0.5477 val_rmse_stderror: 1.07
# New best_val_rmse: 0.5477
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4622 train_rmse_stderror: 0.06192 train_kl_div: 0.4774
# val_rmse_target: 0.5314 val_rmse_stderror: 1.084
# New best_val_rmse: 0.5314
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4947 train_rmse_stderror: 0.1257 train_kl_div: 0.51
# val_rmse_target: 0.5499 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.5314 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.4268 train_rmse_stderror: 0.04935 train_kl_div: 0.3654
# val_rmse_target: 0.5281 val_rmse_stderror: 1.098
# New best_val_rmse: 0.5281
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5986 train_rmse_stderror: 0.03106 train_kl_div: 0.7292
# val_rmse_target: 0.569 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.5281 (from epoch 1)
#
# 64 steps took 37.9 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4269 train_rmse_stderror: 0.06386 train_kl_div: 0.4228
# val_rmse_target: 0.6093 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.5281 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3047 train_rmse_stderror: 0.02847 train_kl_div: 0.1862
# val_rmse_target: 0.522 val_rmse_stderror: 1.106
# New best_val_rmse: 0.522
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3522 train_rmse_stderror: 0.02829 train_kl_div: 0.2782
# val_rmse_target: 0.5327 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.522 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2651 train_rmse_stderror: 0.05001 train_kl_div: 0.1637
# val_rmse_target: 0.5226 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.522 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2456 train_rmse_stderror: 0.04347 train_kl_div: 0.1303
# val_rmse_target: 0.5596 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.522 (from epoch 2)
#
# 64 steps took 38.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2715 train_rmse_stderror: 0.04617 train_kl_div: 0.1456
# val_rmse_target: 0.5278 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.522 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3735 train_rmse_stderror: 0.05334 train_kl_div: 0.2972
# val_rmse_target: 0.5296 val_rmse_stderror: 1.095
# Still best_val_rmse: 0.522 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2403 train_rmse_stderror: 0.03708 train_kl_div: 0.1279
# val_rmse_target: 0.5107 val_rmse_stderror: 1.105
# New best_val_rmse: 0.5107
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.4397 train_rmse_stderror: 0.04374 train_kl_div: 0.44
# val_rmse_target: 0.5303 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.5107 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.248 train_rmse_stderror: 0.0675 train_kl_div: 0.09678
# val_rmse_target: 0.5047 val_rmse_stderror: 1.11
# New best_val_rmse: 0.5047
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2332 train_rmse_stderror: 0.05329 train_kl_div: 0.1062
# val_rmse_target: 0.5046 val_rmse_stderror: 1.098
# New best_val_rmse: 0.5046
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.194 train_rmse_stderror: 0.02895 train_kl_div: 0.08703
# val_rmse_target: 0.5035 val_rmse_stderror: 1.112
# New best_val_rmse: 0.5035
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2273 train_rmse_stderror: 0.02769 train_kl_div: 0.08469
# val_rmse_target: 0.5047 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5035 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1365 train_rmse_stderror: 0.03837 train_kl_div: 0.04935
# val_rmse_target: 0.5024 val_rmse_stderror: 1.124
# New best_val_rmse: 0.5024
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.141 train_rmse_stderror: 0.03119 train_kl_div: 0.04674
# val_rmse_target: 0.5053 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5024 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.2238 train_rmse_stderror: 0.04116 train_kl_div: 0.1035
# val_rmse_target: 0.5019 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5019
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1529 train_rmse_stderror: 0.03976 train_kl_div: 0.0565
# val_rmse_target: 0.5044 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.5019 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1506 train_rmse_stderror: 0.05708 train_kl_div: 0.06266
# val_rmse_target: 0.5014 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5014
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1693 train_rmse_stderror: 0.02966 train_kl_div: 0.06448
# val_rmse_target: 0.5022 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.2962 train_rmse_stderror: 0.0654 train_kl_div: 0.1662
# val_rmse_target: 0.5044 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.0666 train_rmse_stderror: 0.03601 train_kl_div: 0.01454
# val_rmse_target: 0.5022 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1347 train_rmse_stderror: 0.03501 train_kl_div: 0.04072
# val_rmse_target: 0.5041 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.148 train_rmse_stderror: 0.01726 train_kl_div: 0.0453
# val_rmse_target: 0.5024 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.17 train_rmse_stderror: 0.02951 train_kl_div: 0.0466
# val_rmse_target: 0.5017 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.07672 train_rmse_stderror: 0.02995 train_kl_div: 0.0158
# val_rmse_target: 0.5014 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.03581 train_rmse_stderror: 0.03679 train_kl_div: 0.008275
# val_rmse_target: 0.5016 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.141 train_rmse_stderror: 0.04947 train_kl_div: 0.0422
# val_rmse_target: 0.5017 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5014 (from epoch 3)
#
# Performance estimates:
# [0.47536843052512934, 0.5013690294345564]
# Mean: 0.4883687299798429
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 3/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6759 train_rmse_stderror: 0.1353 train_kl_div: 0.9119
# val_rmse_target: 0.6909 val_rmse_stderror: 1.737
# New best_val_rmse: 0.6909
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6397 train_rmse_stderror: 0.08938 train_kl_div: 0.7932
# val_rmse_target: 0.6876 val_rmse_stderror: 1.756
# New best_val_rmse: 0.6876
#
# 64 steps took 37.8 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.7793 train_rmse_stderror: 0.06913 train_kl_div: 1.117
# val_rmse_target: 0.5868 val_rmse_stderror: 1.781
# New best_val_rmse: 0.5868
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6541 train_rmse_stderror: 0.09089 train_kl_div: 0.7943
# val_rmse_target: 0.6158 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.5868 (from epoch 0)
#
# 64 steps took 38.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3281 train_rmse_stderror: 0.08882 train_kl_div: 0.1857
# val_rmse_target: 0.5055 val_rmse_stderror: 1.743
# New best_val_rmse: 0.5055
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.1653 train_rmse_stderror: 0.05981 train_kl_div: 0.07356
# val_rmse_target: 0.5211 val_rmse_stderror: 1.726
# Still best_val_rmse: 0.5055 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2197 train_rmse_stderror: 0.05767 train_kl_div: 0.1128
# val_rmse_target: 0.5563 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.5055 (from epoch 1)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3867 train_rmse_stderror: 0.0785 train_kl_div: 0.349
# val_rmse_target: 0.5757 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.5055 (from epoch 1)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4358 train_rmse_stderror: 0.05481 train_kl_div: 0.3137
# val_rmse_target: 0.5235 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.5055 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.2959 train_rmse_stderror: 0.08759 train_kl_div: 0.1978
# val_rmse_target: 0.5094 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.5055 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.394 train_rmse_stderror: 0.05337 train_kl_div: 0.275
# val_rmse_target: 0.5002 val_rmse_stderror: 1.756
# New best_val_rmse: 0.5002
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4562 train_rmse_stderror: 0.05169 train_kl_div: 0.37
# val_rmse_target: 0.516 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.5002 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3455 train_rmse_stderror: 0.04761 train_kl_div: 0.2425
# val_rmse_target: 0.4886 val_rmse_stderror: 1.744
# New best_val_rmse: 0.4886
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2869 train_rmse_stderror: 0.04902 train_kl_div: 0.1855
# val_rmse_target: 0.498 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4886 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1315 train_rmse_stderror: 0.05375 train_kl_div: 0.04773
# val_rmse_target: 0.4994 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4886 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2948 train_rmse_stderror: 0.04943 train_kl_div: 0.2043
# val_rmse_target: 0.4937 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4886 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3675 train_rmse_stderror: 0.07329 train_kl_div: 0.2201
# val_rmse_target: 0.4991 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4886 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1929 train_rmse_stderror: 0.04551 train_kl_div: 0.08194
# val_rmse_target: 0.4949 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4886 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.3643 train_rmse_stderror: 0.0554 train_kl_div: 0.2476
# val_rmse_target: 0.4835 val_rmse_stderror: 1.737
# New best_val_rmse: 0.4835
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.102 train_rmse_stderror: 0.04344 train_kl_div: 0.03261
# val_rmse_target: 0.4878 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1449 train_rmse_stderror: 0.04846 train_kl_div: 0.05261
# val_rmse_target: 0.484 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.0968 train_rmse_stderror: 0.03581 train_kl_div: 0.02129
# val_rmse_target: 0.4871 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1952 train_rmse_stderror: 0.04708 train_kl_div: 0.09377
# val_rmse_target: 0.4813 val_rmse_stderror: 1.742
# New best_val_rmse: 0.4813
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1652 train_rmse_stderror: 0.04614 train_kl_div: 0.05694
# val_rmse_target: 0.4863 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1954 train_rmse_stderror: 0.03687 train_kl_div: 0.079
# val_rmse_target: 0.4855 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1423 train_rmse_stderror: 0.02535 train_kl_div: 0.04735
# val_rmse_target: 0.4834 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.07806 train_rmse_stderror: 0.03778 train_kl_div: 0.01928
# val_rmse_target: 0.4828 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1011 train_rmse_stderror: 0.02908 train_kl_div: 0.0244
# val_rmse_target: 0.4837 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.08773 train_rmse_stderror: 0.03379 train_kl_div: 0.02182
# val_rmse_target: 0.4837 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08638 train_rmse_stderror: 0.04804 train_kl_div: 0.02325
# val_rmse_target: 0.4834 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06882 train_rmse_stderror: 0.0461 train_kl_div: 0.01912
# val_rmse_target: 0.4842 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 18.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.09274 train_rmse_stderror: 0.03986 train_kl_div: 0.02519
# val_rmse_target: 0.4837 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.06754 train_rmse_stderror: 0.02178 train_kl_div: 0.01196
# val_rmse_target: 0.4827 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.09585 train_rmse_stderror: 0.04623 train_kl_div: 0.02709
# val_rmse_target: 0.483 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 18.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05079 train_rmse_stderror: 0.03601 train_kl_div: 0.00956
# val_rmse_target: 0.4835 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.06705 train_rmse_stderror: 0.02801 train_kl_div: 0.01195
# val_rmse_target: 0.4834 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1004 train_rmse_stderror: 0.05439 train_kl_div: 0.03361
# val_rmse_target: 0.4833 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4813 (from epoch 3)
#
# Performance estimates:
# [0.47536843052512934, 0.5013690294345564, 0.4813158158819358]
# Mean: 0.48601775861387386
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 4/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4408 train_rmse_stderror: 0.1097 train_kl_div: 0.503
# val_rmse_target: 0.7368 val_rmse_stderror: 1.14
# New best_val_rmse: 0.7368
#
# 64 steps took 37.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.064 train_rmse_stderror: 0.0822 train_kl_div: 2.008
# val_rmse_target: 0.8035 val_rmse_stderror: 1.145
# Still best_val_rmse: 0.7368 (from epoch 0)
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.7592 train_rmse_stderror: 0.0748 train_kl_div: 1.142
# val_rmse_target: 0.5987 val_rmse_stderror: 1.185
# New best_val_rmse: 0.5987
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 1.099 train_rmse_stderror: 0.08986 train_kl_div: 2.133
# val_rmse_target: 0.5305 val_rmse_stderror: 1.147
# New best_val_rmse: 0.5305
#
# 32 steps took 19.2 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.4868 train_rmse_stderror: 0.04769 train_kl_div: 0.4937
# val_rmse_target: 0.6182 val_rmse_stderror: 1.148
# Still best_val_rmse: 0.5305 (from epoch 0)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.5027 train_rmse_stderror: 0.04321 train_kl_div: 0.5662
# val_rmse_target: 0.5017 val_rmse_stderror: 1.166
# New best_val_rmse: 0.5017
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.3957 train_rmse_stderror: 0.04021 train_kl_div: 0.3232
# val_rmse_target: 0.5167 val_rmse_stderror: 1.159
# Still best_val_rmse: 0.5017 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.3362 train_rmse_stderror: 0.08183 train_kl_div: 0.2388
# val_rmse_target: 0.4853 val_rmse_stderror: 1.166
# New best_val_rmse: 0.4853
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.6132 train_rmse_stderror: 0.04889 train_kl_div: 0.8485
# val_rmse_target: 0.4933 val_rmse_stderror: 1.166
# Still best_val_rmse: 0.4853 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5713 train_rmse_stderror: 0.05451 train_kl_div: 0.6991
# val_rmse_target: 0.4735 val_rmse_stderror: 1.153
# New best_val_rmse: 0.4735
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3093 train_rmse_stderror: 0.05762 train_kl_div: 0.2231
# val_rmse_target: 0.4675 val_rmse_stderror: 1.147
# New best_val_rmse: 0.4675
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4285 train_rmse_stderror: 0.04317 train_kl_div: 0.3378
# val_rmse_target: 0.5483 val_rmse_stderror: 1.145
# Still best_val_rmse: 0.4675 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2669 train_rmse_stderror: 0.02269 train_kl_div: 0.1344
# val_rmse_target: 0.4828 val_rmse_stderror: 1.143
# Still best_val_rmse: 0.4675 (from epoch 1)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4397 train_rmse_stderror: 0.04179 train_kl_div: 0.4253
# val_rmse_target: 0.5025 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4675 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2063 train_rmse_stderror: 0.04312 train_kl_div: 0.08148
# val_rmse_target: 0.4853 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4675 (from epoch 1)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1555 train_rmse_stderror: 0.03957 train_kl_div: 0.05864
# val_rmse_target: 0.4624 val_rmse_stderror: 1.157
# New best_val_rmse: 0.4624
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.3132 train_rmse_stderror: 0.03583 train_kl_div: 0.2449
# val_rmse_target: 0.4957 val_rmse_stderror: 1.167
# Still best_val_rmse: 0.4624 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3512 train_rmse_stderror: 0.05954 train_kl_div: 0.2476
# val_rmse_target: 0.4619 val_rmse_stderror: 1.151
# New best_val_rmse: 0.4619
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3077 train_rmse_stderror: 0.0577 train_kl_div: 0.1893
# val_rmse_target: 0.454 val_rmse_stderror: 1.152
# New best_val_rmse: 0.454
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2525 train_rmse_stderror: 0.04611 train_kl_div: 0.1463
# val_rmse_target: 0.4551 val_rmse_stderror: 1.16
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1984 train_rmse_stderror: 0.06609 train_kl_div: 0.08719
# val_rmse_target: 0.4676 val_rmse_stderror: 1.162
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2499 train_rmse_stderror: 0.04245 train_kl_div: 0.1194
# val_rmse_target: 0.4581 val_rmse_stderror: 1.163
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1263 train_rmse_stderror: 0.03852 train_kl_div: 0.04035
# val_rmse_target: 0.4591 val_rmse_stderror: 1.161
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.2304 train_rmse_stderror: 0.03817 train_kl_div: 0.09021
# val_rmse_target: 0.4627 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2514 train_rmse_stderror: 0.0442 train_kl_div: 0.1341
# val_rmse_target: 0.4766 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1101 train_rmse_stderror: 0.04774 train_kl_div: 0.03613
# val_rmse_target: 0.4564 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.2573 train_rmse_stderror: 0.03747 train_kl_div: 0.1251
# val_rmse_target: 0.4598 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1317 train_rmse_stderror: 0.05623 train_kl_div: 0.042
# val_rmse_target: 0.4638 val_rmse_stderror: 1.159
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.09994 train_rmse_stderror: 0.02881 train_kl_div: 0.02274
# val_rmse_target: 0.4576 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1533 train_rmse_stderror: 0.03628 train_kl_div: 0.05561
# val_rmse_target: 0.4592 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.06111 train_rmse_stderror: 0.04363 train_kl_div: 0.01456
# val_rmse_target: 0.4582 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08121 train_rmse_stderror: 0.01742 train_kl_div: 0.01505
# val_rmse_target: 0.4576 val_rmse_stderror: 1.16
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1281 train_rmse_stderror: 0.0291 train_kl_div: 0.03589
# val_rmse_target: 0.4585 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.0962 train_rmse_stderror: 0.03659 train_kl_div: 0.02451
# val_rmse_target: 0.4581 val_rmse_stderror: 1.159
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07167 train_rmse_stderror: 0.03828 train_kl_div: 0.01529
# val_rmse_target: 0.4595 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.09954 train_rmse_stderror: 0.02172 train_kl_div: 0.02286
# val_rmse_target: 0.4583 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.08193 train_rmse_stderror: 0.03496 train_kl_div: 0.01851
# val_rmse_target: 0.4594 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.07439 train_rmse_stderror: 0.03896 train_kl_div: 0.01614
# val_rmse_target: 0.4596 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.454 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08823 train_rmse_stderror: 0.03933 train_kl_div: 0.0186
# val_rmse_target: 0.4595 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.454 (from epoch 2)
#
# Performance estimates:
# [0.47536843052512934, 0.5013690294345564, 0.4813158158819358, 0.4540388283623997]
# Mean: 0.47802302605100533
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 5/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.781 train_rmse_stderror: 0.1152 train_kl_div: 1.194
# val_rmse_target: 0.6741 val_rmse_stderror: 1.777
# New best_val_rmse: 0.6741
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4363 train_rmse_stderror: 0.09018 train_kl_div: 0.4214
# val_rmse_target: 0.5906 val_rmse_stderror: 1.776
# New best_val_rmse: 0.5906
#
# 64 steps took 37.9 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5771 train_rmse_stderror: 0.05956 train_kl_div: 0.8219
# val_rmse_target: 0.5904 val_rmse_stderror: 1.802
# New best_val_rmse: 0.5904
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5832 train_rmse_stderror: 0.09919 train_kl_div: 0.7379
# val_rmse_target: 0.5528 val_rmse_stderror: 1.773
# New best_val_rmse: 0.5528
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.485 train_rmse_stderror: 0.08395 train_kl_div: 0.3747
# val_rmse_target: 0.5132 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5132
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4189 train_rmse_stderror: 0.0802 train_kl_div: 0.3549
# val_rmse_target: 0.5653 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.5132 (from epoch 1)
#
# 64 steps took 37.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.7068 train_rmse_stderror: 0.0794 train_kl_div: 0.8991
# val_rmse_target: 0.4988 val_rmse_stderror: 1.783
# New best_val_rmse: 0.4988
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4158 train_rmse_stderror: 0.07138 train_kl_div: 0.3848
# val_rmse_target: 0.5147 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4988 (from epoch 1)
#
# 32 steps took 18.9 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5381 train_rmse_stderror: 0.07245 train_kl_div: 0.6735
# val_rmse_target: 0.6744 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4988 (from epoch 1)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4919 train_rmse_stderror: 0.04759 train_kl_div: 0.5325
# val_rmse_target: 0.4943 val_rmse_stderror: 1.754
# New best_val_rmse: 0.4943
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2744 train_rmse_stderror: 0.08505 train_kl_div: 0.1809
# val_rmse_target: 0.4991 val_rmse_stderror: 1.804
# Still best_val_rmse: 0.4943 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.1995 train_rmse_stderror: 0.05193 train_kl_div: 0.1003
# val_rmse_target: 0.4929 val_rmse_stderror: 1.756
# New best_val_rmse: 0.4929
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3262 train_rmse_stderror: 0.08433 train_kl_div: 0.2594
# val_rmse_target: 0.5041 val_rmse_stderror: 1.782
# Still best_val_rmse: 0.4929 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3506 train_rmse_stderror: 0.03576 train_kl_div: 0.2857
# val_rmse_target: 0.4812 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4812
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2316 train_rmse_stderror: 0.06667 train_kl_div: 0.1248
# val_rmse_target: 0.5142 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4812 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2806 train_rmse_stderror: 0.04658 train_kl_div: 0.1601
# val_rmse_target: 0.4815 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4812 (from epoch 2)
#
# 32 steps took 18.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.376 train_rmse_stderror: 0.07573 train_kl_div: 0.2801
# val_rmse_target: 0.508 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4812 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2341 train_rmse_stderror: 0.06305 train_kl_div: 0.1446
# val_rmse_target: 0.5043 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4812 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2952 train_rmse_stderror: 0.08151 train_kl_div: 0.2235
# val_rmse_target: 0.4833 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4812 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.127 train_rmse_stderror: 0.04008 train_kl_div: 0.03285
# val_rmse_target: 0.4808 val_rmse_stderror: 1.765
# New best_val_rmse: 0.4808
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1381 train_rmse_stderror: 0.05898 train_kl_div: 0.0585
# val_rmse_target: 0.4831 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4808 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1504 train_rmse_stderror: 0.06248 train_kl_div: 0.05675
# val_rmse_target: 0.4755 val_rmse_stderror: 1.771
# New best_val_rmse: 0.4755
#
# 32 steps took 18.9 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2265 train_rmse_stderror: 0.04106 train_kl_div: 0.1231
# val_rmse_target: 0.4768 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4755 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1983 train_rmse_stderror: 0.03776 train_kl_div: 0.08509
# val_rmse_target: 0.4747 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4747
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1653 train_rmse_stderror: 0.04449 train_kl_div: 0.06641
# val_rmse_target: 0.4783 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1179 train_rmse_stderror: 0.04761 train_kl_div: 0.04135
# val_rmse_target: 0.4857 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1799 train_rmse_stderror: 0.06096 train_kl_div: 0.07578
# val_rmse_target: 0.4867 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.08499 train_rmse_stderror: 0.05557 train_kl_div: 0.02765
# val_rmse_target: 0.4781 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.08242 train_rmse_stderror: 0.03147 train_kl_div: 0.01611
# val_rmse_target: 0.4784 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.07766 train_rmse_stderror: 0.04388 train_kl_div: 0.01993
# val_rmse_target: 0.4773 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.08832 train_rmse_stderror: 0.01776 train_kl_div: 0.01793
# val_rmse_target: 0.4773 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.06488 train_rmse_stderror: 0.04492 train_kl_div: 0.01491
# val_rmse_target: 0.4773 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 18.9 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.09192 train_rmse_stderror: 0.03539 train_kl_div: 0.01767
# val_rmse_target: 0.4794 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.07572 train_rmse_stderror: 0.05215 train_kl_div: 0.02042
# val_rmse_target: 0.4772 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 18.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09129 train_rmse_stderror: 0.0638 train_kl_div: 0.03332
# val_rmse_target: 0.4772 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 18.9 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.06827 train_rmse_stderror: 0.04534 train_kl_div: 0.01874
# val_rmse_target: 0.4775 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1143 train_rmse_stderror: 0.07321 train_kl_div: 0.04913
# val_rmse_target: 0.4776 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4747 (from epoch 3)
#
# Performance estimates:
# [0.47536843052512934, 0.5013690294345564, 0.4813158158819358, 0.4540388283623997, 0.4747424767286941]
# Mean: 0.47736691618654314
# {'total_MiB': 16160, 'used_MiB': 1359}

# %%
print(list_val_rmse)
# Out:
# [0.47536843052512934, 0.5013690294345564, 0.4813158158819358, 0.4540388283623997, 0.4747424767286941]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# !cp -r /content/TFIDF_1.pkl /content/model/TFIDF_1.pkl
# !cp -r /content/TFIDF_2.pkl /content/model/TFIDF_2.pkl
# !cp -r /content/TFIDF_3.pkl /content/model/TFIDF_3.pkl
# !cp -r /content/TFIDF_4.pkl /content/model/TFIDF_4.pkl
# !cp -r /content/TFIDF_5.pkl /content/model/TFIDF_5.pkl
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Starting upload for file TFIDF_1.pkl
# 100%|██████████| 1.32M/1.32M [00:03<00:00, 361kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: TFIDF_1.pkl (1MB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.34G/1.34G [00:55<00:00, 25.9MB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.34G/1.34G [00:50<00:00, 28.3MB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.34G/1.34G [00:51<00:00, 27.7MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file TFIDF_5.pkl
# 100%|██████████| 1.32M/1.32M [00:05<00:00, 254kB/s]
#   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Upload successful: TFIDF_5.pkl (1MB)
# Starting upload for file TFIDF_3.pkl
# 100%|██████████| 1.32M/1.32M [00:04<00:00, 344kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: TFIDF_3.pkl (1MB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.34G/1.34G [00:50<00:00, 28.7MB/s]
#   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file TFIDF_4.pkl
# 100%|██████████| 1.32M/1.32M [00:04<00:00, 330kB/s]
#   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Upload successful: TFIDF_4.pkl (1MB)
# Starting upload for file TFIDF_2.pkl
# 100%|██████████| 1.32M/1.32M [00:03<00:00, 377kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: TFIDF_2.pkl (1MB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.34G/1.34G [00:49<00:00, 29.1MB/s]
# Upload successful: model_5.pth (1GB)
