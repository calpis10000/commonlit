# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '054-train-05-3'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import pickle
import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 248 # ベクトル長
TFIDF_MAX_FEAT = 16384

EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# ベースとなる継承元のクラス
class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    def transform(self, input_df):
        raise NotImplementedError()

class CountVectorizerSimpleBlock(BaseBlock):
    """CountVectorizerのベクトルをそのまま返す block"""
    def __init__(self, column: str, master_df=None, max_features=50, ngram_range=(1,1)):
        """
        args:
            column: str
                変換対象のカラム名
        """
        self.column = column
        self.master_df=master_df
        self.max_features=max_features
        self.ngram_range=ngram_range
        self.param_prefix = f"col={column}_feats={max_features}_ngram={''.join([str(i) for i in self.ngram_range])}"

    def preprocess(self, input_df):
        x = text_normalization(input_df[self.column])
        return x

    def fit(self, 
            input_df, 
            y=None
           ):
        master_df = input_df if self.master_df is None else self.master_df
        text = self.preprocess(master_df)
        self.vectorizer_ = CountVectorizer(max_features=self.max_features, ngram_range=self.ngram_range)

        self.vectorizer_.fit(text)
        self.prefix = 'countvec'
        return self.transform(input_df)

    def transform(self, input_df):
        text = self.preprocess(input_df)
        z = self.vectorizer_.transform(text)

        out_df = pd.DataFrame(z.toarray())
        out_df.columns = self.vectorizer_.get_feature_names()
        return out_df.add_prefix(f'{self.prefix}_')

# %%
class LitDataset(Dataset):
    def __init__(self, df, vectorizer_, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])
        self.vectorizer_ = vectorizer_ # fit済みのものを入力する。（クラス内ではtransformのみ行う）
        self.vectorizer_val = vectorizer_.transform(df).values

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)
        input_bow = torch.tensor(self.vectorizer_val[index, :], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len, input_tfidf)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, input_bow, target, standard_error)

# %%
#vectorizer_ = CountVectorizerSimpleBlock('excerpt', max_features=TFIDF_MAX_FEAT)
#vec_df = vectorizer_.fit(train_df)
# litds = LitDataset(train_df, vectorizer_)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_wordlen = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64)
        )

        self.mlm_tfidf = nn.Sequential(
            nn.Linear(TFIDF_MAX_FEAT, 192),
            nn.ReLU(),
            nn.Linear(192, 192),
            nn.ReLU(),
            nn.Linear(192, 64)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64 + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len, input_tfidf):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # mlm_layers
        mlm_wordlen = self.mlm_wordlen(input_len)
        mlm_tfidf = self.mlm_tfidf(input_tfidf)

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_wordlen, mlm_tfidf], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len, input_tfidf) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target
    del input_len
    del input_tfidf

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len, input_tfidf) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += output.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len, input_tfidf) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_wrd_parameters = list(model.mlm_wordlen.named_parameters())
    mlm_wrd_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_wrd_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_wrd_group

    mlm_tfidf_parameters = list(model.mlm_tfidf.named_parameters())
    mlm_tfidf_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_tfidf_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_tfidf_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path, feat_suffix):
    tfidf = CountVectorizerSimpleBlock('excerpt', max_features=TFIDF_MAX_FEAT) # TODO: 名前をtfidfから変更する
    df_cntvec = tfidf.fit(train_df.loc[train_indices]) # TODO: fit_transformみたいなメソッド作って、fitではdfが返らないようにする。

    with open(f'CntVec_{feat_suffix}', 'wb') as f:
      pickle.dump(tfidf, f)

    train_dataset = LitDataset(train_df.loc[train_indices], tfidf) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices], tfidf)
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    feat_suffix = f"{fold + 1}.pkl" 

    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path, feat_suffix))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8318 train_rmse_stderror: 0.1173 train_kl_div: 1.47
# val_rmse_target: 0.7931 val_rmse_stderror: 1.173
# New best_val_rmse: 0.7931
#
# 64 steps took 38.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5964 train_rmse_stderror: 0.1251 train_kl_div: 0.8419
# val_rmse_target: 0.6596 val_rmse_stderror: 1.242
# New best_val_rmse: 0.6596
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5317 train_rmse_stderror: 0.07291 train_kl_div: 0.6108
# val_rmse_target: 0.6277 val_rmse_stderror: 1.179
# New best_val_rmse: 0.6277
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6172 train_rmse_stderror: 0.0899 train_kl_div: 0.7594
# val_rmse_target: 0.6063 val_rmse_stderror: 1.204
# New best_val_rmse: 0.6063
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.7096 train_rmse_stderror: 0.06495 train_kl_div: 0.964
# val_rmse_target: 0.5488 val_rmse_stderror: 1.197
# New best_val_rmse: 0.5488
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.453 train_rmse_stderror: 0.06785 train_kl_div: 0.315
# val_rmse_target: 0.548 val_rmse_stderror: 1.18
# New best_val_rmse: 0.548
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2813 train_rmse_stderror: 0.0559 train_kl_div: 0.1819
# val_rmse_target: 0.5477 val_rmse_stderror: 1.201
# New best_val_rmse: 0.5477
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.554 train_rmse_stderror: 0.05199 train_kl_div: 0.6954
# val_rmse_target: 0.6574 val_rmse_stderror: 1.209
# Still best_val_rmse: 0.5477 (from epoch 1)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5224 train_rmse_stderror: 0.06315 train_kl_div: 0.5775
# val_rmse_target: 0.5222 val_rmse_stderror: 1.203
# New best_val_rmse: 0.5222
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.7453 train_rmse_stderror: 0.06103 train_kl_div: 1.14
# val_rmse_target: 0.6154 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.5222 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3138 train_rmse_stderror: 0.05012 train_kl_div: 0.2322
# val_rmse_target: 0.5049 val_rmse_stderror: 1.191
# New best_val_rmse: 0.5049
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4688 train_rmse_stderror: 0.08572 train_kl_div: 0.4364
# val_rmse_target: 0.505 val_rmse_stderror: 1.216
# Still best_val_rmse: 0.5049 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3518 train_rmse_stderror: 0.06485 train_kl_div: 0.2626
# val_rmse_target: 0.5575 val_rmse_stderror: 1.192
# Still best_val_rmse: 0.5049 (from epoch 2)
#
# 64 steps took 38.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2668 train_rmse_stderror: 0.04464 train_kl_div: 0.1556
# val_rmse_target: 0.5152 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.5049 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2421 train_rmse_stderror: 0.04623 train_kl_div: 0.1487
# val_rmse_target: 0.5287 val_rmse_stderror: 1.189
# Still best_val_rmse: 0.5049 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2125 train_rmse_stderror: 0.06905 train_kl_div: 0.1116
# val_rmse_target: 0.5327 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.5049 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.4004 train_rmse_stderror: 0.04863 train_kl_div: 0.3233
# val_rmse_target: 0.4914 val_rmse_stderror: 1.188
# New best_val_rmse: 0.4914
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2479 train_rmse_stderror: 0.07456 train_kl_div: 0.1568
# val_rmse_target: 0.5115 val_rmse_stderror: 1.185
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2006 train_rmse_stderror: 0.0535 train_kl_div: 0.08419
# val_rmse_target: 0.4907 val_rmse_stderror: 1.188
# New best_val_rmse: 0.4907
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1685 train_rmse_stderror: 0.04095 train_kl_div: 0.06934
# val_rmse_target: 0.4797 val_rmse_stderror: 1.187
# New best_val_rmse: 0.4797
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1804 train_rmse_stderror: 0.05886 train_kl_div: 0.07825
# val_rmse_target: 0.4902 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4797 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2574 train_rmse_stderror: 0.05451 train_kl_div: 0.1327
# val_rmse_target: 0.5072 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4797 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.267 train_rmse_stderror: 0.05082 train_kl_div: 0.182
# val_rmse_target: 0.4805 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4797 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1876 train_rmse_stderror: 0.03062 train_kl_div: 0.07951
# val_rmse_target: 0.4836 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4797 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1328 train_rmse_stderror: 0.04584 train_kl_div: 0.04839
# val_rmse_target: 0.4769 val_rmse_stderror: 1.189
# New best_val_rmse: 0.4769
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1472 train_rmse_stderror: 0.04789 train_kl_div: 0.05605
# val_rmse_target: 0.4827 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1579 train_rmse_stderror: 0.03591 train_kl_div: 0.05297
# val_rmse_target: 0.4851 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1335 train_rmse_stderror: 0.04668 train_kl_div: 0.0446
# val_rmse_target: 0.4851 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1111 train_rmse_stderror: 0.03424 train_kl_div: 0.03022
# val_rmse_target: 0.4839 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1562 train_rmse_stderror: 0.03106 train_kl_div: 0.05034
# val_rmse_target: 0.4852 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1238 train_rmse_stderror: 0.04206 train_kl_div: 0.04271
# val_rmse_target: 0.4839 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1071 train_rmse_stderror: 0.04318 train_kl_div: 0.03177
# val_rmse_target: 0.4847 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.08603 train_rmse_stderror: 0.03928 train_kl_div: 0.02304
# val_rmse_target: 0.4833 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.07431 train_rmse_stderror: 0.04452 train_kl_div: 0.02133
# val_rmse_target: 0.4847 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1223 train_rmse_stderror: 0.03667 train_kl_div: 0.03136
# val_rmse_target: 0.4844 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08703 train_rmse_stderror: 0.03558 train_kl_div: 0.02251
# val_rmse_target: 0.4845 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4769 (from epoch 3)
#
# Performance estimates:
# [0.47688312037187347]
# Mean: 0.47688312037187347
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.653 train_rmse_stderror: 0.1014 train_kl_div: 0.8737
# val_rmse_target: 0.9271 val_rmse_stderror: 1.082
# New best_val_rmse: 0.9271
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.124 train_rmse_stderror: 0.059 train_kl_div: 2.362
# val_rmse_target: 0.6643 val_rmse_stderror: 1.126
# New best_val_rmse: 0.6643
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5403 train_rmse_stderror: 0.07693 train_kl_div: 0.5442
# val_rmse_target: 0.5734 val_rmse_stderror: 1.116
# New best_val_rmse: 0.5734
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4131 train_rmse_stderror: 0.06608 train_kl_div: 0.372
# val_rmse_target: 0.5847 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.5734 (from epoch 0)
#
# 64 steps took 38.3 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.525 train_rmse_stderror: 0.07291 train_kl_div: 0.6248
# val_rmse_target: 0.5513 val_rmse_stderror: 1.076
# New best_val_rmse: 0.5513
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4551 train_rmse_stderror: 0.1183 train_kl_div: 0.4422
# val_rmse_target: 0.5608 val_rmse_stderror: 1.122
# Still best_val_rmse: 0.5513 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.63 train_rmse_stderror: 0.035 train_kl_div: 0.7892
# val_rmse_target: 0.6032 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.5513 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4245 train_rmse_stderror: 0.06514 train_kl_div: 0.4211
# val_rmse_target: 0.6123 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.5513 (from epoch 1)
#
# 64 steps took 38.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1574 train_rmse_stderror: 0.03309 train_kl_div: 0.06049
# val_rmse_target: 0.5202 val_rmse_stderror: 1.1
# New best_val_rmse: 0.5202
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.276 train_rmse_stderror: 0.05044 train_kl_div: 0.1479
# val_rmse_target: 0.5102 val_rmse_stderror: 1.102
# New best_val_rmse: 0.5102
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1775 train_rmse_stderror: 0.04353 train_kl_div: 0.06886
# val_rmse_target: 0.518 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.5102 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2241 train_rmse_stderror: 0.06755 train_kl_div: 0.1055
# val_rmse_target: 0.5056 val_rmse_stderror: 1.112
# New best_val_rmse: 0.5056
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1659 train_rmse_stderror: 0.04235 train_kl_div: 0.06591
# val_rmse_target: 0.5061 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2124 train_rmse_stderror: 0.04149 train_kl_div: 0.1041
# val_rmse_target: 0.5338 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.247 train_rmse_stderror: 0.04114 train_kl_div: 0.1263
# val_rmse_target: 0.524 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2823 train_rmse_stderror: 0.04862 train_kl_div: 0.1915
# val_rmse_target: 0.5198 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2761 train_rmse_stderror: 0.06005 train_kl_div: 0.1762
# val_rmse_target: 0.5084 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1129 train_rmse_stderror: 0.05192 train_kl_div: 0.03779
# val_rmse_target: 0.5074 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.5056 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.109 train_rmse_stderror: 0.039 train_kl_div: 0.03306
# val_rmse_target: 0.5013 val_rmse_stderror: 1.112
# New best_val_rmse: 0.5013
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1135 train_rmse_stderror: 0.03447 train_kl_div: 0.03091
# val_rmse_target: 0.5004 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5004
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2165 train_rmse_stderror: 0.03451 train_kl_div: 0.0958
# val_rmse_target: 0.5048 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1694 train_rmse_stderror: 0.04559 train_kl_div: 0.07167
# val_rmse_target: 0.5038 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1258 train_rmse_stderror: 0.02173 train_kl_div: 0.03688
# val_rmse_target: 0.5012 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1854 train_rmse_stderror: 0.0352 train_kl_div: 0.07681
# val_rmse_target: 0.5008 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1609 train_rmse_stderror: 0.04968 train_kl_div: 0.05274
# val_rmse_target: 0.502 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1334 train_rmse_stderror: 0.04683 train_kl_div: 0.045
# val_rmse_target: 0.5008 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1117 train_rmse_stderror: 0.02349 train_kl_div: 0.02568
# val_rmse_target: 0.5028 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1257 train_rmse_stderror: 0.04411 train_kl_div: 0.03667
# val_rmse_target: 0.5043 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06616 train_rmse_stderror: 0.03881 train_kl_div: 0.01534
# val_rmse_target: 0.5036 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.08101 train_rmse_stderror: 0.02676 train_kl_div: 0.01406
# val_rmse_target: 0.5014 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.05105 train_rmse_stderror: 0.02676 train_kl_div: 0.009046
# val_rmse_target: 0.5006 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1167 train_rmse_stderror: 0.0296 train_kl_div: 0.03174
# val_rmse_target: 0.5006 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05317 train_rmse_stderror: 0.02319 train_kl_div: 0.008098
# val_rmse_target: 0.5011 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.06129 train_rmse_stderror: 0.03479 train_kl_div: 0.01373
# val_rmse_target: 0.5008 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.06993 train_rmse_stderror: 0.03829 train_kl_div: 0.01539
# val_rmse_target: 0.5007 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5004 (from epoch 3)
#
# Performance estimates:
# [0.47688312037187347, 0.500389435651391]
# Mean: 0.48863627801163223
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 3/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6359 train_rmse_stderror: 0.1299 train_kl_div: 0.8009
# val_rmse_target: 0.6679 val_rmse_stderror: 1.725
# New best_val_rmse: 0.6679
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.609 train_rmse_stderror: 0.0821 train_kl_div: 0.7134
# val_rmse_target: 0.6543 val_rmse_stderror: 1.743
# New best_val_rmse: 0.6543
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 1.096 train_rmse_stderror: 0.08369 train_kl_div: 2.27
# val_rmse_target: 0.6613 val_rmse_stderror: 1.815
# Still best_val_rmse: 0.6543 (from epoch 0)
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6982 train_rmse_stderror: 0.0913 train_kl_div: 0.9485
# val_rmse_target: 0.6782 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.6543 (from epoch 0)
#
# 64 steps took 38.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3554 train_rmse_stderror: 0.09392 train_kl_div: 0.2271
# val_rmse_target: 0.5083 val_rmse_stderror: 1.732
# New best_val_rmse: 0.5083
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.216 train_rmse_stderror: 0.07424 train_kl_div: 0.1154
# val_rmse_target: 0.6077 val_rmse_stderror: 1.722
# Still best_val_rmse: 0.5083 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.593 train_rmse_stderror: 0.05241 train_kl_div: 0.7132
# val_rmse_target: 0.5596 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.5083 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.2307 train_rmse_stderror: 0.06808 train_kl_div: 0.1426
# val_rmse_target: 0.5229 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5083 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3608 train_rmse_stderror: 0.05305 train_kl_div: 0.2276
# val_rmse_target: 0.5158 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5083 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.2938 train_rmse_stderror: 0.0874 train_kl_div: 0.2007
# val_rmse_target: 0.5236 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.5083 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.5291 train_rmse_stderror: 0.05063 train_kl_div: 0.4691
# val_rmse_target: 0.505 val_rmse_stderror: 1.768
# New best_val_rmse: 0.505
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.5909 train_rmse_stderror: 0.04924 train_kl_div: 0.5801
# val_rmse_target: 0.5096 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.505 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2667 train_rmse_stderror: 0.04374 train_kl_div: 0.1369
# val_rmse_target: 0.5008 val_rmse_stderror: 1.746
# New best_val_rmse: 0.5008
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2723 train_rmse_stderror: 0.05114 train_kl_div: 0.1641
# val_rmse_target: 0.5112 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.5008 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2507 train_rmse_stderror: 0.05307 train_kl_div: 0.1431
# val_rmse_target: 0.5059 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.5008 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2535 train_rmse_stderror: 0.05584 train_kl_div: 0.158
# val_rmse_target: 0.4901 val_rmse_stderror: 1.77
# New best_val_rmse: 0.4901
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.4437 train_rmse_stderror: 0.07896 train_kl_div: 0.3164
# val_rmse_target: 0.4957 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4901 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2296 train_rmse_stderror: 0.04605 train_kl_div: 0.1129
# val_rmse_target: 0.5069 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4901 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2689 train_rmse_stderror: 0.04654 train_kl_div: 0.15
# val_rmse_target: 0.4878 val_rmse_stderror: 1.732
# New best_val_rmse: 0.4878
#
# 32 steps took 19.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1694 train_rmse_stderror: 0.04505 train_kl_div: 0.07303
# val_rmse_target: 0.4873 val_rmse_stderror: 1.737
# New best_val_rmse: 0.4873
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1205 train_rmse_stderror: 0.05408 train_kl_div: 0.03996
# val_rmse_target: 0.4785 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4785
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1855 train_rmse_stderror: 0.04926 train_kl_div: 0.06417
# val_rmse_target: 0.4874 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2017 train_rmse_stderror: 0.04962 train_kl_div: 0.09899
# val_rmse_target: 0.4798 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1878 train_rmse_stderror: 0.04931 train_kl_div: 0.06855
# val_rmse_target: 0.4821 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.3331 train_rmse_stderror: 0.03536 train_kl_div: 0.2331
# val_rmse_target: 0.4915 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1969 train_rmse_stderror: 0.02278 train_kl_div: 0.07802
# val_rmse_target: 0.4803 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1383 train_rmse_stderror: 0.04796 train_kl_div: 0.0482
# val_rmse_target: 0.4835 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.0907 train_rmse_stderror: 0.03457 train_kl_div: 0.02231
# val_rmse_target: 0.481 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1012 train_rmse_stderror: 0.03741 train_kl_div: 0.02751
# val_rmse_target: 0.483 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1188 train_rmse_stderror: 0.05883 train_kl_div: 0.04049
# val_rmse_target: 0.4836 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1012 train_rmse_stderror: 0.04821 train_kl_div: 0.03226
# val_rmse_target: 0.4852 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.09024 train_rmse_stderror: 0.04314 train_kl_div: 0.02416
# val_rmse_target: 0.4852 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.09629 train_rmse_stderror: 0.02336 train_kl_div: 0.02213
# val_rmse_target: 0.4843 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.08929 train_rmse_stderror: 0.05095 train_kl_div: 0.02587
# val_rmse_target: 0.4841 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1384 train_rmse_stderror: 0.0438 train_kl_div: 0.03911
# val_rmse_target: 0.485 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1174 train_rmse_stderror: 0.03328 train_kl_div: 0.03019
# val_rmse_target: 0.4851 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.06671 train_rmse_stderror: 0.05554 train_kl_div: 0.02324
# val_rmse_target: 0.4851 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4785 (from epoch 3)
#
# Performance estimates:
# [0.47688312037187347, 0.500389435651391, 0.47854329196616063]
# Mean: 0.4852719493298084
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 4/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5691 train_rmse_stderror: 0.07088 train_kl_div: 0.721
# val_rmse_target: 0.911 val_rmse_stderror: 1.129
# New best_val_rmse: 0.911
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.07 train_rmse_stderror: 0.08062 train_kl_div: 2.034
# val_rmse_target: 0.8036 val_rmse_stderror: 1.147
# New best_val_rmse: 0.8036
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.756 train_rmse_stderror: 0.08091 train_kl_div: 1.166
# val_rmse_target: 0.5692 val_rmse_stderror: 1.187
# New best_val_rmse: 0.5692
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 1.043 train_rmse_stderror: 0.0919 train_kl_div: 1.926
# val_rmse_target: 0.506 val_rmse_stderror: 1.15
# New best_val_rmse: 0.506
#
# 32 steps took 19.3 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.4733 train_rmse_stderror: 0.04235 train_kl_div: 0.4617
# val_rmse_target: 0.6479 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.506 (from epoch 0)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4463 train_rmse_stderror: 0.05202 train_kl_div: 0.4518
# val_rmse_target: 0.56 val_rmse_stderror: 1.163
# Still best_val_rmse: 0.506 (from epoch 0)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.2475 train_rmse_stderror: 0.08133 train_kl_div: 0.1501
# val_rmse_target: 0.488 val_rmse_stderror: 1.169
# New best_val_rmse: 0.488
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5895 train_rmse_stderror: 0.03321 train_kl_div: 0.7671
# val_rmse_target: 0.513 val_rmse_stderror: 1.165
# Still best_val_rmse: 0.488 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5135 train_rmse_stderror: 0.04639 train_kl_div: 0.5633
# val_rmse_target: 0.466 val_rmse_stderror: 1.154
# New best_val_rmse: 0.466
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.2689 train_rmse_stderror: 0.05345 train_kl_div: 0.1672
# val_rmse_target: 0.4669 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.466 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4643 train_rmse_stderror: 0.03944 train_kl_div: 0.3935
# val_rmse_target: 0.5443 val_rmse_stderror: 1.135
# Still best_val_rmse: 0.466 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2765 train_rmse_stderror: 0.03789 train_kl_div: 0.176
# val_rmse_target: 0.4838 val_rmse_stderror: 1.159
# Still best_val_rmse: 0.466 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4311 train_rmse_stderror: 0.07725 train_kl_div: 0.3841
# val_rmse_target: 0.4905 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.466 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2197 train_rmse_stderror: 0.0795 train_kl_div: 0.1298
# val_rmse_target: 0.4637 val_rmse_stderror: 1.153
# New best_val_rmse: 0.4637
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3223 train_rmse_stderror: 0.02319 train_kl_div: 0.2178
# val_rmse_target: 0.5388 val_rmse_stderror: 1.18
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1829 train_rmse_stderror: 0.0522 train_kl_div: 0.07917
# val_rmse_target: 0.4821 val_rmse_stderror: 1.166
# Still best_val_rmse: 0.4637 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2096 train_rmse_stderror: 0.04044 train_kl_div: 0.08713
# val_rmse_target: 0.4636 val_rmse_stderror: 1.153
# New best_val_rmse: 0.4636
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2713 train_rmse_stderror: 0.08377 train_kl_div: 0.1739
# val_rmse_target: 0.4696 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4636 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2392 train_rmse_stderror: 0.0571 train_kl_div: 0.1377
# val_rmse_target: 0.4634 val_rmse_stderror: 1.152
# New best_val_rmse: 0.4634
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.4118 train_rmse_stderror: 0.06278 train_kl_div: 0.358
# val_rmse_target: 0.4531 val_rmse_stderror: 1.152
# New best_val_rmse: 0.4531
#
# 32 steps took 19.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1635 train_rmse_stderror: 0.05593 train_kl_div: 0.06213
# val_rmse_target: 0.4593 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1824 train_rmse_stderror: 0.03257 train_kl_div: 0.07962
# val_rmse_target: 0.4689 val_rmse_stderror: 1.168
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1547 train_rmse_stderror: 0.04034 train_kl_div: 0.05401
# val_rmse_target: 0.4714 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.105 train_rmse_stderror: 0.04535 train_kl_div: 0.03264
# val_rmse_target: 0.4606 val_rmse_stderror: 1.163
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1988 train_rmse_stderror: 0.04418 train_kl_div: 0.08837
# val_rmse_target: 0.459 val_rmse_stderror: 1.149
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1232 train_rmse_stderror: 0.05677 train_kl_div: 0.04191
# val_rmse_target: 0.4623 val_rmse_stderror: 1.159
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1747 train_rmse_stderror: 0.03732 train_kl_div: 0.06767
# val_rmse_target: 0.4774 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1235 train_rmse_stderror: 0.02852 train_kl_div: 0.03014
# val_rmse_target: 0.4623 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.08568 train_rmse_stderror: 0.06184 train_kl_div: 0.03028
# val_rmse_target: 0.4616 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.07399 train_rmse_stderror: 0.02661 train_kl_div: 0.01468
# val_rmse_target: 0.4635 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1826 train_rmse_stderror: 0.05049 train_kl_div: 0.06504
# val_rmse_target: 0.4652 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.07825 train_rmse_stderror: 0.03882 train_kl_div: 0.0213
# val_rmse_target: 0.4638 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.08571 train_rmse_stderror: 0.03971 train_kl_div: 0.02107
# val_rmse_target: 0.4648 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1204 train_rmse_stderror: 0.05421 train_kl_div: 0.03791
# val_rmse_target: 0.4615 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.07948 train_rmse_stderror: 0.04515 train_kl_div: 0.02074
# val_rmse_target: 0.4625 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05528 train_rmse_stderror: 0.02697 train_kl_div: 0.01052
# val_rmse_target: 0.4643 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.07644 train_rmse_stderror: 0.04087 train_kl_div: 0.01924
# val_rmse_target: 0.4635 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1214 train_rmse_stderror: 0.03233 train_kl_div: 0.02865
# val_rmse_target: 0.4633 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4531 (from epoch 2)
#
# Performance estimates:
# [0.47688312037187347, 0.500389435651391, 0.47854329196616063, 0.4531098858634471]
# Mean: 0.47723143346321806
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 5/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.7957 train_rmse_stderror: 0.1301 train_kl_div: 1.246
# val_rmse_target: 0.7593 val_rmse_stderror: 1.756
# New best_val_rmse: 0.7593
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5902 train_rmse_stderror: 0.1002 train_kl_div: 0.7517
# val_rmse_target: 0.6053 val_rmse_stderror: 1.765
# New best_val_rmse: 0.6053
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5358 train_rmse_stderror: 0.05916 train_kl_div: 0.6807
# val_rmse_target: 0.5549 val_rmse_stderror: 1.787
# New best_val_rmse: 0.5549
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6262 train_rmse_stderror: 0.09331 train_kl_div: 0.8275
# val_rmse_target: 0.6028 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.5549 (from epoch 0)
#
# 64 steps took 38.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.6185 train_rmse_stderror: 0.07694 train_kl_div: 0.6459
# val_rmse_target: 0.5531 val_rmse_stderror: 1.754
# New best_val_rmse: 0.5531
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4606 train_rmse_stderror: 0.08578 train_kl_div: 0.4671
# val_rmse_target: 0.5613 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5531 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.513 train_rmse_stderror: 0.08741 train_kl_div: 0.6007
# val_rmse_target: 0.5413 val_rmse_stderror: 1.771
# New best_val_rmse: 0.5413
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5313 train_rmse_stderror: 0.07924 train_kl_div: 0.6588
# val_rmse_target: 0.628 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5413 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4145 train_rmse_stderror: 0.0439 train_kl_div: 0.3629
# val_rmse_target: 0.5164 val_rmse_stderror: 1.748
# New best_val_rmse: 0.5164
#
# 32 steps took 19.4 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3703 train_rmse_stderror: 0.07169 train_kl_div: 0.3205
# val_rmse_target: 0.5228 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.5164 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.4389 train_rmse_stderror: 0.07624 train_kl_div: 0.4026
# val_rmse_target: 0.6213 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.5164 (from epoch 1)
#
# 64 steps took 38.2 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.4603 train_rmse_stderror: 0.07616 train_kl_div: 0.4412
# val_rmse_target: 0.5028 val_rmse_stderror: 1.751
# New best_val_rmse: 0.5028
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.5157 train_rmse_stderror: 0.05373 train_kl_div: 0.5485
# val_rmse_target: 0.4946 val_rmse_stderror: 1.774
# New best_val_rmse: 0.4946
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.176 train_rmse_stderror: 0.07585 train_kl_div: 0.08858
# val_rmse_target: 0.4849 val_rmse_stderror: 1.769
# New best_val_rmse: 0.4849
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2709 train_rmse_stderror: 0.07167 train_kl_div: 0.1788
# val_rmse_target: 0.4967 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.3563 train_rmse_stderror: 0.07771 train_kl_div: 0.2721
# val_rmse_target: 0.4939 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2533 train_rmse_stderror: 0.05824 train_kl_div: 0.1593
# val_rmse_target: 0.5263 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2493 train_rmse_stderror: 0.03978 train_kl_div: 0.1454
# val_rmse_target: 0.495 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2377 train_rmse_stderror: 0.05574 train_kl_div: 0.1253
# val_rmse_target: 0.5208 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.2649 train_rmse_stderror: 0.08605 train_kl_div: 0.1663
# val_rmse_target: 0.4893 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1977 train_rmse_stderror: 0.05219 train_kl_div: 0.09753
# val_rmse_target: 0.491 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.2673 train_rmse_stderror: 0.04783 train_kl_div: 0.1318
# val_rmse_target: 0.4854 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.2176 train_rmse_stderror: 0.06882 train_kl_div: 0.1209
# val_rmse_target: 0.4867 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.2019 train_rmse_stderror: 0.08918 train_kl_div: 0.1236
# val_rmse_target: 0.4858 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.2691 train_rmse_stderror: 0.05796 train_kl_div: 0.1681
# val_rmse_target: 0.4895 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.2105 train_rmse_stderror: 0.05135 train_kl_div: 0.102
# val_rmse_target: 0.4884 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1366 train_rmse_stderror: 0.03602 train_kl_div: 0.0463
# val_rmse_target: 0.4874 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.15 train_rmse_stderror: 0.0417 train_kl_div: 0.05021
# val_rmse_target: 0.4864 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.247 train_rmse_stderror: 0.05069 train_kl_div: 0.1288
# val_rmse_target: 0.4897 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.12 train_rmse_stderror: 0.04032 train_kl_div: 0.03489
# val_rmse_target: 0.4876 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1476 train_rmse_stderror: 0.05832 train_kl_div: 0.05609
# val_rmse_target: 0.4873 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1562 train_rmse_stderror: 0.0496 train_kl_div: 0.06319
# val_rmse_target: 0.4882 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.2003 train_rmse_stderror: 0.04183 train_kl_div: 0.09199
# val_rmse_target: 0.4879 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.05987 train_rmse_stderror: 0.06772 train_kl_div: 0.02775
# val_rmse_target: 0.4882 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1612 train_rmse_stderror: 0.0933 train_kl_div: 0.101
# val_rmse_target: 0.4881 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4849 (from epoch 2)
#
# Performance estimates:
# [0.47688312037187347, 0.500389435651391, 0.47854329196616063, 0.4531098858634471, 0.48491476003680256]
# Mean: 0.47876809877793497
# {'total_MiB': 16160, 'used_MiB': 1359}

# %%
print(list_val_rmse)
# Out:
# [0.47688312037187347, 0.500389435651391, 0.47854329196616063, 0.4531098858634471, 0.48491476003680256]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# !cp -r /content/CntVec_1.pkl /content/model/CntVec_1.pkl
# !cp -r /content/CntVec_2.pkl /content/model/CntVec_2.pkl
# !cp -r /content/CntVec_3.pkl /content/model/CntVec_3.pkl
# !cp -r /content/CntVec_4.pkl /content/model/CntVec_4.pkl
# !cp -r /content/CntVec_5.pkl /content/model/CntVec_5.pkl
# Out:
# /root
# mkdir: cannot create directory ‘.kaggle’: File exists
# mkdir: cannot create directory ‘/content/model’: File exists

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Starting upload for file model_1.pth
# 100%|██████████| 1.34G/1.34G [00:52<00:00, 27.5MB/s]
#   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file CntVec_1.pkl
# 100%|██████████| 1.07M/1.07M [00:05<00:00, 225kB/s]
#   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Upload successful: CntVec_1.pkl (1MB)
# Starting upload for file CntVec_3.pkl
# 100%|██████████| 1.07M/1.07M [00:05<00:00, 210kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: CntVec_3.pkl (1MB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.34G/1.34G [00:55<00:00, 25.9MB/s]
#   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file CntVec_2.pkl
# 100%|██████████| 1.07M/1.07M [00:04<00:00, 261kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: CntVec_2.pkl (1MB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.34G/1.34G [00:57<00:00, 25.1MB/s]
#   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file CntVec_5.pkl
# 100%|██████████| 1.07M/1.07M [00:06<00:00, 183kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: CntVec_5.pkl (1MB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.34G/1.34G [00:55<00:00, 25.9MB/s]
#   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file CntVec_4.pkl
# 100%|██████████| 1.07M/1.07M [00:02<00:00, 404kB/s]
#   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Upload successful: CntVec_4.pkl (1MB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.34G/1.34G [00:49<00:00, 29.3MB/s]
# Upload successful: model_5.pth (1GB)
