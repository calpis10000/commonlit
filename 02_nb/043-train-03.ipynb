# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Collecting pytorch_memlab
#   Downloading https://files.pythonhosted.org/packages/c4/90/0e2e7a9efd85a208a43cce627d4d718738a01c1713d129a08d714becff5d/pytorch_memlab-0.2.3.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Collecting calmsize
#   Downloading https://files.pythonhosted.org/packages/da/69/382ee4e1553f15321dd76109325f6a186a79354c53e8ac97cf79a2ebddbe/calmsize-0.1.3.tar.gz
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)
# Building wheels for collected packages: pytorch-memlab, calmsize
#   Building wheel for pytorch-memlab (setup.py) ... done
#   Created wheel for pytorch-memlab: filename=pytorch_memlab-0.2.3-cp37-none-any.whl size=20200 sha256=072d7dc287cbc333c1574c9fa8244f9d56188b5d9c7d6115524df9e8c93d06c8
#   Stored in directory: /root/.cache/pip/wheels/0f/5a/89/2469c2174bfe7a9cdee7e2faa97be08b6f85cffca423b57e31
#   Building wheel for calmsize (setup.py) ... done
#   Created wheel for calmsize: filename=calmsize-0.1.3-cp37-none-any.whl size=2887 sha256=ebf7ce12d923c65f77b663cdef91ae16c0456bad133ef1556413f0859ea2e9b9
#   Stored in directory: /root/.cache/pip/wheels/02/ac/1a/2a3418bc8f81abda6cd1b6d0f8f287556fc8de80dbabab75d1
# Successfully built pytorch-memlab calmsize
# Installing collected packages: calmsize, pytorch-memlab
# Successfully installed calmsize-0.1.3 pytorch-memlab-0.2.3

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-base'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '043-train-03'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 3 # Epochs
BATCH_SIZE = 16 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=481.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355863.0, style=ProgressStyle(descript…

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512), # 768は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor_target = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 1)                        
        )

        self.regressor_stderror = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 1)                        
        )

    def forward(self, input_ids, attention_mask):
        #print('model: get_roberta_out: Start', gpuinfo())                 
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        #print('model: get_roberta_out: Done', gpuinfo())                 

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        #last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        last_hidden_state = roberta_output[0]

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base). # 
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        #weights = self.attention(last_layer_hidden_states) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        #context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor_target(mean_embeddings), self.regressor_stderror(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse01_sum = 0
    mse02_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            pred01, pred02 = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse01_sum += nn.MSELoss(reduction="sum")(pred01.flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse02_sum += nn.MSELoss(reduction="sum")(pred02.flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
    del input_ids
    del attention_mask
    del target

    mse01_result = mse01_sum / len(data_loader.dataset)
    mse02_result = mse02_sum / len(data_loader.dataset)
  
    return mse01_result, mse02_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred, pred02 = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            pred01, pred02 = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            mse01 = nn.MSELoss(reduction="mean")(pred01.flatten(), target)
            mse02 = nn.MSELoss(reduction="mean")(pred02.flatten(), standard_error)
            mse = mse01 #+ mse02

            mse.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                val_mse01, val_mse02 = eval_mse(model, val_loader)
                val_rmse01 = math.sqrt(val_mse01) # valid-setによるrmse計算                           
                val_rmse02 = math.sqrt(val_mse02) # valid-setによるrmse計算                           

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse_target: {val_rmse01:0.4}",
                      f"val_rmse_stderror: {val_rmse02:0.4}")

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_rmse01 >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_rmse01 < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_rmse01
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = named_parameters[:197] # パラメータをroberta用、attention用、regressor用に格納。(どうやって決めてるのだろう？)
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    )
    
    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=num_splits)
    
    # note that, instead of targets, we use bins!
    return kf.split(X=data, y=data.bins.values)

# %%
st_kfold_bins = create_folds(train_df, num_splits=5)

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(st_kfold_bins):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    #print('getmodel: Start', gpuinfo())                 
    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    #print('getmodel: Done', gpuinfo())                 

    #print('get_optim_sched: Start', gpuinfo())                 
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    #print('get_optim_sched: Done', gpuinfo())                 

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501200538.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.66 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.8439 val_rmse_stderror: 1.622
# New best_val_rmse: 0.8439
#
# 16 steps took 9.04 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.7663 val_rmse_stderror: 1.653
# New best_val_rmse: 0.7663
#
# 16 steps took 9.04 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.6616 val_rmse_stderror: 1.694
# New best_val_rmse: 0.6616
#
# 16 steps took 9.04 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6146 val_rmse_stderror: 1.662
# New best_val_rmse: 0.6146
#
# 16 steps took 9.05 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6764 val_rmse_stderror: 1.642
# Still best_val_rmse: 0.6146 (from epoch 0)
#
# 16 steps took 9.03 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5619 val_rmse_stderror: 1.642
# New best_val_rmse: 0.5619
#
# 16 steps took 9.05 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5566 val_rmse_stderror: 1.611
# New best_val_rmse: 0.5566
#
# 16 steps took 9.04 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.583 val_rmse_stderror: 1.597
# Still best_val_rmse: 0.5566 (from epoch 0)
#
# 16 steps took 9.18 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5282 val_rmse_stderror: 1.598
# New best_val_rmse: 0.5282
#
# 16 steps took 9.04 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5857 val_rmse_stderror: 1.615
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 16 steps took 9.03 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5511 val_rmse_stderror: 1.581
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 16 steps took 9.03 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.6651 val_rmse_stderror: 1.608
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 16 steps took 9.04 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5473 val_rmse_stderror: 1.585
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 16 steps took 9.04 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5702 val_rmse_stderror: 1.559
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 16 steps took 9.03 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5171 val_rmse_stderror: 1.57
# New best_val_rmse: 0.5171
#
# 16 steps took 9.04 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.4936 val_rmse_stderror: 1.562
# New best_val_rmse: 0.4936
#
# 8 steps took 4.52 seconds
# Epoch: 1 batch_num: 123 val_rmse_target: 0.5013 val_rmse_stderror: 1.567
# Still best_val_rmse: 0.4936 (from epoch 1)
#
# 16 steps took 9.04 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.4944 val_rmse_stderror: 1.558
# Still best_val_rmse: 0.4936 (from epoch 1)
#
# 8 steps took 4.66 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.4967 val_rmse_stderror: 1.575
# Still best_val_rmse: 0.4936 (from epoch 1)
#
# 8 steps took 4.52 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.51 val_rmse_stderror: 1.568
# Still best_val_rmse: 0.4936 (from epoch 1)
#
# 16 steps took 9.03 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.4878 val_rmse_stderror: 1.569
# New best_val_rmse: 0.4878
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.4953 val_rmse_stderror: 1.567
# Still best_val_rmse: 0.4878 (from epoch 2)
#
# 8 steps took 4.52 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.4868 val_rmse_stderror: 1.569
# New best_val_rmse: 0.4868
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4827 val_rmse_stderror: 1.57
# New best_val_rmse: 0.4827
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4831 val_rmse_stderror: 1.572
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4847 val_rmse_stderror: 1.573
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.485 val_rmse_stderror: 1.57
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4882 val_rmse_stderror: 1.568
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4873 val_rmse_stderror: 1.568
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4866 val_rmse_stderror: 1.569
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4906 val_rmse_stderror: 1.568
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 8 steps took 4.52 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.4898 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4875 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.4858 val_rmse_stderror: 1.567
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4848 val_rmse_stderror: 1.567
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4852 val_rmse_stderror: 1.567
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4863 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4869 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4861 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4852 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.27 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.485 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4854 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4857 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4858 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4859 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# 4 steps took 2.26 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4859 val_rmse_stderror: 1.566
# Still best_val_rmse: 0.4827 (from epoch 2)
#
# Performance estimates:
# [0.48272599678651706]
# Mean: 0.48272599678651706
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.3 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.152 val_rmse_stderror: 1.016
# New best_val_rmse: 1.152
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.8352 val_rmse_stderror: 1.05
# New best_val_rmse: 0.8352
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7196 val_rmse_stderror: 1.041
# New best_val_rmse: 0.7196
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7423 val_rmse_stderror: 1.066
# Still best_val_rmse: 0.7196 (from epoch 0)
#
# 16 steps took 8.8 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6072 val_rmse_stderror: 1.067
# New best_val_rmse: 0.6072
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.665 val_rmse_stderror: 1.037
# Still best_val_rmse: 0.6072 (from epoch 0)
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6644 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.6072 (from epoch 0)
#
# 16 steps took 8.79 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5513 val_rmse_stderror: 1.081
# New best_val_rmse: 0.5513
#
# 16 steps took 8.94 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.54 val_rmse_stderror: 1.083
# New best_val_rmse: 0.54
#
# 16 steps took 8.78 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5621 val_rmse_stderror: 1.073
# Still best_val_rmse: 0.54 (from epoch 1)
#
# 16 steps took 8.8 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5433 val_rmse_stderror: 1.087
# Still best_val_rmse: 0.54 (from epoch 1)
#
# 16 steps took 8.8 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5151 val_rmse_stderror: 1.072
# New best_val_rmse: 0.5151
#
# 16 steps took 8.79 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5714 val_rmse_stderror: 1.064
# Still best_val_rmse: 0.5151 (from epoch 1)
#
# 16 steps took 8.79 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5162 val_rmse_stderror: 1.069
# Still best_val_rmse: 0.5151 (from epoch 1)
#
# 16 steps took 8.81 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5075 val_rmse_stderror: 1.075
# New best_val_rmse: 0.5075
#
# 16 steps took 8.8 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5199 val_rmse_stderror: 1.066
# Still best_val_rmse: 0.5075 (from epoch 1)
#
# 16 steps took 8.79 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5191 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.5075 (from epoch 1)
#
# 16 steps took 8.94 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5009 val_rmse_stderror: 1.072
# New best_val_rmse: 0.5009
#
# 16 steps took 8.78 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.4965 val_rmse_stderror: 1.071
# New best_val_rmse: 0.4965
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.4961 val_rmse_stderror: 1.068
# New best_val_rmse: 0.4961
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.5029 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4961 (from epoch 2)
#
# 16 steps took 8.79 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4914 val_rmse_stderror: 1.072
# New best_val_rmse: 0.4914
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4957 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.5 val_rmse_stderror: 1.068
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4921 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.39 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4929 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.4 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.5015 val_rmse_stderror: 1.071
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.79 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.508 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.78 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.5063 val_rmse_stderror: 1.07
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# Performance estimates:
# [0.48272599678651706, 0.4914349458665815]
# Mean: 0.4870804713265493
#
# Fold 3/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.25 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.037 val_rmse_stderror: 1.681
# New best_val_rmse: 1.037
#
# 16 steps took 8.72 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.9662 val_rmse_stderror: 1.698
# New best_val_rmse: 0.9662
#
# 16 steps took 8.73 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7483 val_rmse_stderror: 1.75
# New best_val_rmse: 0.7483
#
# 16 steps took 8.72 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6451 val_rmse_stderror: 1.8
# New best_val_rmse: 0.6451
#
# 16 steps took 8.72 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.601 val_rmse_stderror: 1.781
# New best_val_rmse: 0.601
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5429 val_rmse_stderror: 1.754
# New best_val_rmse: 0.5429
#
# 16 steps took 8.71 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5345 val_rmse_stderror: 1.759
# New best_val_rmse: 0.5345
#
# 16 steps took 8.71 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5239 val_rmse_stderror: 1.765
# New best_val_rmse: 0.5239
#
# 16 steps took 8.89 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5231 val_rmse_stderror: 1.767
# New best_val_rmse: 0.5231
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.4894 val_rmse_stderror: 1.777
# New best_val_rmse: 0.4894
#
# 4 steps took 2.19 seconds
# Epoch: 1 batch_num: 23 val_rmse_target: 0.5605 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4894 (from epoch 1)
#
# 16 steps took 8.72 seconds
# Epoch: 1 batch_num: 39 val_rmse_target: 0.4751 val_rmse_stderror: 1.76
# New best_val_rmse: 0.4751
#
# 2 steps took 1.1 seconds
# Epoch: 1 batch_num: 41 val_rmse_target: 0.4812 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4751 (from epoch 1)
#
# 4 steps took 2.19 seconds
# Epoch: 1 batch_num: 45 val_rmse_target: 0.5326 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4751 (from epoch 1)
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 61 val_rmse_target: 0.4701 val_rmse_stderror: 1.765
# New best_val_rmse: 0.4701
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 63 val_rmse_target: 0.4696 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4696
#
# 1 steps took 0.55 seconds
# Epoch: 1 batch_num: 64 val_rmse_target: 0.47 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4696 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 1 batch_num: 65 val_rmse_target: 0.4682 val_rmse_stderror: 1.763
# New best_val_rmse: 0.4682
#
# 1 steps took 0.549 seconds
# Epoch: 1 batch_num: 66 val_rmse_target: 0.4715 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 68 val_rmse_target: 0.4827 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 4 steps took 2.18 seconds
# Epoch: 1 batch_num: 72 val_rmse_target: 0.4731 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 74 val_rmse_target: 0.4989 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 8 steps took 4.35 seconds
# Epoch: 1 batch_num: 82 val_rmse_target: 0.5204 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 98 val_rmse_target: 0.4709 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 100 val_rmse_target: 0.4683 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4682 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 1 batch_num: 101 val_rmse_target: 0.468 val_rmse_stderror: 1.757
# New best_val_rmse: 0.468
#
# 1 steps took 0.547 seconds
# Epoch: 1 batch_num: 102 val_rmse_target: 0.4579 val_rmse_stderror: 1.759
# New best_val_rmse: 0.4579
#
# 1 steps took 0.55 seconds
# Epoch: 1 batch_num: 103 val_rmse_target: 0.4649 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4579 (from epoch 1)
#
# 1 steps took 0.549 seconds
# Epoch: 1 batch_num: 104 val_rmse_target: 0.4703 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4579 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 106 val_rmse_target: 0.4863 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4579 (from epoch 1)
#
# 4 steps took 2.18 seconds
# Epoch: 1 batch_num: 110 val_rmse_target: 0.4481 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4481
#
# 1 steps took 0.547 seconds
# Epoch: 1 batch_num: 111 val_rmse_target: 0.4531 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.545 seconds
# Epoch: 1 batch_num: 112 val_rmse_target: 0.472 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 114 val_rmse_target: 0.5274 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 130 val_rmse_target: 0.4687 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.4669 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 1 batch_num: 132 val_rmse_target: 0.4645 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 1 batch_num: 133 val_rmse_target: 0.4697 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.549 seconds
# Epoch: 1 batch_num: 134 val_rmse_target: 0.4706 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 1 batch_num: 136 val_rmse_target: 0.4639 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 1 batch_num: 137 val_rmse_target: 0.4661 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 1 batch_num: 138 val_rmse_target: 0.4689 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.461 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.551 seconds
# Epoch: 1 batch_num: 140 val_rmse_target: 0.459 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.698 seconds
# Epoch: 2 batch_num: 0 val_rmse_target: 0.4609 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.549 seconds
# Epoch: 2 batch_num: 1 val_rmse_target: 0.468 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 2 val_rmse_target: 0.4846 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 4 steps took 2.18 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.4911 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 8 steps took 4.35 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.4684 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 15 val_rmse_target: 0.475 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 17 val_rmse_target: 0.4691 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 18 val_rmse_target: 0.4784 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 20 val_rmse_target: 0.5204 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 36 val_rmse_target: 0.5015 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 16 steps took 8.71 seconds
# Epoch: 2 batch_num: 52 val_rmse_target: 0.4671 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.553 seconds
# Epoch: 2 batch_num: 53 val_rmse_target: 0.4653 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.553 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4648 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.552 seconds
# Epoch: 2 batch_num: 55 val_rmse_target: 0.4646 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 56 val_rmse_target: 0.4635 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 2 batch_num: 57 val_rmse_target: 0.4634 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.463 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.545 seconds
# Epoch: 2 batch_num: 59 val_rmse_target: 0.4629 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 60 val_rmse_target: 0.4627 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.549 seconds
# Epoch: 2 batch_num: 61 val_rmse_target: 0.4623 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.462 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 63 val_rmse_target: 0.462 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 64 val_rmse_target: 0.4629 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 65 val_rmse_target: 0.4625 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4639 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 67 val_rmse_target: 0.4657 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 68 val_rmse_target: 0.4674 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 69 val_rmse_target: 0.4696 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4714 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 72 val_rmse_target: 0.4745 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.478 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.1 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.4783 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.4763 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4733 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.4686 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 83 val_rmse_target: 0.4667 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4662 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 85 val_rmse_target: 0.4653 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4634 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 87 val_rmse_target: 0.4629 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.55 seconds
# Epoch: 2 batch_num: 88 val_rmse_target: 0.4631 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 89 val_rmse_target: 0.4633 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.549 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.4638 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 91 val_rmse_target: 0.4651 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.55 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.4668 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 2 batch_num: 93 val_rmse_target: 0.4675 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.55 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4682 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 95 val_rmse_target: 0.4692 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.548 seconds
# Epoch: 2 batch_num: 96 val_rmse_target: 0.4694 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 97 val_rmse_target: 0.4687 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4677 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.552 seconds
# Epoch: 2 batch_num: 99 val_rmse_target: 0.4671 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 100 val_rmse_target: 0.4672 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.55 seconds
# Epoch: 2 batch_num: 101 val_rmse_target: 0.4674 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.545 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4679 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 103 val_rmse_target: 0.4686 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 104 val_rmse_target: 0.4684 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 105 val_rmse_target: 0.4687 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.544 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4691 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.546 seconds
# Epoch: 2 batch_num: 107 val_rmse_target: 0.4697 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 1 steps took 0.547 seconds
# Epoch: 2 batch_num: 108 val_rmse_target: 0.47 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.471 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.4718 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4724 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 116 val_rmse_target: 0.473 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4732 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 120 val_rmse_target: 0.4734 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4729 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 124 val_rmse_target: 0.4722 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.1 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4717 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 128 val_rmse_target: 0.4715 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4713 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4712 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4712 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 136 val_rmse_target: 0.4711 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4711 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# 2 steps took 1.09 seconds
# Epoch: 2 batch_num: 140 val_rmse_target: 0.4711 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4481 (from epoch 1)
#
# Performance estimates:
# [0.48272599678651706, 0.4914349458665815, 0.4480896879975985]
# Mean: 0.47408354355023236
#
# Fold 4/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.06 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.166 val_rmse_stderror: 1.434
# New best_val_rmse: 1.166
#
# 16 steps took 8.56 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.011 val_rmse_stderror: 1.476
# New best_val_rmse: 1.011
#
# 16 steps took 8.55 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 1.012 val_rmse_stderror: 1.536
# Still best_val_rmse: 1.011 (from epoch 0)
#
# 16 steps took 8.56 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6955 val_rmse_stderror: 1.543
# New best_val_rmse: 0.6955
#
# 16 steps took 8.55 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6787 val_rmse_stderror: 1.532
# New best_val_rmse: 0.6787
#
# 16 steps took 8.56 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5815 val_rmse_stderror: 1.504
# New best_val_rmse: 0.5815
#
# 16 steps took 8.56 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5512 val_rmse_stderror: 1.485
# New best_val_rmse: 0.5512
#
# 16 steps took 8.55 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6061 val_rmse_stderror: 1.468
# Still best_val_rmse: 0.5512 (from epoch 0)
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5296 val_rmse_stderror: 1.503
# New best_val_rmse: 0.5296
#
# 16 steps took 8.56 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.522 val_rmse_stderror: 1.491
# New best_val_rmse: 0.522
#
# 16 steps took 8.56 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5275 val_rmse_stderror: 1.485
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 8.54 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.4958 val_rmse_stderror: 1.497
# New best_val_rmse: 0.4958
#
# 8 steps took 4.28 seconds
# Epoch: 1 batch_num: 59 val_rmse_target: 0.509 val_rmse_stderror: 1.501
# Still best_val_rmse: 0.4958 (from epoch 1)
#
# 16 steps took 8.55 seconds
# Epoch: 1 batch_num: 75 val_rmse_target: 0.4972 val_rmse_stderror: 1.502
# Still best_val_rmse: 0.4958 (from epoch 1)
#
# 8 steps took 4.28 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5018 val_rmse_stderror: 1.5
# Still best_val_rmse: 0.4958 (from epoch 1)
#
# 16 steps took 8.55 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.4991 val_rmse_stderror: 1.497
# Still best_val_rmse: 0.4958 (from epoch 1)
#
# 8 steps took 4.28 seconds
# Epoch: 1 batch_num: 107 val_rmse_target: 0.5435 val_rmse_stderror: 1.511
# Still best_val_rmse: 0.4958 (from epoch 1)
#
# 16 steps took 8.56 seconds
# Epoch: 1 batch_num: 123 val_rmse_target: 0.4922 val_rmse_stderror: 1.51
# New best_val_rmse: 0.4922
#
# 8 steps took 4.3 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5666 val_rmse_stderror: 1.516
# Still best_val_rmse: 0.4922 (from epoch 1)
#
# 16 steps took 8.74 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.4976 val_rmse_stderror: 1.511
# Still best_val_rmse: 0.4922 (from epoch 1)
#
# 8 steps took 4.29 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.4859 val_rmse_stderror: 1.507
# New best_val_rmse: 0.4859
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 18 val_rmse_target: 0.4853 val_rmse_stderror: 1.511
# New best_val_rmse: 0.4853
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.5082 val_rmse_stderror: 1.516
# Still best_val_rmse: 0.4853 (from epoch 2)
#
# 16 steps took 8.56 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4853 val_rmse_stderror: 1.51
# Still best_val_rmse: 0.4853 (from epoch 2)
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.5076 val_rmse_stderror: 1.513
# Still best_val_rmse: 0.4853 (from epoch 2)
#
# 16 steps took 8.56 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.4842 val_rmse_stderror: 1.509
# New best_val_rmse: 0.4842
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4805 val_rmse_stderror: 1.508
# New best_val_rmse: 0.4805
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4847 val_rmse_stderror: 1.505
# Still best_val_rmse: 0.4805 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4818 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4805 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4792 val_rmse_stderror: 1.508
# New best_val_rmse: 0.4792
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.4817 val_rmse_stderror: 1.509
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4876 val_rmse_stderror: 1.51
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4817 val_rmse_stderror: 1.507
# Still best_val_rmse: 0.4792 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 88 val_rmse_target: 0.4787 val_rmse_stderror: 1.503
# New best_val_rmse: 0.4787
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.48 val_rmse_stderror: 1.502
# Still best_val_rmse: 0.4787 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.483 val_rmse_stderror: 1.5
# Still best_val_rmse: 0.4787 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4835 val_rmse_stderror: 1.5
# Still best_val_rmse: 0.4787 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4799 val_rmse_stderror: 1.501
# Still best_val_rmse: 0.4787 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 104 val_rmse_target: 0.4786 val_rmse_stderror: 1.502
# New best_val_rmse: 0.4786
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4782 val_rmse_stderror: 1.503
# New best_val_rmse: 0.4782
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 108 val_rmse_target: 0.4785 val_rmse_stderror: 1.504
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4791 val_rmse_stderror: 1.505
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.4795 val_rmse_stderror: 1.505
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4799 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 116 val_rmse_target: 0.4801 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 4 steps took 2.14 seconds
# Epoch: 2 batch_num: 120 val_rmse_target: 0.4798 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 122 val_rmse_target: 0.4797 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 124 val_rmse_target: 0.4796 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4795 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 128 val_rmse_target: 0.4793 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4792 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4791 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4791 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 136 val_rmse_target: 0.4791 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.479 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 140 val_rmse_target: 0.479 val_rmse_stderror: 1.506
# Still best_val_rmse: 0.4782 (from epoch 2)
#
# Performance estimates:
# [0.48272599678651706, 0.4914349458665815, 0.4480896879975985, 0.47820948519040063]
# Mean: 0.4751150289602744
#
# Fold 5/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 8.9 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.8632 val_rmse_stderror: 1.351
# New best_val_rmse: 0.8632
#
# 16 steps took 8.39 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.015 val_rmse_stderror: 1.395
# Still best_val_rmse: 0.8632 (from epoch 0)
#
# 16 steps took 8.39 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.657 val_rmse_stderror: 1.419
# New best_val_rmse: 0.657
#
# 16 steps took 8.4 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6269 val_rmse_stderror: 1.468
# New best_val_rmse: 0.6269
#
# 16 steps took 8.39 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6603 val_rmse_stderror: 1.41
# Still best_val_rmse: 0.6269 (from epoch 0)
#
# 16 steps took 8.39 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5815 val_rmse_stderror: 1.431
# New best_val_rmse: 0.5815
#
# 16 steps took 8.4 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6755 val_rmse_stderror: 1.46
# Still best_val_rmse: 0.5815 (from epoch 0)
#
# 16 steps took 8.39 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6432 val_rmse_stderror: 1.45
# Still best_val_rmse: 0.5815 (from epoch 0)
#
# 16 steps took 8.57 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5332 val_rmse_stderror: 1.467
# New best_val_rmse: 0.5332
#
# 16 steps took 8.4 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5649 val_rmse_stderror: 1.419
# Still best_val_rmse: 0.5332 (from epoch 1)
#
# 16 steps took 8.38 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5931 val_rmse_stderror: 1.431
# Still best_val_rmse: 0.5332 (from epoch 1)
#
# 16 steps took 8.4 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5496 val_rmse_stderror: 1.425
# Still best_val_rmse: 0.5332 (from epoch 1)
#
# 16 steps took 8.38 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.539 val_rmse_stderror: 1.437
# Still best_val_rmse: 0.5332 (from epoch 1)
#
# 16 steps took 8.38 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5364 val_rmse_stderror: 1.433
# Still best_val_rmse: 0.5332 (from epoch 1)
#
# 16 steps took 8.38 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.522 val_rmse_stderror: 1.46
# New best_val_rmse: 0.522
#
# 16 steps took 8.39 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5236 val_rmse_stderror: 1.447
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 8.37 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5101 val_rmse_stderror: 1.463
# New best_val_rmse: 0.5101
#
# 16 steps took 8.56 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5243 val_rmse_stderror: 1.448
# Still best_val_rmse: 0.5101 (from epoch 1)
#
# 16 steps took 8.38 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.503 val_rmse_stderror: 1.457
# New best_val_rmse: 0.503
#
# 16 steps took 8.38 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.5112 val_rmse_stderror: 1.46
# Still best_val_rmse: 0.503 (from epoch 2)
#
# 16 steps took 8.37 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.5041 val_rmse_stderror: 1.459
# Still best_val_rmse: 0.503 (from epoch 2)
#
# 16 steps took 8.36 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.5029 val_rmse_stderror: 1.457
# New best_val_rmse: 0.5029
#
# 16 steps took 8.38 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.5085 val_rmse_stderror: 1.457
# Still best_val_rmse: 0.5029 (from epoch 2)
#
# 16 steps took 8.38 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.5049 val_rmse_stderror: 1.46
# Still best_val_rmse: 0.5029 (from epoch 2)
#
# 16 steps took 8.38 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.505 val_rmse_stderror: 1.461
# Still best_val_rmse: 0.5029 (from epoch 2)
#
# 16 steps took 8.37 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.5046 val_rmse_stderror: 1.461
# Still best_val_rmse: 0.5029 (from epoch 2)
#
# Performance estimates:
# [0.48272599678651706, 0.4914349458665815, 0.4480896879975985, 0.47820948519040063, 0.5029212747586282]
# Mean: 0.4806762781199452

# %%
print(list_val_rmse)
# Out:
# [0.48272599678651706, 0.4914349458665815, 0.4480896879975985, 0.47820948519040063, 0.5029212747586282]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_1.pth
# 100%|██████████| 477M/477M [00:33<00:00, 15.0MB/s]
# Upload successful: model_1.pth (477MB)
# Starting upload for file model_5.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.4MB/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_3.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.5MB/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_2.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.3MB/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_4.pth
# 100%|██████████| 477M/477M [00:36<00:00, 13.5MB/s]
# Upload successful: model_4.pth (477MB)
