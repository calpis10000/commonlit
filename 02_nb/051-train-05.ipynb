# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-05'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )
        
        self.layer_norm = nn.LayerNorm(config.hidden_size) # layer_normレイヤー
        
        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        norm_embeddings = self.layer_norm(context_vector)
        return self.regressor(norm_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得

    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
    norm_parameters = list(model.layer_norm.named_parameters())

    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]

    parameters = []
    parameters += attention_group
    parameters += regressor_group
    parameters += norm_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6083 train_rmse_stderror: 0.06259 train_kl_div: 0.7602
# val_rmse_target: 0.6917 val_rmse_stderror: 1.826
# New best_val_rmse: 0.6917
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5379 train_rmse_stderror: 0.05275 train_kl_div: 0.603
# val_rmse_target: 0.6351 val_rmse_stderror: 1.877
# New best_val_rmse: 0.6351
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4232 train_rmse_stderror: 0.04044 train_kl_div: 0.3955
# val_rmse_target: 0.6478 val_rmse_stderror: 1.892
# Still best_val_rmse: 0.6351 (from epoch 0)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5258 train_rmse_stderror: 0.03419 train_kl_div: 0.5214
# val_rmse_target: 0.5323 val_rmse_stderror: 1.855
# New best_val_rmse: 0.5323
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.3729 train_rmse_stderror: 0.03405 train_kl_div: 0.2975
# val_rmse_target: 0.5236 val_rmse_stderror: 1.864
# New best_val_rmse: 0.5236
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.219 train_rmse_stderror: 0.05808 train_kl_div: 0.121
# val_rmse_target: 0.5025 val_rmse_stderror: 1.883
# New best_val_rmse: 0.5025
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.3944 train_rmse_stderror: 0.0325 train_kl_div: 0.3612
# val_rmse_target: 0.4906 val_rmse_stderror: 1.85
# New best_val_rmse: 0.4906
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.285 train_rmse_stderror: 0.02155 train_kl_div: 0.1726
# val_rmse_target: 0.5319 val_rmse_stderror: 1.875
# Still best_val_rmse: 0.4906 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2757 train_rmse_stderror: 0.03122 train_kl_div: 0.1614
# val_rmse_target: 0.5024 val_rmse_stderror: 1.861
# Still best_val_rmse: 0.4906 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2854 train_rmse_stderror: 0.03157 train_kl_div: 0.176
# val_rmse_target: 0.5426 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4906 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3693 train_rmse_stderror: 0.04101 train_kl_div: 0.2718
# val_rmse_target: 0.5148 val_rmse_stderror: 1.859
# Still best_val_rmse: 0.4906 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3061 train_rmse_stderror: 0.02822 train_kl_div: 0.1806
# val_rmse_target: 0.5066 val_rmse_stderror: 1.842
# Still best_val_rmse: 0.4906 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2374 train_rmse_stderror: 0.03197 train_kl_div: 0.1272
# val_rmse_target: 0.4744 val_rmse_stderror: 1.866
# New best_val_rmse: 0.4744
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1878 train_rmse_stderror: 0.02801 train_kl_div: 0.07902
# val_rmse_target: 0.4816 val_rmse_stderror: 1.863
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1544 train_rmse_stderror: 0.02736 train_kl_div: 0.05008
# val_rmse_target: 0.4868 val_rmse_stderror: 1.851
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1358 train_rmse_stderror: 0.03159 train_kl_div: 0.04121
# val_rmse_target: 0.4892 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1508 train_rmse_stderror: 0.02764 train_kl_div: 0.04956
# val_rmse_target: 0.4879 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1753 train_rmse_stderror: 0.01894 train_kl_div: 0.06449
# val_rmse_target: 0.4842 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1971 train_rmse_stderror: 0.03108 train_kl_div: 0.07573
# val_rmse_target: 0.4857 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1033 train_rmse_stderror: 0.01931 train_kl_div: 0.02448
# val_rmse_target: 0.4848 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.08664 train_rmse_stderror: 0.02016 train_kl_div: 0.01732
# val_rmse_target: 0.4836 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08404 train_rmse_stderror: 0.02507 train_kl_div: 0.0164
# val_rmse_target: 0.484 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1175 train_rmse_stderror: 0.02473 train_kl_div: 0.03302
# val_rmse_target: 0.4847 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1481 train_rmse_stderror: 0.02508 train_kl_div: 0.04549
# val_rmse_target: 0.4856 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1173 train_rmse_stderror: 0.02231 train_kl_div: 0.02729
# val_rmse_target: 0.4851 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# Performance estimates:
# [0.474390033142337]
# Mean: 0.474390033142337
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5601 train_rmse_stderror: 0.06843 train_kl_div: 0.6086
# val_rmse_target: 0.6785 val_rmse_stderror: 1.123
# New best_val_rmse: 0.6785
#
# 64 steps took 81.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4047 train_rmse_stderror: 0.04543 train_kl_div: 0.3399
# val_rmse_target: 0.5665 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5665
#
# 64 steps took 81.2 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5058 train_rmse_stderror: 0.02773 train_kl_div: 0.4468
# val_rmse_target: 0.5463 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5463
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.4125 train_rmse_stderror: 0.03911 train_kl_div: 0.2881
# val_rmse_target: 0.5794 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.5463 (from epoch 1)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4255 train_rmse_stderror: 0.02581 train_kl_div: 0.387
# val_rmse_target: 0.5761 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.5463 (from epoch 1)
#
# 64 steps took 81.0 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5458 train_rmse_stderror: 0.04644 train_kl_div: 0.5124
# val_rmse_target: 0.5316 val_rmse_stderror: 1.11
# New best_val_rmse: 0.5316
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2636 train_rmse_stderror: 0.02015 train_kl_div: 0.146
# val_rmse_target: 0.537 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.5316 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2753 train_rmse_stderror: 0.0322 train_kl_div: 0.1581
# val_rmse_target: 0.5076 val_rmse_stderror: 1.094
# New best_val_rmse: 0.5076
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2028 train_rmse_stderror: 0.02353 train_kl_div: 0.09219
# val_rmse_target: 0.5103 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.5076 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2631 train_rmse_stderror: 0.03887 train_kl_div: 0.1317
# val_rmse_target: 0.5131 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.5076 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.1934 train_rmse_stderror: 0.02093 train_kl_div: 0.08068
# val_rmse_target: 0.5044 val_rmse_stderror: 1.119
# New best_val_rmse: 0.5044
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2291 train_rmse_stderror: 0.03071 train_kl_div: 0.1201
# val_rmse_target: 0.5035 val_rmse_stderror: 1.109
# New best_val_rmse: 0.5035
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1504 train_rmse_stderror: 0.01461 train_kl_div: 0.04775
# val_rmse_target: 0.5017 val_rmse_stderror: 1.118
# New best_val_rmse: 0.5017
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1503 train_rmse_stderror: 0.02229 train_kl_div: 0.05052
# val_rmse_target: 0.5042 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.5017 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1051 train_rmse_stderror: 0.02592 train_kl_div: 0.02676
# val_rmse_target: 0.4957 val_rmse_stderror: 1.114
# New best_val_rmse: 0.4957
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.05058 train_rmse_stderror: 0.02282 train_kl_div: 0.007152
# val_rmse_target: 0.4966 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.15 train_rmse_stderror: 0.01606 train_kl_div: 0.04695
# val_rmse_target: 0.5052 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1194 train_rmse_stderror: 0.02539 train_kl_div: 0.03232
# val_rmse_target: 0.4991 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1534 train_rmse_stderror: 0.02647 train_kl_div: 0.0471
# val_rmse_target: 0.4992 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.05874 train_rmse_stderror: 0.02929 train_kl_div: 0.01095
# val_rmse_target: 0.4998 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1032 train_rmse_stderror: 0.0173 train_kl_div: 0.02281
# val_rmse_target: 0.4964 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09667 train_rmse_stderror: 0.03267 train_kl_div: 0.02059
# val_rmse_target: 0.4959 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4957 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08425 train_rmse_stderror: 0.03876 train_kl_div: 0.02079
# val_rmse_target: 0.4954 val_rmse_stderror: 1.11
# New best_val_rmse: 0.4954
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.08766 train_rmse_stderror: 0.01725 train_kl_div: 0.01894
# val_rmse_target: 0.4958 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4954 (from epoch 4)
#
# Performance estimates:
# [0.474390033142337, 0.4954035463901495]
# Mean: 0.4848967897662433
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5529 train_rmse_stderror: 0.07177 train_kl_div: 0.6338
# val_rmse_target: 0.6758 val_rmse_stderror: 1.745
# New best_val_rmse: 0.6758
#
# 64 steps took 81.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.66 train_rmse_stderror: 0.05543 train_kl_div: 0.9105
# val_rmse_target: 0.5885 val_rmse_stderror: 1.738
# New best_val_rmse: 0.5885
#
# 64 steps took 81.2 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4128 train_rmse_stderror: 0.02886 train_kl_div: 0.3425
# val_rmse_target: 0.6182 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.5885 (from epoch 0)
#
# 64 steps took 81.0 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.2765 train_rmse_stderror: 0.02643 train_kl_div: 0.1547
# val_rmse_target: 0.5002 val_rmse_stderror: 1.716
# New best_val_rmse: 0.5002
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5258 train_rmse_stderror: 0.05882 train_kl_div: 0.4844
# val_rmse_target: 0.5256 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.5002 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5438 train_rmse_stderror: 0.0322 train_kl_div: 0.5487
# val_rmse_target: 0.5678 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.5002 (from epoch 1)
#
# 64 steps took 81.1 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2679 train_rmse_stderror: 0.02561 train_kl_div: 0.1492
# val_rmse_target: 0.5304 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.5002 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3234 train_rmse_stderror: 0.03564 train_kl_div: 0.2345
# val_rmse_target: 0.4972 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4972
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.307 train_rmse_stderror: 0.04208 train_kl_div: 0.1908
# val_rmse_target: 0.4796 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4796
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2082 train_rmse_stderror: 0.02685 train_kl_div: 0.09888
# val_rmse_target: 0.4797 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4796 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2333 train_rmse_stderror: 0.03285 train_kl_div: 0.1065
# val_rmse_target: 0.4848 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4796 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.231 train_rmse_stderror: 0.03554 train_kl_div: 0.1183
# val_rmse_target: 0.4744 val_rmse_stderror: 1.743
# New best_val_rmse: 0.4744
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1115 train_rmse_stderror: 0.03083 train_kl_div: 0.02872
# val_rmse_target: 0.4766 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1721 train_rmse_stderror: 0.02287 train_kl_div: 0.06196
# val_rmse_target: 0.4763 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1482 train_rmse_stderror: 0.02238 train_kl_div: 0.04701
# val_rmse_target: 0.475 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1166 train_rmse_stderror: 0.03054 train_kl_div: 0.03519
# val_rmse_target: 0.4745 val_rmse_stderror: 1.729
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1223 train_rmse_stderror: 0.01906 train_kl_div: 0.03458
# val_rmse_target: 0.4774 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1305 train_rmse_stderror: 0.03243 train_kl_div: 0.03751
# val_rmse_target: 0.4767 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1008 train_rmse_stderror: 0.02928 train_kl_div: 0.02519
# val_rmse_target: 0.4805 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1062 train_rmse_stderror: 0.02043 train_kl_div: 0.02473
# val_rmse_target: 0.4815 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.06883 train_rmse_stderror: 0.02965 train_kl_div: 0.01334
# val_rmse_target: 0.4763 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09588 train_rmse_stderror: 0.02 train_kl_div: 0.02199
# val_rmse_target: 0.4773 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.07209 train_rmse_stderror: 0.02438 train_kl_div: 0.0138
# val_rmse_target: 0.4774 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.08332 train_rmse_stderror: 0.02235 train_kl_div: 0.01586
# val_rmse_target: 0.477 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4744 (from epoch 2)
#
# Performance estimates:
# [0.474390033142337, 0.4954035463901495, 0.4744390480403146]
# Mean: 0.4814108758576004
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6579 train_rmse_stderror: 0.07821 train_kl_div: 0.7936
# val_rmse_target: 0.627 val_rmse_stderror: 1.774
# New best_val_rmse: 0.627
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.3712 train_rmse_stderror: 0.03253 train_kl_div: 0.3021
# val_rmse_target: 0.6264 val_rmse_stderror: 1.793
# New best_val_rmse: 0.6264
#
# 64 steps took 81.2 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.58 train_rmse_stderror: 0.03005 train_kl_div: 0.6622
# val_rmse_target: 0.5106 val_rmse_stderror: 1.781
# New best_val_rmse: 0.5106
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.3283 train_rmse_stderror: 0.02509 train_kl_div: 0.2266
# val_rmse_target: 0.4808 val_rmse_stderror: 1.783
# New best_val_rmse: 0.4808
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.3695 train_rmse_stderror: 0.02784 train_kl_div: 0.2953
# val_rmse_target: 0.4983 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4808 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.392 train_rmse_stderror: 0.03358 train_kl_div: 0.3245
# val_rmse_target: 0.5408 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.4808 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.3361 train_rmse_stderror: 0.0319 train_kl_div: 0.2332
# val_rmse_target: 0.5032 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4808 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.1879 train_rmse_stderror: 0.04069 train_kl_div: 0.07728
# val_rmse_target: 0.4846 val_rmse_stderror: 1.806
# Still best_val_rmse: 0.4808 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2811 train_rmse_stderror: 0.01972 train_kl_div: 0.1652
# val_rmse_target: 0.4731 val_rmse_stderror: 1.784
# New best_val_rmse: 0.4731
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3093 train_rmse_stderror: 0.02387 train_kl_div: 0.2197
# val_rmse_target: 0.4738 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4731 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.1138 train_rmse_stderror: 0.0246 train_kl_div: 0.03096
# val_rmse_target: 0.4729 val_rmse_stderror: 1.787
# New best_val_rmse: 0.4729
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2457 train_rmse_stderror: 0.03318 train_kl_div: 0.1282
# val_rmse_target: 0.4707 val_rmse_stderror: 1.788
# New best_val_rmse: 0.4707
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.08696 train_rmse_stderror: 0.02794 train_kl_div: 0.0189
# val_rmse_target: 0.4583 val_rmse_stderror: 1.787
# New best_val_rmse: 0.4583
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3332 train_rmse_stderror: 0.03726 train_kl_div: 0.2073
# val_rmse_target: 0.4622 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4583 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.08195 train_rmse_stderror: 0.01869 train_kl_div: 0.01521
# val_rmse_target: 0.4441 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4441
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1586 train_rmse_stderror: 0.02488 train_kl_div: 0.04832
# val_rmse_target: 0.4518 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.07621 train_rmse_stderror: 0.02049 train_kl_div: 0.01472
# val_rmse_target: 0.4522 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1315 train_rmse_stderror: 0.01481 train_kl_div: 0.03787
# val_rmse_target: 0.4507 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1536 train_rmse_stderror: 0.02566 train_kl_div: 0.05497
# val_rmse_target: 0.4508 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1682 train_rmse_stderror: 0.03355 train_kl_div: 0.04749
# val_rmse_target: 0.4577 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1096 train_rmse_stderror: 0.02314 train_kl_div: 0.02375
# val_rmse_target: 0.4521 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.09054 train_rmse_stderror: 0.01644 train_kl_div: 0.01767
# val_rmse_target: 0.4508 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08515 train_rmse_stderror: 0.02079 train_kl_div: 0.01677
# val_rmse_target: 0.4507 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.07954 train_rmse_stderror: 0.01885 train_kl_div: 0.01489
# val_rmse_target: 0.4511 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08005 train_rmse_stderror: 0.01194 train_kl_div: 0.01422
# val_rmse_target: 0.4521 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1068 train_rmse_stderror: 0.01799 train_kl_div: 0.02462
# val_rmse_target: 0.4518 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4441 (from epoch 3)
#
# Performance estimates:
# [0.474390033142337, 0.4954035463901495, 0.4744390480403146, 0.4441279368742014]
# Mean: 0.4720901411117506
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5728 train_rmse_stderror: 0.07238 train_kl_div: 0.6341
# val_rmse_target: 0.6234 val_rmse_stderror: 1.733
# New best_val_rmse: 0.6234
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4922 train_rmse_stderror: 0.0318 train_kl_div: 0.5215
# val_rmse_target: 0.5498 val_rmse_stderror: 1.762
# New best_val_rmse: 0.5498
#
# 32 steps took 40.5 seconds
# Epoch: 0 batch_num: 160
# train_rmse_target: 0.5483 train_rmse_stderror: 0.05109 train_kl_div: 0.5741
# val_rmse_target: 0.5677 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.5498 (from epoch 0)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.2873 train_rmse_stderror: 0.03123 train_kl_div: 0.1708
# val_rmse_target: 0.5174 val_rmse_stderror: 1.753
# New best_val_rmse: 0.5174
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.7541 train_rmse_stderror: 0.05151 train_kl_div: 1.047
# val_rmse_target: 0.5295 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5174 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5148 train_rmse_stderror: 0.03033 train_kl_div: 0.5784
# val_rmse_target: 0.5301 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5174 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.2774 train_rmse_stderror: 0.04008 train_kl_div: 0.1522
# val_rmse_target: 0.5186 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.5174 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.2588 train_rmse_stderror: 0.03285 train_kl_div: 0.1372
# val_rmse_target: 0.5006 val_rmse_stderror: 1.776
# New best_val_rmse: 0.5006
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.4736 train_rmse_stderror: 0.03884 train_kl_div: 0.4729
# val_rmse_target: 0.5573 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.5006 (from epoch 1)
#
# 64 steps took 81.0 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2497 train_rmse_stderror: 0.02453 train_kl_div: 0.1368
# val_rmse_target: 0.4869 val_rmse_stderror: 1.762
# New best_val_rmse: 0.4869
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.304 train_rmse_stderror: 0.03512 train_kl_div: 0.1776
# val_rmse_target: 0.4848 val_rmse_stderror: 1.763
# New best_val_rmse: 0.4848
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2801 train_rmse_stderror: 0.02582 train_kl_div: 0.1662
# val_rmse_target: 0.4957 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3569 train_rmse_stderror: 0.05326 train_kl_div: 0.2238
# val_rmse_target: 0.4909 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1648 train_rmse_stderror: 0.02515 train_kl_div: 0.0577
# val_rmse_target: 0.4867 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4848 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.181 train_rmse_stderror: 0.02219 train_kl_div: 0.0734
# val_rmse_target: 0.4809 val_rmse_stderror: 1.768
# New best_val_rmse: 0.4809
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1519 train_rmse_stderror: 0.01681 train_kl_div: 0.04966
# val_rmse_target: 0.4816 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.153 train_rmse_stderror: 0.03407 train_kl_div: 0.04969
# val_rmse_target: 0.4851 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1324 train_rmse_stderror: 0.03094 train_kl_div: 0.0319
# val_rmse_target: 0.4817 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1529 train_rmse_stderror: 0.03236 train_kl_div: 0.04473
# val_rmse_target: 0.4888 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1102 train_rmse_stderror: 0.02358 train_kl_div: 0.02583
# val_rmse_target: 0.4842 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.06959 train_rmse_stderror: 0.02125 train_kl_div: 0.01204
# val_rmse_target: 0.483 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08219 train_rmse_stderror: 0.02595 train_kl_div: 0.01638
# val_rmse_target: 0.4826 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.07907 train_rmse_stderror: 0.0301 train_kl_div: 0.01594
# val_rmse_target: 0.4854 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.146 train_rmse_stderror: 0.02732 train_kl_div: 0.03666
# val_rmse_target: 0.4845 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.08692 train_rmse_stderror: 0.02755 train_kl_div: 0.01715
# val_rmse_target: 0.4848 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# Performance estimates:
# [0.474390033142337, 0.4954035463901495, 0.4744390480403146, 0.4441279368742014, 0.4808930420033374]
# Mean: 0.47385072129006794
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.474390033142337, 0.4954035463901495, 0.4744390480403146, 0.4441279368742014, 0.4808930420033374]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [01:25<00:00, 16.6MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [01:26<00:00, 16.5MB/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [01:29<00:00, 15.9MB/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [01:21<00:00, 17.5MB/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [01:24<00:00, 16.9MB/s]
# Upload successful: model_1.pth (1GB)
