# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_roberta_large_248/clrp_roberta_large_248/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # ここのディレクトリは固定（中身を都度入れ替える）
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # ここのディレクトリは固定（中身を都度入れ替える）
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '053-train-03'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df_src = pd.read_csv(DATA_DIR/"train.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
print(train_df_src.shape)
train_df_src.head()
# Out:
# (2834, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # word_length_mlm
        mlm_layers = self.mlm_layers(input_len)


        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_layers], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_parameters = list(model.mlm_layers.named_parameters())
    mlm_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6231 train_rmse_stderror: 0.09667 train_kl_div: 0.8164
# val_rmse_target: 0.8837 val_rmse_stderror: 1.873
# New best_val_rmse: 0.8837
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7871 train_rmse_stderror: 0.1063 train_kl_div: 1.295
# val_rmse_target: 0.6823 val_rmse_stderror: 1.86
# New best_val_rmse: 0.6823
#
# 64 steps took 81.7 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.3398 train_rmse_stderror: 0.07631 train_kl_div: 0.2638
# val_rmse_target: 0.5899 val_rmse_stderror: 1.908
# New best_val_rmse: 0.5899
#
# 64 steps took 81.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4802 train_rmse_stderror: 0.06054 train_kl_div: 0.4994
# val_rmse_target: 0.5711 val_rmse_stderror: 1.866
# New best_val_rmse: 0.5711
#
# 64 steps took 81.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.537 train_rmse_stderror: 0.07024 train_kl_div: 0.6194
# val_rmse_target: 0.5358 val_rmse_stderror: 1.851
# New best_val_rmse: 0.5358
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.3284 train_rmse_stderror: 0.09826 train_kl_div: 0.2892
# val_rmse_target: 0.5233 val_rmse_stderror: 1.845
# New best_val_rmse: 0.5233
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2863 train_rmse_stderror: 0.08067 train_kl_div: 0.1963
# val_rmse_target: 0.5046 val_rmse_stderror: 1.857
# New best_val_rmse: 0.5046
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2511 train_rmse_stderror: 0.06958 train_kl_div: 0.1599
# val_rmse_target: 0.4889 val_rmse_stderror: 1.86
# New best_val_rmse: 0.4889
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.4712 train_rmse_stderror: 0.06687 train_kl_div: 0.452
# val_rmse_target: 0.5783 val_rmse_stderror: 1.867
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 64 steps took 81.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3024 train_rmse_stderror: 0.05714 train_kl_div: 0.1964
# val_rmse_target: 0.5332 val_rmse_stderror: 1.866
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2509 train_rmse_stderror: 0.05805 train_kl_div: 0.1369
# val_rmse_target: 0.5076 val_rmse_stderror: 1.861
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1388 train_rmse_stderror: 0.08102 train_kl_div: 0.06909
# val_rmse_target: 0.4915 val_rmse_stderror: 1.865
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.09349 train_rmse_stderror: 0.0644 train_kl_div: 0.03707
# val_rmse_target: 0.4986 val_rmse_stderror: 1.859
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1954 train_rmse_stderror: 0.05497 train_kl_div: 0.07574
# val_rmse_target: 0.5067 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1878 train_rmse_stderror: 0.05469 train_kl_div: 0.07388
# val_rmse_target: 0.4957 val_rmse_stderror: 1.852
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1641 train_rmse_stderror: 0.05849 train_kl_div: 0.07451
# val_rmse_target: 0.4926 val_rmse_stderror: 1.864
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1718 train_rmse_stderror: 0.06656 train_kl_div: 0.07715
# val_rmse_target: 0.4959 val_rmse_stderror: 1.87
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1266 train_rmse_stderror: 0.06239 train_kl_div: 0.04984
# val_rmse_target: 0.5009 val_rmse_stderror: 1.863
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1175 train_rmse_stderror: 0.05542 train_kl_div: 0.04081
# val_rmse_target: 0.497 val_rmse_stderror: 1.861
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1376 train_rmse_stderror: 0.03163 train_kl_div: 0.04186
# val_rmse_target: 0.4964 val_rmse_stderror: 1.865
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1534 train_rmse_stderror: 0.05916 train_kl_div: 0.05892
# val_rmse_target: 0.4976 val_rmse_stderror: 1.864
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.07711 train_rmse_stderror: 0.05504 train_kl_div: 0.02549
# val_rmse_target: 0.498 val_rmse_stderror: 1.862
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1018 train_rmse_stderror: 0.04779 train_kl_div: 0.03231
# val_rmse_target: 0.498 val_rmse_stderror: 1.863
# Still best_val_rmse: 0.4889 (from epoch 2)
#
# Performance estimates:
# [0.4889148887541961]
# Mean: 0.4889148887541961
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.553 train_rmse_stderror: 0.07304 train_kl_div: 0.7122
# val_rmse_target: 0.5841 val_rmse_stderror: 1.719
# New best_val_rmse: 0.5841
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6106 train_rmse_stderror: 0.08733 train_kl_div: 0.8377
# val_rmse_target: 0.5616 val_rmse_stderror: 1.73
# New best_val_rmse: 0.5616
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4978 train_rmse_stderror: 0.07775 train_kl_div: 0.5047
# val_rmse_target: 0.5472 val_rmse_stderror: 1.778
# New best_val_rmse: 0.5472
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.7025 train_rmse_stderror: 0.06608 train_kl_div: 0.9975
# val_rmse_target: 0.674 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.5472 (from epoch 1)
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4267 train_rmse_stderror: 0.07067 train_kl_div: 0.3577
# val_rmse_target: 0.5303 val_rmse_stderror: 1.79
# New best_val_rmse: 0.5303
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4873 train_rmse_stderror: 0.07571 train_kl_div: 0.5125
# val_rmse_target: 0.5176 val_rmse_stderror: 1.712
# New best_val_rmse: 0.5176
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5055 train_rmse_stderror: 0.1189 train_kl_div: 0.4282
# val_rmse_target: 0.5114 val_rmse_stderror: 1.714
# New best_val_rmse: 0.5114
#
# 32 steps took 41.0 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2973 train_rmse_stderror: 0.06736 train_kl_div: 0.1956
# val_rmse_target: 0.5234 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.5114 (from epoch 1)
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2952 train_rmse_stderror: 0.06633 train_kl_div: 0.1936
# val_rmse_target: 0.5021 val_rmse_stderror: 1.768
# New best_val_rmse: 0.5021
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2588 train_rmse_stderror: 0.04889 train_kl_div: 0.1507
# val_rmse_target: 0.4936 val_rmse_stderror: 1.731
# New best_val_rmse: 0.4936
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2644 train_rmse_stderror: 0.06535 train_kl_div: 0.1528
# val_rmse_target: 0.4892 val_rmse_stderror: 1.756
# New best_val_rmse: 0.4892
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.1573 train_rmse_stderror: 0.05491 train_kl_div: 0.06091
# val_rmse_target: 0.5038 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4892 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3576 train_rmse_stderror: 0.05633 train_kl_div: 0.2358
# val_rmse_target: 0.4991 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4892 (from epoch 2)
#
# 32 steps took 41.0 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.09432 train_rmse_stderror: 0.08633 train_kl_div: 0.04757
# val_rmse_target: 0.4919 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4892 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1845 train_rmse_stderror: 0.03591 train_kl_div: 0.07261
# val_rmse_target: 0.4958 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4892 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1695 train_rmse_stderror: 0.04369 train_kl_div: 0.0613
# val_rmse_target: 0.4884 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4884
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1337 train_rmse_stderror: 0.04997 train_kl_div: 0.04878
# val_rmse_target: 0.4881 val_rmse_stderror: 1.741
# New best_val_rmse: 0.4881
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1371 train_rmse_stderror: 0.04101 train_kl_div: 0.04596
# val_rmse_target: 0.4879 val_rmse_stderror: 1.755
# New best_val_rmse: 0.4879
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1067 train_rmse_stderror: 0.04258 train_kl_div: 0.03183
# val_rmse_target: 0.4882 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4879 (from epoch 3)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.08667 train_rmse_stderror: 0.04203 train_kl_div: 0.02314
# val_rmse_target: 0.4874 val_rmse_stderror: 1.738
# New best_val_rmse: 0.4874
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.06536 train_rmse_stderror: 0.04283 train_kl_div: 0.01656
# val_rmse_target: 0.4872 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4872
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1003 train_rmse_stderror: 0.05157 train_kl_div: 0.03356
# val_rmse_target: 0.4859 val_rmse_stderror: 1.751
# New best_val_rmse: 0.4859
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.08124 train_rmse_stderror: 0.03017 train_kl_div: 0.0176
# val_rmse_target: 0.487 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4859 (from epoch 4)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08516 train_rmse_stderror: 0.03891 train_kl_div: 0.02167
# val_rmse_target: 0.4868 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4859 (from epoch 4)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.07307 train_rmse_stderror: 0.04312 train_kl_div: 0.01868
# val_rmse_target: 0.4869 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4859 (from epoch 4)
#
# Performance estimates:
# [0.4889148887541961, 0.4859495589768427]
# Mean: 0.48743222386551943
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5744 train_rmse_stderror: 0.08983 train_kl_div: 0.6763
# val_rmse_target: 0.6776 val_rmse_stderror: 1.117
# New best_val_rmse: 0.6776
#
# 64 steps took 81.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6012 train_rmse_stderror: 0.09178 train_kl_div: 0.7103
# val_rmse_target: 0.6433 val_rmse_stderror: 1.076
# New best_val_rmse: 0.6433
#
# 64 steps took 81.8 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.3743 train_rmse_stderror: 0.05512 train_kl_div: 0.3191
# val_rmse_target: 0.5213 val_rmse_stderror: 1.115
# New best_val_rmse: 0.5213
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.3564 train_rmse_stderror: 0.04242 train_kl_div: 0.2468
# val_rmse_target: 0.543 val_rmse_stderror: 1.08
# Still best_val_rmse: 0.5213 (from epoch 1)
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.3496 train_rmse_stderror: 0.0445 train_kl_div: 0.2701
# val_rmse_target: 0.5212 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5212
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5275 train_rmse_stderror: 0.06543 train_kl_div: 0.6224
# val_rmse_target: 0.5629 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.5212 (from epoch 1)
#
# 64 steps took 81.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4006 train_rmse_stderror: 0.077 train_kl_div: 0.3207
# val_rmse_target: 0.6297 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5212 (from epoch 1)
#
# 64 steps took 81.8 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2162 train_rmse_stderror: 0.06921 train_kl_div: 0.1232
# val_rmse_target: 0.51 val_rmse_stderror: 1.109
# New best_val_rmse: 0.51
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.25 train_rmse_stderror: 0.06763 train_kl_div: 0.1443
# val_rmse_target: 0.4901 val_rmse_stderror: 1.104
# New best_val_rmse: 0.4901
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2508 train_rmse_stderror: 0.03479 train_kl_div: 0.1332
# val_rmse_target: 0.4875 val_rmse_stderror: 1.104
# New best_val_rmse: 0.4875
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2315 train_rmse_stderror: 0.07611 train_kl_div: 0.1095
# val_rmse_target: 0.524 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.1498 train_rmse_stderror: 0.05667 train_kl_div: 0.06134
# val_rmse_target: 0.4889 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 32 steps took 41.0 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1539 train_rmse_stderror: 0.05101 train_kl_div: 0.05631
# val_rmse_target: 0.5048 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1055 train_rmse_stderror: 0.06876 train_kl_div: 0.04069
# val_rmse_target: 0.4896 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4875 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2028 train_rmse_stderror: 0.03356 train_kl_div: 0.09275
# val_rmse_target: 0.4855 val_rmse_stderror: 1.108
# New best_val_rmse: 0.4855
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1675 train_rmse_stderror: 0.05173 train_kl_div: 0.06811
# val_rmse_target: 0.4878 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4855 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1664 train_rmse_stderror: 0.056 train_kl_div: 0.069
# val_rmse_target: 0.4859 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4855 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2141 train_rmse_stderror: 0.06679 train_kl_div: 0.08781
# val_rmse_target: 0.4816 val_rmse_stderror: 1.096
# New best_val_rmse: 0.4816
#
# 32 steps took 41.0 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09998 train_rmse_stderror: 0.03907 train_kl_div: 0.02474
# val_rmse_target: 0.4883 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.07394 train_rmse_stderror: 0.0341 train_kl_div: 0.01703
# val_rmse_target: 0.4831 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.0929 train_rmse_stderror: 0.04397 train_kl_div: 0.02425
# val_rmse_target: 0.4836 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.06172 train_rmse_stderror: 0.04927 train_kl_div: 0.01848
# val_rmse_target: 0.4817 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.124 train_rmse_stderror: 0.0502 train_kl_div: 0.03978
# val_rmse_target: 0.4824 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# 32 steps took 40.8 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.103 train_rmse_stderror: 0.04313 train_kl_div: 0.02873
# val_rmse_target: 0.4824 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4816 (from epoch 3)
#
# Performance estimates:
# [0.4889148887541961, 0.4859495589768427, 0.4816353816835429]
# Mean: 0.48549994313819395
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5398 train_rmse_stderror: 0.09524 train_kl_div: 0.615
# val_rmse_target: 0.6708 val_rmse_stderror: 1.841
# New best_val_rmse: 0.6708
#
# 64 steps took 81.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5306 train_rmse_stderror: 0.07342 train_kl_div: 0.5732
# val_rmse_target: 0.5534 val_rmse_stderror: 1.808
# New best_val_rmse: 0.5534
#
# 64 steps took 81.8 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.2877 train_rmse_stderror: 0.06533 train_kl_div: 0.1826
# val_rmse_target: 0.5282 val_rmse_stderror: 1.806
# New best_val_rmse: 0.5282
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.4825 train_rmse_stderror: 0.04449 train_kl_div: 0.4702
# val_rmse_target: 0.5303 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5703 train_rmse_stderror: 0.03046 train_kl_div: 0.6683
# val_rmse_target: 0.6395 val_rmse_stderror: 1.805
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 64 steps took 81.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5891 train_rmse_stderror: 0.06828 train_kl_div: 0.6357
# val_rmse_target: 0.5356 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 32 steps took 40.8 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.2673 train_rmse_stderror: 0.061 train_kl_div: 0.1739
# val_rmse_target: 0.5295 val_rmse_stderror: 1.816
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 32 steps took 41.0 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.277 train_rmse_stderror: 0.05892 train_kl_div: 0.1831
# val_rmse_target: 0.5483 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.5282 (from epoch 1)
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3226 train_rmse_stderror: 0.04148 train_kl_div: 0.1994
# val_rmse_target: 0.4909 val_rmse_stderror: 1.802
# New best_val_rmse: 0.4909
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2807 train_rmse_stderror: 0.06631 train_kl_div: 0.1753
# val_rmse_target: 0.4937 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4909 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3387 train_rmse_stderror: 0.0357 train_kl_div: 0.2615
# val_rmse_target: 0.4785 val_rmse_stderror: 1.796
# New best_val_rmse: 0.4785
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.4143 train_rmse_stderror: 0.05939 train_kl_div: 0.299
# val_rmse_target: 0.4747 val_rmse_stderror: 1.794
# New best_val_rmse: 0.4747
#
# 32 steps took 40.8 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.1934 train_rmse_stderror: 0.0354 train_kl_div: 0.08306
# val_rmse_target: 0.482 val_rmse_stderror: 1.8
# Still best_val_rmse: 0.4747 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1729 train_rmse_stderror: 0.04331 train_kl_div: 0.06475
# val_rmse_target: 0.4923 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4747 (from epoch 2)
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1717 train_rmse_stderror: 0.03165 train_kl_div: 0.0633
# val_rmse_target: 0.4731 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4731
#
# 32 steps took 40.8 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2003 train_rmse_stderror: 0.04056 train_kl_div: 0.09929
# val_rmse_target: 0.4953 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4731 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.128 train_rmse_stderror: 0.04307 train_kl_div: 0.04465
# val_rmse_target: 0.4684 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4684
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1429 train_rmse_stderror: 0.04627 train_kl_div: 0.05235
# val_rmse_target: 0.474 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1485 train_rmse_stderror: 0.07078 train_kl_div: 0.06144
# val_rmse_target: 0.4703 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09469 train_rmse_stderror: 0.05237 train_kl_div: 0.02919
# val_rmse_target: 0.476 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.159 train_rmse_stderror: 0.03949 train_kl_div: 0.05977
# val_rmse_target: 0.4703 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08647 train_rmse_stderror: 0.04222 train_kl_div: 0.02447
# val_rmse_target: 0.4686 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09553 train_rmse_stderror: 0.04004 train_kl_div: 0.02795
# val_rmse_target: 0.4702 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1325 train_rmse_stderror: 0.03011 train_kl_div: 0.03891
# val_rmse_target: 0.4694 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.05897 train_rmse_stderror: 0.04611 train_kl_div: 0.01386
# val_rmse_target: 0.4694 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4684 (from epoch 3)
#
# Performance estimates:
# [0.4889148887541961, 0.4859495589768427, 0.4816353816835429, 0.4684313069295142]
# Mean: 0.481232784086024
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4888 train_rmse_stderror: 0.07657 train_kl_div: 0.5397
# val_rmse_target: 0.6295 val_rmse_stderror: 1.125
# New best_val_rmse: 0.6295
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5167 train_rmse_stderror: 0.08277 train_kl_div: 0.6037
# val_rmse_target: 0.5989 val_rmse_stderror: 1.102
# New best_val_rmse: 0.5989
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.453 train_rmse_stderror: 0.08184 train_kl_div: 0.4281
# val_rmse_target: 0.5682 val_rmse_stderror: 1.111
# New best_val_rmse: 0.5682
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4111 train_rmse_stderror: 0.0827 train_kl_div: 0.3532
# val_rmse_target: 0.5565 val_rmse_stderror: 1.098
# New best_val_rmse: 0.5565
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4555 train_rmse_stderror: 0.04176 train_kl_div: 0.3966
# val_rmse_target: 0.5696 val_rmse_stderror: 1.091
# Still best_val_rmse: 0.5565 (from epoch 1)
#
# 64 steps took 81.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3813 train_rmse_stderror: 0.06406 train_kl_div: 0.3364
# val_rmse_target: 0.5576 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.5565 (from epoch 1)
#
# 64 steps took 81.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2764 train_rmse_stderror: 0.0648 train_kl_div: 0.1576
# val_rmse_target: 0.519 val_rmse_stderror: 1.09
# New best_val_rmse: 0.519
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2608 train_rmse_stderror: 0.03909 train_kl_div: 0.1391
# val_rmse_target: 0.5011 val_rmse_stderror: 1.102
# New best_val_rmse: 0.5011
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3462 train_rmse_stderror: 0.07016 train_kl_div: 0.2868
# val_rmse_target: 0.4997 val_rmse_stderror: 1.103
# New best_val_rmse: 0.4997
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2176 train_rmse_stderror: 0.05249 train_kl_div: 0.1232
# val_rmse_target: 0.5074 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.4997 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.2424 train_rmse_stderror: 0.08391 train_kl_div: 0.1166
# val_rmse_target: 0.4985 val_rmse_stderror: 1.1
# New best_val_rmse: 0.4985
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1526 train_rmse_stderror: 0.04874 train_kl_div: 0.05351
# val_rmse_target: 0.4947 val_rmse_stderror: 1.114
# New best_val_rmse: 0.4947
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1251 train_rmse_stderror: 0.05018 train_kl_div: 0.04447
# val_rmse_target: 0.4981 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4947 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1547 train_rmse_stderror: 0.06053 train_kl_div: 0.06021
# val_rmse_target: 0.4932 val_rmse_stderror: 1.1
# New best_val_rmse: 0.4932
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1442 train_rmse_stderror: 0.049 train_kl_div: 0.04976
# val_rmse_target: 0.5018 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4932 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1543 train_rmse_stderror: 0.06105 train_kl_div: 0.06518
# val_rmse_target: 0.4923 val_rmse_stderror: 1.116
# New best_val_rmse: 0.4923
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.08127 train_rmse_stderror: 0.04111 train_kl_div: 0.02125
# val_rmse_target: 0.4889 val_rmse_stderror: 1.111
# New best_val_rmse: 0.4889
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1154 train_rmse_stderror: 0.05036 train_kl_div: 0.03716
# val_rmse_target: 0.4895 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.4889 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.0584 train_rmse_stderror: 0.03911 train_kl_div: 0.01312
# val_rmse_target: 0.4914 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4889 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09149 train_rmse_stderror: 0.03241 train_kl_div: 0.02204
# val_rmse_target: 0.4899 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4889 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.0695 train_rmse_stderror: 0.05384 train_kl_div: 0.02285
# val_rmse_target: 0.4902 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4889 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.04167 train_rmse_stderror: 0.04851 train_kl_div: 0.01271
# val_rmse_target: 0.4903 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4889 (from epoch 4)
#
# Performance estimates:
# [0.4889148887541961, 0.4859495589768427, 0.4816353816835429, 0.4684313069295142, 0.48893733097377406]
# Mean: 0.482773693463574
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.4889148887541961, 0.4859495589768427, 0.4816353816835429, 0.4684313069295142, 0.48893733097377406]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [01:21<00:00, 17.4MB/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [01:26<00:00, 16.5MB/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [01:23<00:00, 17.0MB/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [01:29<00:00, 15.9MB/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [01:22<00:00, 17.3MB/s]
# Upload successful: model_5.pth (1GB)
