# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '054-train-03'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import pickle
import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 248 # ベクトル長
TFIDF_MAX_FEAT = 1024

EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# 参考: https://www.guruguru.science/competitions/16/discussions/556029f7-484d-40d4-ad6a-9d86337487e2/
from sklearn.feature_extraction.text import TfidfVectorizer

# ベースとなる継承元のクラス
class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    def transform(self, input_df):
        raise NotImplementedError()


class TfidfSimpleBlock(BaseBlock):
    """シンプルなTF-IDF特徴を作成する block"""
    def __init__(self, column: str, max_features=50, ngram_range=(1,1), use_idf=True):
        """
        args:
            column: str
                変換対象のカラム名
        """
        self.column = column
        self.max_features=max_features
        self.ngram_range=ngram_range
        self.use_idf=use_idf
        self.param_prefix=f"col={column}_max_features={max_features}_\
                              ngram={ngram_range[0]}_{ngram_range[1]}_use_idf={use_idf}"

    def preprocess(self, input_df):
        x = text_normalization(input_df[self.column])
        return x

    def get_master(self, _master_df):
        """tdidfを計算するための全体集合を返す."""
        return _master_df
    def fit(self, 
            input_df, 
            _master_df=None, 
            y=None
           ):
        master_df = input_df if _master_df is None else self.get_master(_master_df)
        text = self.preprocess(master_df)
        self.vectorizer_ = TfidfVectorizer(max_features=self.max_features
                                      ,ngram_range=self.ngram_range
                                      ,use_idf=self.use_idf)

        self.vectorizer_.fit(text)
        self.prefix = 'tfidf' if self.use_idf == True else 'tf'
        return self.transform(input_df)

    def transform(self, input_df):
        text = self.preprocess(input_df)
        z = self.vectorizer_.transform(text)

        out_df = pd.DataFrame(z.toarray())
        out_df.columns = self.vectorizer_.get_feature_names()
        return out_df.add_prefix(f'{self.prefix}_')

# %%
class LitDataset(Dataset):
    def __init__(self, df, tfidf, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])
        self.tfidf = tfidf # fit済みのものを入力する。（クラス内ではtransformのみ行う）
        self.tfidf_vector = tfidf.transform(df).values

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)
        input_tfidf = torch.tensor(self.tfidf_vector[index, :], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len, input_tfidf)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, input_tfidf, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_wordlen = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64)
        )

        self.mlm_tfidf = nn.Sequential(
            nn.Linear(TFIDF_MAX_FEAT, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 64),
            nn.ReLU(),
            nn.Linear(64, 64)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64 + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len, input_tfidf):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # mlm_layers
        mlm_wordlen = self.mlm_wordlen(input_len)
        mlm_tfidf = self.mlm_tfidf(input_tfidf)

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_wordlen, mlm_tfidf], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len, input_tfidf) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target
    del input_len
    del input_tfidf

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len, input_tfidf) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += output.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len, input_tfidf) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_wrd_parameters = list(model.mlm_wordlen.named_parameters())
    mlm_wrd_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_wrd_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_wrd_group

    mlm_tfidf_parameters = list(model.mlm_tfidf.named_parameters())
    mlm_tfidf_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_tfidf_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_tfidf_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path, feat_suffix):
    tfidf = TfidfSimpleBlock('excerpt', max_features=TFIDF_MAX_FEAT)
    df_tfidf = tfidf.fit(train_df.loc[train_indices]) # TODO: fit_transformみたいなメソッド作って、fitではdfが返らないようにする。

    with open(f'TFIDF_{feat_suffix}', 'wb') as f:
      pickle.dump(tfidf, f)

    train_dataset = LitDataset(train_df.loc[train_indices], tfidf) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices], tfidf)
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    feat_suffix = f"{fold + 1}.pkl" 

    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path, feat_suffix))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.882 train_rmse_stderror: 0.06779 train_kl_div: 1.572
# val_rmse_target: 0.7198 val_rmse_stderror: 1.189
# New best_val_rmse: 0.7198
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5779 train_rmse_stderror: 0.09641 train_kl_div: 0.6236
# val_rmse_target: 0.641 val_rmse_stderror: 1.203
# New best_val_rmse: 0.641
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4183 train_rmse_stderror: 0.09261 train_kl_div: 0.384
# val_rmse_target: 0.7245 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.641 (from epoch 0)
#
# 64 steps took 38.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5389 train_rmse_stderror: 0.1215 train_kl_div: 0.6047
# val_rmse_target: 0.7722 val_rmse_stderror: 1.211
# Still best_val_rmse: 0.641 (from epoch 0)
#
# 64 steps took 38.3 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.2852 train_rmse_stderror: 0.07368 train_kl_div: 0.1786
# val_rmse_target: 0.5617 val_rmse_stderror: 1.197
# New best_val_rmse: 0.5617
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4144 train_rmse_stderror: 0.06091 train_kl_div: 0.3783
# val_rmse_target: 0.526 val_rmse_stderror: 1.198
# New best_val_rmse: 0.526
#
# 32 steps took 19.2 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.371 train_rmse_stderror: 0.07761 train_kl_div: 0.2865
# val_rmse_target: 0.5443 val_rmse_stderror: 1.186
# Still best_val_rmse: 0.526 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3213 train_rmse_stderror: 0.131 train_kl_div: 0.2852
# val_rmse_target: 0.5095 val_rmse_stderror: 1.168
# New best_val_rmse: 0.5095
#
# 32 steps took 19.2 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.2527 train_rmse_stderror: 0.09827 train_kl_div: 0.19
# val_rmse_target: 0.593 val_rmse_stderror: 1.18
# Still best_val_rmse: 0.5095 (from epoch 1)
#
# 64 steps took 38.0 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.44 train_rmse_stderror: 0.06114 train_kl_div: 0.3987
# val_rmse_target: 0.5389 val_rmse_stderror: 1.202
# Still best_val_rmse: 0.5095 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.238 train_rmse_stderror: 0.05603 train_kl_div: 0.1284
# val_rmse_target: 0.5162 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.5095 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.481 train_rmse_stderror: 0.03855 train_kl_div: 0.3729
# val_rmse_target: 0.5077 val_rmse_stderror: 1.186
# New best_val_rmse: 0.5077
#
# 32 steps took 19.4 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3823 train_rmse_stderror: 0.03 train_kl_div: 0.2684
# val_rmse_target: 0.5203 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.5077 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2959 train_rmse_stderror: 0.03547 train_kl_div: 0.2037
# val_rmse_target: 0.5044 val_rmse_stderror: 1.221
# New best_val_rmse: 0.5044
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2037 train_rmse_stderror: 0.06177 train_kl_div: 0.1088
# val_rmse_target: 0.5106 val_rmse_stderror: 1.214
# Still best_val_rmse: 0.5044 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.328 train_rmse_stderror: 0.06416 train_kl_div: 0.2321
# val_rmse_target: 0.5026 val_rmse_stderror: 1.193
# New best_val_rmse: 0.5026
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2609 train_rmse_stderror: 0.071 train_kl_div: 0.1363
# val_rmse_target: 0.4955 val_rmse_stderror: 1.22
# New best_val_rmse: 0.4955
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.3978 train_rmse_stderror: 0.07562 train_kl_div: 0.2985
# val_rmse_target: 0.4951 val_rmse_stderror: 1.205
# New best_val_rmse: 0.4951
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.3586 train_rmse_stderror: 0.03874 train_kl_div: 0.3113
# val_rmse_target: 0.4864 val_rmse_stderror: 1.205
# New best_val_rmse: 0.4864
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2073 train_rmse_stderror: 0.05137 train_kl_div: 0.1008
# val_rmse_target: 0.4854 val_rmse_stderror: 1.202
# New best_val_rmse: 0.4854
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2792 train_rmse_stderror: 0.06917 train_kl_div: 0.1741
# val_rmse_target: 0.5009 val_rmse_stderror: 1.181
# Still best_val_rmse: 0.4854 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.2743 train_rmse_stderror: 0.06839 train_kl_div: 0.1574
# val_rmse_target: 0.4822 val_rmse_stderror: 1.203
# New best_val_rmse: 0.4822
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1581 train_rmse_stderror: 0.05728 train_kl_div: 0.06709
# val_rmse_target: 0.4853 val_rmse_stderror: 1.186
# Still best_val_rmse: 0.4822 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1234 train_rmse_stderror: 0.04164 train_kl_div: 0.04022
# val_rmse_target: 0.4741 val_rmse_stderror: 1.199
# New best_val_rmse: 0.4741
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1822 train_rmse_stderror: 0.04811 train_kl_div: 0.07503
# val_rmse_target: 0.4901 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1774 train_rmse_stderror: 0.06929 train_kl_div: 0.07931
# val_rmse_target: 0.4988 val_rmse_stderror: 1.193
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1555 train_rmse_stderror: 0.0524 train_kl_div: 0.05774
# val_rmse_target: 0.4944 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.2371 train_rmse_stderror: 0.06917 train_kl_div: 0.1393
# val_rmse_target: 0.4875 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1206 train_rmse_stderror: 0.03871 train_kl_div: 0.03537
# val_rmse_target: 0.4862 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1312 train_rmse_stderror: 0.03824 train_kl_div: 0.04131
# val_rmse_target: 0.4797 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.08174 train_rmse_stderror: 0.04195 train_kl_div: 0.02257
# val_rmse_target: 0.4799 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.05067 train_rmse_stderror: 0.05105 train_kl_div: 0.01554
# val_rmse_target: 0.4812 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.06104 train_rmse_stderror: 0.05203 train_kl_div: 0.01885
# val_rmse_target: 0.4828 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.157 train_rmse_stderror: 0.04523 train_kl_div: 0.0515
# val_rmse_target: 0.4838 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1417 train_rmse_stderror: 0.04029 train_kl_div: 0.04577
# val_rmse_target: 0.4835 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1166 train_rmse_stderror: 0.04532 train_kl_div: 0.04058
# val_rmse_target: 0.484 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1235 train_rmse_stderror: 0.04078 train_kl_div: 0.03868
# val_rmse_target: 0.4842 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4741 (from epoch 3)
#
# Performance estimates:
# [0.4740541625911686]
# Mean: 0.4740541625911686
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5868 train_rmse_stderror: 0.1271 train_kl_div: 0.8007
# val_rmse_target: 0.6283 val_rmse_stderror: 1.684
# New best_val_rmse: 0.6283
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7468 train_rmse_stderror: 0.08873 train_kl_div: 1.261
# val_rmse_target: 0.6579 val_rmse_stderror: 1.808
# Still best_val_rmse: 0.6283 (from epoch 0)
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.6893 train_rmse_stderror: 0.06191 train_kl_div: 1.017
# val_rmse_target: 0.5998 val_rmse_stderror: 1.722
# New best_val_rmse: 0.5998
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4616 train_rmse_stderror: 0.06735 train_kl_div: 0.4551
# val_rmse_target: 0.5893 val_rmse_stderror: 1.75
# New best_val_rmse: 0.5893
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.2093 train_rmse_stderror: 0.07215 train_kl_div: 0.1191
# val_rmse_target: 0.5493 val_rmse_stderror: 1.772
# New best_val_rmse: 0.5493
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.3543 train_rmse_stderror: 0.08547 train_kl_div: 0.2717
# val_rmse_target: 0.6027 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.5493 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.2288 train_rmse_stderror: 0.05187 train_kl_div: 0.1182
# val_rmse_target: 0.5374 val_rmse_stderror: 1.753
# New best_val_rmse: 0.5374
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.2413 train_rmse_stderror: 0.0664 train_kl_div: 0.138
# val_rmse_target: 0.5507 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.5374 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4435 train_rmse_stderror: 0.05198 train_kl_div: 0.4494
# val_rmse_target: 0.5237 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5237
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4695 train_rmse_stderror: 0.07238 train_kl_div: 0.3916
# val_rmse_target: 0.5286 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.5237 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.18 train_rmse_stderror: 0.05112 train_kl_div: 0.07746
# val_rmse_target: 0.5036 val_rmse_stderror: 1.742
# New best_val_rmse: 0.5036
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2083 train_rmse_stderror: 0.08217 train_kl_div: 0.134
# val_rmse_target: 0.5032 val_rmse_stderror: 1.751
# New best_val_rmse: 0.5032
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2198 train_rmse_stderror: 0.03243 train_kl_div: 0.1043
# val_rmse_target: 0.5262 val_rmse_stderror: 1.725
# Still best_val_rmse: 0.5032 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2235 train_rmse_stderror: 0.07847 train_kl_div: 0.1334
# val_rmse_target: 0.5041 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.5032 (from epoch 2)
#
# 32 steps took 19.4 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2478 train_rmse_stderror: 0.06223 train_kl_div: 0.1329
# val_rmse_target: 0.5105 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.5032 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2085 train_rmse_stderror: 0.05685 train_kl_div: 0.1017
# val_rmse_target: 0.5099 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.5032 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2528 train_rmse_stderror: 0.03671 train_kl_div: 0.1284
# val_rmse_target: 0.5126 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.5032 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.3099 train_rmse_stderror: 0.06762 train_kl_div: 0.1956
# val_rmse_target: 0.5024 val_rmse_stderror: 1.764
# New best_val_rmse: 0.5024
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2724 train_rmse_stderror: 0.04718 train_kl_div: 0.1648
# val_rmse_target: 0.508 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.5024 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1277 train_rmse_stderror: 0.04428 train_kl_div: 0.04181
# val_rmse_target: 0.5032 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.5024 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1788 train_rmse_stderror: 0.04037 train_kl_div: 0.07602
# val_rmse_target: 0.5001 val_rmse_stderror: 1.747
# New best_val_rmse: 0.5001
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1364 train_rmse_stderror: 0.03041 train_kl_div: 0.0397
# val_rmse_target: 0.4939 val_rmse_stderror: 1.741
# New best_val_rmse: 0.4939
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.09502 train_rmse_stderror: 0.03978 train_kl_div: 0.02348
# val_rmse_target: 0.497 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4939 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.09012 train_rmse_stderror: 0.03061 train_kl_div: 0.02134
# val_rmse_target: 0.4992 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4939 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1262 train_rmse_stderror: 0.04225 train_kl_div: 0.03914
# val_rmse_target: 0.493 val_rmse_stderror: 1.75
# New best_val_rmse: 0.493
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.0882 train_rmse_stderror: 0.03937 train_kl_div: 0.0238
# val_rmse_target: 0.4954 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1251 train_rmse_stderror: 0.03216 train_kl_div: 0.03455
# val_rmse_target: 0.4968 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.06545 train_rmse_stderror: 0.0363 train_kl_div: 0.01616
# val_rmse_target: 0.4958 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.05372 train_rmse_stderror: 0.04245 train_kl_div: 0.01367
# val_rmse_target: 0.4967 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08167 train_rmse_stderror: 0.03294 train_kl_div: 0.01672
# val_rmse_target: 0.4951 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.05733 train_rmse_stderror: 0.0427 train_kl_div: 0.0141
# val_rmse_target: 0.4946 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.06188 train_rmse_stderror: 0.03456 train_kl_div: 0.01326
# val_rmse_target: 0.4939 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1143 train_rmse_stderror: 0.04905 train_kl_div: 0.03341
# val_rmse_target: 0.4936 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.04617 train_rmse_stderror: 0.02945 train_kl_div: 0.008252
# val_rmse_target: 0.4933 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.08323 train_rmse_stderror: 0.03168 train_kl_div: 0.01895
# val_rmse_target: 0.4937 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1247 train_rmse_stderror: 0.051 train_kl_div: 0.0448
# val_rmse_target: 0.4941 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.493 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.05487 train_rmse_stderror: 0.0372 train_kl_div: 0.01249
# val_rmse_target: 0.4942 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.493 (from epoch 3)
#
# Performance estimates:
# [0.4740541625911686, 0.4930212498035972]
# Mean: 0.4835377061973829
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 3/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.6 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6498 train_rmse_stderror: 0.1618 train_kl_div: 0.9747
# val_rmse_target: 0.6406 val_rmse_stderror: 1.84
# New best_val_rmse: 0.6406
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.001 train_rmse_stderror: 0.1135 train_kl_div: 2.221
# val_rmse_target: 0.7233 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.6406 (from epoch 0)
#
# 64 steps took 38.3 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4517 train_rmse_stderror: 0.0673 train_kl_div: 0.4636
# val_rmse_target: 0.5631 val_rmse_stderror: 1.717
# New best_val_rmse: 0.5631
#
# 64 steps took 38.2 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6145 train_rmse_stderror: 0.05803 train_kl_div: 0.8262
# val_rmse_target: 0.5686 val_rmse_stderror: 1.726
# Still best_val_rmse: 0.5631 (from epoch 0)
#
# 64 steps took 38.5 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3749 train_rmse_stderror: 0.09534 train_kl_div: 0.33
# val_rmse_target: 0.5145 val_rmse_stderror: 1.748
# New best_val_rmse: 0.5145
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.667 train_rmse_stderror: 0.05005 train_kl_div: 0.8532
# val_rmse_target: 0.518 val_rmse_stderror: 1.728
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4308 train_rmse_stderror: 0.06911 train_kl_div: 0.4184
# val_rmse_target: 0.5895 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3159 train_rmse_stderror: 0.05366 train_kl_div: 0.2164
# val_rmse_target: 0.5224 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.67 train_rmse_stderror: 0.05902 train_kl_div: 0.7375
# val_rmse_target: 0.5334 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5145 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3246 train_rmse_stderror: 0.0352 train_kl_div: 0.2411
# val_rmse_target: 0.508 val_rmse_stderror: 1.755
# New best_val_rmse: 0.508
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4171 train_rmse_stderror: 0.07131 train_kl_div: 0.3035
# val_rmse_target: 0.5264 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.508 (from epoch 1)
#
# 32 steps took 19.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3218 train_rmse_stderror: 0.07049 train_kl_div: 0.237
# val_rmse_target: 0.5051 val_rmse_stderror: 1.757
# New best_val_rmse: 0.5051
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2679 train_rmse_stderror: 0.05793 train_kl_div: 0.1482
# val_rmse_target: 0.4935 val_rmse_stderror: 1.751
# New best_val_rmse: 0.4935
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.3656 train_rmse_stderror: 0.06589 train_kl_div: 0.3047
# val_rmse_target: 0.4923 val_rmse_stderror: 1.732
# New best_val_rmse: 0.4923
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2186 train_rmse_stderror: 0.05183 train_kl_div: 0.09885
# val_rmse_target: 0.4835 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4835
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2382 train_rmse_stderror: 0.03159 train_kl_div: 0.1252
# val_rmse_target: 0.4884 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2052 train_rmse_stderror: 0.05596 train_kl_div: 0.1023
# val_rmse_target: 0.4838 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3312 train_rmse_stderror: 0.04797 train_kl_div: 0.2442
# val_rmse_target: 0.4829 val_rmse_stderror: 1.732
# New best_val_rmse: 0.4829
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2826 train_rmse_stderror: 0.07811 train_kl_div: 0.1995
# val_rmse_target: 0.4801 val_rmse_stderror: 1.752
# New best_val_rmse: 0.4801
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1564 train_rmse_stderror: 0.05708 train_kl_div: 0.05203
# val_rmse_target: 0.4886 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1893 train_rmse_stderror: 0.02284 train_kl_div: 0.07432
# val_rmse_target: 0.484 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1052 train_rmse_stderror: 0.0681 train_kl_div: 0.03971
# val_rmse_target: 0.4881 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1237 train_rmse_stderror: 0.06213 train_kl_div: 0.05149
# val_rmse_target: 0.4804 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1285 train_rmse_stderror: 0.04631 train_kl_div: 0.04028
# val_rmse_target: 0.4816 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.09738 train_rmse_stderror: 0.03269 train_kl_div: 0.02257
# val_rmse_target: 0.4804 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.118 train_rmse_stderror: 0.0358 train_kl_div: 0.02906
# val_rmse_target: 0.4817 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1047 train_rmse_stderror: 0.05601 train_kl_div: 0.03418
# val_rmse_target: 0.4842 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4801 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.175 train_rmse_stderror: 0.03838 train_kl_div: 0.06934
# val_rmse_target: 0.4793 val_rmse_stderror: 1.747
# New best_val_rmse: 0.4793
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1378 train_rmse_stderror: 0.05288 train_kl_div: 0.05351
# val_rmse_target: 0.4803 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.4 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1048 train_rmse_stderror: 0.04244 train_kl_div: 0.02571
# val_rmse_target: 0.4855 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.09497 train_rmse_stderror: 0.06975 train_kl_div: 0.03853
# val_rmse_target: 0.4811 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.07461 train_rmse_stderror: 0.04082 train_kl_div: 0.01768
# val_rmse_target: 0.482 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.07139 train_rmse_stderror: 0.03433 train_kl_div: 0.0152
# val_rmse_target: 0.4821 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.06645 train_rmse_stderror: 0.02114 train_kl_div: 0.01112
# val_rmse_target: 0.4825 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1133 train_rmse_stderror: 0.03698 train_kl_div: 0.03174
# val_rmse_target: 0.482 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.087 train_rmse_stderror: 0.03007 train_kl_div: 0.02044
# val_rmse_target: 0.482 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1003 train_rmse_stderror: 0.04601 train_kl_div: 0.03011
# val_rmse_target: 0.4817 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.04987 train_rmse_stderror: 0.03747 train_kl_div: 0.01187
# val_rmse_target: 0.4818 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4793 (from epoch 3)
#
# Performance estimates:
# [0.4740541625911686, 0.4930212498035972, 0.4793317812852389]
# Mean: 0.48213573122666825
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 4/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.007 train_rmse_stderror: 0.06532 train_kl_div: 1.735
# val_rmse_target: 0.6673 val_rmse_stderror: 1.816
# New best_val_rmse: 0.6673
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8553 train_rmse_stderror: 0.07696 train_kl_div: 1.571
# val_rmse_target: 0.6034 val_rmse_stderror: 1.815
# New best_val_rmse: 0.6034
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.8158 train_rmse_stderror: 0.05479 train_kl_div: 1.381
# val_rmse_target: 0.5793 val_rmse_stderror: 1.788
# New best_val_rmse: 0.5793
#
# 64 steps took 38.4 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6382 train_rmse_stderror: 0.04955 train_kl_div: 0.9094
# val_rmse_target: 0.6636 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.5793 (from epoch 0)
#
# 64 steps took 38.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.4898 train_rmse_stderror: 0.07067 train_kl_div: 0.4917
# val_rmse_target: 0.5643 val_rmse_stderror: 1.776
# New best_val_rmse: 0.5643
#
# 64 steps took 38.2 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.3973 train_rmse_stderror: 0.04946 train_kl_div: 0.3069
# val_rmse_target: 0.5075 val_rmse_stderror: 1.774
# New best_val_rmse: 0.5075
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.5237 train_rmse_stderror: 0.05363 train_kl_div: 0.4983
# val_rmse_target: 0.5264 val_rmse_stderror: 1.813
# Still best_val_rmse: 0.5075 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5297 train_rmse_stderror: 0.05204 train_kl_div: 0.5612
# val_rmse_target: 0.5403 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.5075 (from epoch 1)
#
# 32 steps took 19.4 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5227 train_rmse_stderror: 0.06216 train_kl_div: 0.5893
# val_rmse_target: 0.5401 val_rmse_stderror: 1.801
# Still best_val_rmse: 0.5075 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4225 train_rmse_stderror: 0.05344 train_kl_div: 0.4092
# val_rmse_target: 0.4804 val_rmse_stderror: 1.779
# New best_val_rmse: 0.4804
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4166 train_rmse_stderror: 0.02779 train_kl_div: 0.348
# val_rmse_target: 0.484 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4804 (from epoch 1)
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1913 train_rmse_stderror: 0.03954 train_kl_div: 0.08719
# val_rmse_target: 0.4754 val_rmse_stderror: 1.801
# New best_val_rmse: 0.4754
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2278 train_rmse_stderror: 0.06425 train_kl_div: 0.1146
# val_rmse_target: 0.4489 val_rmse_stderror: 1.786
# New best_val_rmse: 0.4489
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.4348 train_rmse_stderror: 0.04684 train_kl_div: 0.3286
# val_rmse_target: 0.4671 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.4 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2964 train_rmse_stderror: 0.02421 train_kl_div: 0.1367
# val_rmse_target: 0.4651 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1796 train_rmse_stderror: 0.03171 train_kl_div: 0.05997
# val_rmse_target: 0.5083 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.1678 train_rmse_stderror: 0.04296 train_kl_div: 0.06333
# val_rmse_target: 0.4539 val_rmse_stderror: 1.797
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3266 train_rmse_stderror: 0.04289 train_kl_div: 0.2224
# val_rmse_target: 0.4637 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2696 train_rmse_stderror: 0.04168 train_kl_div: 0.1418
# val_rmse_target: 0.4628 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2568 train_rmse_stderror: 0.04542 train_kl_div: 0.1368
# val_rmse_target: 0.4567 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.5 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.2715 train_rmse_stderror: 0.01951 train_kl_div: 0.1253
# val_rmse_target: 0.452 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1712 train_rmse_stderror: 0.04399 train_kl_div: 0.07178
# val_rmse_target: 0.4551 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1123 train_rmse_stderror: 0.03111 train_kl_div: 0.02841
# val_rmse_target: 0.4631 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.0896 train_rmse_stderror: 0.03296 train_kl_div: 0.02258
# val_rmse_target: 0.455 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1074 train_rmse_stderror: 0.03103 train_kl_div: 0.02758
# val_rmse_target: 0.453 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1246 train_rmse_stderror: 0.02825 train_kl_div: 0.04015
# val_rmse_target: 0.4571 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.08667 train_rmse_stderror: 0.02615 train_kl_div: 0.01858
# val_rmse_target: 0.4503 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1684 train_rmse_stderror: 0.0482 train_kl_div: 0.06645
# val_rmse_target: 0.4529 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.3 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.05464 train_rmse_stderror: 0.04017 train_kl_div: 0.01283
# val_rmse_target: 0.458 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.5 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.07675 train_rmse_stderror: 0.02889 train_kl_div: 0.01415
# val_rmse_target: 0.4527 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08071 train_rmse_stderror: 0.02286 train_kl_div: 0.01468
# val_rmse_target: 0.4513 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.4 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.07774 train_rmse_stderror: 0.04427 train_kl_div: 0.02087
# val_rmse_target: 0.4512 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.08587 train_rmse_stderror: 0.03427 train_kl_div: 0.02064
# val_rmse_target: 0.4555 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.0929 train_rmse_stderror: 0.03283 train_kl_div: 0.02225
# val_rmse_target: 0.4523 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.06696 train_rmse_stderror: 0.0335 train_kl_div: 0.01377
# val_rmse_target: 0.4524 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.0918 train_rmse_stderror: 0.02116 train_kl_div: 0.0207
# val_rmse_target: 0.4523 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1634 train_rmse_stderror: 0.04318 train_kl_div: 0.0556
# val_rmse_target: 0.4527 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.06838 train_rmse_stderror: 0.02179 train_kl_div: 0.01062
# val_rmse_target: 0.4526 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4489 (from epoch 2)
#
# Performance estimates:
# [0.4740541625911686, 0.4930212498035972, 0.4793317812852389, 0.4488815056775918]
# Mean: 0.47382217483939915
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 5/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 38.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.7222 train_rmse_stderror: 0.06723 train_kl_div: 1.102
# val_rmse_target: 0.689 val_rmse_stderror: 1.777
# New best_val_rmse: 0.689
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6915 train_rmse_stderror: 0.05797 train_kl_div: 1.031
# val_rmse_target: 0.6852 val_rmse_stderror: 1.745
# New best_val_rmse: 0.6852
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.7613 train_rmse_stderror: 0.09875 train_kl_div: 1.006
# val_rmse_target: 0.5621 val_rmse_stderror: 1.77
# New best_val_rmse: 0.5621
#
# 64 steps took 38.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.7963 train_rmse_stderror: 0.08612 train_kl_div: 1.299
# val_rmse_target: 0.6112 val_rmse_stderror: 1.804
# Still best_val_rmse: 0.5621 (from epoch 0)
#
# 64 steps took 38.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.2885 train_rmse_stderror: 0.05857 train_kl_div: 0.2042
# val_rmse_target: 0.5364 val_rmse_stderror: 1.714
# New best_val_rmse: 0.5364
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.376 train_rmse_stderror: 0.05774 train_kl_div: 0.3287
# val_rmse_target: 0.5618 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.5364 (from epoch 1)
#
# 64 steps took 38.1 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.238 train_rmse_stderror: 0.07573 train_kl_div: 0.1356
# val_rmse_target: 0.5078 val_rmse_stderror: 1.758
# New best_val_rmse: 0.5078
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5601 train_rmse_stderror: 0.1053 train_kl_div: 0.6362
# val_rmse_target: 0.5283 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.5078 (from epoch 1)
#
# 32 steps took 19.0 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.305 train_rmse_stderror: 0.08168 train_kl_div: 0.2245
# val_rmse_target: 0.5485 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.5078 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3392 train_rmse_stderror: 0.06665 train_kl_div: 0.2506
# val_rmse_target: 0.5116 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.5078 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.337 train_rmse_stderror: 0.06088 train_kl_div: 0.2594
# val_rmse_target: 0.5603 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.5078 (from epoch 1)
#
# 64 steps took 38.5 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2712 train_rmse_stderror: 0.04189 train_kl_div: 0.1635
# val_rmse_target: 0.5372 val_rmse_stderror: 1.723
# Still best_val_rmse: 0.5078 (from epoch 1)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2728 train_rmse_stderror: 0.05229 train_kl_div: 0.1513
# val_rmse_target: 0.4961 val_rmse_stderror: 1.769
# New best_val_rmse: 0.4961
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2331 train_rmse_stderror: 0.04673 train_kl_div: 0.1155
# val_rmse_target: 0.4934 val_rmse_stderror: 1.758
# New best_val_rmse: 0.4934
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1735 train_rmse_stderror: 0.04156 train_kl_div: 0.07135
# val_rmse_target: 0.5121 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4934 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2043 train_rmse_stderror: 0.06105 train_kl_div: 0.09886
# val_rmse_target: 0.4975 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4934 (from epoch 2)
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.169 train_rmse_stderror: 0.04495 train_kl_div: 0.06116
# val_rmse_target: 0.4917 val_rmse_stderror: 1.771
# New best_val_rmse: 0.4917
#
# 32 steps took 19.1 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2658 train_rmse_stderror: 0.03923 train_kl_div: 0.1591
# val_rmse_target: 0.5183 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4917 (from epoch 2)
#
# 32 steps took 19.0 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1872 train_rmse_stderror: 0.04032 train_kl_div: 0.08011
# val_rmse_target: 0.5095 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4917 (from epoch 2)
#
# 32 steps took 19.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1341 train_rmse_stderror: 0.02632 train_kl_div: 0.04223
# val_rmse_target: 0.5101 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4917 (from epoch 2)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1274 train_rmse_stderror: 0.0336 train_kl_div: 0.03695
# val_rmse_target: 0.4912 val_rmse_stderror: 1.769
# New best_val_rmse: 0.4912
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1253 train_rmse_stderror: 0.03299 train_kl_div: 0.0369
# val_rmse_target: 0.498 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4912 (from epoch 3)
#
# 32 steps took 19.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.07988 train_rmse_stderror: 0.02342 train_kl_div: 0.0166
# val_rmse_target: 0.4908 val_rmse_stderror: 1.762
# New best_val_rmse: 0.4908
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.06781 train_rmse_stderror: 0.04875 train_kl_div: 0.01844
# val_rmse_target: 0.4982 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.08035 train_rmse_stderror: 0.05015 train_kl_div: 0.02431
# val_rmse_target: 0.4914 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1484 train_rmse_stderror: 0.02171 train_kl_div: 0.0475
# val_rmse_target: 0.4958 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 19.2 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.09305 train_rmse_stderror: 0.04496 train_kl_div: 0.02381
# val_rmse_target: 0.4954 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 19.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1894 train_rmse_stderror: 0.04725 train_kl_div: 0.08283
# val_rmse_target: 0.4912 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 19.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1174 train_rmse_stderror: 0.04884 train_kl_div: 0.03539
# val_rmse_target: 0.4883 val_rmse_stderror: 1.766
# New best_val_rmse: 0.4883
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.07069 train_rmse_stderror: 0.02522 train_kl_div: 0.01507
# val_rmse_target: 0.4898 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.05533 train_rmse_stderror: 0.0404 train_kl_div: 0.01241
# val_rmse_target: 0.4918 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.09798 train_rmse_stderror: 0.03808 train_kl_div: 0.02858
# val_rmse_target: 0.4884 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.0 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.0617 train_rmse_stderror: 0.0305 train_kl_div: 0.01187
# val_rmse_target: 0.4916 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.05175 train_rmse_stderror: 0.03841 train_kl_div: 0.01069
# val_rmse_target: 0.4891 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05731 train_rmse_stderror: 0.03329 train_kl_div: 0.01167
# val_rmse_target: 0.4903 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.4 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.04989 train_rmse_stderror: 0.03922 train_kl_div: 0.0119
# val_rmse_target: 0.4898 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# 32 steps took 19.1 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08139 train_rmse_stderror: 0.02781 train_kl_div: 0.01642
# val_rmse_target: 0.4899 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4883 (from epoch 4)
#
# Performance estimates:
# [0.4740541625911686, 0.4930212498035972, 0.4793317812852389, 0.4488815056775918, 0.48828937992835825]
# Mean: 0.4767156158571909
# {'total_MiB': 16160, 'used_MiB': 1359}

# %%
print(list_val_rmse)
# Out:
# [0.4740541625911686, 0.4930212498035972, 0.4793317812852389, 0.4488815056775918, 0.48828937992835825]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# !cp -r /content/TFIDF_1.pkl /content/model/TFIDF_1.pkl
# !cp -r /content/TFIDF_2.pkl /content/model/TFIDF_2.pkl
# !cp -r /content/TFIDF_3.pkl /content/model/TFIDF_3.pkl
# !cp -r /content/TFIDF_4.pkl /content/model/TFIDF_4.pkl
# !cp -r /content/TFIDF_5.pkl /content/model/TFIDF_5.pkl
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file TFIDF_1.pkl
# 100%|██████████| 560k/560k [00:05<00:00, 105kB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: TFIDF_1.pkl (560KB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:51<00:00, 27.8MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:58<00:00, 24.6MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:59<00:00, 23.8MB/s]
#   0%|          | 0.00/561k [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file TFIDF_5.pkl
# 100%|██████████| 561k/561k [00:04<00:00, 119kB/s]
#   0%|          | 0.00/561k [00:00<?, ?B/s]
# Upload successful: TFIDF_5.pkl (561KB)
# Starting upload for file TFIDF_3.pkl
# 100%|██████████| 561k/561k [00:05<00:00, 98.5kB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: TFIDF_3.pkl (561KB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:56<00:00, 25.1MB/s]
#   0%|          | 0.00/561k [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file TFIDF_4.pkl
# 100%|██████████| 561k/561k [00:05<00:00, 113kB/s]
#   0%|          | 0.00/561k [00:00<?, ?B/s]
# Upload successful: TFIDF_4.pkl (561KB)
# Starting upload for file TFIDF_2.pkl
# 100%|██████████| 561k/561k [00:05<00:00, 103kB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: TFIDF_2.pkl (561KB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:52<00:00, 27.4MB/s]
# Upload successful: model_5.pth (1GB)

# %%
# %env MODEL_OUT_DIR ''
# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# !cp -r /content/TFIDF_1.pkl /content/model/TFIDF_1.pkl
# !cp -r /content/TFIDF_2.pkl /content/model/TFIDF_2.pkl
# !cp -r /content/TFIDF_3.pkl /content/model/TFIDF_3.pkl
# !cp -r /content/TFIDF_4.pkl /content/model/TFIDF_4.pkl
# !cp -r /content/TFIDF_5.pkl /content/model/TFIDF_5.pkl
