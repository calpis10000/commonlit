# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (0.1.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-base'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '043-train-04'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 16 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512), # 768は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        #print('model: get_roberta_out: Start', gpuinfo())                 
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        #print('model: get_roberta_out: Done', gpuinfo())                 

        # There are a total of 13 layers of hidden states.
        # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # We take the hidden states from the last Roberta layer.
        #last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        last_hidden_state = roberta_output[0]

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask

        # The number of cells is MAX_LEN.
        # The size of the hidden state of each cell is 768 (for roberta-base). # 
        # In order to condense hidden states of all cells to a context vector,
        # we compute a weighted average of the hidden states of all cells.
        # We compute the weight of each cell, using the attention neural network.
        #weights = self.attention(last_layer_hidden_states) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る
                
        # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # Now we compute context_vector as the weighted average.
        # context_vector.shape is BATCH_SIZE x 768
        #context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            #del target
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = named_parameters[:197] # パラメータをroberta用、attention用、regressor用に格納。(どうやって決めてるのだろう？)
    attention_parameters = named_parameters[199:203]
    regressor_parameters = named_parameters[203:]
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    )
    
    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=num_splits)
    
    # note that, instead of targets, we use bins!
    return kf.split(X=data, y=data.bins.values)

# %%
st_kfold_bins = create_folds(train_df, num_splits=5)

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(st_kfold_bins):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    #print('getmodel: Start', gpuinfo())                 
    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    #print('getmodel: Done', gpuinfo())                 

    #print('get_optim_sched: Start', gpuinfo())                 
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    #print('get_optim_sched: Done', gpuinfo())                 

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.5 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9878 val_rmse_stderror: 1.598
# New best_val_rmse: 0.9878
#
# 16 steps took 8.98 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.8612 val_rmse_stderror: 1.791
# New best_val_rmse: 0.8612
#
# 16 steps took 8.98 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.8095 val_rmse_stderror: 1.601
# New best_val_rmse: 0.8095
#
# 16 steps took 9.0 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7262 val_rmse_stderror: 1.671
# New best_val_rmse: 0.7262
#
# 16 steps took 9.0 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.681 val_rmse_stderror: 1.654
# New best_val_rmse: 0.681
#
# 16 steps took 9.0 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6404 val_rmse_stderror: 1.67
# New best_val_rmse: 0.6404
#
# 16 steps took 8.98 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6586 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.6404 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5839 val_rmse_stderror: 1.661
# New best_val_rmse: 0.5839
#
# 16 steps took 9.15 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5973 val_rmse_stderror: 1.685
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.697 val_rmse_stderror: 1.666
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 9.0 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.631 val_rmse_stderror: 1.647
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.7266 val_rmse_stderror: 1.68
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 9.01 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.6046 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.6236 val_rmse_stderror: 1.648
# Still best_val_rmse: 0.5839 (from epoch 0)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5498 val_rmse_stderror: 1.67
# New best_val_rmse: 0.5498
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5331 val_rmse_stderror: 1.653
# New best_val_rmse: 0.5331
#
# 16 steps took 9.01 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5315 val_rmse_stderror: 1.658
# New best_val_rmse: 0.5315
#
# 16 steps took 9.16 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5066 val_rmse_stderror: 1.661
# New best_val_rmse: 0.5066
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.4883 val_rmse_stderror: 1.653
# New best_val_rmse: 0.4883
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.4904 val_rmse_stderror: 1.655
# Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 2 batch_num: 34 val_rmse_target: 0.4883 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4883 (from epoch 2)
#
# 4 steps took 2.25 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4957 val_rmse_stderror: 1.659
# Still best_val_rmse: 0.4883 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4897 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4883 (from epoch 2)
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4772 val_rmse_stderror: 1.659
# New best_val_rmse: 0.4772
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 52 val_rmse_target: 0.4765 val_rmse_stderror: 1.656
# New best_val_rmse: 0.4765
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4766 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 56 val_rmse_target: 0.495 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 2 batch_num: 64 val_rmse_target: 0.499 val_rmse_stderror: 1.662
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 2 batch_num: 72 val_rmse_target: 0.4774 val_rmse_stderror: 1.649
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4794 val_rmse_stderror: 1.647
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.4812 val_rmse_stderror: 1.648
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 4 steps took 2.25 seconds
# Epoch: 2 batch_num: 80 val_rmse_target: 0.4802 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 4 steps took 2.25 seconds
# Epoch: 2 batch_num: 84 val_rmse_target: 0.4961 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.5151 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 108 val_rmse_target: 0.4871 val_rmse_stderror: 1.665
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.5085 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 16 steps took 9.0 seconds
# Epoch: 2 batch_num: 128 val_rmse_target: 0.4843 val_rmse_stderror: 1.652
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4765 val_rmse_stderror: 1.656
# New best_val_rmse: 0.4765
#
# 2 steps took 1.12 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4901 val_rmse_stderror: 1.659
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 8 steps took 4.68 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4931 val_rmse_stderror: 1.664
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.5001 val_rmse_stderror: 1.659
# Still best_val_rmse: 0.4765 (from epoch 2)
#
# 16 steps took 9.0 seconds
# Epoch: 3 batch_num: 25 val_rmse_target: 0.4744 val_rmse_stderror: 1.66
# New best_val_rmse: 0.4744
#
# 2 steps took 1.13 seconds
# Epoch: 3 batch_num: 27 val_rmse_target: 0.4796 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 29 val_rmse_target: 0.4776 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 31 val_rmse_target: 0.4762 val_rmse_stderror: 1.66
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 33 val_rmse_target: 0.4771 val_rmse_stderror: 1.659
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 35 val_rmse_target: 0.4781 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 37 val_rmse_target: 0.4811 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 41 val_rmse_target: 0.4821 val_rmse_stderror: 1.652
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 45 val_rmse_target: 0.4893 val_rmse_stderror: 1.649
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 49 val_rmse_target: 0.4815 val_rmse_stderror: 1.647
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 53 val_rmse_target: 0.4753 val_rmse_stderror: 1.649
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 55 val_rmse_target: 0.4751 val_rmse_stderror: 1.651
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 57 val_rmse_target: 0.4775 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 59 val_rmse_target: 0.4748 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4744 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 61 val_rmse_target: 0.4725 val_rmse_stderror: 1.66
# New best_val_rmse: 0.4725
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 63 val_rmse_target: 0.4758 val_rmse_stderror: 1.662
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.4791 val_rmse_stderror: 1.662
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 67 val_rmse_target: 0.4748 val_rmse_stderror: 1.664
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4769 val_rmse_stderror: 1.666
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 71 val_rmse_target: 0.4799 val_rmse_stderror: 1.667
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 73 val_rmse_target: 0.481 val_rmse_stderror: 1.666
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4943 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4898 val_rmse_stderror: 1.659
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.4794 val_rmse_stderror: 1.662
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 91 val_rmse_target: 0.4806 val_rmse_stderror: 1.663
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 95 val_rmse_target: 0.4812 val_rmse_stderror: 1.663
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 99 val_rmse_target: 0.4723 val_rmse_stderror: 1.66
# New best_val_rmse: 0.4723
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 101 val_rmse_target: 0.4713 val_rmse_stderror: 1.658
# New best_val_rmse: 0.4713
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 103 val_rmse_target: 0.4693 val_rmse_stderror: 1.657
# New best_val_rmse: 0.4693
#
# 1 steps took 0.557 seconds
# Epoch: 3 batch_num: 104 val_rmse_target: 0.4693 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4693 (from epoch 3)
#
# 1 steps took 0.558 seconds
# Epoch: 3 batch_num: 105 val_rmse_target: 0.4691 val_rmse_stderror: 1.657
# New best_val_rmse: 0.4691
#
# 1 steps took 0.556 seconds
# Epoch: 3 batch_num: 106 val_rmse_target: 0.4689 val_rmse_stderror: 1.657
# New best_val_rmse: 0.4689
#
# 1 steps took 0.555 seconds
# Epoch: 3 batch_num: 107 val_rmse_target: 0.4687 val_rmse_stderror: 1.657
# New best_val_rmse: 0.4687
#
# 1 steps took 0.559 seconds
# Epoch: 3 batch_num: 108 val_rmse_target: 0.4696 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 1 steps took 0.558 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4714 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 111 val_rmse_target: 0.472 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4712 val_rmse_stderror: 1.655
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 115 val_rmse_target: 0.4726 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4777 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 119 val_rmse_target: 0.483 val_rmse_stderror: 1.652
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 123 val_rmse_target: 0.4844 val_rmse_stderror: 1.651
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 127 val_rmse_target: 0.4781 val_rmse_stderror: 1.651
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4771 val_rmse_stderror: 1.652
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 131 val_rmse_target: 0.477 val_rmse_stderror: 1.652
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 133 val_rmse_target: 0.4781 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 135 val_rmse_target: 0.4789 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4772 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 3 batch_num: 139 val_rmse_target: 0.4744 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.28 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.4763 val_rmse_stderror: 1.653
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.13 seconds
# Epoch: 4 batch_num: 2 val_rmse_target: 0.4796 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4848 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.483 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4795 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 14 val_rmse_target: 0.4761 val_rmse_stderror: 1.654
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4745 val_rmse_stderror: 1.655
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 18 val_rmse_target: 0.4749 val_rmse_stderror: 1.655
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4756 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 22 val_rmse_target: 0.4763 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4769 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 26 val_rmse_target: 0.4783 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.4818 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4893 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.4865 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4815 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4779 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 46 val_rmse_target: 0.4771 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4765 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 50 val_rmse_target: 0.4763 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4765 val_rmse_stderror: 1.658
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 54 val_rmse_target: 0.4757 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4751 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 58 val_rmse_target: 0.4747 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4747 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 62 val_rmse_target: 0.4747 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.475 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 66 val_rmse_target: 0.4752 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4753 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 70 val_rmse_target: 0.4752 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4754 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 74 val_rmse_target: 0.4755 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.13 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4757 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 78 val_rmse_target: 0.4763 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.4772 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 82 val_rmse_target: 0.4775 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4774 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 86 val_rmse_target: 0.4774 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4771 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 90 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4772 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 94 val_rmse_target: 0.4771 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4771 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 98 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 102 val_rmse_target: 0.4772 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4772 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 106 val_rmse_target: 0.4771 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4771 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 110 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 114 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 118 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 122 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 126 val_rmse_target: 0.477 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 130 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 134 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 138 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# 2 steps took 1.12 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4769 val_rmse_stderror: 1.656
# Still best_val_rmse: 0.4687 (from epoch 3)
#
# Performance estimates:
# [0.46874391976819313]
# Mean: 0.46874391976819313
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.23 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.182 val_rmse_stderror: 1.03
# New best_val_rmse: 1.182
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.056 val_rmse_stderror: 0.9657
# New best_val_rmse: 1.056
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7313 val_rmse_stderror: 0.9544
# New best_val_rmse: 0.7313
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.631 val_rmse_stderror: 0.9361
# New best_val_rmse: 0.631
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6449 val_rmse_stderror: 0.9761
# Still best_val_rmse: 0.631 (from epoch 0)
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5947 val_rmse_stderror: 0.9583
# New best_val_rmse: 0.5947
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6093 val_rmse_stderror: 0.9637
# Still best_val_rmse: 0.5947 (from epoch 0)
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6031 val_rmse_stderror: 0.9709
# Still best_val_rmse: 0.5947 (from epoch 0)
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5649 val_rmse_stderror: 0.9519
# New best_val_rmse: 0.5649
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5952 val_rmse_stderror: 0.9675
# Still best_val_rmse: 0.5649 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5703 val_rmse_stderror: 0.9714
# Still best_val_rmse: 0.5649 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5421 val_rmse_stderror: 0.9696
# New best_val_rmse: 0.5421
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5113 val_rmse_stderror: 0.9672
# New best_val_rmse: 0.5113
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5558 val_rmse_stderror: 0.9654
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 16 steps took 8.68 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.52 val_rmse_stderror: 0.9649
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5329 val_rmse_stderror: 0.9655
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5276 val_rmse_stderror: 0.9731
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 16 steps took 8.85 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5082 val_rmse_stderror: 0.9692
# New best_val_rmse: 0.5082
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.5563 val_rmse_stderror: 0.9665
# Still best_val_rmse: 0.5082 (from epoch 2)
#
# 16 steps took 8.7 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4995 val_rmse_stderror: 0.9632
# New best_val_rmse: 0.4995
#
# 8 steps took 4.35 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.5367 val_rmse_stderror: 0.9619
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.68 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.5109 val_rmse_stderror: 0.9728
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.5426 val_rmse_stderror: 0.975
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.5213 val_rmse_stderror: 0.9713
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.5464 val_rmse_stderror: 0.9718
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.68 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.5418 val_rmse_stderror: 0.9817
# Still best_val_rmse: 0.4995 (from epoch 2)
#
# 16 steps took 8.83 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4975 val_rmse_stderror: 0.9647
# New best_val_rmse: 0.4975
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.4893 val_rmse_stderror: 0.9694
# New best_val_rmse: 0.4893
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 13 val_rmse_target: 0.4974 val_rmse_stderror: 0.9711
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 21 val_rmse_target: 0.4909 val_rmse_stderror: 0.9683
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 29 val_rmse_target: 0.5195 val_rmse_stderror: 0.9694
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 16 steps took 8.69 seconds
# Epoch: 3 batch_num: 45 val_rmse_target: 0.4932 val_rmse_stderror: 0.9706
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 53 val_rmse_target: 0.5115 val_rmse_stderror: 0.9686
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 16 steps took 8.69 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.5218 val_rmse_stderror: 0.9729
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 16 steps took 8.69 seconds
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4997 val_rmse_stderror: 0.9722
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 93 val_rmse_target: 0.4905 val_rmse_stderror: 0.9683
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.35 seconds
# Epoch: 3 batch_num: 101 val_rmse_target: 0.4989 val_rmse_stderror: 0.9714
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4993 val_rmse_stderror: 0.9719
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4957 val_rmse_stderror: 0.9691
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.5061 val_rmse_stderror: 0.969
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 16 steps took 8.84 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.5085 val_rmse_stderror: 0.9711
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 16 steps took 8.69 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.495 val_rmse_stderror: 0.9709
# Still best_val_rmse: 0.4893 (from epoch 3)
#
# 8 steps took 4.36 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4885 val_rmse_stderror: 0.9687
# New best_val_rmse: 0.4885
#
# 4 steps took 2.17 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.4895 val_rmse_stderror: 0.9689
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 4 steps took 2.17 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4953 val_rmse_stderror: 0.9704
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4961 val_rmse_stderror: 0.9711
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.35 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4924 val_rmse_stderror: 0.9706
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.35 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4918 val_rmse_stderror: 0.9703
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.35 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4976 val_rmse_stderror: 0.9714
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.35 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.5032 val_rmse_stderror: 0.9721
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 16 steps took 8.69 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4994 val_rmse_stderror: 0.9717
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4981 val_rmse_stderror: 0.9714
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.35 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4964 val_rmse_stderror: 0.971
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.4952 val_rmse_stderror: 0.9706
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4951 val_rmse_stderror: 0.9705
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4951 val_rmse_stderror: 0.9705
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# 8 steps took 4.34 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4951 val_rmse_stderror: 0.9705
# Still best_val_rmse: 0.4885 (from epoch 4)
#
# Performance estimates:
# [0.46874391976819313, 0.4884675417693578]
# Mean: 0.47860573076877544
#
# Fold 3/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.16 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.295 val_rmse_stderror: 1.221
# New best_val_rmse: 1.295
#
# 16 steps took 8.65 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.077 val_rmse_stderror: 1.444
# New best_val_rmse: 1.077
#
# 16 steps took 8.61 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7256 val_rmse_stderror: 1.345
# New best_val_rmse: 0.7256
#
# 16 steps took 8.61 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6464 val_rmse_stderror: 1.415
# New best_val_rmse: 0.6464
#
# 16 steps took 8.61 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.5842 val_rmse_stderror: 1.368
# New best_val_rmse: 0.5842
#
# 16 steps took 8.62 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.7013 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.5842 (from epoch 0)
#
# 16 steps took 8.62 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5727 val_rmse_stderror: 1.358
# New best_val_rmse: 0.5727
#
# 16 steps took 8.61 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5954 val_rmse_stderror: 1.383
# Still best_val_rmse: 0.5727 (from epoch 0)
#
# 16 steps took 8.79 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.7563 val_rmse_stderror: 1.384
# Still best_val_rmse: 0.5727 (from epoch 0)
#
# 16 steps took 8.6 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.6174 val_rmse_stderror: 1.304
# Still best_val_rmse: 0.5727 (from epoch 0)
#
# 16 steps took 8.62 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.6822 val_rmse_stderror: 1.377
# Still best_val_rmse: 0.5727 (from epoch 0)
#
# 16 steps took 8.62 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5048 val_rmse_stderror: 1.369
# New best_val_rmse: 0.5048
#
# 16 steps took 8.61 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5157 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.5048 (from epoch 1)
#
# 16 steps took 8.61 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5714 val_rmse_stderror: 1.37
# Still best_val_rmse: 0.5048 (from epoch 1)
#
# 16 steps took 8.61 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.4863 val_rmse_stderror: 1.358
# New best_val_rmse: 0.4863
#
# 4 steps took 2.15 seconds
# Epoch: 1 batch_num: 103 val_rmse_target: 0.4957 val_rmse_stderror: 1.359
# Still best_val_rmse: 0.4863 (from epoch 1)
#
# 8 steps took 4.31 seconds
# Epoch: 1 batch_num: 111 val_rmse_target: 0.5665 val_rmse_stderror: 1.38
# Still best_val_rmse: 0.4863 (from epoch 1)
#
# 16 steps took 8.61 seconds
# Epoch: 1 batch_num: 127 val_rmse_target: 0.4855 val_rmse_stderror: 1.349
# New best_val_rmse: 0.4855
#
# 4 steps took 2.15 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.4668 val_rmse_stderror: 1.363
# New best_val_rmse: 0.4668
#
# 1 steps took 0.535 seconds
# Epoch: 1 batch_num: 132 val_rmse_target: 0.4716 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 2 steps took 1.07 seconds
# Epoch: 1 batch_num: 134 val_rmse_target: 0.4914 val_rmse_stderror: 1.375
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 8 steps took 4.47 seconds
# Epoch: 2 batch_num: 1 val_rmse_target: 0.4929 val_rmse_stderror: 1.372
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 8 steps took 4.3 seconds
# Epoch: 2 batch_num: 9 val_rmse_target: 0.4862 val_rmse_stderror: 1.361
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 13 val_rmse_target: 0.5212 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 16 steps took 8.62 seconds
# Epoch: 2 batch_num: 29 val_rmse_target: 0.4808 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 33 val_rmse_target: 0.5081 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 16 steps took 8.62 seconds
# Epoch: 2 batch_num: 49 val_rmse_target: 0.4939 val_rmse_stderror: 1.377
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 8 steps took 4.3 seconds
# Epoch: 2 batch_num: 57 val_rmse_target: 0.526 val_rmse_stderror: 1.376
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 16 steps took 8.61 seconds
# Epoch: 2 batch_num: 73 val_rmse_target: 0.4909 val_rmse_stderror: 1.352
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 8 steps took 4.31 seconds
# Epoch: 2 batch_num: 81 val_rmse_target: 0.4845 val_rmse_stderror: 1.371
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 85 val_rmse_target: 0.5727 val_rmse_stderror: 1.375
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 16 steps took 8.61 seconds
# Epoch: 2 batch_num: 101 val_rmse_target: 0.5899 val_rmse_stderror: 1.373
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 16 steps took 8.62 seconds
# Epoch: 2 batch_num: 117 val_rmse_target: 0.4747 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 119 val_rmse_target: 0.4734 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 121 val_rmse_target: 0.4727 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.4668 (from epoch 1)
#
# 2 steps took 1.07 seconds
# Epoch: 2 batch_num: 123 val_rmse_target: 0.4655 val_rmse_stderror: 1.366
# New best_val_rmse: 0.4655
#
# 1 steps took 0.535 seconds
# Epoch: 2 batch_num: 124 val_rmse_target: 0.4678 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 1 steps took 0.534 seconds
# Epoch: 2 batch_num: 125 val_rmse_target: 0.4888 val_rmse_stderror: 1.373
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 4 steps took 2.15 seconds
# Epoch: 2 batch_num: 129 val_rmse_target: 0.5541 val_rmse_stderror: 1.377
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 16 steps took 8.79 seconds
# Epoch: 3 batch_num: 4 val_rmse_target: 0.4734 val_rmse_stderror: 1.357
# Still best_val_rmse: 0.4655 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 6 val_rmse_target: 0.4647 val_rmse_stderror: 1.357
# New best_val_rmse: 0.4647
#
# 1 steps took 0.533 seconds
# Epoch: 3 batch_num: 7 val_rmse_target: 0.464 val_rmse_stderror: 1.356
# New best_val_rmse: 0.464
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 8 val_rmse_target: 0.4656 val_rmse_stderror: 1.357
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.4702 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 11 val_rmse_target: 0.4994 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 8 steps took 4.3 seconds
# Epoch: 3 batch_num: 19 val_rmse_target: 0.4651 val_rmse_stderror: 1.368
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 3 batch_num: 20 val_rmse_target: 0.4672 val_rmse_stderror: 1.368
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 3 batch_num: 21 val_rmse_target: 0.4733 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 23 val_rmse_target: 0.4897 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 27 val_rmse_target: 0.5157 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 16 steps took 8.61 seconds
# Epoch: 3 batch_num: 43 val_rmse_target: 0.4988 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 8 steps took 4.31 seconds
# Epoch: 3 batch_num: 51 val_rmse_target: 0.4653 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 52 val_rmse_target: 0.4661 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.534 seconds
# Epoch: 3 batch_num: 53 val_rmse_target: 0.4698 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.531 seconds
# Epoch: 3 batch_num: 54 val_rmse_target: 0.4764 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 56 val_rmse_target: 0.4904 val_rmse_stderror: 1.368
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 8 steps took 4.31 seconds
# Epoch: 3 batch_num: 64 val_rmse_target: 0.4654 val_rmse_stderror: 1.361
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.4645 val_rmse_stderror: 1.359
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.536 seconds
# Epoch: 3 batch_num: 66 val_rmse_target: 0.4645 val_rmse_stderror: 1.359
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 67 val_rmse_target: 0.4646 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.534 seconds
# Epoch: 3 batch_num: 68 val_rmse_target: 0.4662 val_rmse_stderror: 1.361
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4715 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 71 val_rmse_target: 0.4972 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 8 steps took 4.3 seconds
# Epoch: 3 batch_num: 79 val_rmse_target: 0.4697 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.534 seconds
# Epoch: 3 batch_num: 80 val_rmse_target: 0.4716 val_rmse_stderror: 1.359
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 82 val_rmse_target: 0.4819 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 86 val_rmse_target: 0.5007 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 16 steps took 8.62 seconds
# Epoch: 3 batch_num: 102 val_rmse_target: 0.4816 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 106 val_rmse_target: 0.4718 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 108 val_rmse_target: 0.4721 val_rmse_stderror: 1.36
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 110 val_rmse_target: 0.4735 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 112 val_rmse_target: 0.4792 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 114 val_rmse_target: 0.4899 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 118 val_rmse_target: 0.4805 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 122 val_rmse_target: 0.4673 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.534 seconds
# Epoch: 3 batch_num: 123 val_rmse_target: 0.4669 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.532 seconds
# Epoch: 3 batch_num: 124 val_rmse_target: 0.4669 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.536 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4668 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 3 batch_num: 126 val_rmse_target: 0.4676 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.535 seconds
# Epoch: 3 batch_num: 127 val_rmse_target: 0.4692 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.534 seconds
# Epoch: 3 batch_num: 128 val_rmse_target: 0.4715 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 130 val_rmse_target: 0.4793 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 132 val_rmse_target: 0.4823 val_rmse_stderror: 1.371
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 3 batch_num: 136 val_rmse_target: 0.4753 val_rmse_stderror: 1.372
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 138 val_rmse_target: 0.4761 val_rmse_stderror: 1.372
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 3 batch_num: 140 val_rmse_target: 0.4809 val_rmse_stderror: 1.372
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.34 seconds
# Epoch: 4 batch_num: 3 val_rmse_target: 0.4942 val_rmse_stderror: 1.373
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 8 steps took 4.31 seconds
# Epoch: 4 batch_num: 11 val_rmse_target: 0.4872 val_rmse_stderror: 1.369
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 15 val_rmse_target: 0.4808 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 19 val_rmse_target: 0.4757 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 21 val_rmse_target: 0.4742 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 23 val_rmse_target: 0.4744 val_rmse_stderror: 1.362
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 25 val_rmse_target: 0.4755 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 27 val_rmse_target: 0.4776 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 29 val_rmse_target: 0.477 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 31 val_rmse_target: 0.4812 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 35 val_rmse_target: 0.4867 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 39 val_rmse_target: 0.4826 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 43 val_rmse_target: 0.474 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 45 val_rmse_target: 0.4715 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 47 val_rmse_target: 0.47 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4696 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 4 batch_num: 49 val_rmse_target: 0.4694 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 4 batch_num: 50 val_rmse_target: 0.4697 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 1 steps took 0.533 seconds
# Epoch: 4 batch_num: 51 val_rmse_target: 0.4704 val_rmse_stderror: 1.363
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 53 val_rmse_target: 0.4722 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 55 val_rmse_target: 0.475 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 57 val_rmse_target: 0.4786 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 59 val_rmse_target: 0.4835 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 63 val_rmse_target: 0.487 val_rmse_stderror: 1.367
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 67 val_rmse_target: 0.4841 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 71 val_rmse_target: 0.4802 val_rmse_stderror: 1.366
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 4 steps took 2.15 seconds
# Epoch: 4 batch_num: 75 val_rmse_target: 0.4778 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 77 val_rmse_target: 0.478 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 79 val_rmse_target: 0.4788 val_rmse_stderror: 1.365
# Still best_val_rmse: 0.464 (from epoch 3)
#
# 2 steps took 1.07 seconds
# Epoch: 4 batch_num: 81 val_rmse_target: 0.4779 val_rmse_stderror: 1.364
# Still best_val_rmse: 0.464 (from epoch 3)
#
# ...
# Epoch: 3 batch_num: 31 val_rmse_target: 0.487 val_rmse_stderror: 1.305
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 35 val_rmse_target: 0.488 val_rmse_stderror: 1.289
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 39 val_rmse_target: 0.4895 val_rmse_stderror: 1.28
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 43 val_rmse_target: 0.4898 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 47 val_rmse_target: 0.4963 val_rmse_stderror: 1.289
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.23 seconds
# Epoch: 3 batch_num: 55 val_rmse_target: 0.4852 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 59 val_rmse_target: 0.4823 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 63 val_rmse_target: 0.4822 val_rmse_stderror: 1.288
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 67 val_rmse_target: 0.4799 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 2 steps took 1.05 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4825 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 73 val_rmse_target: 0.4866 val_rmse_stderror: 1.305
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4938 val_rmse_stderror: 1.3
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.22 seconds
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4849 val_rmse_stderror: 1.284
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.4828 val_rmse_stderror: 1.294
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 93 val_rmse_target: 0.485 val_rmse_stderror: 1.29
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.12 seconds
# Epoch: 3 batch_num: 97 val_rmse_target: 0.487 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.12 seconds
# Epoch: 3 batch_num: 101 val_rmse_target: 0.4824 val_rmse_stderror: 1.283
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 105 val_rmse_target: 0.4811 val_rmse_stderror: 1.283
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4847 val_rmse_stderror: 1.293
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4883 val_rmse_stderror: 1.298
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4928 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.23 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4959 val_rmse_stderror: 1.282
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.22 seconds
# Epoch: 3 batch_num: 133 val_rmse_target: 0.4855 val_rmse_stderror: 1.299
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4876 val_rmse_stderror: 1.301
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.28 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.4831 val_rmse_stderror: 1.294
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4842 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.4846 val_rmse_stderror: 1.285
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4841 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4842 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4838 val_rmse_stderror: 1.295
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4844 val_rmse_stderror: 1.294
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.4842 val_rmse_stderror: 1.289
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4852 val_rmse_stderror: 1.286
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.4849 val_rmse_stderror: 1.286
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4839 val_rmse_stderror: 1.287
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4837 val_rmse_stderror: 1.29
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4841 val_rmse_stderror: 1.293
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4851 val_rmse_stderror: 1.295
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4849 val_rmse_stderror: 1.293
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4843 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4844 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4844 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4842 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4841 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.4843 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4849 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4855 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4859 val_rmse_stderror: 1.292
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4858 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.4856 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4853 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.4853 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4853 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4853 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4852 val_rmse_stderror: 1.291
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# Performance estimates:
# [0.46874391976819313, 0.4884675417693578, 0.4640263624035539, 0.47773498870351777]
# Mean: 0.47474320316115565
#
# Fold 5/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9301 val_rmse_stderror: 0.9934
# New best_val_rmse: 0.9301
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.7883 val_rmse_stderror: 0.967
# New best_val_rmse: 0.7883
#
# 16 steps took 8.29 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7549 val_rmse_stderror: 0.9719
# New best_val_rmse: 0.7549
#
# 16 steps took 8.31 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7232 val_rmse_stderror: 1.001
# New best_val_rmse: 0.7232
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6581 val_rmse_stderror: 0.9901
# New best_val_rmse: 0.6581
#
# 16 steps took 8.29 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5791 val_rmse_stderror: 1.006
# New best_val_rmse: 0.5791
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.6122 val_rmse_stderror: 1.014
# Still best_val_rmse: 0.5791 (from epoch 0)
#
# 16 steps took 8.3 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5893 val_rmse_stderror: 1.01
# Still best_val_rmse: 0.5791 (from epoch 0)
#
# 16 steps took 8.46 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5767 val_rmse_stderror: 0.9967
# New best_val_rmse: 0.5767
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5437 val_rmse_stderror: 1.005
# New best_val_rmse: 0.5437
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5726 val_rmse_stderror: 0.9994
# Still best_val_rmse: 0.5437 (from epoch 1)
#
# 16 steps took 8.29 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5346 val_rmse_stderror: 1.015
# New best_val_rmse: 0.5346
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5464 val_rmse_stderror: 0.9982
# Still best_val_rmse: 0.5346 (from epoch 1)
#
# 16 steps took 8.29 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5374 val_rmse_stderror: 1.001
# Still best_val_rmse: 0.5346 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5413 val_rmse_stderror: 0.9964
# Still best_val_rmse: 0.5346 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5104 val_rmse_stderror: 0.9993
# New best_val_rmse: 0.5104
#
# 16 steps took 8.3 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.496 val_rmse_stderror: 0.9955
# New best_val_rmse: 0.496
#
# 8 steps took 4.14 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.5118 val_rmse_stderror: 1.009
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.46 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.5314 val_rmse_stderror: 1.016
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.31 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.508 val_rmse_stderror: 1.009
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.31 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.5086 val_rmse_stderror: 1.009
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.5106 val_rmse_stderror: 1.017
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.5019 val_rmse_stderror: 1.012
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.31 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.5144 val_rmse_stderror: 1.008
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.5247 val_rmse_stderror: 1.015
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.5057 val_rmse_stderror: 1.013
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.44 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4987 val_rmse_stderror: 1.008
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 8 steps took 4.15 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.5026 val_rmse_stderror: 1.003
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.31 seconds
# Epoch: 3 batch_num: 25 val_rmse_target: 0.5031 val_rmse_stderror: 1.009
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 3 batch_num: 41 val_rmse_target: 0.5061 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 3 batch_num: 57 val_rmse_target: 0.5022 val_rmse_stderror: 1.003
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 16 steps took 8.3 seconds
# Epoch: 3 batch_num: 73 val_rmse_target: 0.4986 val_rmse_stderror: 1.007
# Still best_val_rmse: 0.496 (from epoch 1)
#
# 8 steps took 4.16 seconds
# Epoch: 3 batch_num: 81 val_rmse_target: 0.4952 val_rmse_stderror: 1.003
# New best_val_rmse: 0.4952
#
# 8 steps took 4.15 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.4981 val_rmse_stderror: 0.9996
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 8 steps took 4.15 seconds
# Epoch: 3 batch_num: 97 val_rmse_target: 0.5016 val_rmse_stderror: 1.011
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.29 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.5019 val_rmse_stderror: 0.9999
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.5017 val_rmse_stderror: 1.006
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.45 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.5038 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.5006 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.31 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.4995 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 8 steps took 4.15 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4998 val_rmse_stderror: 1.004
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 8 steps took 4.15 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.5008 val_rmse_stderror: 1.004
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.5014 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.5015 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.5027 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.31 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.5029 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# 16 steps took 8.3 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.5029 val_rmse_stderror: 1.005
# Still best_val_rmse: 0.4952 (from epoch 3)
#
# Performance estimates:
# [0.46874391976819313, 0.4884675417693578, 0.4640263624035539, 0.47773498870351777, 0.49524187526647234]
# Mean: 0.478842937582219

# %%
print(list_val_rmse)
# Out:
# [0.46874391976819313, 0.4884675417693578, 0.4640263624035539, 0.47773498870351777, 0.49524187526647234]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 477M/477M [00:32<00:00, 15.6MB/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_3.pth
# 100%|██████████| 477M/477M [00:34<00:00, 14.7MB/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_5.pth
# 100%|██████████| 477M/477M [00:35<00:00, 14.2MB/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_4.pth
# 100%|██████████| 477M/477M [00:36<00:00, 13.6MB/s]
# Upload successful: model_4.pth (477MB)
# Starting upload for file model_1.pth
# 100%|██████████| 477M/477M [00:34<00:00, 14.4MB/s]
# Upload successful: model_1.pth (477MB)
