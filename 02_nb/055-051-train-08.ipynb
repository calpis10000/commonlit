# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '055-051-train-08'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# read train_df(kfold)
train_kf_df = pd.read_csv(DATA_DIR/"train_kfold.csv")

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # word_length_mlm
        mlm_layers = self.mlm_layers(input_len)


        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_layers], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += output.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_parameters = list(model.mlm_layers.named_parameters())
    mlm_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_kf_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_kf_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

for fold in sorted(train_kf_df['kfold'].unique()):
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする

    train_indices = (train_kf_df['kfold'] != fold)
    val_indices = (train_kf_df['kfold'] == fold)
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6375 train_rmse_stderror: 0.1136 train_kl_div: 0.9426
# val_rmse_target: 0.6963 val_rmse_stderror: 1.175
# New best_val_rmse: 0.6963
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7125 train_rmse_stderror: 0.0758 train_kl_div: 1.134
# val_rmse_target: 0.5783 val_rmse_stderror: 1.139
# New best_val_rmse: 0.5783
#
# 64 steps took 81.0 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.2809 train_rmse_stderror: 0.08102 train_kl_div: 0.2029
# val_rmse_target: 0.543 val_rmse_stderror: 1.139
# New best_val_rmse: 0.543
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.5495 train_rmse_stderror: 0.05243 train_kl_div: 0.6749
# val_rmse_target: 0.6412 val_rmse_stderror: 1.143
# Still best_val_rmse: 0.543 (from epoch 1)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4136 train_rmse_stderror: 0.09026 train_kl_div: 0.371
# val_rmse_target: 0.5599 val_rmse_stderror: 1.135
# Still best_val_rmse: 0.543 (from epoch 1)
#
# 64 steps took 80.8 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.3679 train_rmse_stderror: 0.0553 train_kl_div: 0.2938
# val_rmse_target: 0.5242 val_rmse_stderror: 1.148
# New best_val_rmse: 0.5242
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2861 train_rmse_stderror: 0.07543 train_kl_div: 0.1748
# val_rmse_target: 0.5432 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.5242 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2526 train_rmse_stderror: 0.07016 train_kl_div: 0.1419
# val_rmse_target: 0.4939 val_rmse_stderror: 1.148
# New best_val_rmse: 0.4939
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.262 train_rmse_stderror: 0.09193 train_kl_div: 0.1622
# val_rmse_target: 0.509 val_rmse_stderror: 1.16
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2257 train_rmse_stderror: 0.04521 train_kl_div: 0.1142
# val_rmse_target: 0.5087 val_rmse_stderror: 1.149
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3182 train_rmse_stderror: 0.057 train_kl_div: 0.2142
# val_rmse_target: 0.5085 val_rmse_stderror: 1.138
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.244 train_rmse_stderror: 0.04677 train_kl_div: 0.1244
# val_rmse_target: 0.53 val_rmse_stderror: 1.163
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1018 train_rmse_stderror: 0.06215 train_kl_div: 0.03926
# val_rmse_target: 0.5133 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1252 train_rmse_stderror: 0.0555 train_kl_div: 0.04198
# val_rmse_target: 0.5007 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.07238 train_rmse_stderror: 0.07988 train_kl_div: 0.03918
# val_rmse_target: 0.5044 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.07562 train_rmse_stderror: 0.04934 train_kl_div: 0.02226
# val_rmse_target: 0.4984 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1319 train_rmse_stderror: 0.06686 train_kl_div: 0.05478
# val_rmse_target: 0.4998 val_rmse_stderror: 1.147
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1136 train_rmse_stderror: 0.06042 train_kl_div: 0.04092
# val_rmse_target: 0.4993 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.07934 train_rmse_stderror: 0.05392 train_kl_div: 0.02505
# val_rmse_target: 0.5023 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1474 train_rmse_stderror: 0.04524 train_kl_div: 0.04515
# val_rmse_target: 0.5009 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.07608 train_rmse_stderror: 0.03566 train_kl_div: 0.01876
# val_rmse_target: 0.5021 val_rmse_stderror: 1.151
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09144 train_rmse_stderror: 0.05617 train_kl_div: 0.02745
# val_rmse_target: 0.5019 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1737 train_rmse_stderror: 0.06147 train_kl_div: 0.06588
# val_rmse_target: 0.5014 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.08621 train_rmse_stderror: 0.03266 train_kl_div: 0.01938
# val_rmse_target: 0.5015 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4939 (from epoch 2)
#
# Performance estimates:
# [0.49388455273663545]
# Mean: 0.49388455273663545
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6619 train_rmse_stderror: 0.07962 train_kl_div: 0.7947
# val_rmse_target: 0.6623 val_rmse_stderror: 1.719
# New best_val_rmse: 0.6623
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7119 train_rmse_stderror: 0.1074 train_kl_div: 1.103
# val_rmse_target: 0.7429 val_rmse_stderror: 1.857
# Still best_val_rmse: 0.6623 (from epoch 0)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5568 train_rmse_stderror: 0.07934 train_kl_div: 0.636
# val_rmse_target: 0.5604 val_rmse_stderror: 1.817
# New best_val_rmse: 0.5604
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.474 train_rmse_stderror: 0.06893 train_kl_div: 0.534
# val_rmse_target: 0.5082 val_rmse_stderror: 1.801
# New best_val_rmse: 0.5082
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4555 train_rmse_stderror: 0.1004 train_kl_div: 0.4325
# val_rmse_target: 0.5012 val_rmse_stderror: 1.773
# New best_val_rmse: 0.5012
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.363 train_rmse_stderror: 0.06091 train_kl_div: 0.279
# val_rmse_target: 0.515 val_rmse_stderror: 1.833
# Still best_val_rmse: 0.5012 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5312 train_rmse_stderror: 0.08772 train_kl_div: 0.5308
# val_rmse_target: 0.5144 val_rmse_stderror: 1.78
# Still best_val_rmse: 0.5012 (from epoch 1)
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.1691 train_rmse_stderror: 0.04131 train_kl_div: 0.06815
# val_rmse_target: 0.4845 val_rmse_stderror: 1.797
# New best_val_rmse: 0.4845
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2271 train_rmse_stderror: 0.07138 train_kl_div: 0.1284
# val_rmse_target: 0.5338 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4845 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2577 train_rmse_stderror: 0.05564 train_kl_div: 0.1231
# val_rmse_target: 0.4827 val_rmse_stderror: 1.793
# New best_val_rmse: 0.4827
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2427 train_rmse_stderror: 0.06448 train_kl_div: 0.1504
# val_rmse_target: 0.474 val_rmse_stderror: 1.784
# New best_val_rmse: 0.474
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2573 train_rmse_stderror: 0.04809 train_kl_div: 0.1355
# val_rmse_target: 0.488 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3256 train_rmse_stderror: 0.06705 train_kl_div: 0.2094
# val_rmse_target: 0.4753 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.2443 train_rmse_stderror: 0.04235 train_kl_div: 0.1278
# val_rmse_target: 0.4808 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1229 train_rmse_stderror: 0.0492 train_kl_div: 0.0449
# val_rmse_target: 0.4755 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2042 train_rmse_stderror: 0.03416 train_kl_div: 0.09397
# val_rmse_target: 0.4759 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.09013 train_rmse_stderror: 0.03423 train_kl_div: 0.02292
# val_rmse_target: 0.4745 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.474 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1356 train_rmse_stderror: 0.07074 train_kl_div: 0.0547
# val_rmse_target: 0.4725 val_rmse_stderror: 1.779
# New best_val_rmse: 0.4725
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1271 train_rmse_stderror: 0.05592 train_kl_div: 0.03979
# val_rmse_target: 0.4728 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09743 train_rmse_stderror: 0.05137 train_kl_div: 0.0288
# val_rmse_target: 0.4739 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1372 train_rmse_stderror: 0.02977 train_kl_div: 0.04146
# val_rmse_target: 0.4728 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.0994 train_rmse_stderror: 0.04049 train_kl_div: 0.0278
# val_rmse_target: 0.4736 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1237 train_rmse_stderror: 0.05991 train_kl_div: 0.03692
# val_rmse_target: 0.4731 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1187 train_rmse_stderror: 0.0614 train_kl_div: 0.04166
# val_rmse_target: 0.4731 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1094 train_rmse_stderror: 0.04017 train_kl_div: 0.03006
# val_rmse_target: 0.4731 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4725 (from epoch 3)
#
# Performance estimates:
# [0.49388455273663545, 0.4724766497086967]
# Mean: 0.48318060122266604
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.83 train_rmse_stderror: 0.08263 train_kl_div: 1.399
# val_rmse_target: 0.6086 val_rmse_stderror: 1.149
# New best_val_rmse: 0.6086
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7235 train_rmse_stderror: 0.07334 train_kl_div: 1.034
# val_rmse_target: 0.7142 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.6086 (from epoch 0)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.8192 train_rmse_stderror: 0.07386 train_kl_div: 1.34
# val_rmse_target: 0.6282 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.6086 (from epoch 0)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4745 train_rmse_stderror: 0.07369 train_kl_div: 0.4488
# val_rmse_target: 0.539 val_rmse_stderror: 1.12
# New best_val_rmse: 0.539
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4103 train_rmse_stderror: 0.07571 train_kl_div: 0.3454
# val_rmse_target: 0.5363 val_rmse_stderror: 1.108
# New best_val_rmse: 0.5363
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4962 train_rmse_stderror: 0.0785 train_kl_div: 0.5381
# val_rmse_target: 0.5032 val_rmse_stderror: 1.121
# New best_val_rmse: 0.5032
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4072 train_rmse_stderror: 0.06542 train_kl_div: 0.3022
# val_rmse_target: 0.5262 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.5032 (from epoch 1)
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.256 train_rmse_stderror: 0.03795 train_kl_div: 0.1535
# val_rmse_target: 0.4974 val_rmse_stderror: 1.119
# New best_val_rmse: 0.4974
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3042 train_rmse_stderror: 0.06139 train_kl_div: 0.185
# val_rmse_target: 0.5049 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.4974 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2572 train_rmse_stderror: 0.05524 train_kl_div: 0.1489
# val_rmse_target: 0.4874 val_rmse_stderror: 1.106
# New best_val_rmse: 0.4874
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.1568 train_rmse_stderror: 0.0574 train_kl_div: 0.06579
# val_rmse_target: 0.4981 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2128 train_rmse_stderror: 0.05079 train_kl_div: 0.1042
# val_rmse_target: 0.4898 val_rmse_stderror: 1.132
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.1962 train_rmse_stderror: 0.04984 train_kl_div: 0.09124
# val_rmse_target: 0.4836 val_rmse_stderror: 1.121
# New best_val_rmse: 0.4836
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.2194 train_rmse_stderror: 0.06236 train_kl_div: 0.1084
# val_rmse_target: 0.4866 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4836 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.09162 train_rmse_stderror: 0.0525 train_kl_div: 0.0282
# val_rmse_target: 0.5041 val_rmse_stderror: 1.137
# Still best_val_rmse: 0.4836 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.09359 train_rmse_stderror: 0.04093 train_kl_div: 0.02263
# val_rmse_target: 0.4909 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.4836 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1614 train_rmse_stderror: 0.05426 train_kl_div: 0.06459
# val_rmse_target: 0.4857 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4836 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1025 train_rmse_stderror: 0.03957 train_kl_div: 0.02852
# val_rmse_target: 0.4819 val_rmse_stderror: 1.128
# New best_val_rmse: 0.4819
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1936 train_rmse_stderror: 0.05145 train_kl_div: 0.07732
# val_rmse_target: 0.4902 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.06894 train_rmse_stderror: 0.04043 train_kl_div: 0.01415
# val_rmse_target: 0.484 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.07953 train_rmse_stderror: 0.03349 train_kl_div: 0.01846
# val_rmse_target: 0.4836 val_rmse_stderror: 1.122
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.07775 train_rmse_stderror: 0.03344 train_kl_div: 0.01757
# val_rmse_target: 0.4868 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09088 train_rmse_stderror: 0.0368 train_kl_div: 0.02301
# val_rmse_target: 0.4851 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.06103 train_rmse_stderror: 0.04753 train_kl_div: 0.01774
# val_rmse_target: 0.4848 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1269 train_rmse_stderror: 0.04065 train_kl_div: 0.04296
# val_rmse_target: 0.4847 val_rmse_stderror: 1.122
# Still best_val_rmse: 0.4819 (from epoch 3)
#
# Performance estimates:
# [0.49388455273663545, 0.4724766497086967, 0.481884671659356]
# Mean: 0.4827486247015627
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.7307 train_rmse_stderror: 0.06544 train_kl_div: 1.215
# val_rmse_target: 0.6678 val_rmse_stderror: 1.119
# New best_val_rmse: 0.6678
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7551 train_rmse_stderror: 0.06864 train_kl_div: 1.275
# val_rmse_target: 0.6165 val_rmse_stderror: 1.106
# New best_val_rmse: 0.6165
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5949 train_rmse_stderror: 0.08126 train_kl_div: 0.7884
# val_rmse_target: 0.5355 val_rmse_stderror: 1.127
# New best_val_rmse: 0.5355
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.5472 train_rmse_stderror: 0.07653 train_kl_div: 0.5183
# val_rmse_target: 0.5297 val_rmse_stderror: 1.114
# New best_val_rmse: 0.5297
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4228 train_rmse_stderror: 0.05883 train_kl_div: 0.366
# val_rmse_target: 0.5335 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.5297 (from epoch 1)
#
# 32 steps took 40.4 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5934 train_rmse_stderror: 0.04846 train_kl_div: 0.7953
# val_rmse_target: 0.5762 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.5297 (from epoch 1)
#
# 64 steps took 80.9 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4733 train_rmse_stderror: 0.06821 train_kl_div: 0.4165
# val_rmse_target: 0.5161 val_rmse_stderror: 1.119
# New best_val_rmse: 0.5161
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3164 train_rmse_stderror: 0.04566 train_kl_div: 0.2068
# val_rmse_target: 0.4908 val_rmse_stderror: 1.107
# New best_val_rmse: 0.4908
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3603 train_rmse_stderror: 0.05124 train_kl_div: 0.276
# val_rmse_target: 0.4829 val_rmse_stderror: 1.121
# New best_val_rmse: 0.4829
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3164 train_rmse_stderror: 0.06428 train_kl_div: 0.2481
# val_rmse_target: 0.4893 val_rmse_stderror: 1.131
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2768 train_rmse_stderror: 0.03663 train_kl_div: 0.1762
# val_rmse_target: 0.4999 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3376 train_rmse_stderror: 0.05757 train_kl_div: 0.2696
# val_rmse_target: 0.5122 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3014 train_rmse_stderror: 0.06947 train_kl_div: 0.186
# val_rmse_target: 0.4964 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.2364 train_rmse_stderror: 0.03933 train_kl_div: 0.09978
# val_rmse_target: 0.4958 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2152 train_rmse_stderror: 0.04489 train_kl_div: 0.09784
# val_rmse_target: 0.4864 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2482 train_rmse_stderror: 0.04346 train_kl_div: 0.1317
# val_rmse_target: 0.4938 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2295 train_rmse_stderror: 0.04786 train_kl_div: 0.1041
# val_rmse_target: 0.4847 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1942 train_rmse_stderror: 0.05272 train_kl_div: 0.08581
# val_rmse_target: 0.4866 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.4829 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2076 train_rmse_stderror: 0.0346 train_kl_div: 0.09497
# val_rmse_target: 0.4817 val_rmse_stderror: 1.114
# New best_val_rmse: 0.4817
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1183 train_rmse_stderror: 0.06634 train_kl_div: 0.04274
# val_rmse_target: 0.4853 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1317 train_rmse_stderror: 0.02975 train_kl_div: 0.04072
# val_rmse_target: 0.4873 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.152 train_rmse_stderror: 0.05002 train_kl_div: 0.06643
# val_rmse_target: 0.4844 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1631 train_rmse_stderror: 0.0529 train_kl_div: 0.06606
# val_rmse_target: 0.4841 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.2147 train_rmse_stderror: 0.04615 train_kl_div: 0.09628
# val_rmse_target: 0.4851 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.09652 train_rmse_stderror: 0.04359 train_kl_div: 0.02802
# val_rmse_target: 0.4851 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.4817 (from epoch 3)
#
# Performance estimates:
# [0.49388455273663545, 0.4724766497086967, 0.481884671659356, 0.4817161383712023]
# Mean: 0.4824905031189726
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 81.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6547 train_rmse_stderror: 0.05201 train_kl_div: 0.8098
# val_rmse_target: 0.5896 val_rmse_stderror: 1.135
# New best_val_rmse: 0.5896
#
# 64 steps took 80.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4949 train_rmse_stderror: 0.08617 train_kl_div: 0.5669
# val_rmse_target: 0.5445 val_rmse_stderror: 1.134
# New best_val_rmse: 0.5445
#
# 32 steps took 40.5 seconds
# Epoch: 0 batch_num: 160
# train_rmse_target: 0.4196 train_rmse_stderror: 0.0703 train_kl_div: 0.4035
# val_rmse_target: 0.6457 val_rmse_stderror: 1.14
# Still best_val_rmse: 0.5445 (from epoch 0)
#
# 64 steps took 81.1 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.3585 train_rmse_stderror: 0.08606 train_kl_div: 0.2976
# val_rmse_target: 0.5203 val_rmse_stderror: 1.137
# New best_val_rmse: 0.5203
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4157 train_rmse_stderror: 0.07075 train_kl_div: 0.3885
# val_rmse_target: 0.5414 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.5203 (from epoch 1)
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4366 train_rmse_stderror: 0.0759 train_kl_div: 0.4238
# val_rmse_target: 0.5073 val_rmse_stderror: 1.164
# New best_val_rmse: 0.5073
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5713 train_rmse_stderror: 0.08661 train_kl_div: 0.5657
# val_rmse_target: 0.5065 val_rmse_stderror: 1.14
# New best_val_rmse: 0.5065
#
# 32 steps took 40.5 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4096 train_rmse_stderror: 0.05861 train_kl_div: 0.344
# val_rmse_target: 0.4986 val_rmse_stderror: 1.143
# New best_val_rmse: 0.4986
#
# 32 steps took 40.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3752 train_rmse_stderror: 0.08884 train_kl_div: 0.3492
# val_rmse_target: 0.6138 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4986 (from epoch 1)
#
# 64 steps took 80.9 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2267 train_rmse_stderror: 0.05806 train_kl_div: 0.1261
# val_rmse_target: 0.4817 val_rmse_stderror: 1.149
# New best_val_rmse: 0.4817
#
# 32 steps took 40.4 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.317 train_rmse_stderror: 0.05232 train_kl_div: 0.2152
# val_rmse_target: 0.4955 val_rmse_stderror: 1.132
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.1848 train_rmse_stderror: 0.05301 train_kl_div: 0.08696
# val_rmse_target: 0.5108 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2385 train_rmse_stderror: 0.05279 train_kl_div: 0.1245
# val_rmse_target: 0.494 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1355 train_rmse_stderror: 0.04727 train_kl_div: 0.04611
# val_rmse_target: 0.5006 val_rmse_stderror: 1.149
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.183 train_rmse_stderror: 0.03551 train_kl_div: 0.07139
# val_rmse_target: 0.4902 val_rmse_stderror: 1.147
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1596 train_rmse_stderror: 0.05818 train_kl_div: 0.0572
# val_rmse_target: 0.4899 val_rmse_stderror: 1.131
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1124 train_rmse_stderror: 0.04543 train_kl_div: 0.03463
# val_rmse_target: 0.4978 val_rmse_stderror: 1.137
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1604 train_rmse_stderror: 0.03824 train_kl_div: 0.0571
# val_rmse_target: 0.4832 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1336 train_rmse_stderror: 0.05081 train_kl_div: 0.05161
# val_rmse_target: 0.4834 val_rmse_stderror: 1.146
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.05892 train_rmse_stderror: 0.03186 train_kl_div: 0.01177
# val_rmse_target: 0.4897 val_rmse_stderror: 1.147
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.08473 train_rmse_stderror: 0.04239 train_kl_div: 0.02029
# val_rmse_target: 0.4872 val_rmse_stderror: 1.144
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1106 train_rmse_stderror: 0.06712 train_kl_div: 0.04318
# val_rmse_target: 0.4872 val_rmse_stderror: 1.147
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1217 train_rmse_stderror: 0.03655 train_kl_div: 0.03486
# val_rmse_target: 0.4885 val_rmse_stderror: 1.145
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08746 train_rmse_stderror: 0.06485 train_kl_div: 0.03293
# val_rmse_target: 0.4886 val_rmse_stderror: 1.146
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# 32 steps took 40.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.07528 train_rmse_stderror: 0.04782 train_kl_div: 0.02048
# val_rmse_target: 0.4878 val_rmse_stderror: 1.145
# Still best_val_rmse: 0.4817 (from epoch 2)
#
# Performance estimates:
# [0.49388455273663545, 0.4724766497086967, 0.481884671659356, 0.4817161383712023, 0.481732367577254]
# Mean: 0.48233887601062886
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.49388455273663545, 0.4724766497086967, 0.481884671659356, 0.4817161383712023, 0.481732367577254]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.9MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_1.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:26<00:00, 53.6MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.4MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:24<00:00, 57.7MB/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.3MB/s]
# Upload successful: model_5.pth (1GB)

# %%
# validation再実行_予測結果取得
all_predictions = np.zeros(len(train_kf_df)) # 推論結果について、「fold　× 推論df」のzero行列で枠を作る

for fold_ in sorted(train_kf_df['kfold'].unique()):
    model_path = INF_MODEL_DIR/f"model_{fold_ + 1}.pth" # 対応するモデルを読む
    print(f"\nUsing {model_path}")

    val_idx = train_kf_df['kfold'] == fold_
    val_df = train_kf_df[val_idx]
    val_dataset = LitDataset(val_df, inference_only=True) # TestのDataset(何で、もう一回作るのだろう？)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                          drop_last=False, shuffle=False, num_workers=2) # TestのDataLoader

    model = LitModel()
    model.load_state_dict(torch.load(model_path))    # 対応するモデルから、重みを読み込む
    model.to(DEVICE) # モデルをDEVICEへぶち込む

    all_predictions[val_idx] = predict(model, val_loader) # 推論結果行列の対象列に、推論結果を入力(以後、繰り返し)

    del model
    gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-0c10ad6096e3> in <module>()
#       3
#       4 for fold_ in sorted(train_kf_df['kfold'].unique()):
# ----> 5     model_path = INF_MODEL_DIR/f"model_{fold_ + 1}.pth" # 対応するモデルを読む
#       6     print(f"\nUsing {model_path}")
#       7
#
# NameError: name 'INF_MODEL_DIR' is not defined

# %%
from sklearn.metrics import mean_squared_error
import math
np.sqrt(mean_squared_error(train_kf_df.target.values, all_predictions))

# %%
train_kf_df['pred'] = all_predictions
fold = 0
tg_true = train_kf_df[train_kf_df['kfold']==fold]['target'].values
tg_pred = train_kf_df[train_kf_df['kfold']==fold]['pred'].values
np.sqrt(mean_squared_error(tg_true, tg_pred))
