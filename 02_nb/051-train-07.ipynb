# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-07'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df_src = pd.read_csv(DATA_DIR/"train.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
print(train_df_src.shape)
train_df_src.head()
# Out:
# (2834, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        #self.attention = nn.Sequential(# attentionレイヤー            
        #    nn.Linear(config.hidden_size, 512),      
        #    nn.Tanh(),                       
        #    nn.Linear(512, 1),
        #    nn.Softmax(dim=1)
        #)
        
        self.layer_norm = nn.LayerNorm(config.hidden_size) # layer_normレイヤー
        
        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        #last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        #weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        #context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        #norm_embeddings = self.layer_norm(context_vector)
        #return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        last_hidden_state = roberta_output[0]
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask
        norm_embeddings = self.layer_norm(mean_embeddings)
        return self.regressor(norm_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    #attention_parameters = list(model.attention.named_parameters())
    #attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    #parameters += attention_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.7 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6964 train_rmse_stderror: 0.04677 train_kl_div: 0.9559
# val_rmse_target: 0.7432 val_rmse_stderror: 1.208
# New best_val_rmse: 0.7432
#
# 64 steps took 48.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6508 train_rmse_stderror: 0.03458 train_kl_div: 0.9277
# val_rmse_target: 0.5925 val_rmse_stderror: 1.19
# New best_val_rmse: 0.5925
#
# 64 steps took 48.8 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.2422 train_rmse_stderror: 0.03044 train_kl_div: 0.1218
# val_rmse_target: 0.7103 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.5925 (from epoch 0)
#
# 64 steps took 48.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5025 train_rmse_stderror: 0.04165 train_kl_div: 0.4766
# val_rmse_target: 0.5611 val_rmse_stderror: 1.189
# New best_val_rmse: 0.5611
#
# 64 steps took 48.6 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5233 train_rmse_stderror: 0.02933 train_kl_div: 0.5799
# val_rmse_target: 0.5263 val_rmse_stderror: 1.215
# New best_val_rmse: 0.5263
#
# 32 steps took 24.3 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4068 train_rmse_stderror: 0.02494 train_kl_div: 0.3244
# val_rmse_target: 0.5235 val_rmse_stderror: 1.19
# New best_val_rmse: 0.5235
#
# 32 steps took 24.5 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3255 train_rmse_stderror: 0.0314 train_kl_div: 0.219
# val_rmse_target: 0.499 val_rmse_stderror: 1.208
# New best_val_rmse: 0.499
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3338 train_rmse_stderror: 0.02779 train_kl_div: 0.228
# val_rmse_target: 0.5547 val_rmse_stderror: 1.21
# Still best_val_rmse: 0.499 (from epoch 2)
#
# 64 steps took 48.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.234 train_rmse_stderror: 0.03558 train_kl_div: 0.1164
# val_rmse_target: 0.489 val_rmse_stderror: 1.207
# New best_val_rmse: 0.489
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.335 train_rmse_stderror: 0.02616 train_kl_div: 0.2158
# val_rmse_target: 0.5315 val_rmse_stderror: 1.205
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3344 train_rmse_stderror: 0.02157 train_kl_div: 0.2508
# val_rmse_target: 0.5432 val_rmse_stderror: 1.202
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.19 train_rmse_stderror: 0.01806 train_kl_div: 0.06621
# val_rmse_target: 0.4915 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2156 train_rmse_stderror: 0.02477 train_kl_div: 0.09842
# val_rmse_target: 0.5068 val_rmse_stderror: 1.209
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1106 train_rmse_stderror: 0.02249 train_kl_div: 0.02804
# val_rmse_target: 0.5094 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.142 train_rmse_stderror: 0.02104 train_kl_div: 0.04115
# val_rmse_target: 0.5037 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1573 train_rmse_stderror: 0.03547 train_kl_div: 0.06025
# val_rmse_target: 0.508 val_rmse_stderror: 1.202
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1696 train_rmse_stderror: 0.02169 train_kl_div: 0.06198
# val_rmse_target: 0.4966 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.07304 train_rmse_stderror: 0.01386 train_kl_div: 0.01279
# val_rmse_target: 0.4978 val_rmse_stderror: 1.206
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1473 train_rmse_stderror: 0.01376 train_kl_div: 0.04513
# val_rmse_target: 0.4969 val_rmse_stderror: 1.204
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.08435 train_rmse_stderror: 0.02548 train_kl_div: 0.01882
# val_rmse_target: 0.4965 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1069 train_rmse_stderror: 0.02087 train_kl_div: 0.02356
# val_rmse_target: 0.4984 val_rmse_stderror: 1.204
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08345 train_rmse_stderror: 0.01878 train_kl_div: 0.01627
# val_rmse_target: 0.4997 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.489 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.09227 train_rmse_stderror: 0.009271 train_kl_div: 0.01837
# val_rmse_target: 0.5003 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.489 (from epoch 2)
#
# Performance estimates:
# [0.4890381725796881]
# Mean: 0.4890381725796881
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4821 train_rmse_stderror: 0.1091 train_kl_div: 0.5186
# val_rmse_target: 0.6859 val_rmse_stderror: 1.048
# New best_val_rmse: 0.6859
#
# 64 steps took 48.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7539 train_rmse_stderror: 0.08777 train_kl_div: 1.055
# val_rmse_target: 0.6736 val_rmse_stderror: 1.138
# New best_val_rmse: 0.6736
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.8159 train_rmse_stderror: 0.2506 train_kl_div: 1.648
# val_rmse_target: 0.7604 val_rmse_stderror: 1.168
# Still best_val_rmse: 0.6736 (from epoch 0)
#
# 64 steps took 48.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.631 train_rmse_stderror: 0.056 train_kl_div: 0.7332
# val_rmse_target: 0.5819 val_rmse_stderror: 1.103
# New best_val_rmse: 0.5819
#
# 64 steps took 48.7 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4795 train_rmse_stderror: 0.03087 train_kl_div: 0.4461
# val_rmse_target: 0.5269 val_rmse_stderror: 1.119
# New best_val_rmse: 0.5269
#
# 32 steps took 24.3 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.6183 train_rmse_stderror: 0.04426 train_kl_div: 0.7598
# val_rmse_target: 0.5636 val_rmse_stderror: 1.092
# Still best_val_rmse: 0.5269 (from epoch 1)
#
# 64 steps took 48.9 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.398 train_rmse_stderror: 0.04256 train_kl_div: 0.3336
# val_rmse_target: 0.5459 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.5269 (from epoch 1)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.4698 train_rmse_stderror: 0.04023 train_kl_div: 0.3632
# val_rmse_target: 0.5652 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.5269 (from epoch 1)
#
# 64 steps took 48.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.4689 train_rmse_stderror: 0.0401 train_kl_div: 0.4776
# val_rmse_target: 0.536 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.5269 (from epoch 1)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.4473 train_rmse_stderror: 0.04176 train_kl_div: 0.4249
# val_rmse_target: 0.5642 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5269 (from epoch 1)
#
# 64 steps took 49.0 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2983 train_rmse_stderror: 0.03047 train_kl_div: 0.1872
# val_rmse_target: 0.522 val_rmse_stderror: 1.114
# New best_val_rmse: 0.522
#
# 32 steps took 24.3 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.4603 train_rmse_stderror: 0.03387 train_kl_div: 0.3847
# val_rmse_target: 0.5229 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.522 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.3639 train_rmse_stderror: 0.0406 train_kl_div: 0.2538
# val_rmse_target: 0.5188 val_rmse_stderror: 1.111
# New best_val_rmse: 0.5188
#
# 32 steps took 24.3 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.3337 train_rmse_stderror: 0.02547 train_kl_div: 0.2318
# val_rmse_target: 0.5071 val_rmse_stderror: 1.114
# New best_val_rmse: 0.5071
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.3314 train_rmse_stderror: 0.04219 train_kl_div: 0.1857
# val_rmse_target: 0.5001 val_rmse_stderror: 1.11
# New best_val_rmse: 0.5001
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.2331 train_rmse_stderror: 0.02762 train_kl_div: 0.1177
# val_rmse_target: 0.5074 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.2135 train_rmse_stderror: 0.01714 train_kl_div: 0.09684
# val_rmse_target: 0.5015 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.2247 train_rmse_stderror: 0.01774 train_kl_div: 0.1042
# val_rmse_target: 0.5137 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.2647 train_rmse_stderror: 0.02448 train_kl_div: 0.1515
# val_rmse_target: 0.505 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.2954 train_rmse_stderror: 0.04842 train_kl_div: 0.173
# val_rmse_target: 0.5037 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.3036 train_rmse_stderror: 0.03471 train_kl_div: 0.1841
# val_rmse_target: 0.504 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.5001 (from epoch 3)
#
# Performance estimates:
# [0.4890381725796881, 0.5001188732725894]
# Mean: 0.4945785229261388
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 3/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8054 train_rmse_stderror: 0.04013 train_kl_div: 1.179
# val_rmse_target: 0.8373 val_rmse_stderror: 1.08
# New best_val_rmse: 0.8373
#
# 64 steps took 48.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 1.062 train_rmse_stderror: 0.01896 train_kl_div: 2.264
# val_rmse_target: 1.025 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 50.1 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 1.168 train_rmse_stderror: 0.03417 train_kl_div: 2.573
# val_rmse_target: 1.01 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.6 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 1.053 train_rmse_stderror: 0.0165 train_kl_div: 2.263
# val_rmse_target: 1.025 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.5 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 1.138 train_rmse_stderror: 0.02426 train_kl_div: 2.491
# val_rmse_target: 1.011 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.8 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 1.188 train_rmse_stderror: 0.0403 train_kl_div: 2.502
# val_rmse_target: 1.013 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.6 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.6832 train_rmse_stderror: 0.02815 train_kl_div: 1.03
# val_rmse_target: 1.03 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.6 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 1.444 train_rmse_stderror: 0.06357 train_kl_div: 3.469
# val_rmse_target: 1.01 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.8 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 1.141 train_rmse_stderror: 0.04868 train_kl_div: 2.283
# val_rmse_target: 1.017 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.5 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 1.172 train_rmse_stderror: 0.05296 train_kl_div: 2.369
# val_rmse_target: 1.013 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.6 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.883 train_rmse_stderror: 0.02124 train_kl_div: 1.697
# val_rmse_target: 1.015 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.8102 train_rmse_stderror: 0.03159 train_kl_div: 1.475
# val_rmse_target: 1.01 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.6 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.8567 train_rmse_stderror: 0.02363 train_kl_div: 1.494
# val_rmse_target: 1.01 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# 64 steps took 48.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 1.056 train_rmse_stderror: 0.03386 train_kl_div: 2.081
# val_rmse_target: 1.01 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.8373 (from epoch 0)
#
# Performance estimates:
# [0.4890381725796881, 0.5001188732725894, 0.8372558164271773]
# Mean: 0.608804287426485
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 4/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5551 train_rmse_stderror: 0.055 train_kl_div: 0.6826
# val_rmse_target: 0.6491 val_rmse_stderror: 1.738
# New best_val_rmse: 0.6491
#
# 64 steps took 48.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8729 train_rmse_stderror: 0.04137 train_kl_div: 1.532
# val_rmse_target: 0.6156 val_rmse_stderror: 1.793
# New best_val_rmse: 0.6156
#
# 64 steps took 49.0 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.495 train_rmse_stderror: 0.05086 train_kl_div: 0.4489
# val_rmse_target: 0.5587 val_rmse_stderror: 1.782
# New best_val_rmse: 0.5587
#
# 64 steps took 48.8 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.2561 train_rmse_stderror: 0.0329 train_kl_div: 0.1501
# val_rmse_target: 0.5294 val_rmse_stderror: 1.798
# New best_val_rmse: 0.5294
#
# 32 steps took 24.3 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5893 train_rmse_stderror: 0.06422 train_kl_div: 0.7235
# val_rmse_target: 0.4954 val_rmse_stderror: 1.821
# New best_val_rmse: 0.4954
#
# 32 steps took 24.3 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4513 train_rmse_stderror: 0.03508 train_kl_div: 0.4324
# val_rmse_target: 0.5592 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.4954 (from epoch 1)
#
# 64 steps took 49.0 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2275 train_rmse_stderror: 0.02859 train_kl_div: 0.1139
# val_rmse_target: 0.4865 val_rmse_stderror: 1.797
# New best_val_rmse: 0.4865
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2421 train_rmse_stderror: 0.04332 train_kl_div: 0.1302
# val_rmse_target: 0.4795 val_rmse_stderror: 1.773
# New best_val_rmse: 0.4795
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3456 train_rmse_stderror: 0.03804 train_kl_div: 0.1965
# val_rmse_target: 0.4836 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4795 (from epoch 2)
#
# 32 steps took 24.3 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3217 train_rmse_stderror: 0.02693 train_kl_div: 0.2263
# val_rmse_target: 0.5355 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4795 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3769 train_rmse_stderror: 0.0333 train_kl_div: 0.2815
# val_rmse_target: 0.4726 val_rmse_stderror: 1.803
# New best_val_rmse: 0.4726
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2977 train_rmse_stderror: 0.02477 train_kl_div: 0.1805
# val_rmse_target: 0.4716 val_rmse_stderror: 1.791
# New best_val_rmse: 0.4716
#
# 32 steps took 24.6 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.185 train_rmse_stderror: 0.02676 train_kl_div: 0.0747
# val_rmse_target: 0.4623 val_rmse_stderror: 1.794
# New best_val_rmse: 0.4623
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1518 train_rmse_stderror: 0.01808 train_kl_div: 0.04751
# val_rmse_target: 0.4625 val_rmse_stderror: 1.796
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1304 train_rmse_stderror: 0.02283 train_kl_div: 0.03318
# val_rmse_target: 0.4646 val_rmse_stderror: 1.802
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2117 train_rmse_stderror: 0.02064 train_kl_div: 0.08943
# val_rmse_target: 0.4695 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1715 train_rmse_stderror: 0.01737 train_kl_div: 0.05892
# val_rmse_target: 0.4732 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1605 train_rmse_stderror: 0.0262 train_kl_div: 0.05087
# val_rmse_target: 0.4654 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.6 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1247 train_rmse_stderror: 0.02031 train_kl_div: 0.03381
# val_rmse_target: 0.4738 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.0984 train_rmse_stderror: 0.0181 train_kl_div: 0.02111
# val_rmse_target: 0.4661 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.09548 train_rmse_stderror: 0.03054 train_kl_div: 0.01962
# val_rmse_target: 0.4657 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.06775 train_rmse_stderror: 0.02176 train_kl_div: 0.0125
# val_rmse_target: 0.4668 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08239 train_rmse_stderror: 0.0278 train_kl_div: 0.01553
# val_rmse_target: 0.4641 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1196 train_rmse_stderror: 0.01929 train_kl_div: 0.0337
# val_rmse_target: 0.4641 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4623 (from epoch 3)
#
# Performance estimates:
# [0.4890381725796881, 0.5001188732725894, 0.8372558164271773, 0.46227638990267866]
# Mean: 0.5721723130455334
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 5/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 49.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8097 train_rmse_stderror: 0.04657 train_kl_div: 1.474
# val_rmse_target: 0.8315 val_rmse_stderror: 1.773
# New best_val_rmse: 0.8315
#
# 64 steps took 48.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.651 train_rmse_stderror: 0.03618 train_kl_div: 0.9126
# val_rmse_target: 0.7209 val_rmse_stderror: 1.79
# New best_val_rmse: 0.7209
#
# 64 steps took 49.0 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.448 train_rmse_stderror: 0.04178 train_kl_div: 0.3627
# val_rmse_target: 0.7129 val_rmse_stderror: 1.764
# New best_val_rmse: 0.7129
#
# 64 steps took 48.8 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4288 train_rmse_stderror: 0.03086 train_kl_div: 0.3601
# val_rmse_target: 0.5104 val_rmse_stderror: 1.778
# New best_val_rmse: 0.5104
#
# 32 steps took 24.4 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.508 train_rmse_stderror: 0.02389 train_kl_div: 0.5909
# val_rmse_target: 0.5781 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4693 train_rmse_stderror: 0.03484 train_kl_div: 0.4529
# val_rmse_target: 0.5179 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 32 steps took 24.6 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.5781 train_rmse_stderror: 0.04581 train_kl_div: 0.5279
# val_rmse_target: 0.5503 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.7 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.9439 train_rmse_stderror: 0.04715 train_kl_div: 1.393
# val_rmse_target: 1.005 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.6 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 1.119 train_rmse_stderror: 0.03708 train_kl_div: 2.381
# val_rmse_target: 1.005 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 1.082 train_rmse_stderror: 0.03917 train_kl_div: 2.289
# val_rmse_target: 1.012 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.6 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 1.126 train_rmse_stderror: 0.03366 train_kl_div: 2.376
# val_rmse_target: 1.008 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.6 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 1.013 train_rmse_stderror: 0.04364 train_kl_div: 1.83
# val_rmse_target: 1.006 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.8 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 1.234 train_rmse_stderror: 0.04939 train_kl_div: 2.658
# val_rmse_target: 1.015 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.7721 train_rmse_stderror: 0.0282 train_kl_div: 1.245
# val_rmse_target: 1.005 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 64 steps took 48.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 1.011 train_rmse_stderror: 0.02826 train_kl_div: 1.986
# val_rmse_target: 1.005 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# Performance estimates:
# [0.4890381725796881, 0.5001188732725894, 0.8372558164271773, 0.46227638990267866, 0.5104303174765437]
# Mean: 0.5598239139317355
# {'total_MiB': 16160, 'used_MiB': 1359}

# %%
print(list_val_rmse)
# Out:
# [0.4890381725796881, 0.5001188732725894, 0.8372558164271773, 0.46227638990267866, 0.5104303174765437]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Starting upload for file model_2.pth
# 100%|██████████| 1.32G/1.32G [00:51<00:00, 27.7MB/s]
#   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.32G/1.32G [00:51<00:00, 27.6MB/s]
#   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.32G/1.32G [00:51<00:00, 27.6MB/s]
#   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.32G/1.32G [00:51<00:00, 27.6MB/s]
#   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.32G/1.32G [00:50<00:00, 28.1MB/s]
# Upload successful: model_1.pth (1GB)
