# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-02'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 300 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )
        
        self.layer_norm = nn.LayerNorm(config.hidden_size) # layer_normレイヤー
        
        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        norm_embeddings = self.layer_norm(context_vector)
        return self.regressor(norm_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6718 train_rmse_stderror: 0.04161 train_kl_div: 0.9955
# val_rmse_target: 0.7559 val_rmse_stderror: 1.846
# New best_val_rmse: 0.7559
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6445 train_rmse_stderror: 0.03576 train_kl_div: 0.9132
# val_rmse_target: 0.7332 val_rmse_stderror: 1.835
# New best_val_rmse: 0.7332
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.6036 train_rmse_stderror: 0.03206 train_kl_div: 0.7034
# val_rmse_target: 0.6498 val_rmse_stderror: 1.864
# New best_val_rmse: 0.6498
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5616 train_rmse_stderror: 0.0647 train_kl_div: 0.5779
# val_rmse_target: 0.6417 val_rmse_stderror: 1.83
# New best_val_rmse: 0.6417
#
# 64 steps took 72.0 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.6011 train_rmse_stderror: 0.051 train_kl_div: 0.735
# val_rmse_target: 0.5607 val_rmse_stderror: 1.849
# New best_val_rmse: 0.5607
#
# 64 steps took 71.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2824 train_rmse_stderror: 0.01469 train_kl_div: 0.1869
# val_rmse_target: 0.5458 val_rmse_stderror: 1.861
# New best_val_rmse: 0.5458
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.4467 train_rmse_stderror: 0.022 train_kl_div: 0.4505
# val_rmse_target: 0.5117 val_rmse_stderror: 1.851
# New best_val_rmse: 0.5117
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5047 train_rmse_stderror: 0.04589 train_kl_div: 0.556
# val_rmse_target: 0.6078 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.5117 (from epoch 1)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4083 train_rmse_stderror: 0.01698 train_kl_div: 0.3799
# val_rmse_target: 0.5309 val_rmse_stderror: 1.839
# Still best_val_rmse: 0.5117 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.6299 train_rmse_stderror: 0.03387 train_kl_div: 0.8731
# val_rmse_target: 0.528 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.5117 (from epoch 1)
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.4245 train_rmse_stderror: 0.02322 train_kl_div: 0.3526
# val_rmse_target: 0.5072 val_rmse_stderror: 1.845
# New best_val_rmse: 0.5072
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.2637 train_rmse_stderror: 0.02205 train_kl_div: 0.1418
# val_rmse_target: 0.501 val_rmse_stderror: 1.864
# New best_val_rmse: 0.501
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2126 train_rmse_stderror: 0.02184 train_kl_div: 0.09513
# val_rmse_target: 0.5167 val_rmse_stderror: 1.848
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3169 train_rmse_stderror: 0.0205 train_kl_div: 0.2083
# val_rmse_target: 0.5158 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.5077 train_rmse_stderror: 0.04233 train_kl_div: 0.3924
# val_rmse_target: 0.5321 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3537 train_rmse_stderror: 0.02637 train_kl_div: 0.2371
# val_rmse_target: 0.5192 val_rmse_stderror: 1.846
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1723 train_rmse_stderror: 0.01802 train_kl_div: 0.06311
# val_rmse_target: 0.516 val_rmse_stderror: 1.857
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1569 train_rmse_stderror: 0.02109 train_kl_div: 0.05102
# val_rmse_target: 0.5247 val_rmse_stderror: 1.836
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2873 train_rmse_stderror: 0.03638 train_kl_div: 0.1565
# val_rmse_target: 0.5074 val_rmse_stderror: 1.857
# Still best_val_rmse: 0.501 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1969 train_rmse_stderror: 0.02858 train_kl_div: 0.07693
# val_rmse_target: 0.4951 val_rmse_stderror: 1.865
# New best_val_rmse: 0.4951
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1762 train_rmse_stderror: 0.01585 train_kl_div: 0.0715
# val_rmse_target: 0.4906 val_rmse_stderror: 1.854
# New best_val_rmse: 0.4906
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1209 train_rmse_stderror: 0.02738 train_kl_div: 0.03043
# val_rmse_target: 0.5119 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.4906 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.0844 train_rmse_stderror: 0.02138 train_kl_div: 0.01783
# val_rmse_target: 0.4958 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.4906 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1056 train_rmse_stderror: 0.01834 train_kl_div: 0.02566
# val_rmse_target: 0.5023 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4906 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1547 train_rmse_stderror: 0.02241 train_kl_div: 0.05283
# val_rmse_target: 0.5013 val_rmse_stderror: 1.845
# Still best_val_rmse: 0.4906 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1028 train_rmse_stderror: 0.0172 train_kl_div: 0.02572
# val_rmse_target: 0.4878 val_rmse_stderror: 1.85
# New best_val_rmse: 0.4878
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.2407 train_rmse_stderror: 0.02477 train_kl_div: 0.1239
# val_rmse_target: 0.4903 val_rmse_stderror: 1.862
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1731 train_rmse_stderror: 0.02364 train_kl_div: 0.06981
# val_rmse_target: 0.4896 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1009 train_rmse_stderror: 0.02745 train_kl_div: 0.02383
# val_rmse_target: 0.4906 val_rmse_stderror: 1.85
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.09296 train_rmse_stderror: 0.01932 train_kl_div: 0.01961
# val_rmse_target: 0.4916 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1031 train_rmse_stderror: 0.02546 train_kl_div: 0.02653
# val_rmse_target: 0.4918 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.04036 train_rmse_stderror: 0.02682 train_kl_div: 0.006059
# val_rmse_target: 0.4909 val_rmse_stderror: 1.859
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.07128 train_rmse_stderror: 0.02464 train_kl_div: 0.01167
# val_rmse_target: 0.4923 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.07613 train_rmse_stderror: 0.0161 train_kl_div: 0.0132
# val_rmse_target: 0.4926 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1403 train_rmse_stderror: 0.01737 train_kl_div: 0.04328
# val_rmse_target: 0.4916 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1052 train_rmse_stderror: 0.01776 train_kl_div: 0.02597
# val_rmse_target: 0.492 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.07693 train_rmse_stderror: 0.01772 train_kl_div: 0.01424
# val_rmse_target: 0.4921 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4878 (from epoch 3)
#
# Performance estimates:
# [0.48775469793536935]
# Mean: 0.48775469793536935
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8416 train_rmse_stderror: 0.09203 train_kl_div: 1.469
# val_rmse_target: 0.6677 val_rmse_stderror: 1.069
# New best_val_rmse: 0.6677
#
# 64 steps took 71.8 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.9821 train_rmse_stderror: 0.06645 train_kl_div: 1.5
# val_rmse_target: 0.7301 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.6677 (from epoch 0)
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4085 train_rmse_stderror: 0.03901 train_kl_div: 0.347
# val_rmse_target: 0.5732 val_rmse_stderror: 1.092
# New best_val_rmse: 0.5732
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.4142 train_rmse_stderror: 0.0546 train_kl_div: 0.3678
# val_rmse_target: 0.5688 val_rmse_stderror: 1.103
# New best_val_rmse: 0.5688
#
# 64 steps took 72.0 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.4982 train_rmse_stderror: 0.03106 train_kl_div: 0.4586
# val_rmse_target: 0.529 val_rmse_stderror: 1.082
# New best_val_rmse: 0.529
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4823 train_rmse_stderror: 0.04324 train_kl_div: 0.5482
# val_rmse_target: 0.5188 val_rmse_stderror: 1.084
# New best_val_rmse: 0.5188
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.5518 train_rmse_stderror: 0.03042 train_kl_div: 0.5932
# val_rmse_target: 0.5608 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.5188 (from epoch 1)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3729 train_rmse_stderror: 0.02686 train_kl_div: 0.2919
# val_rmse_target: 0.557 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.5188 (from epoch 1)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4506 train_rmse_stderror: 0.0279 train_kl_div: 0.3987
# val_rmse_target: 0.5338 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.5188 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4897 train_rmse_stderror: 0.07077 train_kl_div: 0.4483
# val_rmse_target: 0.5151 val_rmse_stderror: 1.122
# New best_val_rmse: 0.5151
#
# 32 steps took 36.1 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1636 train_rmse_stderror: 0.03435 train_kl_div: 0.0653
# val_rmse_target: 0.5458 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.5151 (from epoch 1)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3439 train_rmse_stderror: 0.04437 train_kl_div: 0.2193
# val_rmse_target: 0.4962 val_rmse_stderror: 1.112
# New best_val_rmse: 0.4962
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2097 train_rmse_stderror: 0.03325 train_kl_div: 0.09384
# val_rmse_target: 0.5012 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4962 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1839 train_rmse_stderror: 0.03548 train_kl_div: 0.07901
# val_rmse_target: 0.4979 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4962 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.5043 train_rmse_stderror: 0.04559 train_kl_div: 0.38
# val_rmse_target: 0.4949 val_rmse_stderror: 1.113
# New best_val_rmse: 0.4949
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2481 train_rmse_stderror: 0.02038 train_kl_div: 0.1187
# val_rmse_target: 0.4915 val_rmse_stderror: 1.111
# New best_val_rmse: 0.4915
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1244 train_rmse_stderror: 0.02355 train_kl_div: 0.03593
# val_rmse_target: 0.5111 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1478 train_rmse_stderror: 0.01781 train_kl_div: 0.04526
# val_rmse_target: 0.5172 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1744 train_rmse_stderror: 0.02378 train_kl_div: 0.06847
# val_rmse_target: 0.5024 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1568 train_rmse_stderror: 0.02454 train_kl_div: 0.05585
# val_rmse_target: 0.4998 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1003 train_rmse_stderror: 0.03371 train_kl_div: 0.02614
# val_rmse_target: 0.4954 val_rmse_stderror: 1.107
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1156 train_rmse_stderror: 0.01724 train_kl_div: 0.03122
# val_rmse_target: 0.51 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1201 train_rmse_stderror: 0.0174 train_kl_div: 0.03134
# val_rmse_target: 0.4975 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1111 train_rmse_stderror: 0.01849 train_kl_div: 0.0233
# val_rmse_target: 0.4972 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.09554 train_rmse_stderror: 0.01463 train_kl_div: 0.01789
# val_rmse_target: 0.4979 val_rmse_stderror: 1.115
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1091 train_rmse_stderror: 0.01983 train_kl_div: 0.02688
# val_rmse_target: 0.4935 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1169 train_rmse_stderror: 0.02357 train_kl_div: 0.03342
# val_rmse_target: 0.5006 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1445 train_rmse_stderror: 0.01798 train_kl_div: 0.04691
# val_rmse_target: 0.5042 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 36.1 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.08373 train_rmse_stderror: 0.01369 train_kl_div: 0.01459
# val_rmse_target: 0.4958 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.07265 train_rmse_stderror: 0.02501 train_kl_div: 0.0136
# val_rmse_target: 0.4936 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1369 train_rmse_stderror: 0.01843 train_kl_div: 0.03807
# val_rmse_target: 0.494 val_rmse_stderror: 1.114
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.05733 train_rmse_stderror: 0.02044 train_kl_div: 0.00869
# val_rmse_target: 0.4967 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.0507 train_rmse_stderror: 0.01559 train_kl_div: 0.006347
# val_rmse_target: 0.4928 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.05347 train_rmse_stderror: 0.01804 train_kl_div: 0.006971
# val_rmse_target: 0.4944 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1038 train_rmse_stderror: 0.03319 train_kl_div: 0.02414
# val_rmse_target: 0.4939 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.06202 train_rmse_stderror: 0.01422 train_kl_div: 0.008931
# val_rmse_target: 0.4939 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.09078 train_rmse_stderror: 0.0227 train_kl_div: 0.01966
# val_rmse_target: 0.494 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4915 (from epoch 2)
#
# Performance estimates:
# [0.48775469793536935, 0.49151877901417995]
# Mean: 0.4896367384747746
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5905 train_rmse_stderror: 0.03598 train_kl_div: 0.689
# val_rmse_target: 0.7 val_rmse_stderror: 1.746
# New best_val_rmse: 0.7
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7869 train_rmse_stderror: 0.0615 train_kl_div: 1.315
# val_rmse_target: 0.5595 val_rmse_stderror: 1.745
# New best_val_rmse: 0.5595
#
# 64 steps took 71.7 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.6232 train_rmse_stderror: 0.03365 train_kl_div: 0.8497
# val_rmse_target: 0.5894 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.5595 (from epoch 0)
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.6409 train_rmse_stderror: 0.04083 train_kl_div: 0.711
# val_rmse_target: 0.6244 val_rmse_stderror: 1.734
# Still best_val_rmse: 0.5595 (from epoch 0)
#
# 64 steps took 71.9 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.4464 train_rmse_stderror: 0.01917 train_kl_div: 0.4666
# val_rmse_target: 0.5213 val_rmse_stderror: 1.744
# New best_val_rmse: 0.5213
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.3495 train_rmse_stderror: 0.06517 train_kl_div: 0.2773
# val_rmse_target: 0.5168 val_rmse_stderror: 1.774
# New best_val_rmse: 0.5168
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.4267 train_rmse_stderror: 0.03259 train_kl_div: 0.3052
# val_rmse_target: 0.5023 val_rmse_stderror: 1.746
# New best_val_rmse: 0.5023
#
# 32 steps took 35.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.2945 train_rmse_stderror: 0.03817 train_kl_div: 0.1884
# val_rmse_target: 0.4995 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4995
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5082 train_rmse_stderror: 0.01934 train_kl_div: 0.508
# val_rmse_target: 0.5254 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4995 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.2884 train_rmse_stderror: 0.02313 train_kl_div: 0.1836
# val_rmse_target: 0.5358 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4995 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.2757 train_rmse_stderror: 0.03585 train_kl_div: 0.1653
# val_rmse_target: 0.5011 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4995 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.3728 train_rmse_stderror: 0.02441 train_kl_div: 0.2884
# val_rmse_target: 0.5018 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4995 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2542 train_rmse_stderror: 0.02383 train_kl_div: 0.1333
# val_rmse_target: 0.5177 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.4995 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3921 train_rmse_stderror: 0.03774 train_kl_div: 0.3097
# val_rmse_target: 0.4928 val_rmse_stderror: 1.73
# New best_val_rmse: 0.4928
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1913 train_rmse_stderror: 0.02609 train_kl_div: 0.0654
# val_rmse_target: 0.4924 val_rmse_stderror: 1.751
# New best_val_rmse: 0.4924
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.1792 train_rmse_stderror: 0.01905 train_kl_div: 0.06851
# val_rmse_target: 0.5021 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4924 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.2173 train_rmse_stderror: 0.04633 train_kl_div: 0.1109
# val_rmse_target: 0.4894 val_rmse_stderror: 1.733
# New best_val_rmse: 0.4894
#
# 32 steps took 35.9 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.4542 train_rmse_stderror: 0.04498 train_kl_div: 0.4393
# val_rmse_target: 0.4997 val_rmse_stderror: 1.722
# Still best_val_rmse: 0.4894 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1359 train_rmse_stderror: 0.02003 train_kl_div: 0.0404
# val_rmse_target: 0.5038 val_rmse_stderror: 1.725
# Still best_val_rmse: 0.4894 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1864 train_rmse_stderror: 0.03756 train_kl_div: 0.08086
# val_rmse_target: 0.48 val_rmse_stderror: 1.762
# New best_val_rmse: 0.48
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1882 train_rmse_stderror: 0.02357 train_kl_div: 0.08539
# val_rmse_target: 0.479 val_rmse_stderror: 1.752
# New best_val_rmse: 0.479
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1646 train_rmse_stderror: 0.01817 train_kl_div: 0.06086
# val_rmse_target: 0.493 val_rmse_stderror: 1.726
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1208 train_rmse_stderror: 0.02118 train_kl_div: 0.03084
# val_rmse_target: 0.4982 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1141 train_rmse_stderror: 0.02154 train_kl_div: 0.02731
# val_rmse_target: 0.4844 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1256 train_rmse_stderror: 0.01883 train_kl_div: 0.03389
# val_rmse_target: 0.4946 val_rmse_stderror: 1.733
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1196 train_rmse_stderror: 0.0244 train_kl_div: 0.03042
# val_rmse_target: 0.4868 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.159 train_rmse_stderror: 0.03813 train_kl_div: 0.05647
# val_rmse_target: 0.4824 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.134 train_rmse_stderror: 0.01062 train_kl_div: 0.03777
# val_rmse_target: 0.481 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1973 train_rmse_stderror: 0.03926 train_kl_div: 0.07861
# val_rmse_target: 0.481 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1229 train_rmse_stderror: 0.0247 train_kl_div: 0.03674
# val_rmse_target: 0.4847 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.09244 train_rmse_stderror: 0.01547 train_kl_div: 0.02052
# val_rmse_target: 0.4882 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1903 train_rmse_stderror: 0.02595 train_kl_div: 0.06719
# val_rmse_target: 0.4838 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06031 train_rmse_stderror: 0.01857 train_kl_div: 0.009566
# val_rmse_target: 0.484 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1275 train_rmse_stderror: 0.02446 train_kl_div: 0.02785
# val_rmse_target: 0.4841 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1116 train_rmse_stderror: 0.01454 train_kl_div: 0.02043
# val_rmse_target: 0.4857 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1307 train_rmse_stderror: 0.01866 train_kl_div: 0.03827
# val_rmse_target: 0.4859 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1114 train_rmse_stderror: 0.01763 train_kl_div: 0.02623
# val_rmse_target: 0.4856 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1507 train_rmse_stderror: 0.02539 train_kl_div: 0.04384
# val_rmse_target: 0.4853 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.479 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08462 train_rmse_stderror: 0.01565 train_kl_div: 0.01629
# val_rmse_target: 0.4852 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.479 (from epoch 2)
#
# Performance estimates:
# [0.48775469793536935, 0.49151877901417995, 0.47896522869058633]
# Mean: 0.48607956854671186
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.5 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.8572 train_rmse_stderror: 0.0861 train_kl_div: 1.367
# val_rmse_target: 0.7001 val_rmse_stderror: 1.828
# New best_val_rmse: 0.7001
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6791 train_rmse_stderror: 0.04499 train_kl_div: 0.9685
# val_rmse_target: 0.6832 val_rmse_stderror: 1.819
# New best_val_rmse: 0.6832
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.4836 train_rmse_stderror: 0.02702 train_kl_div: 0.5068
# val_rmse_target: 0.7246 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.6832 (from epoch 0)
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.8757 train_rmse_stderror: 0.0154 train_kl_div: 1.662
# val_rmse_target: 0.5354 val_rmse_stderror: 1.789
# New best_val_rmse: 0.5354
#
# 32 steps took 36.1 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.6107 train_rmse_stderror: 0.04664 train_kl_div: 0.5703
# val_rmse_target: 0.5906 val_rmse_stderror: 1.806
# Still best_val_rmse: 0.5354 (from epoch 0)
#
# 64 steps took 71.6 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.3139 train_rmse_stderror: 0.019 train_kl_div: 0.223
# val_rmse_target: 0.5251 val_rmse_stderror: 1.792
# New best_val_rmse: 0.5251
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.53 train_rmse_stderror: 0.02202 train_kl_div: 0.5904
# val_rmse_target: 0.5396 val_rmse_stderror: 1.805
# Still best_val_rmse: 0.5251 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.2658 train_rmse_stderror: 0.02638 train_kl_div: 0.168
# val_rmse_target: 0.5265 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.5251 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5882 train_rmse_stderror: 0.06553 train_kl_div: 0.5807
# val_rmse_target: 0.4772 val_rmse_stderror: 1.781
# New best_val_rmse: 0.4772
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.5607 train_rmse_stderror: 0.04863 train_kl_div: 0.6589
# val_rmse_target: 0.4909 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4772 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4725 train_rmse_stderror: 0.03791 train_kl_div: 0.4757
# val_rmse_target: 0.4885 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4772 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.385 train_rmse_stderror: 0.04194 train_kl_div: 0.3108
# val_rmse_target: 0.5087 val_rmse_stderror: 1.803
# Still best_val_rmse: 0.4772 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3027 train_rmse_stderror: 0.02857 train_kl_div: 0.1974
# val_rmse_target: 0.4977 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4772 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3901 train_rmse_stderror: 0.04433 train_kl_div: 0.2905
# val_rmse_target: 0.4652 val_rmse_stderror: 1.781
# New best_val_rmse: 0.4652
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.29 train_rmse_stderror: 0.03052 train_kl_div: 0.159
# val_rmse_target: 0.4601 val_rmse_stderror: 1.8
# New best_val_rmse: 0.4601
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2461 train_rmse_stderror: 0.02317 train_kl_div: 0.1382
# val_rmse_target: 0.4702 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.4151 train_rmse_stderror: 0.01943 train_kl_div: 0.3247
# val_rmse_target: 0.4991 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3415 train_rmse_stderror: 0.03702 train_kl_div: 0.2531
# val_rmse_target: 0.4958 val_rmse_stderror: 1.798
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2815 train_rmse_stderror: 0.02597 train_kl_div: 0.1844
# val_rmse_target: 0.4853 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.4033 train_rmse_stderror: 0.01997 train_kl_div: 0.3098
# val_rmse_target: 0.4748 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2911 train_rmse_stderror: 0.03593 train_kl_div: 0.1824
# val_rmse_target: 0.4691 val_rmse_stderror: 1.781
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.09506 train_rmse_stderror: 0.03027 train_kl_div: 0.02357
# val_rmse_target: 0.4671 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1841 train_rmse_stderror: 0.02712 train_kl_div: 0.07427
# val_rmse_target: 0.4689 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1381 train_rmse_stderror: 0.01745 train_kl_div: 0.04203
# val_rmse_target: 0.4693 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1153 train_rmse_stderror: 0.01862 train_kl_div: 0.03051
# val_rmse_target: 0.4671 val_rmse_stderror: 1.782
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1684 train_rmse_stderror: 0.03454 train_kl_div: 0.06535
# val_rmse_target: 0.4636 val_rmse_stderror: 1.793
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.249 train_rmse_stderror: 0.02192 train_kl_div: 0.1202
# val_rmse_target: 0.469 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1926 train_rmse_stderror: 0.03493 train_kl_div: 0.06755
# val_rmse_target: 0.4715 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1527 train_rmse_stderror: 0.02325 train_kl_div: 0.04978
# val_rmse_target: 0.4616 val_rmse_stderror: 1.794
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.2671 train_rmse_stderror: 0.02568 train_kl_div: 0.1417
# val_rmse_target: 0.4603 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.118 train_rmse_stderror: 0.02059 train_kl_div: 0.03485
# val_rmse_target: 0.4652 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.179 train_rmse_stderror: 0.03837 train_kl_div: 0.05341
# val_rmse_target: 0.4611 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06779 train_rmse_stderror: 0.01682 train_kl_div: 0.01075
# val_rmse_target: 0.4619 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.09321 train_rmse_stderror: 0.01861 train_kl_div: 0.02049
# val_rmse_target: 0.4627 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1008 train_rmse_stderror: 0.02301 train_kl_div: 0.02262
# val_rmse_target: 0.4636 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.05354 train_rmse_stderror: 0.01718 train_kl_div: 0.007888
# val_rmse_target: 0.4653 val_rmse_stderror: 1.788
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1545 train_rmse_stderror: 0.03164 train_kl_div: 0.04729
# val_rmse_target: 0.4622 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.08811 train_rmse_stderror: 0.01619 train_kl_div: 0.01634
# val_rmse_target: 0.4626 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1162 train_rmse_stderror: 0.01529 train_kl_div: 0.02845
# val_rmse_target: 0.4627 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4601 (from epoch 2)
#
# Performance estimates:
# [0.48775469793536935, 0.49151877901417995, 0.47896522869058633, 0.4601177279665087]
# Mean: 0.4795891084016611
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 72.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5235 train_rmse_stderror: 0.04249 train_kl_div: 0.6529
# val_rmse_target: 0.7235 val_rmse_stderror: 1.749
# New best_val_rmse: 0.7235
#
# 64 steps took 71.5 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4504 train_rmse_stderror: 0.04101 train_kl_div: 0.4178
# val_rmse_target: 0.6301 val_rmse_stderror: 1.775
# New best_val_rmse: 0.6301
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.5308 train_rmse_stderror: 0.04161 train_kl_div: 0.5767
# val_rmse_target: 0.5509 val_rmse_stderror: 1.751
# New best_val_rmse: 0.5509
#
# 64 steps took 71.6 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5384 train_rmse_stderror: 0.03581 train_kl_div: 0.5503
# val_rmse_target: 0.5602 val_rmse_stderror: 1.785
# Still best_val_rmse: 0.5509 (from epoch 0)
#
# 64 steps took 71.7 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5385 train_rmse_stderror: 0.02599 train_kl_div: 0.5856
# val_rmse_target: 0.5089 val_rmse_stderror: 1.763
# New best_val_rmse: 0.5089
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4278 train_rmse_stderror: 0.04329 train_kl_div: 0.3805
# val_rmse_target: 0.5073 val_rmse_stderror: 1.75
# New best_val_rmse: 0.5073
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.3041 train_rmse_stderror: 0.01997 train_kl_div: 0.1902
# val_rmse_target: 0.5482 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.5073 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.4906 train_rmse_stderror: 0.05071 train_kl_div: 0.4087
# val_rmse_target: 0.5376 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.5073 (from epoch 1)
#
# 32 steps took 35.7 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.344 train_rmse_stderror: 0.04458 train_kl_div: 0.2481
# val_rmse_target: 0.5072 val_rmse_stderror: 1.796
# New best_val_rmse: 0.5072
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.4913 train_rmse_stderror: 0.03513 train_kl_div: 0.4102
# val_rmse_target: 0.5015 val_rmse_stderror: 1.765
# New best_val_rmse: 0.5015
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.4147 train_rmse_stderror: 0.03006 train_kl_div: 0.3474
# val_rmse_target: 0.5183 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.5015 (from epoch 1)
#
# 32 steps took 35.8 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.4674 train_rmse_stderror: 0.03274 train_kl_div: 0.4521
# val_rmse_target: 0.5117 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.5015 (from epoch 1)
#
# 32 steps took 36.0 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2341 train_rmse_stderror: 0.02924 train_kl_div: 0.1264
# val_rmse_target: 0.4961 val_rmse_stderror: 1.734
# New best_val_rmse: 0.4961
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3064 train_rmse_stderror: 0.0306 train_kl_div: 0.223
# val_rmse_target: 0.4914 val_rmse_stderror: 1.764
# New best_val_rmse: 0.4914
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2547 train_rmse_stderror: 0.014 train_kl_div: 0.1421
# val_rmse_target: 0.4867 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4867
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2489 train_rmse_stderror: 0.05781 train_kl_div: 0.136
# val_rmse_target: 0.4901 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4867 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.3755 train_rmse_stderror: 0.04136 train_kl_div: 0.3052
# val_rmse_target: 0.4923 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4867 (from epoch 2)
#
# 32 steps took 35.7 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.3343 train_rmse_stderror: 0.01712 train_kl_div: 0.2407
# val_rmse_target: 0.487 val_rmse_stderror: 1.777
# Still best_val_rmse: 0.4867 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.2823 train_rmse_stderror: 0.04426 train_kl_div: 0.1386
# val_rmse_target: 0.4813 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4813
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.1965 train_rmse_stderror: 0.02637 train_kl_div: 0.08625
# val_rmse_target: 0.4845 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4813 (from epoch 2)
#
# 32 steps took 35.8 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1494 train_rmse_stderror: 0.02024 train_kl_div: 0.05093
# val_rmse_target: 0.4903 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4813 (from epoch 2)
#
# 32 steps took 35.9 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.09687 train_rmse_stderror: 0.02591 train_kl_div: 0.02186
# val_rmse_target: 0.4809 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4809
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2396 train_rmse_stderror: 0.02403 train_kl_div: 0.1145
# val_rmse_target: 0.4843 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1 train_rmse_stderror: 0.02055 train_kl_div: 0.02404
# val_rmse_target: 0.4819 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1383 train_rmse_stderror: 0.01739 train_kl_div: 0.04215
# val_rmse_target: 0.4818 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1785 train_rmse_stderror: 0.007456 train_kl_div: 0.06277
# val_rmse_target: 0.4842 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.194 train_rmse_stderror: 0.03599 train_kl_div: 0.06135
# val_rmse_target: 0.4856 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1045 train_rmse_stderror: 0.01342 train_kl_div: 0.02322
# val_rmse_target: 0.493 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.8 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1198 train_rmse_stderror: 0.03004 train_kl_div: 0.03114
# val_rmse_target: 0.4821 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 35.7 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1193 train_rmse_stderror: 0.02719 train_kl_div: 0.03505
# val_rmse_target: 0.4839 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4809 (from epoch 3)
#
# 32 steps took 36.0 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.13 train_rmse_stderror: 0.03884 train_kl_div: 0.03305
# val_rmse_target: 0.4794 val_rmse_stderror: 1.758
# New best_val_rmse: 0.4794
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1509 train_rmse_stderror: 0.02743 train_kl_div: 0.03821
# val_rmse_target: 0.4847 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.1116 train_rmse_stderror: 0.01816 train_kl_div: 0.02937
# val_rmse_target: 0.4828 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.8 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.07996 train_rmse_stderror: 0.01649 train_kl_div: 0.01492
# val_rmse_target: 0.4814 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.08887 train_rmse_stderror: 0.03358 train_kl_div: 0.01828
# val_rmse_target: 0.4807 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1489 train_rmse_stderror: 0.02063 train_kl_div: 0.0415
# val_rmse_target: 0.4826 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.05482 train_rmse_stderror: 0.01625 train_kl_div: 0.007557
# val_rmse_target: 0.4817 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.07012 train_rmse_stderror: 0.04146 train_kl_div: 0.01433
# val_rmse_target: 0.482 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# 32 steps took 35.7 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.06853 train_rmse_stderror: 0.01284 train_kl_div: 0.01196
# val_rmse_target: 0.482 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4794 (from epoch 4)
#
# Performance estimates:
# [0.48775469793536935, 0.49151877901417995, 0.47896522869058633, 0.4601177279665087, 0.47936358308531873]
# Mean: 0.4795440033383926
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.48775469793536935, 0.49151877901417995, 0.47896522869058633, 0.4601177279665087, 0.47936358308531873]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:29<00:00, 48.1MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.8MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:29<00:00, 48.8MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 56.5MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.0MB/s]
# Upload successful: model_1.pth (1GB)
