# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (0.1.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-base'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '043-train-08'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 16 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        #self.attention = nn.Sequential(# attentionレイヤー            
        #    nn.Linear(config.hidden_size, 512), # 768は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
        #    nn.Tanh(),                       
        #    nn.Linear(512, 1),
        #    nn.Softmax(dim=1)
        #)

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        #last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        #weights = self.attention(last_layer_hidden_states) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        #context_vector = torch.sum(weights * last_layer_hidden_states, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        last_hidden_state = roberta_output[0]
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            #del target
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    #attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    #attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    #parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
# 検証用
st_kfold_bins_df = create_folds(train_df, 5, return_df=True)
st_kfold_bins_df['bins_tg'] = st_kfold_bins_df['bins_tg'].map(lambda x: float(x))
st_kfold_bins_df['bins_std'] = st_kfold_bins_df['bins_std'].map(lambda x: float(x))
st_kfold_bins_df.groupby('kfold').agg({'bins_tg': ['min', 'max', 'mean'],
                                    'bins_std': ['min', 'max', 'mean']})
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#       bins_tg                 bins_std
#           min   max      mean      min   max      mean
# kfold
# 0         0.0  11.0  5.546737      0.0  11.0  2.938272
# 1         0.0  11.0  5.513228      0.0  11.0  2.932981
# 2         0.0  11.0  5.569665      0.0  11.0  2.932981
# 3         0.0  11.0  5.542403      0.0  11.0  2.922261
# 4         0.0  11.0  5.577739      0.0  11.0  2.918728

# %%
# 実際に使うKFold
st_kfold_bins = create_folds(train_df, 5, return_df=False)
st_kfold_bins
# Out:
# <generator object _BaseKFold.split at 0x7f33a32e6350>

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.45 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.031 val_rmse_stderror: 1.659
# New best_val_rmse: 1.031
#
# 16 steps took 8.99 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.8877 val_rmse_stderror: 1.741
# New best_val_rmse: 0.8877
#
# 16 steps took 9.0 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.6752 val_rmse_stderror: 1.728
# New best_val_rmse: 0.6752
#
# 16 steps took 8.99 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6446 val_rmse_stderror: 1.8
# New best_val_rmse: 0.6446
#
# 16 steps took 8.99 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6003 val_rmse_stderror: 1.783
# New best_val_rmse: 0.6003
#
# 16 steps took 8.98 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5651 val_rmse_stderror: 1.745
# New best_val_rmse: 0.5651
#
# 16 steps took 9.01 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.7663 val_rmse_stderror: 1.817
# Still best_val_rmse: 0.5651 (from epoch 0)
#
# 16 steps took 9.01 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6008 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5651 (from epoch 0)
#
# 16 steps took 9.11 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5155 val_rmse_stderror: 1.77
# New best_val_rmse: 0.5155
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.523 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.5155 (from epoch 1)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5367 val_rmse_stderror: 1.778
# Still best_val_rmse: 0.5155 (from epoch 1)
#
# 16 steps took 9.01 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5131 val_rmse_stderror: 1.78
# New best_val_rmse: 0.5131
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5135 val_rmse_stderror: 1.776
# Still best_val_rmse: 0.5131 (from epoch 1)
#
# 16 steps took 8.99 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.4985 val_rmse_stderror: 1.782
# New best_val_rmse: 0.4985
#
# 8 steps took 4.49 seconds
# Epoch: 1 batch_num: 91 val_rmse_target: 0.5005 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4985 (from epoch 1)
#
# 16 steps took 9.02 seconds
# Epoch: 1 batch_num: 107 val_rmse_target: 0.4952 val_rmse_stderror: 1.77
# New best_val_rmse: 0.4952
#
# 8 steps took 4.51 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5431 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4952 (from epoch 1)
#
# 16 steps took 9.01 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.493 val_rmse_stderror: 1.775
# New best_val_rmse: 0.493
#
# 8 steps took 4.51 seconds
# Epoch: 1 batch_num: 139 val_rmse_target: 0.5229 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.493 (from epoch 1)
#
# 16 steps took 9.16 seconds
# Epoch: 2 batch_num: 14 val_rmse_target: 0.5023 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.493 (from epoch 1)
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.5284 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.493 (from epoch 1)
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4871 val_rmse_stderror: 1.758
# New best_val_rmse: 0.4871
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 50 val_rmse_target: 0.4917 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 2 batch_num: 58 val_rmse_target: 0.5114 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 9.01 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4921 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 2 batch_num: 82 val_rmse_target: 0.5203 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 98 val_rmse_target: 0.4879 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 4 steps took 2.24 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.5047 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 8.99 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4923 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.5278 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 9.16 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4939 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.5088 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 8.99 seconds
# Epoch: 3 batch_num: 25 val_rmse_target: 0.488 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 29 val_rmse_target: 0.5051 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 16 steps took 8.99 seconds
# Epoch: 3 batch_num: 45 val_rmse_target: 0.4918 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.49 seconds
# Epoch: 3 batch_num: 53 val_rmse_target: 0.4967 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4871 (from epoch 2)
#
# 8 steps took 4.5 seconds
# Epoch: 3 batch_num: 61 val_rmse_target: 0.4832 val_rmse_stderror: 1.777
# New best_val_rmse: 0.4832
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.4839 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4954 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4854 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 81 val_rmse_target: 0.4914 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.4853 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 93 val_rmse_target: 0.5057 val_rmse_stderror: 1.768
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 16 steps took 9.02 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4952 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4832 (from epoch 3)
#
# 8 steps took 4.5 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4825 val_rmse_stderror: 1.776
# New best_val_rmse: 0.4825
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.4839 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4889 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4908 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4862 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.38 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.4889 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4861 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.4864 val_rmse_stderror: 1.767
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4887 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4878 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4878 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4875 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.488 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4907 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 8 steps took 4.5 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4905 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4865 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4857 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.486 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4869 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4883 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4891 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4898 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4898 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.49 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4903 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4903 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 8 steps took 4.49 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.489 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4884 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4879 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.4874 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.25 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# 4 steps took 2.24 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4871 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4825 (from epoch 3)
#
# Performance estimates:
# [0.4825475080668917]
# Mean: 0.4825475080668917
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.17 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.267 val_rmse_stderror: 1.058
# New best_val_rmse: 1.267
#
# 16 steps took 8.73 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.009 val_rmse_stderror: 1.03
# New best_val_rmse: 1.009
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.9299 val_rmse_stderror: 1.147
# New best_val_rmse: 0.9299
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.828 val_rmse_stderror: 1.105
# New best_val_rmse: 0.828
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6929 val_rmse_stderror: 1.107
# New best_val_rmse: 0.6929
#
# 16 steps took 8.7 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6262 val_rmse_stderror: 1.123
# New best_val_rmse: 0.6262
#
# 16 steps took 8.71 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5972 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5972
#
# 16 steps took 8.69 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6285 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.5972 (from epoch 0)
#
# 16 steps took 8.85 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5528 val_rmse_stderror: 1.122
# New best_val_rmse: 0.5528
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5749 val_rmse_stderror: 1.117
# Still best_val_rmse: 0.5528 (from epoch 1)
#
# 16 steps took 8.68 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5299 val_rmse_stderror: 1.127
# New best_val_rmse: 0.5299
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5177 val_rmse_stderror: 1.128
# New best_val_rmse: 0.5177
#
# 16 steps took 8.72 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5529 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.7 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5871 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.68 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5519 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.68 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5838 val_rmse_stderror: 1.122
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.69 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5739 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.86 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5238 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.5177 (from epoch 1)
#
# 16 steps took 8.7 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.4881 val_rmse_stderror: 1.123
# New best_val_rmse: 0.4881
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.517 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4881 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 42 val_rmse_target: 0.481 val_rmse_stderror: 1.127
# New best_val_rmse: 0.481
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4799 val_rmse_stderror: 1.125
# New best_val_rmse: 0.4799
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 48 val_rmse_target: 0.4804 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4799 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 52 val_rmse_target: 0.4976 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4799 (from epoch 2)
#
# 8 steps took 4.36 seconds
# Epoch: 2 batch_num: 60 val_rmse_target: 0.4777 val_rmse_stderror: 1.125
# New best_val_rmse: 0.4777
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4841 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4877 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.5044 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4864 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 90 val_rmse_target: 0.4872 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4929 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.34 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4845 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.18 seconds
# Epoch: 2 batch_num: 106 val_rmse_target: 0.4945 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.35 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4809 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.4967 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 4.33 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.4837 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 2 batch_num: 130 val_rmse_target: 0.4708 val_rmse_stderror: 1.125
# New best_val_rmse: 0.4708
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 132 val_rmse_target: 0.4727 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 134 val_rmse_target: 0.4752 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 136 val_rmse_target: 0.4782 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.477 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 2 batch_num: 140 val_rmse_target: 0.4783 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.24 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4786 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 3 val_rmse_target: 0.4771 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.09 seconds
# Epoch: 3 batch_num: 5 val_rmse_target: 0.485 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.4827 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 13 val_rmse_target: 0.4709 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 15 val_rmse_target: 0.4712 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 17 val_rmse_target: 0.5044 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4708 (from epoch 2)
#
# 16 steps took 8.69 seconds
# Epoch: 3 batch_num: 33 val_rmse_target: 0.4704 val_rmse_stderror: 1.121
# New best_val_rmse: 0.4704
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 35 val_rmse_target: 0.4753 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.4704 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 37 val_rmse_target: 0.4755 val_rmse_stderror: 1.119
# Still best_val_rmse: 0.4704 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 39 val_rmse_target: 0.4737 val_rmse_stderror: 1.121
# Still best_val_rmse: 0.4704 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 41 val_rmse_target: 0.4942 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4704 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 49 val_rmse_target: 0.469 val_rmse_stderror: 1.123
# New best_val_rmse: 0.469
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 50 val_rmse_target: 0.4697 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 51 val_rmse_target: 0.4712 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 1.09 seconds
# Epoch: 3 batch_num: 53 val_rmse_target: 0.477 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 1.09 seconds
# Epoch: 3 batch_num: 55 val_rmse_target: 0.4756 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 57 val_rmse_target: 0.4732 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 59 val_rmse_target: 0.4668 val_rmse_stderror: 1.124
# New best_val_rmse: 0.4668
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 60 val_rmse_target: 0.4664 val_rmse_stderror: 1.124
# New best_val_rmse: 0.4664
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 61 val_rmse_target: 0.4662 val_rmse_stderror: 1.124
# New best_val_rmse: 0.4662
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 62 val_rmse_target: 0.4663 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4662 (from epoch 3)
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 63 val_rmse_target: 0.4662 val_rmse_stderror: 1.124
# New best_val_rmse: 0.4662
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 64 val_rmse_target: 0.4663 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4662 (from epoch 3)
#
# 1 steps took 0.54 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.466 val_rmse_stderror: 1.125
# New best_val_rmse: 0.466
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 66 val_rmse_target: 0.4663 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.544 seconds
# Epoch: 3 batch_num: 67 val_rmse_target: 0.4723 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4922 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 8 steps took 4.34 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4677 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 78 val_rmse_target: 0.4694 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 79 val_rmse_target: 0.4698 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 80 val_rmse_target: 0.4689 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 81 val_rmse_target: 0.4671 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 82 val_rmse_target: 0.466 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.466 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 83 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4658
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 84 val_rmse_target: 0.4661 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.54 seconds
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4668 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.54 seconds
# Epoch: 3 batch_num: 86 val_rmse_target: 0.467 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.546 seconds
# Epoch: 3 batch_num: 87 val_rmse_target: 0.469 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.54 seconds
# Epoch: 3 batch_num: 88 val_rmse_target: 0.472 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 90 val_rmse_target: 0.4824 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 94 val_rmse_target: 0.4814 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 98 val_rmse_target: 0.4697 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 99 val_rmse_target: 0.4687 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.545 seconds
# Epoch: 3 batch_num: 100 val_rmse_target: 0.468 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 101 val_rmse_target: 0.468 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 102 val_rmse_target: 0.4681 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 103 val_rmse_target: 0.4681 val_rmse_stderror: 1.123
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 104 val_rmse_target: 0.4681 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.542 seconds
# Epoch: 3 batch_num: 105 val_rmse_target: 0.4687 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.544 seconds
# Epoch: 3 batch_num: 106 val_rmse_target: 0.4683 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 107 val_rmse_target: 0.4685 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 108 val_rmse_target: 0.4692 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4701 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 111 val_rmse_target: 0.4758 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.09 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4854 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 4 steps took 2.17 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4793 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 119 val_rmse_target: 0.4721 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.4674 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.539 seconds
# Epoch: 3 batch_num: 122 val_rmse_target: 0.4665 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.536 seconds
# Epoch: 3 batch_num: 123 val_rmse_target: 0.4661 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.536 seconds
# Epoch: 3 batch_num: 124 val_rmse_target: 0.4662 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4662 val_rmse_stderror: 1.124
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 126 val_rmse_target: 0.4663 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 127 val_rmse_target: 0.4662 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.541 seconds
# Epoch: 3 batch_num: 128 val_rmse_target: 0.4665 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4672 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.54 seconds
# Epoch: 3 batch_num: 130 val_rmse_target: 0.4676 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.547 seconds
# Epoch: 3 batch_num: 131 val_rmse_target: 0.4681 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 132 val_rmse_target: 0.4678 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 133 val_rmse_target: 0.4669 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 134 val_rmse_target: 0.4664 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.538 seconds
# Epoch: 3 batch_num: 135 val_rmse_target: 0.4665 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 136 val_rmse_target: 0.467 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.537 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4686 val_rmse_stderror: 1.125
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.536 seconds
# Epoch: 3 batch_num: 138 val_rmse_target: 0.4717 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.08 seconds
# Epoch: 3 batch_num: 140 val_rmse_target: 0.4794 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.24 seconds
# Epoch: 4 batch_num: 1 val_rmse_target: 0.4857 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 4 steps took 2.17 seconds
# Epoch: 4 batch_num: 5 val_rmse_target: 0.4725 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 2 steps took 1.09 seconds
# Epoch: 4 batch_num: 7 val_rmse_target: 0.4665 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4658 (from epoch 3)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.4654 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4654
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 9 val_rmse_target: 0.4645 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4645
#
# 1 steps took 0.536 seconds
# Epoch: 4 batch_num: 10 val_rmse_target: 0.464 val_rmse_stderror: 1.126
# New best_val_rmse: 0.464
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 11 val_rmse_target: 0.464 val_rmse_stderror: 1.126
# New best_val_rmse: 0.464
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4639 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4639
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 13 val_rmse_target: 0.4639 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4639
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 14 val_rmse_target: 0.464 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 15 val_rmse_target: 0.464 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4639 val_rmse_stderror: 1.126
# New best_val_rmse: 0.4639
#
# 1 steps took 0.545 seconds
# Epoch: 4 batch_num: 17 val_rmse_target: 0.4639 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 18 val_rmse_target: 0.4643 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 19 val_rmse_target: 0.4656 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4674 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 21 val_rmse_target: 0.4696 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 22 val_rmse_target: 0.4718 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 2 steps took 1.09 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4756 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 26 val_rmse_target: 0.4756 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.474 val_rmse_stderror: 1.129
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 30 val_rmse_target: 0.47 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4659 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 33 val_rmse_target: 0.4644 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4639 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 34 val_rmse_target: 0.4634 val_rmse_stderror: 1.128
# New best_val_rmse: 0.4634
#
# 1 steps took 0.546 seconds
# Epoch: 4 batch_num: 35 val_rmse_target: 0.4631 val_rmse_stderror: 1.127
# New best_val_rmse: 0.4631
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.4629 val_rmse_stderror: 1.127
# New best_val_rmse: 0.4629
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 37 val_rmse_target: 0.463 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 38 val_rmse_target: 0.4631 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 39 val_rmse_target: 0.4636 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4641 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.536 seconds
# Epoch: 4 batch_num: 41 val_rmse_target: 0.4642 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 42 val_rmse_target: 0.4643 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.536 seconds
# Epoch: 4 batch_num: 43 val_rmse_target: 0.4647 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4652 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.543 seconds
# Epoch: 4 batch_num: 45 val_rmse_target: 0.4661 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 46 val_rmse_target: 0.4667 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 47 val_rmse_target: 0.4674 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4679 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 49 val_rmse_target: 0.4683 val_rmse_stderror: 1.128
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 50 val_rmse_target: 0.4687 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.543 seconds
# Epoch: 4 batch_num: 51 val_rmse_target: 0.4693 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4696 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 53 val_rmse_target: 0.4686 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.543 seconds
# Epoch: 4 batch_num: 54 val_rmse_target: 0.4678 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 55 val_rmse_target: 0.4671 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4659 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 57 val_rmse_target: 0.4651 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 58 val_rmse_target: 0.4646 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 59 val_rmse_target: 0.4641 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4637 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 61 val_rmse_target: 0.4636 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 62 val_rmse_target: 0.4635 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.543 seconds
# Epoch: 4 batch_num: 63 val_rmse_target: 0.4634 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.543 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4633 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 65 val_rmse_target: 0.4633 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 66 val_rmse_target: 0.4632 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 67 val_rmse_target: 0.4632 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4634 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 69 val_rmse_target: 0.4639 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 70 val_rmse_target: 0.4645 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 71 val_rmse_target: 0.4652 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4659 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 73 val_rmse_target: 0.4664 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 74 val_rmse_target: 0.4673 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 75 val_rmse_target: 0.4684 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4695 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 77 val_rmse_target: 0.4706 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 79 val_rmse_target: 0.4723 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 81 val_rmse_target: 0.473 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 83 val_rmse_target: 0.4725 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 85 val_rmse_target: 0.4715 val_rmse_stderror: 1.127
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 87 val_rmse_target: 0.4704 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 2 steps took 1.08 seconds
# Epoch: 4 batch_num: 89 val_rmse_target: 0.4696 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 90 val_rmse_target: 0.4693 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 91 val_rmse_target: 0.469 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4688 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 93 val_rmse_target: 0.4686 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 94 val_rmse_target: 0.4685 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 95 val_rmse_target: 0.4684 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4684 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 97 val_rmse_target: 0.4682 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 98 val_rmse_target: 0.4681 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 99 val_rmse_target: 0.468 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.4678 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 101 val_rmse_target: 0.4674 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 102 val_rmse_target: 0.467 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 103 val_rmse_target: 0.4666 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4664 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 105 val_rmse_target: 0.4663 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 106 val_rmse_target: 0.4662 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 107 val_rmse_target: 0.466 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4659 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 109 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 110 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 111 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 113 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 114 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 115 val_rmse_target: 0.4656 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 117 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 118 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 119 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 121 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 122 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 123 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.545 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 125 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.548 seconds
# Epoch: 4 batch_num: 126 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 127 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.539 seconds
# Epoch: 4 batch_num: 129 val_rmse_target: 0.4658 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 130 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 131 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 133 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 134 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.54 seconds
# Epoch: 4 batch_num: 135 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.541 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.538 seconds
# Epoch: 4 batch_num: 137 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.542 seconds
# Epoch: 4 batch_num: 138 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.544 seconds
# Epoch: 4 batch_num: 139 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# 1 steps took 0.537 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4657 val_rmse_stderror: 1.126
# Still best_val_rmse: 0.4629 (from epoch 4)
#
# Performance estimates:
# [0.4825475080668917, 0.4628974561415962]
# Mean: 0.47272248210424395
#
# Fold 3/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.1 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.041 val_rmse_stderror: 1.708
# New best_val_rmse: 1.041
#
# 16 steps took 8.61 seconds
# ...
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4756 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4696 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 87 val_rmse_target: 0.4904 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4696 (from epoch 3)
#
# 8 steps took 4.07 seconds
# Epoch: 3 batch_num: 95 val_rmse_target: 0.469 val_rmse_stderror: 1.749
# New best_val_rmse: 0.469
#
# 1 steps took 0.509 seconds
# Epoch: 3 batch_num: 96 val_rmse_target: 0.469 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 3 batch_num: 97 val_rmse_target: 0.4691 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.469 (from epoch 3)
#
# 1 steps took 0.517 seconds
# Epoch: 3 batch_num: 98 val_rmse_target: 0.4689 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4689
#
# 1 steps took 0.504 seconds
# Epoch: 3 batch_num: 99 val_rmse_target: 0.4694 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 3 batch_num: 100 val_rmse_target: 0.4709 val_rmse_stderror: 1.747
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 102 val_rmse_target: 0.4759 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 104 val_rmse_target: 0.4799 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 106 val_rmse_target: 0.4774 val_rmse_stderror: 1.735
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 108 val_rmse_target: 0.4732 val_rmse_stderror: 1.733
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 110 val_rmse_target: 0.4703 val_rmse_stderror: 1.734
# Still best_val_rmse: 0.4689 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 3 batch_num: 112 val_rmse_target: 0.4678 val_rmse_stderror: 1.741
# New best_val_rmse: 0.4678
#
# 1 steps took 0.506 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4676 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4676
#
# 1 steps took 0.504 seconds
# Epoch: 3 batch_num: 114 val_rmse_target: 0.4679 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 3 batch_num: 115 val_rmse_target: 0.4686 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 1 steps took 0.507 seconds
# Epoch: 3 batch_num: 116 val_rmse_target: 0.4695 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4702 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 3 batch_num: 119 val_rmse_target: 0.4721 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.4753 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 123 val_rmse_target: 0.4723 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4676 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4672 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4672
#
# 1 steps took 0.506 seconds
# Epoch: 3 batch_num: 126 val_rmse_target: 0.4672 val_rmse_stderror: 1.743
# New best_val_rmse: 0.4672
#
# 1 steps took 0.508 seconds
# Epoch: 3 batch_num: 127 val_rmse_target: 0.468 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.503 seconds
# Epoch: 3 batch_num: 128 val_rmse_target: 0.4688 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.506 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4688 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 3 batch_num: 130 val_rmse_target: 0.4678 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 3 batch_num: 131 val_rmse_target: 0.4673 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.507 seconds
# Epoch: 3 batch_num: 132 val_rmse_target: 0.468 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 3 batch_num: 133 val_rmse_target: 0.4704 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 3 batch_num: 135 val_rmse_target: 0.479 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4881 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 4 steps took 2.17 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.4783 val_rmse_stderror: 1.756
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 2 val_rmse_target: 0.473 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4704 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 6 val_rmse_target: 0.4704 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.4709 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 10 val_rmse_target: 0.4716 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.473 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 14 val_rmse_target: 0.4745 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4757 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 18 val_rmse_target: 0.4753 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4733 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 22 val_rmse_target: 0.4721 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.4711 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 26 val_rmse_target: 0.4705 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.4698 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.503 seconds
# Epoch: 4 batch_num: 29 val_rmse_target: 0.4695 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.51 seconds
# Epoch: 4 batch_num: 30 val_rmse_target: 0.4693 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.507 seconds
# Epoch: 4 batch_num: 31 val_rmse_target: 0.4691 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.469 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.51 seconds
# Epoch: 4 batch_num: 33 val_rmse_target: 0.469 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.503 seconds
# Epoch: 4 batch_num: 34 val_rmse_target: 0.4693 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 35 val_rmse_target: 0.4696 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.4701 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 38 val_rmse_target: 0.471 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4717 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 42 val_rmse_target: 0.4727 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4734 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 46 val_rmse_target: 0.4743 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4754 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 50 val_rmse_target: 0.4757 val_rmse_stderror: 1.746
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4755 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 54 val_rmse_target: 0.475 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4736 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 58 val_rmse_target: 0.4725 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4723 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 62 val_rmse_target: 0.4722 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4724 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 66 val_rmse_target: 0.4727 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.473 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 70 val_rmse_target: 0.4729 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4731 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 74 val_rmse_target: 0.473 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4722 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 78 val_rmse_target: 0.4716 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.4711 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 82 val_rmse_target: 0.4705 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4701 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 86 val_rmse_target: 0.4697 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 4 batch_num: 87 val_rmse_target: 0.4696 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.505 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4696 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 89 val_rmse_target: 0.4695 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.507 seconds
# Epoch: 4 batch_num: 90 val_rmse_target: 0.4696 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 91 val_rmse_target: 0.4697 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.503 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4698 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.503 seconds
# Epoch: 4 batch_num: 93 val_rmse_target: 0.4698 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.506 seconds
# Epoch: 4 batch_num: 94 val_rmse_target: 0.4699 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 1 steps took 0.504 seconds
# Epoch: 4 batch_num: 95 val_rmse_target: 0.47 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 97 val_rmse_target: 0.4701 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 99 val_rmse_target: 0.4704 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 101 val_rmse_target: 0.4706 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 103 val_rmse_target: 0.4707 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 105 val_rmse_target: 0.4709 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 107 val_rmse_target: 0.471 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 109 val_rmse_target: 0.4711 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 111 val_rmse_target: 0.4711 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 113 val_rmse_target: 0.4712 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 115 val_rmse_target: 0.4712 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 117 val_rmse_target: 0.4712 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 119 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 121 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 123 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 125 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 127 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 129 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 131 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 133 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.02 seconds
# Epoch: 4 batch_num: 135 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 137 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# 2 steps took 1.01 seconds
# Epoch: 4 batch_num: 139 val_rmse_target: 0.4713 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4672 (from epoch 3)
#
# Performance estimates:
# [0.4825475080668917, 0.4628974561415962, 0.47650937671518767, 0.4860145967551636, 0.46715148160659037]
# Mean: 0.4750240838570859

# %%
print(list_val_rmse)
# Out:
# [0.4825475080668917, 0.4628974561415962, 0.47650937671518767, 0.4860145967551636, 0.46715148160659037]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
# Starting upload for file model_2.pth
# 100%|██████████| 476M/476M [00:35<00:00, 14.2MB/s]
# Upload successful: model_2.pth (476MB)
# Starting upload for file model_3.pth
# 100%|██████████| 476M/476M [00:36<00:00, 13.9MB/s]
# Upload successful: model_3.pth (476MB)
# Starting upload for file model_5.pth
# 100%|██████████| 476M/476M [00:36<00:00, 13.5MB/s]
# Upload successful: model_5.pth (476MB)
# Starting upload for file model_4.pth
# 100%|██████████| 476M/476M [00:37<00:00, 13.1MB/s]
# Upload successful: model_4.pth (476MB)
# Starting upload for file model_1.pth
# 100%|██████████| 476M/476M [00:37<00:00, 13.2MB/s]
# Upload successful: model_1.pth (476MB)
