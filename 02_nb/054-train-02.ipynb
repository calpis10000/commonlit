# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '054-train-02'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import pickle
import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 8 # Batch Size
MAX_LEN = 248 # ベクトル長
TFIDF_MAX_FEAT = 8192

EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
print(train_df.shape)
train_df.head()
# Out:
# (2833, 6)
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# 参考: https://www.guruguru.science/competitions/16/discussions/556029f7-484d-40d4-ad6a-9d86337487e2/
from sklearn.feature_extraction.text import TfidfVectorizer

# ベースとなる継承元のクラス
class BaseBlock(object):
    def fit(self, input_df, y=None):
        return self.transform(input_df)
    def transform(self, input_df):
        raise NotImplementedError()


class TfidfSimpleBlock(BaseBlock):
    """シンプルなTF-IDF特徴を作成する block"""
    def __init__(self, column: str, max_features=50, ngram_range=(1,1), use_idf=True):
        """
        args:
            column: str
                変換対象のカラム名
        """
        self.column = column
        self.max_features=max_features
        self.ngram_range=ngram_range
        self.use_idf=use_idf
        self.param_prefix=f"col={column}_max_features={max_features}_\
                              ngram={ngram_range[0]}_{ngram_range[1]}_use_idf={use_idf}"

    def preprocess(self, input_df):
        x = text_normalization(input_df[self.column])
        return x

    def get_master(self, _master_df):
        """tdidfを計算するための全体集合を返す."""
        return _master_df
    def fit(self, 
            input_df, 
            _master_df=None, 
            y=None
           ):
        master_df = input_df if _master_df is None else self.get_master(_master_df)
        text = self.preprocess(master_df)
        self.vectorizer_ = TfidfVectorizer(max_features=self.max_features
                                      ,ngram_range=self.ngram_range
                                      ,use_idf=self.use_idf)

        self.vectorizer_.fit(text)
        self.prefix = 'tfidf' if self.use_idf == True else 'tf'
        return self.transform(input_df)

    def transform(self, input_df):
        text = self.preprocess(input_df)
        z = self.vectorizer_.transform(text)

        out_df = pd.DataFrame(z.toarray())
        out_df.columns = self.vectorizer_.get_feature_names()
        return out_df.add_prefix(f'{self.prefix}_')

# %%
class LitDataset(Dataset):
    def __init__(self, df, tfidf, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])
        self.tfidf = tfidf # fit済みのものを入力する。（クラス内ではtransformのみ行う）
        self.tfidf_vector = tfidf.transform(df).values

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)
        input_tfidf = torch.tensor(self.tfidf_vector[index, :], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len, input_tfidf)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, input_tfidf, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_wordlen = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.mlm_tfidf = nn.Sequential(
            nn.Linear(TFIDF_MAX_FEAT, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64 + 512, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len, input_tfidf):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # mlm_layers
        mlm_wordlen = self.mlm_wordlen(input_len)
        mlm_tfidf = self.mlm_tfidf(input_tfidf)

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # last_hidden_state = roberta_output[0]
        # input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        # sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        # sum_mask = input_mask_expanded.sum(1)
        # sum_mask = torch.clamp(sum_mask, min=1e-9)
        # mean_embeddings = sum_embeddings / sum_mask

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_wordlen, mlm_tfidf], dim=1)        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する
        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len, input_tfidf) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target
    del input_len
    del input_tfidf

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len, input_tfidf) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len, input_tfidf) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += output.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, input_tfidf, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            input_tfidf = input_tfidf.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len, input_tfidf) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    parameters = []

    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)

    attention_parameters = list(model.attention.named_parameters())
    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    parameters += attention_group

    #norm_parameters = list(model.layer_norm.named_parameters())
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]
    #parameters += norm_group

    mlm_wrd_parameters = list(model.mlm_wordlen.named_parameters())
    mlm_wrd_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_wrd_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_wrd_group

    mlm_tfidf_parameters = list(model.mlm_tfidf.named_parameters())
    mlm_tfidf_group = [{'params': params, 'lr': 2e-5} for (name, params) in mlm_tfidf_parameters] # reg用パラメータをリストとして取得
    parameters += mlm_tfidf_group

    regressor_parameters = list(model.regressor.named_parameters())
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    parameters += regressor_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path, feat_suffix):
    tfidf = TfidfSimpleBlock('excerpt', max_features=TFIDF_MAX_FEAT)
    df_tfidf = tfidf.fit(train_df.loc[train_indices]) # TODO: fit_transformみたいなメソッド作って、fitではdfが返らないようにする。

    with open(f'TFIDF_{feat_suffix}', 'wb') as f:
      pickle.dump(tfidf, f)

    train_dataset = LitDataset(train_df.loc[train_indices], tfidf) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices], tfidf)
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    feat_suffix = f"{fold + 1}.pkl" 

    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path, feat_suffix))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 15109, 'used_MiB': 3}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 1e+02 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5731 train_rmse_stderror: 0.1019 train_kl_div: 0.7427
# val_rmse_target: 0.6805 val_rmse_stderror: 1.214
# New best_val_rmse: 0.6805
#
# 64 steps took 98.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6582 train_rmse_stderror: 0.04959 train_kl_div: 0.8849
# val_rmse_target: 0.6182 val_rmse_stderror: 1.15
# New best_val_rmse: 0.6182
#
# 64 steps took 98.3 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.2526 train_rmse_stderror: 0.03609 train_kl_div: 0.1511
# val_rmse_target: 0.6564 val_rmse_stderror: 1.21
# Still best_val_rmse: 0.6182 (from epoch 0)
#
# 64 steps took 98.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.3206 train_rmse_stderror: 0.09077 train_kl_div: 0.2458
# val_rmse_target: 0.5545 val_rmse_stderror: 1.19
# New best_val_rmse: 0.5545
#
# 64 steps took 98.3 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.3351 train_rmse_stderror: 0.06876 train_kl_div: 0.2049
# val_rmse_target: 0.5254 val_rmse_stderror: 1.2
# New best_val_rmse: 0.5254
#
# 32 steps took 49.2 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4377 train_rmse_stderror: 0.05888 train_kl_div: 0.415
# val_rmse_target: 0.6261 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.5254 (from epoch 1)
#
# 64 steps took 97.9 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.7059 train_rmse_stderror: 0.06554 train_kl_div: 0.8545
# val_rmse_target: 0.5891 val_rmse_stderror: 1.19
# Still best_val_rmse: 0.5254 (from epoch 1)
#
# 64 steps took 97.8 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.2637 train_rmse_stderror: 0.07186 train_kl_div: 0.1763
# val_rmse_target: 0.5153 val_rmse_stderror: 1.191
# New best_val_rmse: 0.5153
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.62 train_rmse_stderror: 0.04533 train_kl_div: 0.7686
# val_rmse_target: 0.5643 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.5153 (from epoch 1)
#
# 64 steps took 98.3 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.3827 train_rmse_stderror: 0.06023 train_kl_div: 0.278
# val_rmse_target: 0.5306 val_rmse_stderror: 1.189
# Still best_val_rmse: 0.5153 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.427 train_rmse_stderror: 0.05929 train_kl_div: 0.4133
# val_rmse_target: 0.5286 val_rmse_stderror: 1.218
# Still best_val_rmse: 0.5153 (from epoch 1)
#
# 32 steps took 49.0 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2505 train_rmse_stderror: 0.07033 train_kl_div: 0.1297
# val_rmse_target: 0.4808 val_rmse_stderror: 1.194
# New best_val_rmse: 0.4808
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.282 train_rmse_stderror: 0.04547 train_kl_div: 0.1754
# val_rmse_target: 0.5256 val_rmse_stderror: 1.191
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1381 train_rmse_stderror: 0.04543 train_kl_div: 0.05101
# val_rmse_target: 0.5041 val_rmse_stderror: 1.193
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2273 train_rmse_stderror: 0.0659 train_kl_div: 0.1195
# val_rmse_target: 0.5228 val_rmse_stderror: 1.208
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1949 train_rmse_stderror: 0.04292 train_kl_div: 0.08792
# val_rmse_target: 0.518 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2931 train_rmse_stderror: 0.01343 train_kl_div: 0.169
# val_rmse_target: 0.5027 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2597 train_rmse_stderror: 0.06023 train_kl_div: 0.1306
# val_rmse_target: 0.4992 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1469 train_rmse_stderror: 0.04137 train_kl_div: 0.05246
# val_rmse_target: 0.4904 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1689 train_rmse_stderror: 0.02461 train_kl_div: 0.0628
# val_rmse_target: 0.4948 val_rmse_stderror: 1.197
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.169 train_rmse_stderror: 0.02522 train_kl_div: 0.06393
# val_rmse_target: 0.483 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1423 train_rmse_stderror: 0.03938 train_kl_div: 0.05117
# val_rmse_target: 0.4882 val_rmse_stderror: 1.203
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1695 train_rmse_stderror: 0.03857 train_kl_div: 0.0674
# val_rmse_target: 0.495 val_rmse_stderror: 1.194
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1223 train_rmse_stderror: 0.06578 train_kl_div: 0.04539
# val_rmse_target: 0.494 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1383 train_rmse_stderror: 0.04177 train_kl_div: 0.0473
# val_rmse_target: 0.4885 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1008 train_rmse_stderror: 0.03868 train_kl_div: 0.02806
# val_rmse_target: 0.486 val_rmse_stderror: 1.195
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1502 train_rmse_stderror: 0.04241 train_kl_div: 0.05519
# val_rmse_target: 0.4896 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.5 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.1141 train_rmse_stderror: 0.02176 train_kl_div: 0.03108
# val_rmse_target: 0.4875 val_rmse_stderror: 1.196
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.09904 train_rmse_stderror: 0.0209 train_kl_div: 0.02294
# val_rmse_target: 0.493 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.09679 train_rmse_stderror: 0.01862 train_kl_div: 0.02377
# val_rmse_target: 0.4884 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1372 train_rmse_stderror: 0.06032 train_kl_div: 0.05181
# val_rmse_target: 0.4924 val_rmse_stderror: 1.201
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.04992 train_rmse_stderror: 0.02649 train_kl_div: 0.008492
# val_rmse_target: 0.4887 val_rmse_stderror: 1.198
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.08552 train_rmse_stderror: 0.05271 train_kl_div: 0.02843
# val_rmse_target: 0.489 val_rmse_stderror: 1.199
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1122 train_rmse_stderror: 0.0395 train_kl_div: 0.03425
# val_rmse_target: 0.4883 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.07292 train_rmse_stderror: 0.03031 train_kl_div: 0.01527
# val_rmse_target: 0.4877 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.09015 train_rmse_stderror: 0.02878 train_kl_div: 0.02099
# val_rmse_target: 0.4875 val_rmse_stderror: 1.2
# Still best_val_rmse: 0.4808 (from epoch 2)
#
# Performance estimates:
# [0.48084425361068045]
# Mean: 0.48084425361068045
# {'total_MiB': 15109, 'used_MiB': 1084}
#
# Fold 2/5
# {'total_MiB': 15109, 'used_MiB': 1084}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 98.9 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.147 train_rmse_stderror: 0.7293 train_kl_div: 4.215
# val_rmse_target: 1.156 val_rmse_stderror: 2.416
# New best_val_rmse: 1.156
#
# 64 steps took 97.9 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8607 train_rmse_stderror: 0.3494 train_kl_div: 1.882
# val_rmse_target: 1.052 val_rmse_stderror: 2.05
# New best_val_rmse: 1.052
#
# 64 steps took 97.9 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 1.47 train_rmse_stderror: 0.17 train_kl_div: 3.711
# val_rmse_target: 1.007 val_rmse_stderror: 1.89
# New best_val_rmse: 1.007
#
# 64 steps took 98.0 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 1.06 train_rmse_stderror: 0.09398 train_kl_div: 2.397
# val_rmse_target: 0.9833 val_rmse_stderror: 1.795
# New best_val_rmse: 0.9833
#
# 64 steps took 98.0 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.7563 train_rmse_stderror: 0.06899 train_kl_div: 1.131
# val_rmse_target: 0.9524 val_rmse_stderror: 1.761
# New best_val_rmse: 0.9524
#
# 64 steps took 98.5 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 1.016 train_rmse_stderror: 0.07133 train_kl_div: 1.929
# val_rmse_target: 0.8395 val_rmse_stderror: 1.77
# New best_val_rmse: 0.8395
#
# 64 steps took 98.4 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.7286 train_rmse_stderror: 0.08068 train_kl_div: 1.121
# val_rmse_target: 0.6422 val_rmse_stderror: 1.794
# New best_val_rmse: 0.6422
#
# 64 steps took 98.3 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.9663 train_rmse_stderror: 0.02142 train_kl_div: 1.92
# val_rmse_target: 0.5979 val_rmse_stderror: 1.772
# New best_val_rmse: 0.5979
#
# 64 steps took 98.5 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.5171 train_rmse_stderror: 0.07185 train_kl_div: 0.5473
# val_rmse_target: 0.5708 val_rmse_stderror: 1.767
# New best_val_rmse: 0.5708
#
# 64 steps took 98.4 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.5647 train_rmse_stderror: 0.1374 train_kl_div: 0.6439
# val_rmse_target: 0.5638 val_rmse_stderror: 1.755
# New best_val_rmse: 0.5638
#
# 64 steps took 98.2 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.64 train_rmse_stderror: 0.1149 train_kl_div: 0.9037
# val_rmse_target: 0.5433 val_rmse_stderror: 1.768
# New best_val_rmse: 0.5433
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.5094 train_rmse_stderror: 0.06196 train_kl_div: 0.5503
# val_rmse_target: 0.6154 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.5433 (from epoch 2)
#
# 64 steps took 98.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.4352 train_rmse_stderror: 0.09298 train_kl_div: 0.4394
# val_rmse_target: 0.538 val_rmse_stderror: 1.774
# New best_val_rmse: 0.538
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.4505 train_rmse_stderror: 0.08635 train_kl_div: 0.4104
# val_rmse_target: 0.5517 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.538 (from epoch 2)
#
# 64 steps took 98.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.5763 train_rmse_stderror: 0.06694 train_kl_div: 0.657
# val_rmse_target: 0.5379 val_rmse_stderror: 1.757
# New best_val_rmse: 0.5379
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.4963 train_rmse_stderror: 0.04745 train_kl_div: 0.5094
# val_rmse_target: 0.5444 val_rmse_stderror: 1.752
# Still best_val_rmse: 0.5379 (from epoch 3)
#
# 32 steps took 49.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.5027 train_rmse_stderror: 0.09429 train_kl_div: 0.5423
# val_rmse_target: 0.5372 val_rmse_stderror: 1.756
# New best_val_rmse: 0.5372
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.4462 train_rmse_stderror: 0.08291 train_kl_div: 0.4862
# val_rmse_target: 0.5697 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5372 (from epoch 3)
#
# 64 steps took 98.0 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.3071 train_rmse_stderror: 0.06879 train_kl_div: 0.226
# val_rmse_target: 0.5308 val_rmse_stderror: 1.76
# New best_val_rmse: 0.5308
#
# 32 steps took 49.0 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1806 train_rmse_stderror: 0.0696 train_kl_div: 0.09226
# val_rmse_target: 0.5275 val_rmse_stderror: 1.768
# New best_val_rmse: 0.5275
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.4411 train_rmse_stderror: 0.1303 train_kl_div: 0.5423
# val_rmse_target: 0.5319 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.4219 train_rmse_stderror: 0.08428 train_kl_div: 0.3859
# val_rmse_target: 0.5465 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 48.8 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.2289 train_rmse_stderror: 0.08952 train_kl_div: 0.1381
# val_rmse_target: 0.5301 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.4528 train_rmse_stderror: 0.07882 train_kl_div: 0.454
# val_rmse_target: 0.5361 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.3695 train_rmse_stderror: 0.05685 train_kl_div: 0.3212
# val_rmse_target: 0.5378 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.3159 train_rmse_stderror: 0.07957 train_kl_div: 0.2285
# val_rmse_target: 0.5329 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.6329 train_rmse_stderror: 0.05686 train_kl_div: 0.8803
# val_rmse_target: 0.535 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.4532 train_rmse_stderror: 0.0616 train_kl_div: 0.3847
# val_rmse_target: 0.5345 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.5734 train_rmse_stderror: 0.07047 train_kl_div: 0.6132
# val_rmse_target: 0.5331 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.4418 train_rmse_stderror: 0.04941 train_kl_div: 0.4086
# val_rmse_target: 0.5327 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.5275 (from epoch 3)
#
# Performance estimates:
# [0.48084425361068045, 0.5274849842262184]
# Mean: 0.5041646189184494
# {'total_MiB': 15109, 'used_MiB': 1084}
#
# Fold 3/5
# {'total_MiB': 15109, 'used_MiB': 1084}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 99.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 1.323 train_rmse_stderror: 0.2172 train_kl_div: 3.314
# val_rmse_target: 0.7511 val_rmse_stderror: 1.722
# New best_val_rmse: 0.7511
#
# 64 steps took 98.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.8511 train_rmse_stderror: 0.09751 train_kl_div: 1.244
# val_rmse_target: 0.6734 val_rmse_stderror: 1.775
# New best_val_rmse: 0.6734
#
# 64 steps took 97.9 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.519 train_rmse_stderror: 0.07321 train_kl_div: 0.5388
# val_rmse_target: 0.6047 val_rmse_stderror: 1.735
# New best_val_rmse: 0.6047
#
# 64 steps took 98.1 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.7354 train_rmse_stderror: 0.06591 train_kl_div: 1.029
# val_rmse_target: 0.5657 val_rmse_stderror: 1.735
# New best_val_rmse: 0.5657
#
# 64 steps took 98.1 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.424 train_rmse_stderror: 0.04911 train_kl_div: 0.4033
# val_rmse_target: 0.5378 val_rmse_stderror: 1.728
# New best_val_rmse: 0.5378
#
# 32 steps took 49.2 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.3426 train_rmse_stderror: 0.06007 train_kl_div: 0.2572
# val_rmse_target: 0.5363 val_rmse_stderror: 1.771
# New best_val_rmse: 0.5363
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.6546 train_rmse_stderror: 0.07254 train_kl_div: 0.9633
# val_rmse_target: 0.5612 val_rmse_stderror: 1.737
# Still best_val_rmse: 0.5363 (from epoch 1)
#
# 64 steps took 97.9 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.5669 train_rmse_stderror: 0.05139 train_kl_div: 0.6471
# val_rmse_target: 0.513 val_rmse_stderror: 1.732
# New best_val_rmse: 0.513
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.3015 train_rmse_stderror: 0.05125 train_kl_div: 0.1931
# val_rmse_target: 0.5104 val_rmse_stderror: 1.727
# New best_val_rmse: 0.5104
#
# 32 steps took 49.4 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.5098 train_rmse_stderror: 0.05361 train_kl_div: 0.5643
# val_rmse_target: 0.5128 val_rmse_stderror: 1.765
# Still best_val_rmse: 0.5104 (from epoch 1)
#
# 32 steps took 48.9 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.3107 train_rmse_stderror: 0.06332 train_kl_div: 0.2051
# val_rmse_target: 0.5076 val_rmse_stderror: 1.732
# New best_val_rmse: 0.5076
#
# 32 steps took 49.6 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.1688 train_rmse_stderror: 0.03451 train_kl_div: 0.06662
# val_rmse_target: 0.518 val_rmse_stderror: 1.736
# Still best_val_rmse: 0.5076 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.1854 train_rmse_stderror: 0.05727 train_kl_div: 0.08626
# val_rmse_target: 0.5271 val_rmse_stderror: 1.753
# Still best_val_rmse: 0.5076 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.2061 train_rmse_stderror: 0.03154 train_kl_div: 0.1018
# val_rmse_target: 0.4909 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4909
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2348 train_rmse_stderror: 0.02895 train_kl_div: 0.1221
# val_rmse_target: 0.4873 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4873
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.3202 train_rmse_stderror: 0.04072 train_kl_div: 0.1888
# val_rmse_target: 0.4956 val_rmse_stderror: 1.732
# Still best_val_rmse: 0.4873 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.207 train_rmse_stderror: 0.05889 train_kl_div: 0.1183
# val_rmse_target: 0.4863 val_rmse_stderror: 1.755
# New best_val_rmse: 0.4863
#
# 32 steps took 49.3 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.3472 train_rmse_stderror: 0.03901 train_kl_div: 0.2675
# val_rmse_target: 0.4853 val_rmse_stderror: 1.757
# New best_val_rmse: 0.4853
#
# 32 steps took 49.5 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2162 train_rmse_stderror: 0.0445 train_kl_div: 0.1079
# val_rmse_target: 0.486 val_rmse_stderror: 1.749
# Still best_val_rmse: 0.4853 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.2633 train_rmse_stderror: 0.03442 train_kl_div: 0.1417
# val_rmse_target: 0.4908 val_rmse_stderror: 1.729
# Still best_val_rmse: 0.4853 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.3617 train_rmse_stderror: 0.04405 train_kl_div: 0.2353
# val_rmse_target: 0.4837 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4837
#
# 32 steps took 49.5 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.1613 train_rmse_stderror: 0.01653 train_kl_div: 0.05521
# val_rmse_target: 0.4867 val_rmse_stderror: 1.751
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1654 train_rmse_stderror: 0.02532 train_kl_div: 0.06137
# val_rmse_target: 0.4789 val_rmse_stderror: 1.748
# New best_val_rmse: 0.4789
#
# 32 steps took 49.5 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1398 train_rmse_stderror: 0.02629 train_kl_div: 0.04275
# val_rmse_target: 0.4772 val_rmse_stderror: 1.742
# New best_val_rmse: 0.4772
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1531 train_rmse_stderror: 0.03156 train_kl_div: 0.05973
# val_rmse_target: 0.4777 val_rmse_stderror: 1.742
# Still best_val_rmse: 0.4772 (from epoch 3)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.1508 train_rmse_stderror: 0.02628 train_kl_div: 0.0556
# val_rmse_target: 0.4806 val_rmse_stderror: 1.741
# Still best_val_rmse: 0.4772 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1521 train_rmse_stderror: 0.03264 train_kl_div: 0.05871
# val_rmse_target: 0.4807 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4772 (from epoch 3)
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.06591 train_rmse_stderror: 0.05286 train_kl_div: 0.01865
# val_rmse_target: 0.4762 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4762
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1986 train_rmse_stderror: 0.04152 train_kl_div: 0.07789
# val_rmse_target: 0.4795 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4762 (from epoch 3)
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.02929 train_rmse_stderror: 0.04103 train_kl_div: 0.00943
# val_rmse_target: 0.4771 val_rmse_stderror: 1.75
# Still best_val_rmse: 0.4762 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08132 train_rmse_stderror: 0.04932 train_kl_div: 0.02399
# val_rmse_target: 0.4762 val_rmse_stderror: 1.744
# New best_val_rmse: 0.4762
#
# 32 steps took 49.4 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.06304 train_rmse_stderror: 0.01904 train_kl_div: 0.008969
# val_rmse_target: 0.4759 val_rmse_stderror: 1.743
# New best_val_rmse: 0.4759
#
# 32 steps took 49.4 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.0956 train_rmse_stderror: 0.03243 train_kl_div: 0.02434
# val_rmse_target: 0.4776 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.06838 train_rmse_stderror: 0.03817 train_kl_div: 0.01611
# val_rmse_target: 0.4773 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.09735 train_rmse_stderror: 0.0248 train_kl_div: 0.02406
# val_rmse_target: 0.4775 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.09827 train_rmse_stderror: 0.0311 train_kl_div: 0.02513
# val_rmse_target: 0.4772 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.08924 train_rmse_stderror: 0.04126 train_kl_div: 0.02371
# val_rmse_target: 0.4771 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1217 train_rmse_stderror: 0.03702 train_kl_div: 0.0291
# val_rmse_target: 0.4771 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4759 (from epoch 4)
#
# Performance estimates:
# [0.48084425361068045, 0.5274849842262184, 0.4758684736979552]
# Mean: 0.49473257051161806
# {'total_MiB': 15109, 'used_MiB': 1084}
#
# Fold 4/5
# {'total_MiB': 15109, 'used_MiB': 1084}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 99.8 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.3572 train_rmse_stderror: 0.07466 train_kl_div: 0.2915
# val_rmse_target: 0.6568 val_rmse_stderror: 1.15
# New best_val_rmse: 0.6568
#
# 64 steps took 98.0 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7946 train_rmse_stderror: 0.06938 train_kl_div: 1.073
# val_rmse_target: 0.5706 val_rmse_stderror: 1.144
# New best_val_rmse: 0.5706
#
# 64 steps took 98.2 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.7116 train_rmse_stderror: 0.08522 train_kl_div: 0.8952
# val_rmse_target: 0.6664 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.5706 (from epoch 0)
#
# 64 steps took 97.9 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.63 train_rmse_stderror: 0.05957 train_kl_div: 0.8404
# val_rmse_target: 0.564 val_rmse_stderror: 1.145
# New best_val_rmse: 0.564
#
# 64 steps took 98.4 seconds
# Epoch: 1 batch_num: 37
# train_rmse_target: 0.5695 train_rmse_stderror: 0.03623 train_kl_div: 0.6715
# val_rmse_target: 0.5227 val_rmse_stderror: 1.149
# New best_val_rmse: 0.5227
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4564 train_rmse_stderror: 0.05241 train_kl_div: 0.3904
# val_rmse_target: 0.5306 val_rmse_stderror: 1.146
# Still best_val_rmse: 0.5227 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.5346 train_rmse_stderror: 0.02816 train_kl_div: 0.6026
# val_rmse_target: 0.5895 val_rmse_stderror: 1.151
# Still best_val_rmse: 0.5227 (from epoch 1)
#
# 64 steps took 97.9 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.4496 train_rmse_stderror: 0.0378 train_kl_div: 0.4316
# val_rmse_target: 0.5837 val_rmse_stderror: 1.162
# Still best_val_rmse: 0.5227 (from epoch 1)
#
# 64 steps took 98.3 seconds
# Epoch: 1 batch_num: 229
# train_rmse_target: 0.3785 train_rmse_stderror: 0.03842 train_kl_div: 0.3025
# val_rmse_target: 0.4937 val_rmse_stderror: 1.147
# New best_val_rmse: 0.4937
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.6531 train_rmse_stderror: 0.05179 train_kl_div: 0.97
# val_rmse_target: 0.4812 val_rmse_stderror: 1.161
# New best_val_rmse: 0.4812
#
# 32 steps took 49.5 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.4164 train_rmse_stderror: 0.03059 train_kl_div: 0.3287
# val_rmse_target: 0.5032 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.4812 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.3075 train_rmse_stderror: 0.05625 train_kl_div: 0.2098
# val_rmse_target: 0.4769 val_rmse_stderror: 1.159
# New best_val_rmse: 0.4769
#
# 32 steps took 49.3 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.4073 train_rmse_stderror: 0.05453 train_kl_div: 0.326
# val_rmse_target: 0.522 val_rmse_stderror: 1.16
# Still best_val_rmse: 0.4769 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.3017 train_rmse_stderror: 0.02542 train_kl_div: 0.2198
# val_rmse_target: 0.4756 val_rmse_stderror: 1.155
# New best_val_rmse: 0.4756
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.242 train_rmse_stderror: 0.04215 train_kl_div: 0.09472
# val_rmse_target: 0.4626 val_rmse_stderror: 1.133
# New best_val_rmse: 0.4626
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.406 train_rmse_stderror: 0.05505 train_kl_div: 0.3796
# val_rmse_target: 0.4694 val_rmse_stderror: 1.165
# Still best_val_rmse: 0.4626 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.1492 train_rmse_stderror: 0.04531 train_kl_div: 0.05768
# val_rmse_target: 0.499 val_rmse_stderror: 1.169
# Still best_val_rmse: 0.4626 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.3026 train_rmse_stderror: 0.03728 train_kl_div: 0.2095
# val_rmse_target: 0.46 val_rmse_stderror: 1.14
# New best_val_rmse: 0.46
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.1729 train_rmse_stderror: 0.05016 train_kl_div: 0.07694
# val_rmse_target: 0.4787 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.46 (from epoch 2)
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1375 train_rmse_stderror: 0.02861 train_kl_div: 0.04183
# val_rmse_target: 0.4672 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.46 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.2219 train_rmse_stderror: 0.06489 train_kl_div: 0.1309
# val_rmse_target: 0.4623 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.46 (from epoch 2)
#
# 32 steps took 49.0 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1522 train_rmse_stderror: 0.04077 train_kl_div: 0.0551
# val_rmse_target: 0.4568 val_rmse_stderror: 1.146
# New best_val_rmse: 0.4568
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.2545 train_rmse_stderror: 0.04846 train_kl_div: 0.1077
# val_rmse_target: 0.4537 val_rmse_stderror: 1.15
# New best_val_rmse: 0.4537
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1747 train_rmse_stderror: 0.02599 train_kl_div: 0.0654
# val_rmse_target: 0.4523 val_rmse_stderror: 1.165
# New best_val_rmse: 0.4523
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.2384 train_rmse_stderror: 0.03311 train_kl_div: 0.1333
# val_rmse_target: 0.4568 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4523 (from epoch 3)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.1738 train_rmse_stderror: 0.03132 train_kl_div: 0.06017
# val_rmse_target: 0.4515 val_rmse_stderror: 1.146
# New best_val_rmse: 0.4515
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.1667 train_rmse_stderror: 0.01887 train_kl_div: 0.05846
# val_rmse_target: 0.4535 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.4515 (from epoch 3)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.1408 train_rmse_stderror: 0.02906 train_kl_div: 0.04267
# val_rmse_target: 0.4538 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4515 (from epoch 3)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.129 train_rmse_stderror: 0.02619 train_kl_div: 0.03946
# val_rmse_target: 0.4548 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4515 (from epoch 3)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.1875 train_rmse_stderror: 0.04752 train_kl_div: 0.07
# val_rmse_target: 0.4552 val_rmse_stderror: 1.15
# Still best_val_rmse: 0.4515 (from epoch 3)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.0682 train_rmse_stderror: 0.01494 train_kl_div: 0.01028
# val_rmse_target: 0.4536 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4515 (from epoch 3)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1397 train_rmse_stderror: 0.03031 train_kl_div: 0.04998
# val_rmse_target: 0.4512 val_rmse_stderror: 1.151
# New best_val_rmse: 0.4512
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.1071 train_rmse_stderror: 0.02908 train_kl_div: 0.02759
# val_rmse_target: 0.454 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4512 (from epoch 4)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1606 train_rmse_stderror: 0.04118 train_kl_div: 0.04715
# val_rmse_target: 0.4547 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.4512 (from epoch 4)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.1578 train_rmse_stderror: 0.03079 train_kl_div: 0.05423
# val_rmse_target: 0.4538 val_rmse_stderror: 1.151
# Still best_val_rmse: 0.4512 (from epoch 4)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.1355 train_rmse_stderror: 0.02399 train_kl_div: 0.0424
# val_rmse_target: 0.4535 val_rmse_stderror: 1.151
# Still best_val_rmse: 0.4512 (from epoch 4)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.1198 train_rmse_stderror: 0.04921 train_kl_div: 0.04353
# val_rmse_target: 0.4533 val_rmse_stderror: 1.151
# Still best_val_rmse: 0.4512 (from epoch 4)
#
# Performance estimates:
# [0.48084425361068045, 0.5274849842262184, 0.4758684736979552, 0.451210375815147]
# Mean: 0.4838520218375003
# {'total_MiB': 15109, 'used_MiB': 1084}
#
# Fold 5/5
# {'total_MiB': 15109, 'used_MiB': 1084}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 1e+02 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6061 train_rmse_stderror: 0.05999 train_kl_div: 0.7301
# val_rmse_target: 0.9168 val_rmse_stderror: 1.107
# New best_val_rmse: 0.9168
#
# 64 steps took 98.3 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7956 train_rmse_stderror: 0.06177 train_kl_div: 1.154
# val_rmse_target: 0.6467 val_rmse_stderror: 1.112
# New best_val_rmse: 0.6467
#
# 64 steps took 98.4 seconds
# Epoch: 0 batch_num: 192
# train_rmse_target: 0.2837 train_rmse_stderror: 0.05847 train_kl_div: 0.188
# val_rmse_target: 0.5487 val_rmse_stderror: 1.103
# New best_val_rmse: 0.5487
#
# 32 steps took 49.4 seconds
# Epoch: 0 batch_num: 224
# train_rmse_target: 0.391 train_rmse_stderror: 0.07577 train_kl_div: 0.3439
# val_rmse_target: 0.5389 val_rmse_stderror: 1.123
# New best_val_rmse: 0.5389
#
# 32 steps took 49.5 seconds
# Epoch: 0 batch_num: 256
# train_rmse_target: 0.5907 train_rmse_stderror: 0.05368 train_kl_div: 0.6187
# val_rmse_target: 0.5358 val_rmse_stderror: 1.092
# New best_val_rmse: 0.5358
#
# 32 steps took 49.7 seconds
# Epoch: 1 batch_num: 5
# train_rmse_target: 0.3225 train_rmse_stderror: 0.0551 train_kl_div: 0.2273
# val_rmse_target: 0.5608 val_rmse_stderror: 1.085
# Still best_val_rmse: 0.5358 (from epoch 0)
#
# 64 steps took 98.0 seconds
# Epoch: 1 batch_num: 69
# train_rmse_target: 0.4849 train_rmse_stderror: 0.09423 train_kl_div: 0.4452
# val_rmse_target: 0.5386 val_rmse_stderror: 1.089
# Still best_val_rmse: 0.5358 (from epoch 0)
#
# 32 steps took 49.0 seconds
# Epoch: 1 batch_num: 101
# train_rmse_target: 0.2362 train_rmse_stderror: 0.07229 train_kl_div: 0.1319
# val_rmse_target: 0.5326 val_rmse_stderror: 1.1
# New best_val_rmse: 0.5326
#
# 32 steps took 49.4 seconds
# Epoch: 1 batch_num: 133
# train_rmse_target: 0.4344 train_rmse_stderror: 0.07031 train_kl_div: 0.4113
# val_rmse_target: 0.5471 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.5326 (from epoch 1)
#
# 32 steps took 49.3 seconds
# Epoch: 1 batch_num: 165
# train_rmse_target: 0.3357 train_rmse_stderror: 0.07052 train_kl_div: 0.2512
# val_rmse_target: 0.5289 val_rmse_stderror: 1.101
# New best_val_rmse: 0.5289
#
# 32 steps took 49.4 seconds
# Epoch: 1 batch_num: 197
# train_rmse_target: 0.3868 train_rmse_stderror: 0.047 train_kl_div: 0.3345
# val_rmse_target: 0.6357 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.5289 (from epoch 1)
#
# 64 steps took 98.2 seconds
# Epoch: 1 batch_num: 261
# train_rmse_target: 0.3327 train_rmse_stderror: 0.04157 train_kl_div: 0.2247
# val_rmse_target: 0.5444 val_rmse_stderror: 1.08
# Still best_val_rmse: 0.5289 (from epoch 1)
#
# 32 steps took 49.4 seconds
# Epoch: 2 batch_num: 10
# train_rmse_target: 0.2229 train_rmse_stderror: 0.04092 train_kl_div: 0.1118
# val_rmse_target: 0.5316 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.5289 (from epoch 1)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 42
# train_rmse_target: 0.324 train_rmse_stderror: 0.03931 train_kl_div: 0.1883
# val_rmse_target: 0.4893 val_rmse_stderror: 1.107
# New best_val_rmse: 0.4893
#
# 32 steps took 49.5 seconds
# Epoch: 2 batch_num: 74
# train_rmse_target: 0.1912 train_rmse_stderror: 0.07284 train_kl_div: 0.09166
# val_rmse_target: 0.4902 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 106
# train_rmse_target: 0.2668 train_rmse_stderror: 0.05066 train_kl_div: 0.1557
# val_rmse_target: 0.4994 val_rmse_stderror: 1.092
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.0 seconds
# Epoch: 2 batch_num: 138
# train_rmse_target: 0.1807 train_rmse_stderror: 0.03015 train_kl_div: 0.07603
# val_rmse_target: 0.5066 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 170
# train_rmse_target: 0.2111 train_rmse_stderror: 0.05326 train_kl_div: 0.1092
# val_rmse_target: 0.4917 val_rmse_stderror: 1.097
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 2 batch_num: 202
# train_rmse_target: 0.4179 train_rmse_stderror: 0.08689 train_kl_div: 0.2779
# val_rmse_target: 0.5073 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 48.9 seconds
# Epoch: 2 batch_num: 234
# train_rmse_target: 0.2936 train_rmse_stderror: 0.05036 train_kl_div: 0.2142
# val_rmse_target: 0.4961 val_rmse_stderror: 1.118
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 2 batch_num: 266
# train_rmse_target: 0.256 train_rmse_stderror: 0.03523 train_kl_div: 0.1215
# val_rmse_target: 0.4958 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.4 seconds
# Epoch: 3 batch_num: 15
# train_rmse_target: 0.1157 train_rmse_stderror: 0.03552 train_kl_div: 0.03563
# val_rmse_target: 0.4971 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.3 seconds
# Epoch: 3 batch_num: 47
# train_rmse_target: 0.08677 train_rmse_stderror: 0.02958 train_kl_div: 0.01765
# val_rmse_target: 0.4929 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 79
# train_rmse_target: 0.1298 train_rmse_stderror: 0.03152 train_kl_div: 0.03799
# val_rmse_target: 0.4951 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.0 seconds
# Epoch: 3 batch_num: 111
# train_rmse_target: 0.1113 train_rmse_stderror: 0.0307 train_kl_div: 0.02975
# val_rmse_target: 0.5024 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 143
# train_rmse_target: 0.1084 train_rmse_stderror: 0.03207 train_kl_div: 0.03085
# val_rmse_target: 0.4918 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 3 batch_num: 175
# train_rmse_target: 0.113 train_rmse_stderror: 0.02642 train_kl_div: 0.03032
# val_rmse_target: 0.4919 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 207
# train_rmse_target: 0.0547 train_rmse_stderror: 0.0327 train_kl_div: 0.009487
# val_rmse_target: 0.4932 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 239
# train_rmse_target: 0.132 train_rmse_stderror: 0.02248 train_kl_div: 0.04112
# val_rmse_target: 0.4932 val_rmse_stderror: 1.109
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.2 seconds
# Epoch: 3 batch_num: 271
# train_rmse_target: 0.2836 train_rmse_stderror: 0.03732 train_kl_div: 0.1301
# val_rmse_target: 0.4938 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.4 seconds
# Epoch: 4 batch_num: 20
# train_rmse_target: 0.05215 train_rmse_stderror: 0.03922 train_kl_div: 0.01168
# val_rmse_target: 0.4921 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 52
# train_rmse_target: 0.08147 train_rmse_stderror: 0.03365 train_kl_div: 0.01677
# val_rmse_target: 0.4906 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.4893 (from epoch 2)
#
# 32 steps took 48.8 seconds
# Epoch: 4 batch_num: 84
# train_rmse_target: 0.07951 train_rmse_stderror: 0.02314 train_kl_div: 0.01379
# val_rmse_target: 0.489 val_rmse_stderror: 1.108
# New best_val_rmse: 0.489
#
# 32 steps took 49.3 seconds
# Epoch: 4 batch_num: 116
# train_rmse_target: 0.1868 train_rmse_stderror: 0.04404 train_kl_div: 0.07269
# val_rmse_target: 0.4925 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.489 (from epoch 4)
#
# 32 steps took 49.2 seconds
# Epoch: 4 batch_num: 148
# train_rmse_target: 0.0559 train_rmse_stderror: 0.05476 train_kl_div: 0.01906
# val_rmse_target: 0.4899 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.489 (from epoch 4)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 180
# train_rmse_target: 0.1067 train_rmse_stderror: 0.05115 train_kl_div: 0.03523
# val_rmse_target: 0.4895 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.489 (from epoch 4)
#
# 32 steps took 48.9 seconds
# Epoch: 4 batch_num: 212
# train_rmse_target: 0.08539 train_rmse_stderror: 0.02732 train_kl_div: 0.0191
# val_rmse_target: 0.4898 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.489 (from epoch 4)
#
# 32 steps took 49.1 seconds
# Epoch: 4 batch_num: 244
# train_rmse_target: 0.07885 train_rmse_stderror: 0.01798 train_kl_div: 0.0126
# val_rmse_target: 0.4903 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.489 (from epoch 4)
#
# 32 steps took 49.0 seconds
# Epoch: 4 batch_num: 276
# train_rmse_target: 0.08751 train_rmse_stderror: 0.02069 train_kl_div: 0.0194
# val_rmse_target: 0.4904 val_rmse_stderror: 1.106
# Still best_val_rmse: 0.489 (from epoch 4)
#
# Performance estimates:
# [0.48084425361068045, 0.5274849842262184, 0.4758684736979552, 0.451210375815147, 0.48904999116522924]
# Mean: 0.48489161570304606
# {'total_MiB': 15109, 'used_MiB': 1084}

# %%
print(list_val_rmse)
# Out:
# [0.48084425361068045, 0.5274849842262184, 0.4758684736979552, 0.451210375815147, 0.48904999116522924]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# !cp -r /content/TFIDF_1.pkl /content/model/TFIDF_1.pkl
# !cp -r /content/TFIDF_2.pkl /content/model/TFIDF_2.pkl
# !cp -r /content/TFIDF_3.pkl /content/model/TFIDF_3.pkl
# !cp -r /content/TFIDF_4.pkl /content/model/TFIDF_4.pkl
# !cp -r /content/TFIDF_5.pkl /content/model/TFIDF_5.pkl
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}-02'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
