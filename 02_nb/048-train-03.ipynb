# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5' '/content/clrp-roberta-large'
  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/
"""
# Out:
# '\n%cd\n!mkdir .kaggle\n!mkdir /content/model\n!cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/\n'

# %%
"""
# !mkdir /content/pre-trained-roberta
# !kaggle datasets download -p /content/pre-trained-roberta clrprobertalarge --unzip
# !cp -r /content/pre-trained-roberta/ /content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5
"""
# Out:
# '\n!mkdir /content/pre-trained-roberta\n!kaggle datasets download -p /content/pre-trained-roberta clrprobertalarge --unzip\n!cp -r /content/pre-trained-roberta/ /content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5\n'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '048-train-02'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 128), (0.50, 64), (0.49, 32), (-1., 16)] # モデルを保存する間隔
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# 前処理用
import string
import re
# ローカルの場合、stopwordsをダウンロード
import nltk
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    pass
else:
    import nltk
    nltk.download('stopwords')
    nltk.download('averaged_perceptron_tagger')
    os.listdir(os.path.expanduser('~/nltk_data/corpora/stopwords/'))

# テキスト前処理
# https://www.kaggle.com/alaasedeeq/commonlit-readability-eda

#filtering the unwanted symbols, spaces, ....etc
to_replace_by_space = re.compile('[/(){}\[\]|@,;]')
punctuation = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
bad_symbols = re.compile('[^0-9a-z #+_]')
stopwords = set(nltk.corpus.stopwords.words('english'))

def text_prepare(text):
    '''
    text: a string
    returna modified version of the string
    '''
    text = text.lower() # lowercase text
    text = re.sub(punctuation, '',text)
    text = re.sub(to_replace_by_space, " ", text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = re.sub(bad_symbols, "", text)         # delete symbols which are in BAD_SYMBOLS_RE from text
    text = " ".join([word for word in text.split(" ") if word not in stopwords]) # delete stopwords from text
    text = re.sub(' +', ' ', text)
    return text

def text_normalization(s:pd.Series):
    x = s.apply(text_prepare)
    return x

# Counterオブジェクトを取得
def get_counter(text:str):
    text_list = [wrd for wrd in text.split(" ") if wrd not in ('', '\n')]
    counter = collections.Counter(text_list)
    return counter
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        self.text_len = text_normalization(df.excerpt).map(lambda x: [0 if i >= len(x.split(' ')) else len(x.split(' ')[i]) for i in range(132)])

        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        input_len = torch.tensor(self.text_len.iloc[index], dtype=torch.float32)

        if self.inference_only:
            return (input_ids, attention_mask, input_len)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, input_len, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.mlm_layers = nn.Sequential(
            nn.Linear(132, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size + 64, 2)                        
        )

    def forward(self, input_ids, attention_mask, input_len):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        # attention_pooling
        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。

        # word_length_conv1d
        #input_chnl = input_len.unsqueeze(1)
        #conv1_layers = self.conv1_layers(input_chnl)
        #conv1_layers_v = conv1_layers.view(conv1_layers.size(0),-1)

        # word_length_mlm
        mlm_layers = self.mlm_layers(input_len)

        # concat_embeddings
        cat_embeddings = torch.cat([context_vector, mlm_layers], dim=1)
        
        return self.regressor(cat_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)  
            input_len = input_len.to(DEVICE) 
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask, input_len) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask, input_len) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
            input_len = input_len.to(DEVICE)
                        
            output = model(input_ids, attention_mask, input_len) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, input_len, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)   
            input_len = input_len.to(DEVICE)
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask, input_len) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    #conv1d_parameters = list(model.conv1_layers.named_parameters())
    mlm_parameters = list(model.mlm_layers.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    #conv1d_group = [params for (name, params) in conv1d_parameters]
    mlm_group = [params for (name, params) in mlm_parameters]
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    #parameters.append({"params": conv1d_group})
    parameters.append({"params": mlm_group})
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

#kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16160, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 128 steps took 98.5 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6409 train_rmse_stderror: 0.09641 train_kl_div: 0.8349
# val_rmse_target: 0.6333 val_rmse_stderror: 1.166
# New best_val_rmse: 0.6333
#
# 128 steps took 1.02e+02 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.299 train_rmse_stderror: 0.05038 train_kl_div: 0.2023
# val_rmse_target: 0.5588 val_rmse_stderror: 1.151
# New best_val_rmse: 0.5588
#
# 128 steps took 97.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2336 train_rmse_stderror: 0.03652 train_kl_div: 0.1142
# val_rmse_target: 0.5079 val_rmse_stderror: 1.145
# New best_val_rmse: 0.5079
#
# 64 steps took 48.8 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3272 train_rmse_stderror: 0.05185 train_kl_div: 0.1713
# val_rmse_target: 0.4896 val_rmse_stderror: 1.155
# New best_val_rmse: 0.4896
#
# 16 steps took 12.2 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.2748 train_rmse_stderror: 0.03317 train_kl_div: 0.1743
# val_rmse_target: 0.5082 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.4896 (from epoch 2)
#
# 64 steps took 48.8 seconds
# Epoch: 2 batch_num: 152
# train_rmse_target: 0.2099 train_rmse_stderror: 0.02944 train_kl_div: 0.1026
# val_rmse_target: 0.4952 val_rmse_stderror: 1.158
# Still best_val_rmse: 0.4896 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 184
# train_rmse_target: 0.2819 train_rmse_stderror: 0.02734 train_kl_div: 0.1479
# val_rmse_target: 0.4811 val_rmse_stderror: 1.152
# New best_val_rmse: 0.4811
#
# 16 steps took 12.5 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1643 train_rmse_stderror: 0.02252 train_kl_div: 0.04792
# val_rmse_target: 0.4923 val_rmse_stderror: 1.152
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2121 train_rmse_stderror: 0.02472 train_kl_div: 0.08609
# val_rmse_target: 0.4848 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4811 (from epoch 2)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 60
# train_rmse_target: 0.1319 train_rmse_stderror: 0.02607 train_kl_div: 0.04099
# val_rmse_target: 0.4808 val_rmse_stderror: 1.155
# New best_val_rmse: 0.4808
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2056 train_rmse_stderror: 0.02468 train_kl_div: 0.08125
# val_rmse_target: 0.4804 val_rmse_stderror: 1.151
# New best_val_rmse: 0.4804
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 92
# train_rmse_target: 0.0935 train_rmse_stderror: 0.02817 train_kl_div: 0.0213
# val_rmse_target: 0.479 val_rmse_stderror: 1.153
# New best_val_rmse: 0.479
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1105 train_rmse_stderror: 0.0215 train_kl_div: 0.02798
# val_rmse_target: 0.4827 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.479 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 124
# train_rmse_target: 0.09435 train_rmse_stderror: 0.03073 train_kl_div: 0.02319
# val_rmse_target: 0.4845 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.479 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.09725 train_rmse_stderror: 0.03067 train_kl_div: 0.02417
# val_rmse_target: 0.4844 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.479 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 156
# train_rmse_target: 0.122 train_rmse_stderror: 0.03028 train_kl_div: 0.03817
# val_rmse_target: 0.4773 val_rmse_stderror: 1.157
# New best_val_rmse: 0.4773
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.119 train_rmse_stderror: 0.03648 train_kl_div: 0.03343
# val_rmse_target: 0.4919 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 32 steps took 24.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.08567 train_rmse_stderror: 0.02926 train_kl_div: 0.01903
# val_rmse_target: 0.4842 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.05877 train_rmse_stderror: 0.03081 train_kl_div: 0.009857
# val_rmse_target: 0.4841 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.134 train_rmse_stderror: 0.04144 train_kl_div: 0.0387
# val_rmse_target: 0.4828 val_rmse_stderror: 1.153
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.09779 train_rmse_stderror: 0.02411 train_kl_div: 0.02018
# val_rmse_target: 0.4821 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.05919 train_rmse_stderror: 0.02111 train_kl_div: 0.007751
# val_rmse_target: 0.4812 val_rmse_stderror: 1.157
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 96
# train_rmse_target: 0.08278 train_rmse_stderror: 0.02348 train_kl_div: 0.01607
# val_rmse_target: 0.4838 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.07156 train_rmse_stderror: 0.02572 train_kl_div: 0.01397
# val_rmse_target: 0.4812 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 128
# train_rmse_target: 0.06285 train_rmse_stderror: 0.02528 train_kl_div: 0.01073
# val_rmse_target: 0.4823 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08715 train_rmse_stderror: 0.03425 train_kl_div: 0.01997
# val_rmse_target: 0.4816 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 160
# train_rmse_target: 0.1254 train_rmse_stderror: 0.02731 train_kl_div: 0.0324
# val_rmse_target: 0.4814 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1266 train_rmse_stderror: 0.03524 train_kl_div: 0.03215
# val_rmse_target: 0.4813 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4773 (from epoch 3)
#
# Performance estimates:
# [0.4772503911166425]
# Mean: 0.4772503911166425
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 2/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 128 steps took 99.5 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.6898 train_rmse_stderror: 0.029 train_kl_div: 1.003
# val_rmse_target: 0.5957 val_rmse_stderror: 1.781
# New best_val_rmse: 0.5957
#
# 128 steps took 98.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.2121 train_rmse_stderror: 0.02602 train_kl_div: 0.09666
# val_rmse_target: 0.5076 val_rmse_stderror: 1.778
# New best_val_rmse: 0.5076
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5076 train_rmse_stderror: 0.04637 train_kl_div: 0.5581
# val_rmse_target: 0.5059 val_rmse_stderror: 1.793
# New best_val_rmse: 0.5059
#
# 64 steps took 49.1 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2519 train_rmse_stderror: 0.02355 train_kl_div: 0.148
# val_rmse_target: 0.4841 val_rmse_stderror: 1.787
# New best_val_rmse: 0.4841
#
# 16 steps took 12.2 seconds
# Epoch: 2 batch_num: 24
# train_rmse_target: 0.3336 train_rmse_stderror: 0.03565 train_kl_div: 0.1856
# val_rmse_target: 0.5193 val_rmse_stderror: 1.775
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 64 steps took 48.9 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.2872 train_rmse_stderror: 0.02545 train_kl_div: 0.1752
# val_rmse_target: 0.4889 val_rmse_stderror: 1.782
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 16 steps took 12.2 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.1978 train_rmse_stderror: 0.03133 train_kl_div: 0.08768
# val_rmse_target: 0.486 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 16 steps took 12.2 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.3308 train_rmse_stderror: 0.0269 train_kl_div: 0.2444
# val_rmse_target: 0.4914 val_rmse_stderror: 1.786
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 32 steps took 24.5 seconds
# Epoch: 2 batch_num: 152
# train_rmse_target: 0.3408 train_rmse_stderror: 0.02768 train_kl_div: 0.2495
# val_rmse_target: 0.5042 val_rmse_stderror: 1.757
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 64 steps took 49.1 seconds
# Epoch: 3 batch_num: 28
# train_rmse_target: 0.1372 train_rmse_stderror: 0.02084 train_kl_div: 0.04497
# val_rmse_target: 0.4854 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4841 (from epoch 2)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1514 train_rmse_stderror: 0.02388 train_kl_div: 0.04523
# val_rmse_target: 0.4826 val_rmse_stderror: 1.774
# New best_val_rmse: 0.4826
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 60
# train_rmse_target: 0.1335 train_rmse_stderror: 0.02192 train_kl_div: 0.04207
# val_rmse_target: 0.4759 val_rmse_stderror: 1.768
# New best_val_rmse: 0.4759
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1467 train_rmse_stderror: 0.02691 train_kl_div: 0.03955
# val_rmse_target: 0.4884 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4759 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 92
# train_rmse_target: 0.1082 train_rmse_stderror: 0.02277 train_kl_div: 0.02531
# val_rmse_target: 0.4786 val_rmse_stderror: 1.779
# Still best_val_rmse: 0.4759 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1773 train_rmse_stderror: 0.02641 train_kl_div: 0.07224
# val_rmse_target: 0.4713 val_rmse_stderror: 1.782
# New best_val_rmse: 0.4713
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 124
# train_rmse_target: 0.1726 train_rmse_stderror: 0.02521 train_kl_div: 0.05829
# val_rmse_target: 0.4763 val_rmse_stderror: 1.769
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1403 train_rmse_stderror: 0.02244 train_kl_div: 0.04534
# val_rmse_target: 0.4858 val_rmse_stderror: 1.766
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 156
# train_rmse_target: 0.1135 train_rmse_stderror: 0.02024 train_kl_div: 0.02822
# val_rmse_target: 0.4792 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1195 train_rmse_stderror: 0.02145 train_kl_div: 0.0336
# val_rmse_target: 0.4752 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.5 seconds
# Epoch: 4 batch_num: 0
# train_rmse_target: 0.0676 train_rmse_stderror: 0.01971 train_kl_div: 0.01135
# val_rmse_target: 0.4762 val_rmse_stderror: 1.774
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09386 train_rmse_stderror: 0.01938 train_kl_div: 0.02162
# val_rmse_target: 0.4803 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.07067 train_rmse_stderror: 0.02209 train_kl_div: 0.01313
# val_rmse_target: 0.4814 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.09228 train_rmse_stderror: 0.02343 train_kl_div: 0.01969
# val_rmse_target: 0.4798 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.1624 train_rmse_stderror: 0.01527 train_kl_div: 0.04615
# val_rmse_target: 0.4771 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1035 train_rmse_stderror: 0.02452 train_kl_div: 0.02498
# val_rmse_target: 0.4773 val_rmse_stderror: 1.77
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 96
# train_rmse_target: 0.09715 train_rmse_stderror: 0.02638 train_kl_div: 0.02396
# val_rmse_target: 0.478 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1092 train_rmse_stderror: 0.02635 train_kl_div: 0.02823
# val_rmse_target: 0.4777 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 128
# train_rmse_target: 0.08818 train_rmse_stderror: 0.02521 train_kl_div: 0.01494
# val_rmse_target: 0.4794 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.07421 train_rmse_stderror: 0.01818 train_kl_div: 0.01319
# val_rmse_target: 0.4793 val_rmse_stderror: 1.773
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 160
# train_rmse_target: 0.08134 train_rmse_stderror: 0.01776 train_kl_div: 0.01545
# val_rmse_target: 0.4788 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1275 train_rmse_stderror: 0.02787 train_kl_div: 0.03408
# val_rmse_target: 0.4786 val_rmse_stderror: 1.772
# Still best_val_rmse: 0.4713 (from epoch 3)
#
# Performance estimates:
# [0.4772503911166425, 0.47130432412902085]
# Mean: 0.4742773576228317
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 3/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 128 steps took 99.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5615 train_rmse_stderror: 0.0516 train_kl_div: 0.5912
# val_rmse_target: 0.5961 val_rmse_stderror: 1.115
# New best_val_rmse: 0.5961
#
# 128 steps took 98.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.412 train_rmse_stderror: 0.03088 train_kl_div: 0.3609
# val_rmse_target: 0.5336 val_rmse_stderror: 1.106
# New best_val_rmse: 0.5336
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4331 train_rmse_stderror: 0.03186 train_kl_div: 0.3896
# val_rmse_target: 0.5337 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.5336 (from epoch 1)
#
# 64 steps took 49.2 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2902 train_rmse_stderror: 0.04203 train_kl_div: 0.1792
# val_rmse_target: 0.4874 val_rmse_stderror: 1.094
# New best_val_rmse: 0.4874
#
# 16 steps took 12.2 seconds
# Epoch: 2 batch_num: 24
# train_rmse_target: 0.3192 train_rmse_stderror: 0.02869 train_kl_div: 0.2216
# val_rmse_target: 0.5001 val_rmse_stderror: 1.088
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 64 steps took 48.9 seconds
# Epoch: 2 batch_num: 88
# train_rmse_target: 0.3012 train_rmse_stderror: 0.03829 train_kl_div: 0.182
# val_rmse_target: 0.491 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 24.5 seconds
# Epoch: 2 batch_num: 120
# train_rmse_target: 0.2848 train_rmse_stderror: 0.02518 train_kl_div: 0.1771
# val_rmse_target: 0.4915 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 24.4 seconds
# Epoch: 2 batch_num: 152
# train_rmse_target: 0.3909 train_rmse_stderror: 0.0394 train_kl_div: 0.2519
# val_rmse_target: 0.5174 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 64 steps took 49.2 seconds
# Epoch: 3 batch_num: 28
# train_rmse_target: 0.1439 train_rmse_stderror: 0.02314 train_kl_div: 0.0456
# val_rmse_target: 0.4886 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.3379 train_rmse_stderror: 0.02702 train_kl_div: 0.2062
# val_rmse_target: 0.486 val_rmse_stderror: 1.109
# New best_val_rmse: 0.486
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 60
# train_rmse_target: 0.1179 train_rmse_stderror: 0.02475 train_kl_div: 0.03029
# val_rmse_target: 0.4936 val_rmse_stderror: 1.108
# Still best_val_rmse: 0.486 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 92
# train_rmse_target: 0.1723 train_rmse_stderror: 0.01587 train_kl_div: 0.06099
# val_rmse_target: 0.4866 val_rmse_stderror: 1.105
# Still best_val_rmse: 0.486 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2003 train_rmse_stderror: 0.03201 train_kl_div: 0.08341
# val_rmse_target: 0.4924 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.486 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1243 train_rmse_stderror: 0.02391 train_kl_div: 0.03529
# val_rmse_target: 0.4824 val_rmse_stderror: 1.097
# New best_val_rmse: 0.4824
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 156
# train_rmse_target: 0.2196 train_rmse_stderror: 0.0424 train_kl_div: 0.08013
# val_rmse_target: 0.4849 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2149 train_rmse_stderror: 0.0217 train_kl_div: 0.09397
# val_rmse_target: 0.494 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 32 steps took 24.7 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1956 train_rmse_stderror: 0.01684 train_kl_div: 0.07719
# val_rmse_target: 0.489 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 32
# train_rmse_target: 0.1852 train_rmse_stderror: 0.03705 train_kl_div: 0.05954
# val_rmse_target: 0.4891 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1038 train_rmse_stderror: 0.01729 train_kl_div: 0.02364
# val_rmse_target: 0.4882 val_rmse_stderror: 1.1
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 64
# train_rmse_target: 0.1415 train_rmse_stderror: 0.0287 train_kl_div: 0.03566
# val_rmse_target: 0.486 val_rmse_stderror: 1.099
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1202 train_rmse_stderror: 0.01895 train_kl_div: 0.02899
# val_rmse_target: 0.4883 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 96
# train_rmse_target: 0.1376 train_rmse_stderror: 0.02779 train_kl_div: 0.04285
# val_rmse_target: 0.4868 val_rmse_stderror: 1.104
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1626 train_rmse_stderror: 0.02407 train_kl_div: 0.05467
# val_rmse_target: 0.4848 val_rmse_stderror: 1.102
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 128
# train_rmse_target: 0.09983 train_rmse_stderror: 0.0183 train_kl_div: 0.02222
# val_rmse_target: 0.4842 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.13 train_rmse_stderror: 0.01047 train_kl_div: 0.03404
# val_rmse_target: 0.4852 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 160
# train_rmse_target: 0.1418 train_rmse_stderror: 0.01731 train_kl_div: 0.04017
# val_rmse_target: 0.4853 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# 16 steps took 12.2 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1539 train_rmse_stderror: 0.01943 train_kl_div: 0.04785
# val_rmse_target: 0.4853 val_rmse_stderror: 1.101
# Still best_val_rmse: 0.4824 (from epoch 3)
#
# Performance estimates:
# [0.4772503911166425, 0.47130432412902085, 0.482375541726991]
# Mean: 0.4769767523242181
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 4/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 128 steps took 99.6 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.7886 train_rmse_stderror: 0.06303 train_kl_div: 1.328
# val_rmse_target: 0.7147 val_rmse_stderror: 1.129
# New best_val_rmse: 0.7147
#
# 128 steps took 98.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5575 train_rmse_stderror: 0.03307 train_kl_div: 0.5958
# val_rmse_target: 0.5406 val_rmse_stderror: 1.138
# New best_val_rmse: 0.5406
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4274 train_rmse_stderror: 0.05347 train_kl_div: 0.3621
# val_rmse_target: 0.5113 val_rmse_stderror: 1.139
# New best_val_rmse: 0.5113
#
# 64 steps took 49.2 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3602 train_rmse_stderror: 0.0375 train_kl_div: 0.274
# val_rmse_target: 0.5816 val_rmse_stderror: 1.12
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 128 steps took 97.9 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.5988 train_rmse_stderror: 0.04469 train_kl_div: 0.5738
# val_rmse_target: 0.5208 val_rmse_stderror: 1.131
# Still best_val_rmse: 0.5113 (from epoch 1)
#
# 64 steps took 49.3 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1903 train_rmse_stderror: 0.0281 train_kl_div: 0.06779
# val_rmse_target: 0.4915 val_rmse_stderror: 1.135
# New best_val_rmse: 0.4915
#
# 32 steps took 24.5 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.2613 train_rmse_stderror: 0.0394 train_kl_div: 0.1312
# val_rmse_target: 0.4905 val_rmse_stderror: 1.136
# New best_val_rmse: 0.4905
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.2323 train_rmse_stderror: 0.03326 train_kl_div: 0.1164
# val_rmse_target: 0.4902 val_rmse_stderror: 1.131
# New best_val_rmse: 0.4902
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1994 train_rmse_stderror: 0.03417 train_kl_div: 0.08072
# val_rmse_target: 0.5032 val_rmse_stderror: 1.142
# Still best_val_rmse: 0.4902 (from epoch 3)
#
# 64 steps took 48.9 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1591 train_rmse_stderror: 0.03043 train_kl_div: 0.05542
# val_rmse_target: 0.5018 val_rmse_stderror: 1.138
# Still best_val_rmse: 0.4902 (from epoch 3)
#
# 64 steps took 49.2 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1161 train_rmse_stderror: 0.01796 train_kl_div: 0.02813
# val_rmse_target: 0.4914 val_rmse_stderror: 1.135
# Still best_val_rmse: 0.4902 (from epoch 3)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1018 train_rmse_stderror: 0.02708 train_kl_div: 0.02649
# val_rmse_target: 0.4901 val_rmse_stderror: 1.134
# New best_val_rmse: 0.4901
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1421 train_rmse_stderror: 0.03563 train_kl_div: 0.04903
# val_rmse_target: 0.4913 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.4901 (from epoch 4)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1255 train_rmse_stderror: 0.02493 train_kl_div: 0.0328
# val_rmse_target: 0.4915 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.4901 (from epoch 4)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.173 train_rmse_stderror: 0.03546 train_kl_div: 0.07086
# val_rmse_target: 0.4922 val_rmse_stderror: 1.134
# Still best_val_rmse: 0.4901 (from epoch 4)
#
# Performance estimates:
# [0.4772503911166425, 0.47130432412902085, 0.482375541726991, 0.4900878315166627]
# Mean: 0.4802545221223292
# {'total_MiB': 16160, 'used_MiB': 1359}
#
# Fold 5/5
# {'total_MiB': 16160, 'used_MiB': 1359}
# Some weights of the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-roberta-large/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 128 steps took 99.7 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5703 train_rmse_stderror: 0.04472 train_kl_div: 0.7056
# val_rmse_target: 0.6133 val_rmse_stderror: 1.151
# New best_val_rmse: 0.6133
#
# 128 steps took 98.1 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.388 train_rmse_stderror: 0.01811 train_kl_div: 0.3169
# val_rmse_target: 0.5386 val_rmse_stderror: 1.154
# New best_val_rmse: 0.5386
#
# 64 steps took 48.9 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.5814 train_rmse_stderror: 0.04834 train_kl_div: 0.5462
# val_rmse_target: 0.5714 val_rmse_stderror: 1.144
# Still best_val_rmse: 0.5386 (from epoch 1)
#
# 128 steps took 98.1 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3194 train_rmse_stderror: 0.0272 train_kl_div: 0.2218
# val_rmse_target: 0.5174 val_rmse_stderror: 1.16
# New best_val_rmse: 0.5174
#
# 64 steps took 48.9 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.3575 train_rmse_stderror: 0.02605 train_kl_div: 0.2709
# val_rmse_target: 0.5075 val_rmse_stderror: 1.158
# New best_val_rmse: 0.5075
#
# 64 steps took 49.2 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.223 train_rmse_stderror: 0.03823 train_kl_div: 0.1217
# val_rmse_target: 0.5186 val_rmse_stderror: 1.141
# Still best_val_rmse: 0.5075 (from epoch 2)
#
# 64 steps took 48.9 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.16 train_rmse_stderror: 0.02474 train_kl_div: 0.06118
# val_rmse_target: 0.4976 val_rmse_stderror: 1.156
# New best_val_rmse: 0.4976
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.2402 train_rmse_stderror: 0.03016 train_kl_div: 0.1162
# val_rmse_target: 0.4993 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4976 (from epoch 3)
#
# 32 steps took 24.4 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.2155 train_rmse_stderror: 0.0198 train_kl_div: 0.1046
# val_rmse_target: 0.501 val_rmse_stderror: 1.156
# Still best_val_rmse: 0.4976 (from epoch 3)
#
# 64 steps took 49.2 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1235 train_rmse_stderror: 0.0336 train_kl_div: 0.03639
# val_rmse_target: 0.498 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4976 (from epoch 3)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1145 train_rmse_stderror: 0.02007 train_kl_div: 0.02502
# val_rmse_target: 0.4931 val_rmse_stderror: 1.156
# New best_val_rmse: 0.4931
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1102 train_rmse_stderror: 0.01922 train_kl_div: 0.02576
# val_rmse_target: 0.4956 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4931 (from epoch 4)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1427 train_rmse_stderror: 0.02323 train_kl_div: 0.04021
# val_rmse_target: 0.4951 val_rmse_stderror: 1.154
# Still best_val_rmse: 0.4931 (from epoch 4)
#
# 32 steps took 24.5 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1134 train_rmse_stderror: 0.02285 train_kl_div: 0.02715
# val_rmse_target: 0.4962 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4931 (from epoch 4)
#
# 32 steps took 24.4 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1261 train_rmse_stderror: 0.01872 train_kl_div: 0.03548
# val_rmse_target: 0.4958 val_rmse_stderror: 1.155
# Still best_val_rmse: 0.4931 (from epoch 4)
#
# Performance estimates:
# [0.4772503911166425, 0.47130432412902085, 0.482375541726991, 0.4900878315166627, 0.493108719685718]
# Mean: 0.482825361635007
# {'total_MiB': 16160, 'used_MiB': 1359}

# %%
print(list_val_rmse)
# Out:
# [0.4772503911166425, 0.47130432412902085, 0.482375541726991, 0.4900878315166627, 0.493108719685718]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:48<00:00, 29.3MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:49<00:00, 29.1MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:50<00:00, 28.3MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:50<00:00, 28.4MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:50<00:00, 28.3MB/s]
# Upload successful: model_1.pth (1GB)
