# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# データセットをDriveから取得
# !mkdir -p 'input'
# !mkdir -p 'clrp-pre-trained'

# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' '/content/input'
# !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/97_pre_trained/clrp_pretrained_manish_epoch5/pre-trained-roberta/clrp_roberta_large/' '/content/clrp-pre-trained'

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# tokenizer
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    TOKENIZER_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    TOKENIZER_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    TOKENIZER_DIR = 'roberta-large'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = '/content/clrp-pre-trained/clrp_roberta_large' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-large'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '051-train-06'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 12 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.55, 64), (-1., 32)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = TOKENIZER_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512),      
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )
        
        #self.layer_norm = nn.LayerNorm(config.hidden_size) # layer_normレイヤー
        
        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る                
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        #norm_embeddings = self.layer_norm(context_vector)
        return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

        # https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask

        
        # Now we reduce the context vector to the prediction score.
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                train_mean_mse = nn.MSELoss(reduction="mean")(output[:,0].flatten(), target) 
                train_std_mse = nn.MSELoss(reduction="mean")(torch.sqrt(output[:,1]**2).flatten(), standard_error) 

                train_mean_rmse = math.sqrt(train_mean_mse)
                train_std_rmse = math.sqrt(train_std_mse)

                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}")
                print(f"train_rmse_target: {train_mean_rmse:0.4}",
                      f"train_rmse_stderror: {train_std_rmse:0.4}",
                      f"train_kl_div: {loss:0.4}",
                      )
                print(f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            del input_ids
            del attention_mask
            del target
            torch.cuda.empty_cache()                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得

    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
    #norm_parameters = list(model.layer_norm.named_parameters())

    attention_group = [{'params': params, 'lr': 2e-5} for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [{'params': params, 'lr': 2e-5} for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得
    #norm_group = [{'params': params, 'lr': 2e-5} for (name, params) in norm_parameters]

    parameters = []
    parameters += attention_group
    parameters += regressor_group
    #parameters += norm_group

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 8e-6

        if layer_num >= 69:        
            lr = 2e-5

        if layer_num >= 133:
            lr = 4e-5

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, SEED, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
def train_and_save_model(train_indices, val_indices, model_path):
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    

    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    rmse = train(model, model_path, train_loader, val_loader, optimizer, scheduler=scheduler)

    del train_dataset
    del val_dataset
    del train_loader
    del val_loader
    del model
    del optimizer
    del scheduler
    gc.collect() 
    torch.cuda.empty_cache()
    return rmse

# %%
# 実行処理。 KFold & 学習
SEED = 1000
list_val_rmse = []

set_random_seed(SEED)
kfold = create_folds(train_df, 5, SEED=SEED, return_df=False) # binsで切る場合

for fold, (train_indices, val_indices) in enumerate(kfold):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    print(gpuinfo())
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    list_val_rmse.append(train_and_save_model(train_indices, val_indices, model_path))

    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
    print(gpuinfo())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# {'total_MiB': 16280, 'used_MiB': 2}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6856 train_rmse_stderror: 0.03301 train_kl_div: 0.9454
# val_rmse_target: 0.7817 val_rmse_stderror: 1.871
# New best_val_rmse: 0.7817
#
# 64 steps took 81.3 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5809 train_rmse_stderror: 0.07189 train_kl_div: 0.7146
# val_rmse_target: 0.6858 val_rmse_stderror: 1.886
# New best_val_rmse: 0.6858
#
# 64 steps took 81.5 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.3733 train_rmse_stderror: 0.04956 train_kl_div: 0.3035
# val_rmse_target: 0.6006 val_rmse_stderror: 1.906
# New best_val_rmse: 0.6006
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.5117 train_rmse_stderror: 0.04762 train_kl_div: 0.5072
# val_rmse_target: 0.5278 val_rmse_stderror: 1.845
# New best_val_rmse: 0.5278
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.3725 train_rmse_stderror: 0.04156 train_kl_div: 0.2974
# val_rmse_target: 0.4965 val_rmse_stderror: 1.858
# New best_val_rmse: 0.4965
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.2391 train_rmse_stderror: 0.05919 train_kl_div: 0.1363
# val_rmse_target: 0.5281 val_rmse_stderror: 1.884
# Still best_val_rmse: 0.4965 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.3608 train_rmse_stderror: 0.02693 train_kl_div: 0.3016
# val_rmse_target: 0.4908 val_rmse_stderror: 1.849
# New best_val_rmse: 0.4908
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2727 train_rmse_stderror: 0.02543 train_kl_div: 0.1604
# val_rmse_target: 0.5201 val_rmse_stderror: 1.869
# Still best_val_rmse: 0.4908 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2362 train_rmse_stderror: 0.02555 train_kl_div: 0.1152
# val_rmse_target: 0.5153 val_rmse_stderror: 1.861
# Still best_val_rmse: 0.4908 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2597 train_rmse_stderror: 0.029 train_kl_div: 0.147
# val_rmse_target: 0.5235 val_rmse_stderror: 1.859
# Still best_val_rmse: 0.4908 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.3653 train_rmse_stderror: 0.03358 train_kl_div: 0.264
# val_rmse_target: 0.5239 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4908 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2637 train_rmse_stderror: 0.03719 train_kl_div: 0.1159
# val_rmse_target: 0.4888 val_rmse_stderror: 1.845
# New best_val_rmse: 0.4888
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.193 train_rmse_stderror: 0.0319 train_kl_div: 0.08464
# val_rmse_target: 0.4709 val_rmse_stderror: 1.862
# New best_val_rmse: 0.4709
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1656 train_rmse_stderror: 0.02985 train_kl_div: 0.0631
# val_rmse_target: 0.4799 val_rmse_stderror: 1.867
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.109 train_rmse_stderror: 0.0294 train_kl_div: 0.02596
# val_rmse_target: 0.4845 val_rmse_stderror: 1.853
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1248 train_rmse_stderror: 0.02687 train_kl_div: 0.03622
# val_rmse_target: 0.4838 val_rmse_stderror: 1.86
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1464 train_rmse_stderror: 0.02218 train_kl_div: 0.04557
# val_rmse_target: 0.4853 val_rmse_stderror: 1.857
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1457 train_rmse_stderror: 0.02241 train_kl_div: 0.04468
# val_rmse_target: 0.4856 val_rmse_stderror: 1.858
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.217 train_rmse_stderror: 0.03237 train_kl_div: 0.09054
# val_rmse_target: 0.4838 val_rmse_stderror: 1.849
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.08498 train_rmse_stderror: 0.02212 train_kl_div: 0.01826
# val_rmse_target: 0.4867 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.06313 train_rmse_stderror: 0.02099 train_kl_div: 0.01059
# val_rmse_target: 0.4851 val_rmse_stderror: 1.856
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.07664 train_rmse_stderror: 0.02294 train_kl_div: 0.01397
# val_rmse_target: 0.4828 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.09357 train_rmse_stderror: 0.02557 train_kl_div: 0.02192
# val_rmse_target: 0.4841 val_rmse_stderror: 1.854
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1195 train_rmse_stderror: 0.02287 train_kl_div: 0.02978
# val_rmse_target: 0.4849 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1156 train_rmse_stderror: 0.02737 train_kl_div: 0.02828
# val_rmse_target: 0.4847 val_rmse_stderror: 1.855
# Still best_val_rmse: 0.4709 (from epoch 2)
#
# Performance estimates:
# [0.4708870447598722]
# Mean: 0.4708870447598722
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 2/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.3 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.5292 train_rmse_stderror: 0.08052 train_kl_div: 0.6043
# val_rmse_target: 0.5878 val_rmse_stderror: 1.078
# New best_val_rmse: 0.5878
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.3896 train_rmse_stderror: 0.0488 train_kl_div: 0.3134
# val_rmse_target: 0.5609 val_rmse_stderror: 1.127
# New best_val_rmse: 0.5609
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4909 train_rmse_stderror: 0.0399 train_kl_div: 0.422
# val_rmse_target: 0.5533 val_rmse_stderror: 1.103
# New best_val_rmse: 0.5533
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.3664 train_rmse_stderror: 0.04528 train_kl_div: 0.2924
# val_rmse_target: 0.5936 val_rmse_stderror: 1.131
# Still best_val_rmse: 0.5533 (from epoch 1)
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4815 train_rmse_stderror: 0.04719 train_kl_div: 0.4078
# val_rmse_target: 0.5222 val_rmse_stderror: 1.089
# New best_val_rmse: 0.5222
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.5278 train_rmse_stderror: 0.04744 train_kl_div: 0.4826
# val_rmse_target: 0.5469 val_rmse_stderror: 1.098
# Still best_val_rmse: 0.5222 (from epoch 1)
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.2965 train_rmse_stderror: 0.0415 train_kl_div: 0.1962
# val_rmse_target: 0.5493 val_rmse_stderror: 1.103
# Still best_val_rmse: 0.5222 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3428 train_rmse_stderror: 0.04269 train_kl_div: 0.2364
# val_rmse_target: 0.514 val_rmse_stderror: 1.085
# New best_val_rmse: 0.514
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2086 train_rmse_stderror: 0.03161 train_kl_div: 0.09347
# val_rmse_target: 0.4992 val_rmse_stderror: 1.122
# New best_val_rmse: 0.4992
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2337 train_rmse_stderror: 0.03302 train_kl_div: 0.1107
# val_rmse_target: 0.5043 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4992 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2171 train_rmse_stderror: 0.02809 train_kl_div: 0.1068
# val_rmse_target: 0.4982 val_rmse_stderror: 1.116
# New best_val_rmse: 0.4982
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.1744 train_rmse_stderror: 0.02889 train_kl_div: 0.06877
# val_rmse_target: 0.4953 val_rmse_stderror: 1.113
# New best_val_rmse: 0.4953
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1888 train_rmse_stderror: 0.02875 train_kl_div: 0.07657
# val_rmse_target: 0.4909 val_rmse_stderror: 1.11
# New best_val_rmse: 0.4909
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.177 train_rmse_stderror: 0.02525 train_kl_div: 0.06868
# val_rmse_target: 0.4908 val_rmse_stderror: 1.11
# New best_val_rmse: 0.4908
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1629 train_rmse_stderror: 0.01963 train_kl_div: 0.05764
# val_rmse_target: 0.4934 val_rmse_stderror: 1.116
# Still best_val_rmse: 0.4908 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1338 train_rmse_stderror: 0.0285 train_kl_div: 0.03539
# val_rmse_target: 0.4894 val_rmse_stderror: 1.109
# New best_val_rmse: 0.4894
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1961 train_rmse_stderror: 0.0193 train_kl_div: 0.07799
# val_rmse_target: 0.4934 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4894 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1536 train_rmse_stderror: 0.03001 train_kl_div: 0.05346
# val_rmse_target: 0.4892 val_rmse_stderror: 1.113
# New best_val_rmse: 0.4892
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.185 train_rmse_stderror: 0.02721 train_kl_div: 0.06924
# val_rmse_target: 0.4926 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4892 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1135 train_rmse_stderror: 0.02586 train_kl_div: 0.03012
# val_rmse_target: 0.4926 val_rmse_stderror: 1.112
# Still best_val_rmse: 0.4892 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1057 train_rmse_stderror: 0.0172 train_kl_div: 0.02357
# val_rmse_target: 0.4896 val_rmse_stderror: 1.113
# Still best_val_rmse: 0.4892 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.07866 train_rmse_stderror: 0.02797 train_kl_div: 0.01482
# val_rmse_target: 0.4886 val_rmse_stderror: 1.112
# New best_val_rmse: 0.4886
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08143 train_rmse_stderror: 0.03587 train_kl_div: 0.01914
# val_rmse_target: 0.4891 val_rmse_stderror: 1.11
# Still best_val_rmse: 0.4886 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1183 train_rmse_stderror: 0.02591 train_kl_div: 0.02882
# val_rmse_target: 0.4894 val_rmse_stderror: 1.111
# Still best_val_rmse: 0.4886 (from epoch 4)
#
# Performance estimates:
# [0.4708870447598722, 0.4885634613176341]
# Mean: 0.47972525303875313
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 3/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.4891 train_rmse_stderror: 0.05983 train_kl_div: 0.4941
# val_rmse_target: 0.6283 val_rmse_stderror: 1.774
# New best_val_rmse: 0.6283
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.5639 train_rmse_stderror: 0.05726 train_kl_div: 0.6668
# val_rmse_target: 0.6044 val_rmse_stderror: 1.743
# New best_val_rmse: 0.6044
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5301 train_rmse_stderror: 0.03643 train_kl_div: 0.6254
# val_rmse_target: 0.6061 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.6044 (from epoch 0)
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.2604 train_rmse_stderror: 0.03093 train_kl_div: 0.1438
# val_rmse_target: 0.4952 val_rmse_stderror: 1.752
# New best_val_rmse: 0.4952
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.5228 train_rmse_stderror: 0.05425 train_kl_div: 0.4625
# val_rmse_target: 0.5444 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4952 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4672 train_rmse_stderror: 0.03691 train_kl_div: 0.429
# val_rmse_target: 0.511 val_rmse_stderror: 1.743
# Still best_val_rmse: 0.4952 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4433 train_rmse_stderror: 0.03253 train_kl_div: 0.3839
# val_rmse_target: 0.5223 val_rmse_stderror: 1.755
# Still best_val_rmse: 0.4952 (from epoch 1)
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3529 train_rmse_stderror: 0.04217 train_kl_div: 0.2083
# val_rmse_target: 0.5611 val_rmse_stderror: 1.74
# Still best_val_rmse: 0.4952 (from epoch 1)
#
# 64 steps took 81.4 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.3813 train_rmse_stderror: 0.04999 train_kl_div: 0.2798
# val_rmse_target: 0.4927 val_rmse_stderror: 1.739
# New best_val_rmse: 0.4927
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.4036 train_rmse_stderror: 0.04847 train_kl_div: 0.32
# val_rmse_target: 0.5006 val_rmse_stderror: 1.738
# Still best_val_rmse: 0.4927 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.2801 train_rmse_stderror: 0.04255 train_kl_div: 0.185
# val_rmse_target: 0.4859 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4859
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.2213 train_rmse_stderror: 0.03747 train_kl_div: 0.116
# val_rmse_target: 0.5009 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4859 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.1695 train_rmse_stderror: 0.02369 train_kl_div: 0.06017
# val_rmse_target: 0.4828 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4828
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1238 train_rmse_stderror: 0.01884 train_kl_div: 0.03159
# val_rmse_target: 0.4841 val_rmse_stderror: 1.754
# Still best_val_rmse: 0.4828 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1211 train_rmse_stderror: 0.02599 train_kl_div: 0.03358
# val_rmse_target: 0.4831 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4828 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.1328 train_rmse_stderror: 0.03632 train_kl_div: 0.04475
# val_rmse_target: 0.482 val_rmse_stderror: 1.732
# New best_val_rmse: 0.482
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.13 train_rmse_stderror: 0.02022 train_kl_div: 0.04005
# val_rmse_target: 0.4811 val_rmse_stderror: 1.745
# New best_val_rmse: 0.4811
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1034 train_rmse_stderror: 0.02242 train_kl_div: 0.02327
# val_rmse_target: 0.4804 val_rmse_stderror: 1.75
# New best_val_rmse: 0.4804
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1242 train_rmse_stderror: 0.03279 train_kl_div: 0.03699
# val_rmse_target: 0.4831 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.07307 train_rmse_stderror: 0.02222 train_kl_div: 0.0131
# val_rmse_target: 0.485 val_rmse_stderror: 1.748
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1113 train_rmse_stderror: 0.0273 train_kl_div: 0.02616
# val_rmse_target: 0.4811 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.05998 train_rmse_stderror: 0.0258 train_kl_div: 0.01047
# val_rmse_target: 0.4818 val_rmse_stderror: 1.744
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.08249 train_rmse_stderror: 0.02001 train_kl_div: 0.01656
# val_rmse_target: 0.4815 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1053 train_rmse_stderror: 0.01556 train_kl_div: 0.02503
# val_rmse_target: 0.4815 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.4804 (from epoch 3)
#
# Performance estimates:
# [0.4708870447598722, 0.4885634613176341, 0.48040344362874177]
# Mean: 0.4799513165687494
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 4/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6341 train_rmse_stderror: 0.06289 train_kl_div: 0.7231
# val_rmse_target: 0.6275 val_rmse_stderror: 1.83
# New best_val_rmse: 0.6275
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.3743 train_rmse_stderror: 0.03508 train_kl_div: 0.3164
# val_rmse_target: 0.6019 val_rmse_stderror: 1.776
# New best_val_rmse: 0.6019
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.5671 train_rmse_stderror: 0.03229 train_kl_div: 0.5804
# val_rmse_target: 0.5134 val_rmse_stderror: 1.778
# New best_val_rmse: 0.5134
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.2304 train_rmse_stderror: 0.02592 train_kl_div: 0.1138
# val_rmse_target: 0.495 val_rmse_stderror: 1.778
# New best_val_rmse: 0.495
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.691 train_rmse_stderror: 0.04195 train_kl_div: 0.976
# val_rmse_target: 0.6727 val_rmse_stderror: 1.799
# Still best_val_rmse: 0.495 (from epoch 1)
#
# 64 steps took 81.4 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4118 train_rmse_stderror: 0.02847 train_kl_div: 0.3552
# val_rmse_target: 0.5098 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.495 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.2344 train_rmse_stderror: 0.03706 train_kl_div: 0.1189
# val_rmse_target: 0.5306 val_rmse_stderror: 1.81
# Still best_val_rmse: 0.495 (from epoch 1)
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.5521 train_rmse_stderror: 0.03516 train_kl_div: 0.5784
# val_rmse_target: 0.5364 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.495 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.3449 train_rmse_stderror: 0.02993 train_kl_div: 0.2383
# val_rmse_target: 0.5028 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.495 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.5483 train_rmse_stderror: 0.04116 train_kl_div: 0.5614
# val_rmse_target: 0.4785 val_rmse_stderror: 1.788
# New best_val_rmse: 0.4785
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2893 train_rmse_stderror: 0.02538 train_kl_div: 0.1685
# val_rmse_target: 0.5049 val_rmse_stderror: 1.783
# Still best_val_rmse: 0.4785 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.419 train_rmse_stderror: 0.03201 train_kl_div: 0.3816
# val_rmse_target: 0.4808 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4785 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.408 train_rmse_stderror: 0.04814 train_kl_div: 0.3712
# val_rmse_target: 0.4629 val_rmse_stderror: 1.795
# New best_val_rmse: 0.4629
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.3773 train_rmse_stderror: 0.04606 train_kl_div: 0.2762
# val_rmse_target: 0.4516 val_rmse_stderror: 1.788
# New best_val_rmse: 0.4516
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.1237 train_rmse_stderror: 0.02622 train_kl_div: 0.03212
# val_rmse_target: 0.4463 val_rmse_stderror: 1.791
# New best_val_rmse: 0.4463
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.234 train_rmse_stderror: 0.05593 train_kl_div: 0.1214
# val_rmse_target: 0.4619 val_rmse_stderror: 1.791
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.3152 train_rmse_stderror: 0.03162 train_kl_div: 0.2136
# val_rmse_target: 0.465 val_rmse_stderror: 1.792
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.2868 train_rmse_stderror: 0.03012 train_kl_div: 0.1397
# val_rmse_target: 0.4495 val_rmse_stderror: 1.795
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.2029 train_rmse_stderror: 0.03126 train_kl_div: 0.08681
# val_rmse_target: 0.4514 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.1263 train_rmse_stderror: 0.02914 train_kl_div: 0.03821
# val_rmse_target: 0.4487 val_rmse_stderror: 1.784
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.1351 train_rmse_stderror: 0.036 train_kl_div: 0.03951
# val_rmse_target: 0.4511 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.1412 train_rmse_stderror: 0.02085 train_kl_div: 0.03887
# val_rmse_target: 0.4485 val_rmse_stderror: 1.787
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.2322 train_rmse_stderror: 0.04066 train_kl_div: 0.1215
# val_rmse_target: 0.4472 val_rmse_stderror: 1.79
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.1285 train_rmse_stderror: 0.02914 train_kl_div: 0.03685
# val_rmse_target: 0.4499 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.1294 train_rmse_stderror: 0.02653 train_kl_div: 0.03761
# val_rmse_target: 0.4499 val_rmse_stderror: 1.789
# Still best_val_rmse: 0.4463 (from epoch 3)
#
# Performance estimates:
# [0.4708870447598722, 0.4885634613176341, 0.48040344362874177, 0.4462790973545162]
# Mean: 0.47153326176519106
# {'total_MiB': 16280, 'used_MiB': 927}
#
# Fold 5/5
# {'total_MiB': 16280, 'used_MiB': 927}
# Some weights of the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/clrp-pre-trained/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 64 steps took 82.4 seconds
# Epoch: 0 batch_num: 64
# train_rmse_target: 0.6739 train_rmse_stderror: 0.05999 train_kl_div: 0.8374
# val_rmse_target: 0.6771 val_rmse_stderror: 1.819
# New best_val_rmse: 0.6771
#
# 64 steps took 81.4 seconds
# Epoch: 0 batch_num: 128
# train_rmse_target: 0.4775 train_rmse_stderror: 0.033 train_kl_div: 0.4837
# val_rmse_target: 0.5578 val_rmse_stderror: 1.748
# New best_val_rmse: 0.5578
#
# 64 steps took 81.6 seconds
# Epoch: 1 batch_num: 4
# train_rmse_target: 0.4301 train_rmse_stderror: 0.03885 train_kl_div: 0.393
# val_rmse_target: 0.5192 val_rmse_stderror: 1.739
# New best_val_rmse: 0.5192
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 36
# train_rmse_target: 0.2213 train_rmse_stderror: 0.02957 train_kl_div: 0.1061
# val_rmse_target: 0.5438 val_rmse_stderror: 1.745
# Still best_val_rmse: 0.5192 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 68
# train_rmse_target: 0.4063 train_rmse_stderror: 0.0328 train_kl_div: 0.359
# val_rmse_target: 0.4941 val_rmse_stderror: 1.769
# New best_val_rmse: 0.4941
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 100
# train_rmse_target: 0.4548 train_rmse_stderror: 0.02653 train_kl_div: 0.4237
# val_rmse_target: 0.5033 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4941 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 132
# train_rmse_target: 0.4424 train_rmse_stderror: 0.05446 train_kl_div: 0.3846
# val_rmse_target: 0.5355 val_rmse_stderror: 1.739
# Still best_val_rmse: 0.4941 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 1 batch_num: 164
# train_rmse_target: 0.4232 train_rmse_stderror: 0.03935 train_kl_div: 0.3165
# val_rmse_target: 0.4974 val_rmse_stderror: 1.771
# Still best_val_rmse: 0.4941 (from epoch 1)
#
# 32 steps took 40.9 seconds
# Epoch: 2 batch_num: 8
# train_rmse_target: 0.3162 train_rmse_stderror: 0.01823 train_kl_div: 0.2074
# val_rmse_target: 0.5214 val_rmse_stderror: 1.758
# Still best_val_rmse: 0.4941 (from epoch 1)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 40
# train_rmse_target: 0.2692 train_rmse_stderror: 0.02721 train_kl_div: 0.1524
# val_rmse_target: 0.4885 val_rmse_stderror: 1.753
# New best_val_rmse: 0.4885
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 72
# train_rmse_target: 0.2194 train_rmse_stderror: 0.02289 train_kl_div: 0.101
# val_rmse_target: 0.4906 val_rmse_stderror: 1.759
# Still best_val_rmse: 0.4885 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 104
# train_rmse_target: 0.2403 train_rmse_stderror: 0.03427 train_kl_div: 0.119
# val_rmse_target: 0.4874 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4874
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 136
# train_rmse_target: 0.1615 train_rmse_stderror: 0.02608 train_kl_div: 0.05416
# val_rmse_target: 0.5058 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 2 batch_num: 168
# train_rmse_target: 0.3502 train_rmse_stderror: 0.05331 train_kl_div: 0.2104
# val_rmse_target: 0.4986 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 40.9 seconds
# Epoch: 3 batch_num: 12
# train_rmse_target: 0.09638 train_rmse_stderror: 0.02421 train_kl_div: 0.02093
# val_rmse_target: 0.491 val_rmse_stderror: 1.764
# Still best_val_rmse: 0.4874 (from epoch 2)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 44
# train_rmse_target: 0.08894 train_rmse_stderror: 0.02214 train_kl_div: 0.01971
# val_rmse_target: 0.4858 val_rmse_stderror: 1.761
# New best_val_rmse: 0.4858
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 76
# train_rmse_target: 0.1662 train_rmse_stderror: 0.02188 train_kl_div: 0.06304
# val_rmse_target: 0.4858 val_rmse_stderror: 1.76
# New best_val_rmse: 0.4858
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 108
# train_rmse_target: 0.09885 train_rmse_stderror: 0.02497 train_kl_div: 0.02311
# val_rmse_target: 0.4818 val_rmse_stderror: 1.76
# New best_val_rmse: 0.4818
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 140
# train_rmse_target: 0.1054 train_rmse_stderror: 0.01826 train_kl_div: 0.02305
# val_rmse_target: 0.4836 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4818 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 3 batch_num: 172
# train_rmse_target: 0.1005 train_rmse_stderror: 0.02317 train_kl_div: 0.02263
# val_rmse_target: 0.4831 val_rmse_stderror: 1.762
# Still best_val_rmse: 0.4818 (from epoch 3)
#
# 32 steps took 40.9 seconds
# Epoch: 4 batch_num: 16
# train_rmse_target: 0.09044 train_rmse_stderror: 0.02593 train_kl_div: 0.0201
# val_rmse_target: 0.4873 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4818 (from epoch 3)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 48
# train_rmse_target: 0.06412 train_rmse_stderror: 0.02634 train_kl_div: 0.01149
# val_rmse_target: 0.4813 val_rmse_stderror: 1.758
# New best_val_rmse: 0.4813
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 80
# train_rmse_target: 0.0891 train_rmse_stderror: 0.01763 train_kl_div: 0.01713
# val_rmse_target: 0.4821 val_rmse_stderror: 1.763
# Still best_val_rmse: 0.4813 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 112
# train_rmse_target: 0.1091 train_rmse_stderror: 0.0171 train_kl_div: 0.02454
# val_rmse_target: 0.4826 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4813 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 144
# train_rmse_target: 0.0993 train_rmse_stderror: 0.02571 train_kl_div: 0.02257
# val_rmse_target: 0.4829 val_rmse_stderror: 1.761
# Still best_val_rmse: 0.4813 (from epoch 4)
#
# 32 steps took 40.7 seconds
# Epoch: 4 batch_num: 176
# train_rmse_target: 0.07963 train_rmse_stderror: 0.02023 train_kl_div: 0.01577
# val_rmse_target: 0.483 val_rmse_stderror: 1.76
# Still best_val_rmse: 0.4813 (from epoch 4)
#
# Performance estimates:
# [0.4708870447598722, 0.4885634613176341, 0.48040344362874177, 0.4462790973545162, 0.481298066220692]
# Mean: 0.4734862226562912
# {'total_MiB': 16280, 'used_MiB': 927}

# %%
print(list_val_rmse)
# Out:
# [0.4708870447598722, 0.4885634613176341, 0.48040344362874177, 0.4462790973545162, 0.481298066220692]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # upload models

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Starting upload for file model_2.pth
# 100%|██████████| 1.33G/1.33G [00:24<00:00, 57.1MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_2.pth (1GB)
# Starting upload for file model_5.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.9MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_5.pth (1GB)
# Starting upload for file model_4.pth
# 100%|██████████| 1.33G/1.33G [00:29<00:00, 47.6MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_4.pth (1GB)
# Starting upload for file model_3.pth
# 100%|██████████| 1.33G/1.33G [00:25<00:00, 55.8MB/s]
#   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Upload successful: model_3.pth (1GB)
# Starting upload for file model_1.pth
# 100%|██████████| 1.33G/1.33G [00:30<00:00, 47.3MB/s]
# Upload successful: model_1.pth (1GB)
