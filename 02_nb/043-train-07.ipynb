# %%
"""
if 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt' \
   --ignore-installed

  # !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules' \
   transformers -U
  # !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
  # !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'
"""
# Out:
# "\nif 'google.colab' in sys.modules:  # colab環境特有の処理_初回のみ\n  # Google Driveのマウント\n  from google.colab import drive\n  drive.mount('/content/drive')\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/requirements.txt'    --ignore-installed\n\n  !pip install --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'    transformers -U\n  !pip install gensim==4.0.1 --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n  !pip install pytorch_memlab --target '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules'\n"

# %%
# !pip install pytorch_memlab
# Out:
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.1.5)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (1.9.0+cu102)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (0.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytorch_memlab) (57.0.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18->pytorch_memlab) (2.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_memlab) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->pytorch_memlab) (1.15.0)

# %%
import sys
if 'google.colab' in sys.modules:  # colab特有の処理_2回目以降
  # Google Driveのマウント
  from google.colab import drive
  drive.mount('/content/drive')

  # データセットをDriveから取得
  # !mkdir -p 'input'
  # !cp -r '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input' '/content/input'

  # ライブラリのパス指定
  sys.path.append('/content/drive/MyDrive/Colab_Files/kaggle/commonlit/XX_modules')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

# input
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    DATA_DIR = Path('../input/commonlitreadabilityprize/')

elif 'google.colab' in sys.modules: # Colab環境
    # !mkdir 'input' -p
    # !cp '/content/drive/MyDrive/Colab_Files/kaggle/commonlit/00_input/commonlitreadabilityprize/' './input' -r
    DATA_DIR = Path('/content/input/commonlitreadabilityprize')

else:
    DATA_DIR = Path('../00_input/commonlitreadabilityprize/')

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-large'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
from pathlib import Path

# pre-trained model
if 'kaggle_web_client' in sys.modules:  # kaggle環境
    PRE_TRAINED_MODEL_DIR = '../input/roberta-transformers-pytorch/roberta-base'
elif 'google.colab' in sys.modules: # Colab環境
    PRE_TRAINED_MODEL_DIR = 'roberta-base' # 仮で、毎回DLする想定のモデル名を指定。あとで変更予定。
else:
    PRE_TRAINED_MODEL_DIR = 'roberta-base'

# %%
UPLOAD_DIR = Path('/content/model')
EX_NO = '043-train-07'  # 実験番号などを入れる、folderのpathにする
USERID = 'calpis10000'

# %%
import subprocess
import shlex

def gpuinfo():
    """
    Returns size of total GPU RAM and used GPU RAM.

    Parameters
    ----------
    None

    Returns
    -------
    info : dict
        Total GPU RAM in integer for key 'total_MiB'.
        Used GPU RAM in integer for key 'used_MiB'.
    """

    command = 'nvidia-smi -q -d MEMORY | sed -n "/FB Memory Usage/,/Free/p" | sed -e "1d" -e "4d" -e "s/ MiB//g" | cut -d ":" -f 2 | cut -c2-'
    commands = [shlex.split(part) for part in command.split(' | ')]
    for i, cmd in enumerate(commands):
        if i==0:
            res = subprocess.Popen(cmd, stdout=subprocess.PIPE)
        else:
            res = subprocess.Popen(cmd, stdin=res.stdout, stdout=subprocess.PIPE)
    total, used = map(int, res.communicate()[0].decode('utf-8').strip().split('\n'))
    info = {'total_MiB':total, 'used_MiB':used}
    return info

# %% [markdown]
# # Overview
# This nb is based on copy from https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch .
#
# Acknowledgments(from base nb):
# some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW # optimizer
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup # scheduler
from pytorch_memlab import profile
import pytorch_memlab
from pytorch_memlab import MemReporter

from sklearn.model_selection import KFold, StratifiedKFold

import gc
gc.enable()

# %%
NUM_FOLDS = 5 # K Fold
NUM_EPOCHS = 5 # Epochs
BATCH_SIZE = 16 # Batch Size
MAX_LEN = 248 # ベクトル長
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)] # schedulerの何らかの設定？
ROBERTA_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(モデルとして指定)
TOKENIZER_PATH = PRE_TRAINED_MODEL_DIR # roberta pre-trainedモデル(Tokenizerとして指定)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # cudaがなければcpuを使えばいいじゃない

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True# cudnnによる最適化で結果が変わらないためのおまじない

# %%
# train, testを読む
train_df = pd.read_csv(DATA_DIR/"train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv(DATA_DIR/"test.csv")
submission_df = pd.read_csv(DATA_DIR/"sample_submission.csv")

# %%
train_df.head()
# Out:
#           id url_legal  ...    target standard_error
# 0  c12129c31       NaN  ... -0.340259       0.464009
# 1  85aa80a4c       NaN  ... -0.315372       0.480805
# 2  b69ac6792       NaN  ... -0.580118       0.476676
# 3  dd1000b26       NaN  ... -1.054013       0.450007
# 4  37c1b32fb       NaN  ...  0.247197       0.510845
#
# [5 rows x 6 columns]

# %%
# tokenizerを指定
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
# Dataset用のClass。おそらく、trainとtestでインスタンスを生成し、DataFrameと同じように扱えるような思想。
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only # Testデータ用フラグ
        self.text = df.excerpt.tolist() # 分析対象カラムをlistにする。(分かち書きではなく、Seriesをlistへ変換するような処理)
        #self.text = [text.replace("\n", " ") for text in self.text] # 単語単位で分かち書きする場合
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32) # trainのみ、targetをtensorに変換
            self.standard_error = torch.tensor(df.standard_error.values, dtype=torch.float32) 

        self.encoded = tokenizer.batch_encode_plus( # textをtokenize
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True, # 最大長を超える文字は切り捨て
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index): # 変換結果を返す
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            standard_error = self.standard_error[index]
            return (input_ids, attention_mask, target, standard_error)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH) # pretrainedからconfigを読み込み
        config.update({"output_hidden_states":True, # config更新: embedding層を抽出
                       "hidden_dropout_prob": 0.0, # config更新: dropoutしない
                       "layer_norm_eps": 1e-7}) # config更新: layer normalizationのepsilon                      
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config) # cpuで処理する
            
        self.attention = nn.Sequential(# attentionレイヤー            
            nn.Linear(config.hidden_size, 512), # 768は、ベースとなる学習済みモデルの重みをハードコードしてる。イケてないので、configから取得する感じにしたい。     
            nn.Tanh(),                       
            nn.Linear(512, 1),
            nn.Softmax(dim=1)
        )

        self.regressor = nn.Sequential( # 出力レイヤー                    
            nn.Linear(config.hidden_size, 2)                        
        )

    def forward(self, input_ids, attention_mask):
        #print('model: get_roberta_out: Start', gpuinfo())                 
        roberta_output = self.roberta(input_ids=input_ids, # robertaに入力データを流し、出力としてrobertaモデル(layerの複合体)を得る
                                      attention_mask=attention_mask)     
        #print('model: get_roberta_out: Done', gpuinfo())                 

        last_hidden_state = roberta_output.hidden_states[-1] # robertaモデルの最後のlayerを得る
        weights = self.attention(last_hidden_state) # robertaの最後のlayerをattentionへ入力し、出力として重みを得る
        context_vector = torch.sum(weights * last_hidden_state, dim=1) # 重み×最後の層を足し合わせて文書ベクトルとする。
        return self.regressor(context_vector) # 文書ベクトルを線形層に入力し、targetを出力する

        # mean-pooling: https://www.kaggle.com/rhtsingh/utilizing-transformer-representations-efficiently
        # TODO: 外部からPooling処理を与える形式にしたい（切り替えを楽にしたい）
        #last_hidden_state = roberta_output[0]
        #input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        #sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        #sum_mask = input_mask_expanded.sum(1)
        #sum_mask = torch.clamp(sum_mask, min=1e-9)
        #mean_embeddings = sum_embeddings / sum_mask
        #return self.regressor(mean_embeddings) # 文書ベクトルを線形層に入力し、targetを出力する

# %%
# 評価指標(MSE)の計算。最終的に、ルートしてRMSEにすると思われる。
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval() # evalモードを選択。Batch Normとかdropoutをしなくなる           
    mse_mean_sum = 0
    mse_std_sum = 0

    with torch.no_grad(): # 勾配の計算をしないBlock
        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(data_loader): # data_loaderからinput, attentin_mask, targetをbatchごとに取り出す
            input_ids = input_ids.to(DEVICE)   
            attention_mask = attention_mask.to(DEVICE)   
            target = target.to(DEVICE)      
            standard_error = standard_error.to(DEVICE) 
            
            output = model(input_ids, attention_mask) # 取得した値をモデルへ入力し、出力として予測値を得る。

            mse_mean_sum += nn.MSELoss(reduction="sum")(output[:,0].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)
            mse_std_sum += nn.MSELoss(reduction="sum")(output[:,1].flatten(), target).item() # 誤差の合計を得る(Batchごとに計算した誤差を足し上げる)

    del input_ids
    del attention_mask
    del target

    mse_mean_result = mse_mean_sum / len(data_loader.dataset)
    mse_std_result = mse_std_sum / len(data_loader.dataset)
  
    return mse_mean_result, mse_std_result # 誤差の合計をdataset長で除し、mseを取得＆返す

# %%
# 推論結果を返す
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval() # evalモード(dropout, batch_normしない)

    result = np.zeros(len(data_loader.dataset)) # 結果をdataset長のzero配列として用意
    index = 0
    
    with torch.no_grad(): # 勾配の計算をしないblock(inputすると、現状の重みによる推論結果を返す)
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader): # data_loaderからbatchごとにinputを得る
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            output = model(input_ids, attention_mask) # modelにinputを入力し、予測結果を得る。

            result[index : index + output[:,0].shape[0]] = output[:,0].flatten().to("cpu") # result[index ~ predの長さ]へ、予測結果を格納
            index += pred.shape[0] # indexを更新

    return result # 全batchで推論が終わったら、結果を返す

# %%
# 学習
def train(model, # モデル
          model_path, # モデルのアウトプット先
          train_loader, # train-setのdata_loader
          val_loader, # valid-setのdata_loader
          optimizer, # optimizer
          scheduler=None, # scheduler, デフォルトはNone
          num_epochs=NUM_EPOCHS # epoch数、notebook冒頭で指定した値
         ):    
    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1] # eval期間(って何？) 冒頭で決めたEVAL_SCHEDULEの最初のtupleの[1]を取得

    start = time.time() # 時間計測用

    for epoch in range(num_epochs): # 指定したEpoch数だけ繰り返し
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target, standard_error) in enumerate(train_loader): # train_loaderからinput, targetを取得
            input_ids = input_ids.to(DEVICE) # inputをDEVICEへ突っ込む
            attention_mask = attention_mask.to(DEVICE)       
            target = target.to(DEVICE)
            standard_error = standard_error.to(DEVICE)  

            optimizer.zero_grad() # 勾配を初期化            
            model.train() # 学習モード開始

            # https://www.kaggle.com/c/commonlitreadabilityprize/discussion/239421
            output = model(input_ids, attention_mask) # input,attention_maskを入力し、予測結果を得る
            p = torch.distributions.Normal(output[:,0], torch.sqrt(output[:,1]**2))
            q = torch.distributions.Normal(target, standard_error)
            kl_vector = torch.distributions.kl_divergence(p, q)
            loss = kl_vector.mean()

            loss.backward() # 誤差逆伝播法により勾配を得る
            optimizer.step() # 重みを更新する

            if scheduler:
                scheduler.step() # schedulerが与えられた場合は、schedulerの学習率更新
            
            if step >= last_eval_step + eval_period: # batchを回すごとにstepを増やしていって、「前回evalしたstep + eval_period(16)」を超えたら実行。
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start # 経過時間
                num_steps = step - last_eval_step # 経過ステップ数
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step # 前回stepの更新
                
                # valid-setによるrmse計算
                val_mean_mse, val_std_mse = eval_mse(model, val_loader)
                val_mean_rmse = math.sqrt(val_mean_mse)                            
                val_std_rmse = math.sqrt(val_std_mse)                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse_target: {val_mean_rmse:0.4}",
                      f"val_rmse_stderror: {val_std_rmse:0.4}"
                      )

                for rmse, period in EVAL_SCHEDULE: # eval_periodをvalid-rmseで切り替える処理
                    if val_mean_rmse >= rmse: # valid rmseをEVAL_SCHEDULEと比較し、0項 > valid rmseとなるまで回す : EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]
                        eval_period = period # eval_periodを更新
                        break                               

                if not best_val_rmse or val_mean_rmse < best_val_rmse: # 初回(best_val_rmse==None), またはbest_val_rmseを更新したらモデルを保存する
                    best_val_rmse = val_mean_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path) # 最高の自分を保存
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}", # 更新されない場合は、元のスコアを表示
                          f"(from epoch {best_epoch})")      
                                                  
                start = time.time()
            
            # batchごとにメモリ解放
            #print(f'train_{epoch}_{batch_num}: free_memory: Start', gpuinfo())                  
            del input_ids
            del attention_mask
            #del target
            torch.cuda.empty_cache()
            #print(f'train_{epoch}_{batch_num}: free_memory: Done', gpuinfo())  
                                            
            step += 1
    
    return best_val_rmse

# %%
# optimizerの作成
def create_optimizer(model):
    named_parameters = list(model.named_parameters()) # モデルパラメータの取得
    
    roberta_parameters = list(model.roberta.named_parameters())[:-2] # パラメータをroberta用、attention用、regressor用に格納。(直接引っ張ってくる形式に変更)
    attention_parameters = list(model.attention.named_parameters())
    regressor_parameters = list(model.regressor.named_parameters())
        
    attention_group = [params for (name, params) in attention_parameters] # attention用パラメータをリストとして取得
    regressor_group = [params for (name, params) in regressor_parameters] # reg用パラメータをリストとして取得

    parameters = []
    #parameters.append({"params": attention_group}) # パラメータをリストに辞書として格納していく
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters): # レイヤーごとにname, paramsを取得していろんな処理
        weight_decay = 0.0 if "bias" in name else 0.01

        lr = 2e-5

        if layer_num >= 69:        
            lr = 5e-5

        if layer_num >= 133:
            lr = 1e-4

        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters) # 最終的に、AdamWにパラメータを入力する。

# %%
# https://www.kaggle.com/abhishek/step-1-create-folds
def create_folds(data, num_splits, return_df=False):
    # we create a new column called kfold and fill it with -1
    data["kfold"] = -1
    
    # the next step is to randomize the rows of the data
    data = data.sample(frac=1).reset_index(drop=True)

    # calculate number of bins by Sturge's rule
    # I take the floor of the value, you can also
    # just round it
    num_bins = int(np.floor(1 + np.log2(len(data))))
    
    # bin targets
    data.loc[:, "bins_tg"] = pd.cut(
        data["target"], bins=num_bins, labels=False
    ).map(lambda x: str(x))

    # bin standard_error
    data.loc[:, "bins_std"] = pd.cut(
        data["standard_error"], bins=num_bins, labels=False
    )

    # bins
    data.loc[:, "bins"] = data['bins_tg'].map(lambda x: str(x)) + data['bins_std'].map(lambda x: str(x))

    # initiate the kfold class from model_selection module
    kf = StratifiedKFold(n_splits=5)

    # note that, instead of targets, we use bins!
    if return_df:
      for f, (t_, v_) in enumerate(kf.split(X=data, y=data.bins.values)):
        data.loc[v_, 'kfold'] = f
      return data
    else:
      return kf.split(X=data, y=data.bins.values)

# %%
# 検証用
st_kfold_bins_df = create_folds(train_df, 5, return_df=True)
st_kfold_bins_df['bins_tg'] = st_kfold_bins_df['bins_tg'].map(lambda x: float(x))
st_kfold_bins_df['bins_std'] = st_kfold_bins_df['bins_std'].map(lambda x: float(x))
st_kfold_bins_df.groupby('kfold').agg({'bins_tg': ['min', 'max', 'mean'],
                                    'bins_std': ['min', 'max', 'mean']})
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#       bins_tg                 bins_std
#           min   max      mean      min   max      mean
# kfold
# 0         0.0  11.0  5.502646      0.0  11.0  2.932981
# 1         0.0  11.0  5.562610      0.0  11.0  2.927690
# 2         0.0  11.0  5.567901      0.0  11.0  2.911817
# 3         0.0  11.0  5.595406      0.0  11.0  2.941696
# 4         0.0  11.0  5.521201      0.0  11.0  2.931095

# %%
# 実際に使うKFold
st_kfold_bins = create_folds(train_df, 5, return_df=False)
st_kfold_bins
# Out:
# <generator object _BaseKFold.split at 0x7fd0120f3b50>

# %%
# 実行処理。 KFold & 学習
gc.collect()

SEED = 1000
list_val_rmse = []

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(st_kfold_bins):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = f"model_{fold + 1}.pth" # model_fold数_.pth
        
    set_random_seed(SEED + fold) # SEEDはfold別に変わるようにする
    
    train_dataset = LitDataset(train_df.loc[train_indices]) # train, validのDataset
    val_dataset = LitDataset(train_df.loc[val_indices])
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2) # train, validのDataLoader
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold) # なんで二回SEEDをセットするのだろう？

    #print('getmodel: Start', gpuinfo())                 
    model = LitModel().to(DEVICE) # modelをDEVICEへぶち込む
    #print('getmodel: Done', gpuinfo())                 

    #print('get_optim_sched: Start', gpuinfo())                 
    optimizer = create_optimizer(model) # optimizerをモデルから作成
    scheduler = get_cosine_schedule_with_warmup( # schedulerを作成
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    #print('get_optim_sched: Done', gpuinfo())                 

    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler)) # 学習開始し、val_rmseのリストを格納

    del model # モデルは保存したので、消す
    gc.collect() 
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Fold 1/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.62 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9252 val_rmse_stderror: 1.872
# New best_val_rmse: 0.9252
#
# 16 steps took 9.12 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.8442 val_rmse_stderror: 1.59
# New best_val_rmse: 0.8442
#
# 16 steps took 9.12 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7274 val_rmse_stderror: 1.722
# New best_val_rmse: 0.7274
#
# 16 steps took 9.14 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7092 val_rmse_stderror: 1.674
# New best_val_rmse: 0.7092
#
# 16 steps took 9.13 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6079 val_rmse_stderror: 1.688
# New best_val_rmse: 0.6079
#
# 16 steps took 9.12 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.5877 val_rmse_stderror: 1.707
# New best_val_rmse: 0.5877
#
# 16 steps took 9.13 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.5395 val_rmse_stderror: 1.699
# New best_val_rmse: 0.5395
#
# 16 steps took 9.14 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.5424 val_rmse_stderror: 1.688
# Still best_val_rmse: 0.5395 (from epoch 0)
#
# 16 steps took 9.27 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.6079 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.5395 (from epoch 0)
#
# 16 steps took 9.12 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5142 val_rmse_stderror: 1.677
# New best_val_rmse: 0.5142
#
# 16 steps took 9.12 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.4936 val_rmse_stderror: 1.669
# New best_val_rmse: 0.4936
#
# 8 steps took 4.56 seconds
# Epoch: 1 batch_num: 43 val_rmse_target: 0.5033 val_rmse_stderror: 1.69
# Still best_val_rmse: 0.4936 (from epoch 1)
#
# 16 steps took 9.13 seconds
# Epoch: 1 batch_num: 59 val_rmse_target: 0.4849 val_rmse_stderror: 1.687
# New best_val_rmse: 0.4849
#
# 4 steps took 2.29 seconds
# Epoch: 1 batch_num: 63 val_rmse_target: 0.5714 val_rmse_stderror: 1.679
# Still best_val_rmse: 0.4849 (from epoch 1)
#
# 16 steps took 9.12 seconds
# Epoch: 1 batch_num: 79 val_rmse_target: 0.474 val_rmse_stderror: 1.685
# New best_val_rmse: 0.474
#
# 2 steps took 1.14 seconds
# Epoch: 1 batch_num: 81 val_rmse_target: 0.5283 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.474 (from epoch 1)
#
# 16 steps took 9.11 seconds
# Epoch: 1 batch_num: 97 val_rmse_target: 0.5093 val_rmse_stderror: 1.686
# Still best_val_rmse: 0.474 (from epoch 1)
#
# 16 steps took 9.12 seconds
# Epoch: 1 batch_num: 113 val_rmse_target: 0.5318 val_rmse_stderror: 1.682
# Still best_val_rmse: 0.474 (from epoch 1)
#
# 16 steps took 9.14 seconds
# Epoch: 1 batch_num: 129 val_rmse_target: 0.4928 val_rmse_stderror: 1.678
# Still best_val_rmse: 0.474 (from epoch 1)
#
# 8 steps took 4.55 seconds
# Epoch: 1 batch_num: 137 val_rmse_target: 0.4967 val_rmse_stderror: 1.682
# Still best_val_rmse: 0.474 (from epoch 1)
#
# 8 steps took 4.71 seconds
# Epoch: 2 batch_num: 4 val_rmse_target: 0.4718 val_rmse_stderror: 1.664
# New best_val_rmse: 0.4718
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5097 val_rmse_stderror: 1.664
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 16 steps took 9.12 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.4736 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4718 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 24 val_rmse_target: 0.4681 val_rmse_stderror: 1.67
# New best_val_rmse: 0.4681
#
# 1 steps took 0.574 seconds
# Epoch: 2 batch_num: 25 val_rmse_target: 0.4676 val_rmse_stderror: 1.67
# New best_val_rmse: 0.4676
#
# 1 steps took 0.578 seconds
# Epoch: 2 batch_num: 26 val_rmse_target: 0.4677 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4676 (from epoch 2)
#
# 1 steps took 0.575 seconds
# Epoch: 2 batch_num: 27 val_rmse_target: 0.4669 val_rmse_stderror: 1.669
# New best_val_rmse: 0.4669
#
# 1 steps took 0.579 seconds
# Epoch: 2 batch_num: 28 val_rmse_target: 0.4668 val_rmse_stderror: 1.67
# New best_val_rmse: 0.4668
#
# 1 steps took 0.574 seconds
# Epoch: 2 batch_num: 29 val_rmse_target: 0.4674 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 1 steps took 0.577 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.467 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 1 steps took 0.575 seconds
# Epoch: 2 batch_num: 31 val_rmse_target: 0.472 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 33 val_rmse_target: 0.5032 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 16 steps took 9.11 seconds
# Epoch: 2 batch_num: 49 val_rmse_target: 0.4773 val_rmse_stderror: 1.666
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 51 val_rmse_target: 0.4768 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4668 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 53 val_rmse_target: 0.4633 val_rmse_stderror: 1.674
# New best_val_rmse: 0.4633
#
# 1 steps took 0.587 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4796 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 56 val_rmse_target: 0.4976 val_rmse_stderror: 1.682
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 8 steps took 4.56 seconds
# Epoch: 2 batch_num: 64 val_rmse_target: 0.4745 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 66 val_rmse_target: 0.4837 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 4 steps took 2.28 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4872 val_rmse_stderror: 1.661
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 4 steps took 2.29 seconds
# Epoch: 2 batch_num: 74 val_rmse_target: 0.4792 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 2 steps took 1.15 seconds
# Epoch: 2 batch_num: 76 val_rmse_target: 0.515 val_rmse_stderror: 1.679
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 16 steps took 9.13 seconds
# Epoch: 2 batch_num: 92 val_rmse_target: 0.4746 val_rmse_stderror: 1.662
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 2 steps took 1.15 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4912 val_rmse_stderror: 1.657
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 8 steps took 4.55 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.4941 val_rmse_stderror: 1.666
# Still best_val_rmse: 0.4633 (from epoch 2)
#
# 8 steps took 4.55 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.4627 val_rmse_stderror: 1.682
# New best_val_rmse: 0.4627
#
# 1 steps took 0.579 seconds
# Epoch: 2 batch_num: 111 val_rmse_target: 0.4643 val_rmse_stderror: 1.681
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 1 steps took 0.576 seconds
# Epoch: 2 batch_num: 112 val_rmse_target: 0.4725 val_rmse_stderror: 1.679
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 2 steps took 1.15 seconds
# Epoch: 2 batch_num: 114 val_rmse_target: 0.4647 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 1 steps took 0.575 seconds
# Epoch: 2 batch_num: 115 val_rmse_target: 0.4949 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 8 steps took 4.56 seconds
# Epoch: 2 batch_num: 123 val_rmse_target: 0.4732 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 2 steps took 1.15 seconds
# Epoch: 2 batch_num: 125 val_rmse_target: 0.4707 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 127 val_rmse_target: 0.4936 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 8 steps took 4.55 seconds
# Epoch: 2 batch_num: 135 val_rmse_target: 0.4758 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 2 batch_num: 137 val_rmse_target: 0.4655 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 1 steps took 0.571 seconds
# Epoch: 2 batch_num: 138 val_rmse_target: 0.4661 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 1 steps took 0.572 seconds
# Epoch: 2 batch_num: 139 val_rmse_target: 0.4813 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 4 steps took 2.44 seconds
# Epoch: 3 batch_num: 2 val_rmse_target: 0.4787 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 4 val_rmse_target: 0.4636 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4627 (from epoch 2)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 5 val_rmse_target: 0.4607 val_rmse_stderror: 1.67
# New best_val_rmse: 0.4607
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 6 val_rmse_target: 0.4609 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4607 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 7 val_rmse_target: 0.4606 val_rmse_stderror: 1.671
# New best_val_rmse: 0.4606
#
# 1 steps took 0.582 seconds
# Epoch: 3 batch_num: 8 val_rmse_target: 0.4609 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4606 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.4613 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4606 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 10 val_rmse_target: 0.4615 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4606 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 11 val_rmse_target: 0.4581 val_rmse_stderror: 1.673
# New best_val_rmse: 0.4581
#
# 1 steps took 0.582 seconds
# Epoch: 3 batch_num: 12 val_rmse_target: 0.4577 val_rmse_stderror: 1.673
# New best_val_rmse: 0.4577
#
# 1 steps took 0.578 seconds
# Epoch: 3 batch_num: 13 val_rmse_target: 0.4586 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 14 val_rmse_target: 0.4585 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 15 val_rmse_target: 0.4578 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 16 val_rmse_target: 0.4584 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 17 val_rmse_target: 0.4601 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 18 val_rmse_target: 0.4621 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 19 val_rmse_target: 0.4639 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 20 val_rmse_target: 0.4639 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 21 val_rmse_target: 0.4617 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 22 val_rmse_target: 0.4598 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 23 val_rmse_target: 0.4587 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 24 val_rmse_target: 0.4585 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 25 val_rmse_target: 0.4587 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 26 val_rmse_target: 0.4595 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 3 batch_num: 27 val_rmse_target: 0.4603 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 28 val_rmse_target: 0.4609 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 29 val_rmse_target: 0.4613 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 30 val_rmse_target: 0.4617 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 31 val_rmse_target: 0.4638 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 32 val_rmse_target: 0.4675 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 33 val_rmse_target: 0.4737 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.15 seconds
# Epoch: 3 batch_num: 35 val_rmse_target: 0.4864 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 4 steps took 2.28 seconds
# Epoch: 3 batch_num: 39 val_rmse_target: 0.4778 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 41 val_rmse_target: 0.4738 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 43 val_rmse_target: 0.4711 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 45 val_rmse_target: 0.4682 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.569 seconds
# Epoch: 3 batch_num: 46 val_rmse_target: 0.4686 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 47 val_rmse_target: 0.4689 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 3 batch_num: 48 val_rmse_target: 0.4684 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 49 val_rmse_target: 0.4679 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 50 val_rmse_target: 0.4728 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 52 val_rmse_target: 0.4751 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 54 val_rmse_target: 0.469 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 55 val_rmse_target: 0.4694 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 56 val_rmse_target: 0.4714 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 58 val_rmse_target: 0.468 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 59 val_rmse_target: 0.4666 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 60 val_rmse_target: 0.4632 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 61 val_rmse_target: 0.4608 val_rmse_stderror: 1.678
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 62 val_rmse_target: 0.4599 val_rmse_stderror: 1.678
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 63 val_rmse_target: 0.461 val_rmse_stderror: 1.678
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 64 val_rmse_target: 0.4618 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.581 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.4619 val_rmse_stderror: 1.677
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 66 val_rmse_target: 0.4644 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.579 seconds
# Epoch: 3 batch_num: 67 val_rmse_target: 0.4706 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.477 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 71 val_rmse_target: 0.4676 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 72 val_rmse_target: 0.4629 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 73 val_rmse_target: 0.4617 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 74 val_rmse_target: 0.4624 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 75 val_rmse_target: 0.4617 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 76 val_rmse_target: 0.4612 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4592 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.579 seconds
# Epoch: 3 batch_num: 78 val_rmse_target: 0.4588 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 79 val_rmse_target: 0.4619 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 80 val_rmse_target: 0.4721 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 82 val_rmse_target: 0.4873 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 4 steps took 2.28 seconds
# Epoch: 3 batch_num: 86 val_rmse_target: 0.464 val_rmse_stderror: 1.667
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 87 val_rmse_target: 0.4612 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 88 val_rmse_target: 0.4599 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.459 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 90 val_rmse_target: 0.4602 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.569 seconds
# Epoch: 3 batch_num: 91 val_rmse_target: 0.4609 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 92 val_rmse_target: 0.4626 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 93 val_rmse_target: 0.4639 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 94 val_rmse_target: 0.4634 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 95 val_rmse_target: 0.4613 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 96 val_rmse_target: 0.4586 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4577 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 97 val_rmse_target: 0.4575 val_rmse_stderror: 1.676
# New best_val_rmse: 0.4575
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 98 val_rmse_target: 0.4572 val_rmse_stderror: 1.675
# New best_val_rmse: 0.4572
#
# 1 steps took 0.579 seconds
# Epoch: 3 batch_num: 99 val_rmse_target: 0.4574 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 100 val_rmse_target: 0.4577 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 3 batch_num: 101 val_rmse_target: 0.4593 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 102 val_rmse_target: 0.4668 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 103 val_rmse_target: 0.4762 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 3 batch_num: 105 val_rmse_target: 0.4804 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 4 steps took 2.28 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4625 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 110 val_rmse_target: 0.4603 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 111 val_rmse_target: 0.4597 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 112 val_rmse_target: 0.4601 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4606 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 114 val_rmse_target: 0.462 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 3 batch_num: 115 val_rmse_target: 0.4623 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 116 val_rmse_target: 0.4636 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4635 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 118 val_rmse_target: 0.4639 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 119 val_rmse_target: 0.4638 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.57 seconds
# Epoch: 3 batch_num: 120 val_rmse_target: 0.4647 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.465 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 122 val_rmse_target: 0.4655 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 123 val_rmse_target: 0.465 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 124 val_rmse_target: 0.4646 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4643 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 3 batch_num: 126 val_rmse_target: 0.4638 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 127 val_rmse_target: 0.4629 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 128 val_rmse_target: 0.4625 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4633 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 130 val_rmse_target: 0.4638 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 131 val_rmse_target: 0.465 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 3 batch_num: 132 val_rmse_target: 0.4659 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 133 val_rmse_target: 0.4653 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 3 batch_num: 134 val_rmse_target: 0.4653 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 135 val_rmse_target: 0.4647 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.583 seconds
# Epoch: 3 batch_num: 136 val_rmse_target: 0.465 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4664 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 3 batch_num: 138 val_rmse_target: 0.4678 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 3 batch_num: 139 val_rmse_target: 0.4703 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.3 seconds
# Epoch: 4 batch_num: 0 val_rmse_target: 0.4761 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.15 seconds
# Epoch: 4 batch_num: 2 val_rmse_target: 0.475 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.15 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4695 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 5 val_rmse_target: 0.4677 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 6 val_rmse_target: 0.4661 val_rmse_stderror: 1.668
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 7 val_rmse_target: 0.4647 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 8 val_rmse_target: 0.4635 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 9 val_rmse_target: 0.4623 val_rmse_stderror: 1.669
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 10 val_rmse_target: 0.4614 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 11 val_rmse_target: 0.4612 val_rmse_stderror: 1.67
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4611 val_rmse_stderror: 1.671
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 13 val_rmse_target: 0.4612 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 14 val_rmse_target: 0.4613 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 15 val_rmse_target: 0.4613 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 16 val_rmse_target: 0.4613 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 17 val_rmse_target: 0.4618 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 18 val_rmse_target: 0.4625 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 19 val_rmse_target: 0.4636 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4665 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.579 seconds
# Epoch: 4 batch_num: 21 val_rmse_target: 0.47 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.15 seconds
# Epoch: 4 batch_num: 23 val_rmse_target: 0.4782 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 25 val_rmse_target: 0.4824 val_rmse_stderror: 1.676
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 4 steps took 2.28 seconds
# Epoch: 4 batch_num: 29 val_rmse_target: 0.477 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 31 val_rmse_target: 0.4729 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 33 val_rmse_target: 0.4678 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 34 val_rmse_target: 0.4661 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 35 val_rmse_target: 0.4646 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.464 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 37 val_rmse_target: 0.4636 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 38 val_rmse_target: 0.4633 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 39 val_rmse_target: 0.4633 val_rmse_stderror: 1.675
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4638 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 41 val_rmse_target: 0.4646 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 42 val_rmse_target: 0.4656 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 43 val_rmse_target: 0.4666 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4677 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 45 val_rmse_target: 0.4687 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 4 batch_num: 46 val_rmse_target: 0.4698 val_rmse_stderror: 1.674
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 47 val_rmse_target: 0.4704 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 49 val_rmse_target: 0.47 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 50 val_rmse_target: 0.4694 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 51 val_rmse_target: 0.4688 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4681 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 4 batch_num: 53 val_rmse_target: 0.4679 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 54 val_rmse_target: 0.4677 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 55 val_rmse_target: 0.4681 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.468 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 57 val_rmse_target: 0.4674 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 58 val_rmse_target: 0.4671 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 59 val_rmse_target: 0.4671 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4671 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 61 val_rmse_target: 0.4671 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 62 val_rmse_target: 0.4677 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 63 val_rmse_target: 0.4679 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.578 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4685 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 65 val_rmse_target: 0.4691 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 66 val_rmse_target: 0.4703 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4716 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 70 val_rmse_target: 0.4717 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4709 val_rmse_stderror: 1.673
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 2 steps took 1.14 seconds
# Epoch: 4 batch_num: 74 val_rmse_target: 0.4699 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 75 val_rmse_target: 0.469 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4683 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 77 val_rmse_target: 0.4675 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 78 val_rmse_target: 0.4667 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.581 seconds
# Epoch: 4 batch_num: 79 val_rmse_target: 0.4659 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.4652 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 81 val_rmse_target: 0.4646 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 82 val_rmse_target: 0.4642 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 83 val_rmse_target: 0.4641 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4639 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 85 val_rmse_target: 0.4637 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 86 val_rmse_target: 0.4637 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 87 val_rmse_target: 0.4636 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4635 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 89 val_rmse_target: 0.4634 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 90 val_rmse_target: 0.4634 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 91 val_rmse_target: 0.4632 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.463 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 93 val_rmse_target: 0.463 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 94 val_rmse_target: 0.463 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 95 val_rmse_target: 0.4633 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.57 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4635 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 97 val_rmse_target: 0.4638 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 98 val_rmse_target: 0.464 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 99 val_rmse_target: 0.4642 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.4644 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 101 val_rmse_target: 0.4645 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 102 val_rmse_target: 0.4647 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 103 val_rmse_target: 0.4647 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4648 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 105 val_rmse_target: 0.4648 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 106 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 107 val_rmse_target: 0.4651 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4651 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 109 val_rmse_target: 0.4651 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 110 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 111 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 113 val_rmse_target: 0.4649 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 114 val_rmse_target: 0.4649 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 115 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.465 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 117 val_rmse_target: 0.4651 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 118 val_rmse_target: 0.4651 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 119 val_rmse_target: 0.4652 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4652 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 121 val_rmse_target: 0.4653 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.577 seconds
# Epoch: 4 batch_num: 122 val_rmse_target: 0.4653 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 123 val_rmse_target: 0.4654 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4654 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 125 val_rmse_target: 0.4654 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 126 val_rmse_target: 0.4654 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 127 val_rmse_target: 0.4654 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 129 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 130 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 131 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.572 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 133 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 134 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.574 seconds
# Epoch: 4 batch_num: 135 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.571 seconds
# Epoch: 4 batch_num: 137 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.573 seconds
# Epoch: 4 batch_num: 138 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.576 seconds
# Epoch: 4 batch_num: 139 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# 1 steps took 0.575 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4655 val_rmse_stderror: 1.672
# Still best_val_rmse: 0.4572 (from epoch 3)
#
# Performance estimates:
# [0.45721496436178166]
# Mean: 0.45721496436178166
#
# Fold 2/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 9.35 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 1.076 val_rmse_stderror: 1.012
# New best_val_rmse: 1.076
#
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 1.053 val_rmse_stderror: 0.9773
# New best_val_rmse: 1.053
#
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.7499 val_rmse_stderror: 0.9625
# New best_val_rmse: 0.7499
#
# 16 steps took 8.84 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.7057 val_rmse_stderror: 0.9554
# New best_val_rmse: 0.7057
#
# 16 steps took 8.86 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.7753 val_rmse_stderror: 0.9679
# Still best_val_rmse: 0.7057 (from epoch 0)
#
# 16 steps took 8.85 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.6192 val_rmse_stderror: 0.9558
# New best_val_rmse: 0.6192
#
# 16 steps took 8.87 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.879 val_rmse_stderror: 0.965
# Still best_val_rmse: 0.6192 (from epoch 0)
#
# 16 steps took 8.85 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6006 val_rmse_stderror: 0.97
# New best_val_rmse: 0.6006
#
# 16 steps took 9.03 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.6272 val_rmse_stderror: 0.9567
# Still best_val_rmse: 0.6006 (from epoch 0)
#
# 16 steps took 8.86 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5769 val_rmse_stderror: 0.9819
# New best_val_rmse: 0.5769
#
# 16 steps took 8.85 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5516 val_rmse_stderror: 0.9651
# New best_val_rmse: 0.5516
#
# 16 steps took 8.85 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5293 val_rmse_stderror: 0.9756
# New best_val_rmse: 0.5293
#
# 16 steps took 8.86 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5562 val_rmse_stderror: 0.971
# Still best_val_rmse: 0.5293 (from epoch 1)
#
# 16 steps took 8.86 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5342 val_rmse_stderror: 0.9758
# Still best_val_rmse: 0.5293 (from epoch 1)
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.4996 val_rmse_stderror: 0.9682
# New best_val_rmse: 0.4996
#
# 8 steps took 4.43 seconds
# Epoch: 1 batch_num: 107 val_rmse_target: 0.4973 val_rmse_stderror: 0.9705
# New best_val_rmse: 0.4973
#
# 8 steps took 4.43 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5105 val_rmse_stderror: 0.9808
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 8.84 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.6209 val_rmse_stderror: 0.9782
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 9.03 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5233 val_rmse_stderror: 0.9694
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 8.85 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.5042 val_rmse_stderror: 0.9742
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 8.84 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.5029 val_rmse_stderror: 0.9729
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 8.85 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.5065 val_rmse_stderror: 0.9761
# Still best_val_rmse: 0.4973 (from epoch 1)
#
# 16 steps took 8.84 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.4924 val_rmse_stderror: 0.9765
# New best_val_rmse: 0.4924
#
# 8 steps took 4.44 seconds
# Epoch: 2 batch_num: 78 val_rmse_target: 0.5051 val_rmse_stderror: 0.9729
# Still best_val_rmse: 0.4924 (from epoch 2)
#
# 16 steps took 8.86 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.4933 val_rmse_stderror: 0.976
# Still best_val_rmse: 0.4924 (from epoch 2)
#
# 8 steps took 4.42 seconds
# Epoch: 2 batch_num: 102 val_rmse_target: 0.5024 val_rmse_stderror: 0.9722
# Still best_val_rmse: 0.4924 (from epoch 2)
#
# 16 steps took 8.86 seconds
# Epoch: 2 batch_num: 118 val_rmse_target: 0.5133 val_rmse_stderror: 0.9795
# Still best_val_rmse: 0.4924 (from epoch 2)
#
# ...
# New best_val_rmse: 0.4859
#
# 4 steps took 2.14 seconds
# Epoch: 3 batch_num: 109 val_rmse_target: 0.4874 val_rmse_stderror: 1.26
# Still best_val_rmse: 0.4859 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 113 val_rmse_target: 0.4869 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4859 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 3 batch_num: 117 val_rmse_target: 0.4837 val_rmse_stderror: 1.267
# New best_val_rmse: 0.4837
#
# 4 steps took 2.13 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.4871 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 3 batch_num: 125 val_rmse_target: 0.4886 val_rmse_stderror: 1.261
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 3 batch_num: 129 val_rmse_target: 0.4904 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.23 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4925 val_rmse_stderror: 1.267
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.4 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.4966 val_rmse_stderror: 1.267
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.22 seconds
# Epoch: 4 batch_num: 12 val_rmse_target: 0.4914 val_rmse_stderror: 1.268
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.22 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4905 val_rmse_stderror: 1.265
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.24 seconds
# Epoch: 4 batch_num: 28 val_rmse_target: 0.4891 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4895 val_rmse_stderror: 1.267
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 36 val_rmse_target: 0.489 val_rmse_stderror: 1.268
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.488 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4891 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 48 val_rmse_target: 0.4915 val_rmse_stderror: 1.261
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 8 steps took 4.22 seconds
# Epoch: 4 batch_num: 56 val_rmse_target: 0.4867 val_rmse_stderror: 1.261
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4864 val_rmse_stderror: 1.263
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.4877 val_rmse_stderror: 1.265
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.488 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.488 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4886 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 80 val_rmse_target: 0.4889 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.4891 val_rmse_stderror: 1.266
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 88 val_rmse_target: 0.4891 val_rmse_stderror: 1.265
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.489 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 96 val_rmse_target: 0.4887 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.4887 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 104 val_rmse_target: 0.4886 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4885 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 112 val_rmse_target: 0.4885 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.12 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.4885 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 120 val_rmse_target: 0.4885 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4884 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 128 val_rmse_target: 0.4884 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4884 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 136 val_rmse_target: 0.4884 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# 4 steps took 2.11 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4884 val_rmse_stderror: 1.264
# Still best_val_rmse: 0.4837 (from epoch 3)
#
# Performance estimates:
# [0.45721496436178166, 0.4878901488761991, 0.4616565844216547, 0.4837400110879944]
# Mean: 0.4726254271869074
#
# Fold 5/5
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 16 steps took 8.74 seconds
# Epoch: 0 batch_num: 16 val_rmse_target: 0.9312 val_rmse_stderror: 1.041
# New best_val_rmse: 0.9312
#
# 16 steps took 8.21 seconds
# Epoch: 0 batch_num: 32 val_rmse_target: 0.6988 val_rmse_stderror: 1.021
# New best_val_rmse: 0.6988
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 48 val_rmse_target: 0.6442 val_rmse_stderror: 1.052
# New best_val_rmse: 0.6442
#
# 16 steps took 8.22 seconds
# Epoch: 0 batch_num: 64 val_rmse_target: 0.6436 val_rmse_stderror: 1.05
# New best_val_rmse: 0.6436
#
# 16 steps took 8.2 seconds
# Epoch: 0 batch_num: 80 val_rmse_target: 0.6848 val_rmse_stderror: 1.057
# Still best_val_rmse: 0.6436 (from epoch 0)
#
# 16 steps took 8.18 seconds
# Epoch: 0 batch_num: 96 val_rmse_target: 0.7021 val_rmse_stderror: 1.066
# Still best_val_rmse: 0.6436 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 112 val_rmse_target: 0.713 val_rmse_stderror: 1.063
# Still best_val_rmse: 0.6436 (from epoch 0)
#
# 16 steps took 8.19 seconds
# Epoch: 0 batch_num: 128 val_rmse_target: 0.6794 val_rmse_stderror: 1.06
# Still best_val_rmse: 0.6436 (from epoch 0)
#
# 16 steps took 8.36 seconds
# Epoch: 1 batch_num: 3 val_rmse_target: 0.5544 val_rmse_stderror: 1.04
# New best_val_rmse: 0.5544
#
# 16 steps took 8.22 seconds
# Epoch: 1 batch_num: 19 val_rmse_target: 0.5311 val_rmse_stderror: 1.054
# New best_val_rmse: 0.5311
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 35 val_rmse_target: 0.5431 val_rmse_stderror: 1.035
# Still best_val_rmse: 0.5311 (from epoch 1)
#
# 16 steps took 8.18 seconds
# Epoch: 1 batch_num: 51 val_rmse_target: 0.5311 val_rmse_stderror: 1.039
# New best_val_rmse: 0.5311
#
# 16 steps took 8.23 seconds
# Epoch: 1 batch_num: 67 val_rmse_target: 0.5636 val_rmse_stderror: 1.044
# Still best_val_rmse: 0.5311 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 83 val_rmse_target: 0.5088 val_rmse_stderror: 1.052
# New best_val_rmse: 0.5088
#
# 16 steps took 8.21 seconds
# Epoch: 1 batch_num: 99 val_rmse_target: 0.5519 val_rmse_stderror: 1.043
# Still best_val_rmse: 0.5088 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 115 val_rmse_target: 0.5681 val_rmse_stderror: 1.038
# Still best_val_rmse: 0.5088 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 1 batch_num: 131 val_rmse_target: 0.5054 val_rmse_stderror: 1.052
# New best_val_rmse: 0.5054
#
# 16 steps took 8.41 seconds
# Epoch: 2 batch_num: 6 val_rmse_target: 0.5231 val_rmse_stderror: 1.044
# Still best_val_rmse: 0.5054 (from epoch 1)
#
# 16 steps took 8.2 seconds
# Epoch: 2 batch_num: 22 val_rmse_target: 0.4975 val_rmse_stderror: 1.051
# New best_val_rmse: 0.4975
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 30 val_rmse_target: 0.4994 val_rmse_stderror: 1.046
# Still best_val_rmse: 0.4975 (from epoch 2)
#
# 8 steps took 4.09 seconds
# Epoch: 2 batch_num: 38 val_rmse_target: 0.4914 val_rmse_stderror: 1.051
# New best_val_rmse: 0.4914
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 46 val_rmse_target: 0.4981 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 54 val_rmse_target: 0.4962 val_rmse_stderror: 1.056
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.1 seconds
# Epoch: 2 batch_num: 62 val_rmse_target: 0.4929 val_rmse_stderror: 1.041
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.1 seconds
# Epoch: 2 batch_num: 70 val_rmse_target: 0.5028 val_rmse_stderror: 1.058
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.19 seconds
# Epoch: 2 batch_num: 86 val_rmse_target: 0.4966 val_rmse_stderror: 1.054
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.11 seconds
# Epoch: 2 batch_num: 94 val_rmse_target: 0.5093 val_rmse_stderror: 1.048
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.2 seconds
# Epoch: 2 batch_num: 110 val_rmse_target: 0.5146 val_rmse_stderror: 1.047
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.2 seconds
# Epoch: 2 batch_num: 126 val_rmse_target: 0.5002 val_rmse_stderror: 1.047
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 16 steps took 8.37 seconds
# Epoch: 3 batch_num: 1 val_rmse_target: 0.4939 val_rmse_stderror: 1.059
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.09 seconds
# Epoch: 3 batch_num: 9 val_rmse_target: 0.4937 val_rmse_stderror: 1.043
# Still best_val_rmse: 0.4914 (from epoch 2)
#
# 8 steps took 4.09 seconds
# Epoch: 3 batch_num: 17 val_rmse_target: 0.4911 val_rmse_stderror: 1.055
# New best_val_rmse: 0.4911
#
# 8 steps took 4.12 seconds
# Epoch: 3 batch_num: 25 val_rmse_target: 0.4933 val_rmse_stderror: 1.05
# Still best_val_rmse: 0.4911 (from epoch 3)
#
# 8 steps took 4.11 seconds
# Epoch: 3 batch_num: 33 val_rmse_target: 0.4877 val_rmse_stderror: 1.049
# New best_val_rmse: 0.4877
#
# 4 steps took 2.07 seconds
# Epoch: 3 batch_num: 37 val_rmse_target: 0.4867 val_rmse_stderror: 1.047
# New best_val_rmse: 0.4867
#
# 4 steps took 2.06 seconds
# Epoch: 3 batch_num: 41 val_rmse_target: 0.4938 val_rmse_stderror: 1.053
# Still best_val_rmse: 0.4867 (from epoch 3)
#
# 8 steps took 4.11 seconds
# Epoch: 3 batch_num: 49 val_rmse_target: 0.4922 val_rmse_stderror: 1.055
# Still best_val_rmse: 0.4867 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 3 batch_num: 57 val_rmse_target: 0.4963 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4867 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 3 batch_num: 65 val_rmse_target: 0.4847 val_rmse_stderror: 1.054
# New best_val_rmse: 0.4847
#
# 4 steps took 2.07 seconds
# Epoch: 3 batch_num: 69 val_rmse_target: 0.4863 val_rmse_stderror: 1.054
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.06 seconds
# Epoch: 3 batch_num: 73 val_rmse_target: 0.4868 val_rmse_stderror: 1.049
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 3 batch_num: 77 val_rmse_target: 0.4896 val_rmse_stderror: 1.048
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 3 batch_num: 81 val_rmse_target: 0.4888 val_rmse_stderror: 1.05
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 3 batch_num: 85 val_rmse_target: 0.4868 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.06 seconds
# Epoch: 3 batch_num: 89 val_rmse_target: 0.4963 val_rmse_stderror: 1.055
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 3 batch_num: 97 val_rmse_target: 0.4906 val_rmse_stderror: 1.049
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 3 batch_num: 105 val_rmse_target: 0.5091 val_rmse_stderror: 1.056
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 16 steps took 8.2 seconds
# Epoch: 3 batch_num: 121 val_rmse_target: 0.5039 val_rmse_stderror: 1.049
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 16 steps took 8.2 seconds
# Epoch: 3 batch_num: 137 val_rmse_target: 0.4911 val_rmse_stderror: 1.049
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.27 seconds
# Epoch: 4 batch_num: 4 val_rmse_target: 0.5024 val_rmse_stderror: 1.053
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 16 steps took 8.22 seconds
# Epoch: 4 batch_num: 20 val_rmse_target: 0.4884 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 4 batch_num: 24 val_rmse_target: 0.49 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.11 seconds
# Epoch: 4 batch_num: 32 val_rmse_target: 0.4909 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.09 seconds
# Epoch: 4 batch_num: 40 val_rmse_target: 0.4899 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 4 batch_num: 44 val_rmse_target: 0.4915 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 52 val_rmse_target: 0.4932 val_rmse_stderror: 1.054
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 60 val_rmse_target: 0.4882 val_rmse_stderror: 1.053
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.06 seconds
# Epoch: 4 batch_num: 64 val_rmse_target: 0.488 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 4 batch_num: 68 val_rmse_target: 0.4885 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 4 batch_num: 72 val_rmse_target: 0.4897 val_rmse_stderror: 1.053
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 4 steps took 2.05 seconds
# Epoch: 4 batch_num: 76 val_rmse_target: 0.4907 val_rmse_stderror: 1.053
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 84 val_rmse_target: 0.491 val_rmse_stderror: 1.052
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.12 seconds
# Epoch: 4 batch_num: 92 val_rmse_target: 0.4916 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 100 val_rmse_target: 0.4916 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 108 val_rmse_target: 0.4917 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 116 val_rmse_target: 0.4917 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.11 seconds
# Epoch: 4 batch_num: 124 val_rmse_target: 0.4914 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.1 seconds
# Epoch: 4 batch_num: 132 val_rmse_target: 0.4912 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# 8 steps took 4.09 seconds
# Epoch: 4 batch_num: 140 val_rmse_target: 0.4912 val_rmse_stderror: 1.051
# Still best_val_rmse: 0.4847 (from epoch 3)
#
# Performance estimates:
# [0.45721496436178166, 0.4878901488761991, 0.4616565844216547, 0.4837400110879944, 0.4847421842572635]
# Mean: 0.47504877860097866

# %%
print(list_val_rmse)
# Out:
# [0.45721496436178166, 0.4878901488761991, 0.4616565844216547, 0.4837400110879944, 0.4847421842572635]

# %%
#rep = MemReporter(model)
#rep.report()

# %%
#rep = MemReporter(model.roberta)
#rep.report()

# %%
#gpuinfo()

# %%
#del model
#del optimizer 
#del train_loader
#del val_loader
#del scheduler 
#del list_val_rmse
#del train_indices
#del val_indices
#del tokenizer
#torch.cuda.empty_cache()
#gpuinfo()

# %% [markdown]
# # Inference

# %%
# %cd
# !mkdir .kaggle
# !mkdir /content/model
# !cp /content/drive/MyDrive/Colab_Files/kaggle-api/kaggle.json .kaggle/

# !cp -r /content/model_1.pth /content/model/model_1.pth
# !cp -r /content/model_2.pth /content/model/model_2.pth
# !cp -r /content/model_3.pth /content/model/model_3.pth
# !cp -r /content/model_4.pth /content/model/model_4.pth
# !cp -r /content/model_5.pth /content/model/model_5.pth
# Out:
# /root

# %%
def dataset_upload():
    import json
    from kaggle.api.kaggle_api_extended import KaggleApi

    id = f'{USERID}/{EX_NO}'

    dataset_metadata = {}
    dataset_metadata['id'] = id
    dataset_metadata['licenses'] = [{'name': 'CC0-1.0'}]
    dataset_metadata['title'] = f'{EX_NO}'

    with open(UPLOAD_DIR / 'dataset-metadata.json', 'w') as f:
        json.dump(dataset_metadata, f, indent=4)

    api = KaggleApi()
    api.authenticate()

    # データセットがない場合
    if f'{USERID}/{EX_NO}' not in [str(d) for d in api.dataset_list(user=USERID, search=f'"{EX_NO}"')]:
        api.dataset_create_new(folder=UPLOAD_DIR,
                               convert_to_csv=False,
                               dir_mode='skip')
    # データセットがある場合
    else:
        api.dataset_create_version(folder=UPLOAD_DIR,
                                   version_notes='update',
                                   convert_to_csv=False,
                                   delete_old_versions=True,
                                   dir_mode='skip')
dataset_upload()
# Out:
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Starting upload for file model_2.pth
# 100%|██████████| 477M/477M [00:10<00:00, 46.0MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_2.pth (477MB)
# Starting upload for file model_3.pth
# 100%|██████████| 477M/477M [00:10<00:00, 48.6MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_3.pth (477MB)
# Starting upload for file model_5.pth
# 100%|██████████| 477M/477M [00:10<00:00, 47.7MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_5.pth (477MB)
# Starting upload for file model_4.pth
# 100%|██████████| 477M/477M [00:12<00:00, 39.2MB/s]
#   0%|          | 0.00/477M [00:00<?, ?B/s]
# Upload successful: model_4.pth (477MB)
# Starting upload for file model_1.pth
# 100%|██████████| 477M/477M [00:11<00:00, 42.2MB/s]
# Upload successful: model_1.pth (477MB)
